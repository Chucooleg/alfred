# %% [markdown]
# # Look at debugging outputs

# %%
import os
import json
import numpy as np
from collections import defaultdict
import pprint
from nltk.translate.bleu_score import sentence_bleu

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import Image
import matplotlib.image as mpimg

# %%
class args:
    pass

args.dout = '/root/data/home/hoyeung/blob_alfred_data/exp_all/model:seq2seq_per_subgoal,name:v2_epoch_50_enc_max_pool_aux_loss'

# %%
# !ls -l /root/data/home/hoyeung/blob_alfred_data/exp_all/model:seq2seq_nl_with_frames,name:v1_epoch_50_low_level_instrs

# %%
train_sanity_epoch_list = [0, 5, 10, 15, 20, 29]
valid_seen_epoch_list = [0, 5, 10, 15, 20, 29]
valid_unseen_epoch_list = [0, 5, 10, 15, 20, 29]

# %% [markdown]
# # Examine Outputs across Epochs
#
# - across epochs
# - random selection
# - rank by CE, BLEU

# %% [markdown]
# ### SECTION 1: Select a random set of tasks to look at
#
# #### Real Data

# %%
np.random.seed(42)

path = os.path.join(args.dout, 'valid_seen_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_valid_seen = json.load(f)
chosen_valid_seen_task_ids = np.random.choice(list(debug_valid_seen.keys()), size=10, replace=False)

path = os.path.join(args.dout, 'valid_unseen_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_valid_unseen = json.load(f)
chosen_valid_unseen_task_ids = np.random.choice(list(debug_valid_unseen.keys()), size=10, replace=False)

path = os.path.join(args.dout, 'train_sanity_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_train_sanity = json.load(f)
chosen_train_sanity_task_ids = np.random.choice(list(debug_train_sanity.keys()), size=10, replace=False)

def find_num_high_level_goals(chosen_task_ids, debug_dat):
    '''number of high level goals (complexity) of these chosen tasks'''
    for t in chosen_task_ids:
        print (t, '\t\t\t', len(debug_dat[t]['action_high']))

print("\nRandomly Selected for Train Sanity: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_train_sanity_task_ids, debug_train_sanity)
print("\nRandomly Selected for Valid Seen: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_valid_seen_task_ids, debug_valid_seen)
print("\nRandomly Selected for Valid Unseen: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_valid_unseen_task_ids, debug_valid_unseen)
# Out:
# Randomly Selected for Train Sanity: (task, number of planner subgoals)
# trial_T20190908_115507_503798_0 			 14
# trial_T20190907_011351_027508_0 			 9
# trial_T20190910_055356_172564_0 			 9
# trial_T20190919_045956_375063_0 			 8
# trial_T20190918_173742_042769_0 			 14
# trial_T20190908_030909_087593_0 			 7
# trial_T20190909_004008_377860_0 			 7
# trial_T20190908_072254_824822_0 			 8
# trial_T20190907_181954_161870_0 			 9
# trial_T20190909_113100_297495_0 			 5
#
# Randomly Selected for Valid Seen: (task, number of planner subgoals)
# trial_T20190909_150916_682139_0 			 5
# trial_T20190908_192636_561572_0 			 8
# trial_T20190907_013001_399963_0 			 12
# trial_T20190907_074712_870488_0 			 8
# trial_T20190908_102840_789300_0 			 9
# trial_T20190909_031040_889814_0 			 5
# trial_T20190908_140701_251653_0 			 7
# trial_T20190909_055649_717880_0 			 9
# trial_T20190907_151802_277016_0 			 13
# trial_T20190909_032318_169393_0 			 5
#
# Randomly Selected for Valid Unseen: (task, number of planner subgoals)
# trial_T20190909_123918_983775_0 			 13
# trial_T20190909_123732_489327_0 			 11
# trial_T20190906_191445_723170_0 			 5
# trial_T20190907_020329_050110_0 			 7
# trial_T20190907_170955_824797_0 			 5
# trial_T20190909_210238_431966_0 			 5
# trial_T20190906_224843_443882_0 			 13
# trial_T20190906_214631_761426_0 			 5
# trial_T20190907_074524_006355_0 			 5
# trial_T20190908_114656_768805_0 			 7

# %%
chosen_train_sanity_task_ids = [
'trial_T20190908_115507_503798_0',
'trial_T20190907_011351_027508_0',
'trial_T20190910_055356_172564_0',
'trial_T20190919_045956_375063_0',
'trial_T20190918_173742_042769_0',
'trial_T20190908_030909_087593_0',
'trial_T20190909_004008_377860_0',
'trial_T20190908_072254_824822_0',
'trial_T20190907_181954_161870_0',
'trial_T20190909_113100_297495_0',
]

chosen_valid_seen_task_ids = [
'trial_T20190909_150916_682139_0', 
'trial_T20190908_192636_561572_0', 
'trial_T20190907_013001_399963_0', 
'trial_T20190907_074712_870488_0', 
'trial_T20190908_102840_789300_0', 
'trial_T20190909_031040_889814_0', 
'trial_T20190908_140701_251653_0', 
'trial_T20190909_055649_717880_0', 
'trial_T20190907_151802_277016_0', 
'trial_T20190909_032318_169393_0'
]

chosen_valid_unseen_task_ids = [
'trial_T20190909_123918_983775_0',
'trial_T20190909_123732_489327_0',
'trial_T20190906_191445_723170_0',
'trial_T20190907_020329_050110_0',
'trial_T20190907_170955_824797_0',
'trial_T20190909_210238_431966_0',
'trial_T20190906_224843_443882_0',
'trial_T20190906_214631_761426_0',
'trial_T20190907_074524_006355_0',
'trial_T20190908_114656_768805_0'
]

# %%
urls = {
    'trial_T20190908_115507_503798_0':  'https://www.youtube.com/watch?v=HKKh-4WHSsg&t=7s',
    'trial_T20190907_011351_027508_0':  'https://www.youtube.com/watch?v=deDf2pnORts',
    'trial_T20190910_055356_172564_0':  'https://www.youtube.com/watch?v=_ys8HY3G94U',
    'trial_T20190919_045956_375063_0':  'https://www.youtube.com/watch?v=9mE_rLrhAhU',
    'trial_T20190918_173742_042769_0':  'https://www.youtube.com/watch?v=7dHM--8H_ws',
    'trial_T20190908_030909_087593_0':  'https://www.youtube.com/watch?v=kXR2SJ4f47w',
    'trial_T20190909_004008_377860_0':  'https://www.youtube.com/watch?v=YBJgvP4Uai8',
    'trial_T20190908_072254_824822_0':  'https://www.youtube.com/watch?v=GZAUr7AToYY',
    'trial_T20190907_181954_161870_0':  'https://www.youtube.com/watch?v=7uDr2uq7gLs',
    'trial_T20190909_113100_297495_0':  'https://www.youtube.com/watch?v=1D8TGusmIaQ',
    'trial_T20190909_150916_682139_0' : 'https://youtu.be/FHGCyxlwp8E',
    'trial_T20190908_192636_561572_0':  'https://youtu.be/KYG5NEfVbjM', 
    'trial_T20190907_013001_399963_0' : 'https://youtu.be/ezmpJhbhCpI',
    'trial_T20190907_074712_870488_0':  'https://youtu.be/civKnURZaR0',
    'trial_T20190908_102840_789300_0': 'https://youtu.be/Dg9dzxXmxB4',
    'trial_T20190909_031040_889814_0': 'https://youtu.be/TpFjTu0nRoA',
    'trial_T20190908_140701_251653_0': 'https://youtu.be/LQpzGDzww1A',
    'trial_T20190909_055649_717880_0': 'https://youtu.be/C9gkb77sF14',
    'trial_T20190907_151802_277016_0': 'https://youtu.be/P9wm8lJwxT4',
    'trial_T20190909_032318_169393_0': 'https://youtu.be/R8fs1wdTMqI',
    'trial_T20190909_123918_983775_0': 'https://youtu.be/1Ha8RLnfsBg',
    'trial_T20190909_123732_489327_0': 'https://youtu.be/4V2hh2cw4No',
    'trial_T20190906_191445_723170_0': 'https://youtu.be/oZ2goybT4pA',
    'trial_T20190907_020329_050110_0': 'https://youtu.be/H-GQkQllSuA',
    'trial_T20190907_170955_824797_0': 'https://youtu.be/8zfLGiywP1A',
    'trial_T20190909_210238_431966_0': 'https://youtu.be/Ti1faQUCSnc',
    'trial_T20190906_224843_443882_0': 'https://youtu.be/z261C5NcQbU',
    'trial_T20190906_214631_761426_0': 'https://youtu.be/6dSWDozBRLU',
    'trial_T20190907_074524_006355_0': 'https://youtu.be/_TobcwcYR9Q',
    'trial_T20190908_114656_768805_0': 'https://youtu.be/AOYa3y_0uCU'
}

# %% [raw]
# def get_language_annotations(root):
#     lang_goals = []
#     lang_instrs = []
#     path = os.path.join(root, 'pp', 'ann_%d.json' % 0)
#     with open(path, 'r') as f:
#         ex = json.load(f)
#         for i in range(3):
#             lang_goals.append(ex['turk_annotations']['anns'][i]['task_desc'])
#             lang_instrs.append(ex['turk_annotations']['anns'][i]['high_descs'])
#         action_low = [a['discrete_action']['action'] for a in ex['plan']['low_actions']]
#         action_high = [a['discrete_action']['action'] for a in ex['plan']['high_pddl']]
#     return lang_goals, lang_instrs, action_high, action_low
#
# def get_ref_instrs(root):
#     flatten_isntr = lambda instr: [word.strip() for sent in instr for word in sent]
#     ref_instrs = []
#     for i in range(3):
#         path = os.path.join(root, 'pp', 'ann_%d.json' % i)
#         if os.path.exists(path):
#             with open(path, 'r') as f:
#                 ex = json.load(f)
#                 ref_instrs.append(flatten_isntr(ex['ann']['instr']))
#     return ref_instrs
#
# def get_root_location(root):
#     return root.replace('data/', '/root/data_alfred/')
#
# def examine_sampled_tasks(sampled_task_ids, epoch_list, split):
#     sampled_results = defaultdict(dict)
#
#     for epoch in epoch_list:
#
#         path = os.path.join(args.dout, '{}_argmax.debug_epoch_{}.preds.json'.format(split, epoch))
#         path_sampled = os.path.join(args.dout, '{}_sampled.debug_epoch_{}.preds.json'.format(split, epoch))
#         with open(path, 'r') as f:
#             debug_dat = json.load(f)
#         with open(path_sampled, 'r') as f:
#             debug_dat_sampled = json.load(f)
#
#         for task_id in sampled_task_ids:
#             if epoch == 0:
#                 root = get_root_location(debug_dat[task_id]['root'])
#                 sampled_results[task_id]['root'] = root
#
#                 # get all language and action annotations
#                 sampled_results[task_id]['lang_goal'], sampled_results[task_id]['lang_instr'],\
#                 sampled_results[task_id]['action_high'], sampled_results[task_id]['action_low'] \
#                 = get_language_annotations(root)
#
#                 sampled_results[task_id]['num_subgoals'] = len(sampled_results[task_id]['action_high'])
#
#                 # get referece lang for bleu score
#                 sampled_results[task_id]['ref_instrs'] = get_ref_instrs(root)
#
#             sampled_results[task_id]['p_lang_instr_{}'.format(epoch)] = debug_dat[task_id]['p_lang_instr']
#             sampled_results[task_id]['bleu_score_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], debug_dat[task_id]['p_lang_instr'].split(' '))
#
#             sampled_results[task_id]['p_lang_instr_sampled_{}'.format(epoch)] = debug_dat_sampled[task_id]['p_lang_instr']
#             sampled_results[task_id]['bleu_score_sampled_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], debug_dat_sampled[task_id]['p_lang_instr'].split(' '))
#
#     print('SPLIT: {}\n\n\n'.format(split))
#     for task_id in sampled_task_ids:
#         print("TASK :", task_id)
#         print("ROOT:", sampled_results[task_id]['root'])
#         print("Number of subgoals :", sampled_results[task_id]['num_subgoals'])
#         if task_id in urls:
#             print(urls[task_id])
#         print ('---------------------------')
#         print("Gold Input high-level action description:\n\n", sampled_results[task_id]['action_high'])
#         print ('---------------------------')
#         print("Gold Input low-level action description:\n\n", sampled_results[task_id]['action_low'])
#         print ('---------------------------')
#         print("Gold instruction descriptions:\n")
#         for i in range(3):
#             print('Annotation', i)
#             print(sampled_results[task_id]['lang_goal'][i])
#             print(sampled_results[task_id]['lang_instr'][i], '\n')
#         print ('---------------------------')
#         for e in epoch_list:
#             print("\nEpoch {} Prediction Output".format(e))
#             print("- Decoding by Argmax:")
#             print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_{}'.format(e)]))
#             print(sampled_results[task_id]['p_lang_instr_{}'.format(e)])
#             print("- Decoding by Sampling:")
#             print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_sampled_{}'.format(e)]))
#             print(sampled_results[task_id]['p_lang_instr_sampled_{}'.format(e)])
#         print ('---------------------------')
#         print ('--------------------------------------------------------------------------------------\n\n\n\n\n')
#     return sampled_results

# %%
def get_language_annotations(root):
    lang_goals = []
    lang_instrs = []
    path = os.path.join(root, 'pp', 'ann_%d.json' % 0)
    with open(path, 'r') as f:
        ex = json.load(f)
        for i in range(3):
            lang_goals.append(ex['turk_annotations']['anns'][i]['task_desc'])
            lang_instrs.append(ex['turk_annotations']['anns'][i]['high_descs'])
        action_low = [a['discrete_action']['action'] for a in ex['plan']['low_actions']]
        action_high = [a['discrete_action']['action'] for a in ex['plan']['high_pddl']]
    return lang_goals, lang_instrs, action_high, action_low  

def get_ref_instrs(root):
    flatten_isntr = lambda instr: [word.strip() for sent in instr for word in sent]
    ref_instrs = []
    for i in range(3):
        path = os.path.join(root, 'pp', 'ann_%d.json' % i)
        if os.path.exists(path):
            with open(path, 'r') as f:
                ex = json.load(f)
                ref_instrs.append(flatten_isntr(ex['ann']['instr']))
    return ref_instrs

def get_root_location(root):
    return root.replace('data/', '/root/data_alfred/')

def examine_sampled_tasks(sampled_task_ids, epoch_list, split):
    sampled_results = defaultdict(dict)

    for epoch in epoch_list:

        path = os.path.join(args.dout, '{}.debug_epoch_{}.preds.json'.format(split, epoch))
#         path = os.path.join(args.dout, '{}_argmax.debug_epoch_{}.preds.json'.format(split, epoch))
#         path_sampled = os.path.join(args.dout, '{}_sampled.debug_epoch_{}.preds.json'.format(split, epoch))
        with open(path, 'r') as f:
            debug_dat = json.load(f)
#         with open(path_sampled, 'r') as f:
#             debug_dat_sampled = json.load(f)
            
        for task_id in sampled_task_ids:
            if epoch == 0:
                root = get_root_location(debug_dat[task_id]['root'])
                sampled_results[task_id]['root'] = root
                
                # get all language and action annotations
                sampled_results[task_id]['lang_goal'], sampled_results[task_id]['lang_instr'],\
                sampled_results[task_id]['action_high'], sampled_results[task_id]['action_low'] \
                = get_language_annotations(root)
                gold_num_subgoals = len(sampled_results[task_id]['action_high']) - 1
                sampled_results[task_id]['num_subgoals'] = gold_num_subgoals

                # get referece lang for bleu score
                sampled_results[task_id]['ref_instrs'] = get_ref_instrs(root)
                         
            sampled_results[task_id]['p_lang_instr_{}'.format(epoch)] = debug_dat[task_id]['p_lang_instr']
            pred_list = [debug_dat[task_id]['p_lang_instr'][str(i)] for i in range(gold_num_subgoals)]
            pred_tokens_overall = ' '.join(pred_list).split(' ')            
            sampled_results[task_id]['bleu_score_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], pred_tokens_overall)

#             sampled_results[task_id]['p_lang_instr_sampled_{}'.format(epoch)] = debug_dat_sampled[task_id]['p_lang_instr']
#             sampled_results[task_id]['bleu_score_sampled_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], debug_dat_sampled[task_id]['p_lang_instr'].split(' '))            
            
    print('SPLIT: {}\n\n\n'.format(split))
    for task_id in sampled_task_ids:
        print("TASK :", task_id)
        print("ROOT:", sampled_results[task_id]['root'])
        gold_num_subgoals = sampled_results[task_id]['num_subgoals']
        print("Number of subgoals (exlcuding <No-op>):", gold_num_subgoals)
        if task_id in urls:
            print(urls[task_id])
        print ('---------------------------')
        print("Gold Input high-level action description:\n\n", sampled_results[task_id]['action_high'])
        print ('---------------------------')
        print("Gold Input low-level action description:\n\n", sampled_results[task_id]['action_low'])
        print ('---------------------------')
        print("Gold instruction descriptions:\n")
        for i in range(3):
            print('Annotation', i)
            print(sampled_results[task_id]['lang_goal'][i])
            lang_instr = sampled_results[task_id]['lang_instr'][i]
            print({i:lang_instr[i] for i in range(len(lang_instr))}, '\n')
        print ('---------------------------')
        for e in epoch_list:
            print("\nEpoch {} Prediction Output".format(e))
            print("- Decoding by Argmax:")
            print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_{}'.format(e)]))
            pred_lang_instr = sampled_results[task_id]['p_lang_instr_{}'.format(e)]
            print({i:pred_lang_instr[str(i)] for i in range(gold_num_subgoals)})
#             print("- Decoding by Sampling:")
#             print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_sampled_{}'.format(e)]))
#             print(sampled_results[task_id]['p_lang_instr_sampled_{}'.format(e)])
        print ('---------------------------')            
        print ('--------------------------------------------------------------------------------------\n\n\n\n\n')
    return sampled_results

# %%
chosen_train_sanity_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_train_sanity_task_ids, epoch_list = train_sanity_epoch_list, split = 'train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_115507_503798_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-PotatoSliced-None-GarbageCan-28/trial_T20190908_115507_503798
# Number of subgoals (exlcuding <No-op>): 13
# https://www.youtube.com/watch?v=HKKh-4WHSsg&t=7s
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'SliceObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'SliceObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# slice up two potatoes in a green waste basket
# {0: 'turn to the right twice and take a few steps and turn to the left and go to the counter', 1: 'pick up the potato from the counter top', 2: 'turn to the right twice and go to the middle of the room and turn to the left and go to the counter top', 3: 'put the potato in the green waste basket underneath the counter top', 4: 'turn to the left and take a few steps and turn to the left and go to the front of the refrigerator and turn to the right and go to the refrigerator', 5: 'open the refrigerator door and take out the potato on the top shelf and close the door', 6: 'turn to the right and take a step and turn to the right and go to the middle of the room and turn to the left and go to the counter top', 7: 'put the potato in the green waste basket underneath the counter top', 8: 'turn to the left and take a few steps and turn to the right facing the counter', 9: 'pick up the yellow handle knife from the counter top', 10: 'turn to the right and take a few steps and turn to the left facing the counter', 11: 'slice up the two potatoes with the knife in the green waste basket'}
#
# Annotation 1
# put potatoes in a bin and slice the potato with a knife
# {0: 'go to the counter between the fridge and the stove', 1: 'pick up the potato from the counter', 2: 'take the potato to the coffee machine', 3: 'put the potato in the green bin below the counter', 4: 'go the fridge', 5: 'take the potato from the fridge', 6: 'take the potato back to the counter where the coffee machine is', 7: 'put the potato in the green bin below the counter', 8: 'walk over to counter above the dishwasher', 9: 'take the knife from the counter', 10: 'take the knife over to the bin where you put the potatoes', 11: 'cut the potatoes in the bin with the knife'}
#
# Annotation 2
# Put two eggs in a bin and cut them with a knife
# {0: 'Go to the counter between the fridge and the stove', 1: 'Pick up the egg on the counter', 2: 'Go to the green bin', 3: 'Place the egg in the bin', 4: 'Go to the fridge', 5: 'Take an egg out of the fridge', 6: 'Go to the green bin', 7: 'Place the egg in the bin', 8: 'Go to the counter to the left', 9: 'Pick up a knife off the counter', 10: 'Go to the green bin', 11: 'Cut the eggs in the bin'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21969653845034376
# {0: 'turn around , go to the counter .', 1: 'pick up a slice of potato from the counter .', 2: 'turn around , walk to the coffee maker on the counter .', 3: 'place the potato in the trash can .', 4: 'turn left , walk forward , turn right , walk to the fridge .', 5: 'open the fridge and pick up the potato slice from the fridge .', 6: 'turn around , walk to the coffee maker on the counter .', 7: 'place the potato in the trash can .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn right and walk to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21045649865536906
# {0: 'turn around and go to the counter between the stove and the stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin .', 3: 'put the potato in the green bin .', 4: 'turn left and go to the refrigerator .', 5: 'open the fridge and pick up the potato that is on the shelf .', 6: 'turn around and walk to the green trash can .', 7: 'put the potato in the green bin .', 8: 'turn left and go to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn to the right and go to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24402219131372271
# {0: 'turn right , move forward , then turn left to face the counter .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin below the counter .', 4: 'turn left and walk to the fridge .', 5: 'open the fridge and take out the potato from the top shelf and close the door .', 6: 'turn around and walk to the green bin on the right side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife on the counter .', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26494006903027295
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge .', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2936278767702732
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , go forward , turn left at the end of the counter and go to the green bin .', 3: 'put the potato in the green bin under the counter .', 4: 'go to the fridge', 5: 'take the potato from the fridge', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin under the counter .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23611037275070104
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , walk forward , turn left , walk to the green bin', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge', 6: 'turn around and walk to the counter with the coffee maker on it .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green trash can .', 12: 'cut the potato in the green trash can .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_011351_027508_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-HandTowel-None-Toilet-412/trial_T20190907_011351_027508
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=deDf2pnORts
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two towels on a toilet.
# {0: 'Turn right and walk to the right side of the sink.', 1: 'Take the towel on the wall of of the towel rack.', 2: 'Turn left and walk to the toilet.', 3: 'Put the towel on top of the toilet tank.', 4: 'Turn around and face the sink.', 5: 'Take the towel on the left off the towel rack.', 6: 'Turn around and face the toilet.', 7: 'Place the towel on the toilet behind the other towel.'}
#
# Annotation 1
# Put two towels on the toilet tank lid.
# {0: 'Move to the towel rack right of the sink.', 1: 'Pick up the towel from the rack. ', 2: 'Bring the towel to the toilet.', 3: 'Place the towel standing on the toilet tank lid. ', 4: 'Move to the sink.', 5: 'Pick up the towel to the left of the sink. ', 6: 'Bring the towel to the toilet. ', 7: 'Place the towel next to the other towel on the toilet tank lid. '}
#
# Annotation 2
# Place two towels above the toilet
# {0: 'Turn to your right and walk over to the towel on the wall', 1: 'Pick up the towel hanging on the wall', 2: 'Turn around and walk over to the toilet on your right', 3: 'Place the towel above the toilet', 4: 'Turn around and go to the left sink', 5: 'Pick up the towel in front of you', 6: 'Turn around again, and look at the toilet', 7: 'Place the towel behind the other towel, above the toilet'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.517017370949182
# {0: 'walk forward to the wall , turn right to face the wall .', 1: 'pick up the towel from the wall .', 2: 'turn around , walk to the toilet .', 3: 'place the towel on the back of the toilet .', 4: 'turn right and face the counter .', 5: 'pick up the towel from the sink .', 6: 'turn left and face the toilet .', 7: 'place the towel on the back of the toilet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16770228252517308
# {0: 'walk to the towel rack', 1: 'take the towel off of the towel rack', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank .', 4: 'turn around and look up at the sink .', 5: 'take the towel off of the towel rack .', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.20709344286363232
# {0: 'walk forward and turn right towards the towel rack', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'grab the towel on the wall', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29060570191467733
# {0: 'turn right and walk to the towel rack on the wall .', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'grab the towel on the wall', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank behind the other towel .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29060570191467733
# {0: 'turn right and walk to the towel rack on the wall .', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'pick up the towel from the towel holder', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.289473742806432
# {0: 'turn right and walk to the towel rack on the wall', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'pick up the towel from the towel rack', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190910_055356_172564_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Mug-None-Cabinet-318/trial_T20190910_055356_172564
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=_ys8HY3G94U
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move two white mugs into a cabinet.
# {0: 'Walk forward, then turn right and walk up to the wooden desk.', 1: 'Pick up the leftmost white mug off of the wooden desk.', 2: 'Turn around and walk forward, then hang a right and take a step forward, turn right to face the desk.', 3: 'Open the cabinet door below the desk and put the white mug inside on the left side.', 4: 'Turn right and walk forward, then turn left and walk up to the desk.', 5: 'Pick up the white mug off of the desk.', 6: 'Turn around and walk forward, then turn right and walk forward, then turn right to face the wooden desk.', 7: 'Open the cabinet door below the desk and put the white mug inside to the right of the mug that is already in there.'}
#
# Annotation 1
# Move two mugs from the desktop to the desk storage space
# {0: 'Walk to stand in front of the desk.', 1: 'Pick up the white mug in front of the electric clock.', 2: 'Move to the right side of the desk and locate the desk storage space door below the drawer.', 3: 'Open the desk door, place the mug at the front left side of the desk storage space, and to the front of the book, close the desk door.', 4: 'Move right to stand in front of the white mug on the far right end of the desktop.', 5: 'Pick up the white mug from the desktop.', 6: 'Move to your left and open the door to the desk storage space.', 7: 'Place the mug to the right of the first mug and close the desk door.'}
#
# Annotation 2
# Pick up the cups on the desk and place them in the desk drawer.
# {0: 'Turn to your right', 1: 'Pick up the leftmost cup on the desk', 2: 'Turn around and take a step before turning back towards the desk', 3: 'Open the desk drawer and place the cup inside before closing the drawer.', 4: 'Turn to your right and then back towards the desk.', 5: "Pick up the cup that's on the desk", 6: 'Turn around and take a step before turning back towards the desk', 7: 'Open the desk drawer and place the cup inside before closing the drawer.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3145272172508477
# {0: 'turn right and walk to the desk .', 1: 'pick up the mug from the desk .', 2: 'turn left and walk to the desk .', 3: 'place the mug in the cabinet .', 4: 'turn right , walk to the desk', 5: 'pick up the mug with the spoon in it .', 6: 'turn around and walk to the desk on the right .', 7: 'place the mug in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5447543677502811
# {0: 'walk forward and turn right to face the desk .', 1: 'pick up the mug from the desk .', 2: 'turn around and take a step forward , then turn right and take a step forward , then turn right and take one step , turn right again and take a step forward , then turn right and take one step , turn right again to face the desk .', 3: 'open the cabinet door and put the mug in the cabinet .', 4: 'turn right and walk to the desk .', 5: 'pick up the mug from the desk', 6: 'turn around and take a step forward , then turn right and take two steps , then turn right to face the desk .', 7: 'open the cabinet and put the mug in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk .', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'open the cabinet and place the mug inside . shut the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'open the cabinet and place the mug inside .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'place the mug in the desk cabinet to the left of the other white mug .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13099303415494293
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk', 2: 'move to the left side of the desk', 3: 'open the cabinet door and place the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'place the mug in the desk cabinet .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190919_045956_375063_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spatula-Plate-SinkBasin-3/trial_T20190919_045956_375063
# Number of subgoals (exlcuding <No-op>): 7
# https://www.youtube.com/watch?v=9mE_rLrhAhU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a plate and spatula to the sink.
# {0: 'Move forward and turn left toward the end of the counter.', 1: 'Pick up the spatula from the end of the counter.', 2: 'Carry the spatula and take a few steps to the left.', 3: 'Place the spatula on the plate on the counter.', 4: 'Pick up the plate from the counter.', 5: 'Hold the plate and move a few steps to the left to go to the sink.', 6: 'Place the plate and spatula in the sink.'}
#
# Annotation 1
# Put a plate with a spatula on it in the sink.
# {0: 'Move to the counter to the left of you', 1: 'Pick up spatula from the counter', 2: 'Move to the counter to the right of the sink', 3: 'Put spatula on a plate on the counter.', 4: 'Pick up plate from the counter', 5: 'Move to the sink to the left of you', 6: 'Put plate inside the sink'}
#
# Annotation 2
# Place round plate with spatula in sink
# {0: 'go forward to end of counter with loaf of bread', 1: 'pick up spatula on back of counter to the right of bread', 2: 'go to round plate on counter to the left', 3: 'place spatula on round plate on counter to the left of the bread', 4: 'pick up plate with spatula', 5: 'go to sink to the left', 6: 'place round plate with spatula in sink'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5938750370410806
# {0: 'go to the counter to the right of the stove .', 1: 'pick up the spatula on the counter .', 2: 'turn left and walk to the counter .', 3: 'place the spatula on the plate on the counter .', 4: 'pick up the plate with the spoon on it .', 5: 'turn left and walk to the sink .', 6: 'place the plate with the spoon in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29509789991363017
# {0: 'walk forward and turn left to face the counter .', 1: 'pick up the spatula from the counter .', 2: 'turn left and walk to the counter .', 3: 'put the spatula on the plate .', 4: 'pick up the plate from the counter .', 5: 'turn left and walk to the sink .', 6: 'put the plate in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3976626266897693
# {0: 'walk forward and turn left to face the counter .', 1: 'pick up the spatula from the counter .', 2: 'move to the left a bit and face the counter', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'turn left and walk to the sink .', 6: 'place the plate and spatula in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.39986529147720035
# {0: 'walk forward then turn left to face the counter with the loaf of bread on it .', 1: 'pick up the spatula from the counter .', 2: 'turn left and take a step then turn right to face the counter .', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'turn left and walk to the sink .', 6: 'put the plate in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5218212727594117
# {0: 'move to the counter to the left of the stove', 1: 'pick up the spatula from the counter .', 2: 'move to the counter to the left of the sink', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'move to the sink to the left of you', 6: 'put the plate and spatula in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5218212727594117
# {0: 'move to the counter to the left of the stove', 1: 'pick up the spatula from the counter .', 2: 'move to the counter to the left of the sink', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'move to the sink to the left of you', 6: 'put the plate and spatula in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190918_173742_042769_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-18/trial_T20190918_173742_042769
# Number of subgoals (exlcuding <No-op>): 13
# https://www.youtube.com/watch?v=7dHM--8H_ws
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Slice a tomato and place in skillet.
# {0: 'Turn left and walk forward to the table. Make a right to face the table. ', 1: 'Pick up the tomato from the table.', 2: 'Turn to the right and then left to walk around the table to the other side.', 3: 'Set the tomato on the table. ', 4: 'Pick up the yellow knife from the table. ', 5: 'Use the knife to slice the tomato. ', 6: 'Set the knife on the table to the right of the sponge. ', 7: 'Pick up a slice of tomato. ', 8: 'Turn around and go to the left. Then make another left at the oven.', 9: 'Place the tomato slice on the skillet.', 10: 'Pick up the skillet with the tomato slice.', 11: 'Turn to the left and walk over to the table. Turn left again to face the table.', 12: 'Place the skillet on the table with the tomato inside. '}
#
# Annotation 1
# Place a frying pan with a tomato slice in it onto the table.
# {0: 'Turn left then head towards the table against the wall.', 1: 'From the table pick up the tomato behind the green sponge.', 2: 'Turn right then head towards the door, turn left then head towards the refrigerator, then left, head towards the table.', 3: 'Place the tomato to the right of the green sponge.', 4: 'Pick up the knife behind the spoon on the table', 5: 'Cut the tomato into slices.', 6: 'Place the knife behind the tomato on the table.', 7: 'Pick up a tomato from the table.', 8: 'Turn left, then head towards the stove.', 9: 'Place the tomato into the frying pan on the stove.', 10: 'Pick up the frying pan from the stove.', 11: 'Turn left then head towards the table against the wall.', 12: 'Place the frying pan to the left of the plant onto the table.'}
#
# Annotation 2
# put a slice of tomato on a pan onto the black table
# {0: 'turn to the left go to the right', 1: 'pick up the tomato from the black table', 2: 'turn left go right left again facing the black table ', 3: 'put the tomato on top of the table', 4: 'pick up the knife from the table ', 5: 'slice the tomato in 2 pieces', 6: 'cut 1 half into many pieces', 7: 'pick up one piece of the tomato', 8: 'turn to the right go left face the stove', 9: 'put the piece of tomato in the pan that is on the stove', 10: 'pick up the pan from the stove', 11: 'turn to the left across the room', 12: 'put the pan on top of the black table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6159033281345802
# {0: 'turn left and walk to the table on the right .', 1: 'pick up a slice of tomato from the table .', 2: 'turn around , walk forward , turn left , walk to the table , turn left to face the table .', 3: 'put the tomato on the table', 4: 'pick up the knife on the table .', 5: 'slice the tomato on the table .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn around and walk to the stove .', 9: 'place the tomato in the pan on the stove .', 10: 'pick up the pan from the stove .', 11: 'turn left and walk to the white table .', 12: 'place the pan on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.10034344765687508
# {0: 'turn left and go to the wall , then turn right and go to the wall , turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn right and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table .', 6: 'put the knife on the table', 7: 'pick up a slice of tomato .', 8: 'turn around and go to the counter to the right of the stove .', 9: 'put the tomato in the pan .', 10: 'pick up the pan with the knife in it .', 11: 'turn left and walk to the table .', 12: 'put the frying pan on the table .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1804957958004903
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn left and walk around the table to the other side of the table .', 3: 'put the tomato on the table', 4: 'pick up the knife on the table .', 5: 'cut the tomato into slices .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn around and walk to the counter to the right of the stove .', 9: 'place the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room to the black table .', 12: 'put the pan on the table'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28126237213837973
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato from the table .', 2: 'turn right and walk to the table , then turn left and walk across the room , then turn left and walk up to the fridge , turn left and walk up to the black table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the counter to the right of the stove .', 9: 'put the tomato in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room to face the black table .', 12: 'put the pan on the table'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2551828884959909
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn left and walk to the table , then turn left and walk across the room , then turn left and walk up to the fridge , turn left and walk up to the black table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the stove .', 9: 'put the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room , then turn left and walk over to the black round table .', 12: 'put the pan on the table'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14029675321944643
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn right and walk to the other side of the kitchen table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table', 5: 'cut the tomato into slices .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the stove .', 9: 'put the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk over to the black round table .', 12: 'put the pan on the table'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_030909_087593_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Fork-None-Drawer-30/trial_T20190908_030909_087593
# Number of subgoals (exlcuding <No-op>): 6
# https://www.youtube.com/watch?v=kXR2SJ4f47w
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a clean fork in the drawer
# {0: 'move forward towards the table', 1: 'pick up the fork', 2: 'move to the sink ahead', 3: 'drop the fork in the sink and rinse it', 4: 'move to the right of the sink', 5: 'place the fork in the drawer'}
#
# Annotation 1
# Wash a fork in the sink that was left on the counter to be place inside a drawer.
# {0: 'Move slightly to the left side of the  brown counter top island.', 1: 'Pick up the fork that is on the slanted corner. ', 2: 'Move across the kitchen to the sink. ', 3: 'Put the fork in the sink and wash it. Take the fork out of the sink. ', 4: 'Turn to the right and move slightly down the white counter top next to the sink. ', 5: 'Open the drawer that is under the far right of the counter and place the fork inside. C Close the drawer.'}
#
# Annotation 2
# wash the fork and put it in the drawer
# {0: 'go the island and approach the fork', 1: 'pick up the fork', 2: 'take the fork to the sink', 3: 'put the fork in the sink and take back out', 4: 'go the right of the sink at the counter', 5: 'put the knife in the drawer all the way to the right'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4193737480101046
# {0: 'turn right and walk to the counter .', 1: 'pick up the fork from the counter .', 2: 'turn around , go to the sink .', 3: 'place the fork in the sink .', 4: 'turn around and walk to the sink .', 5: 'place the fork in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127425558589731
# {0: 'turn to the right and go to the counter .', 1: 'pick up the fork from the counter .', 2: 'turn around and walk to the sink .', 3: 'wash the fork in the sink .', 4: 'turn around and walk to the counter .', 5: 'put the fork in the drawer'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38774385456396854
# {0: 'move to the island to the left of the fridge', 1: 'pick up the fork that is on the counter .', 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and then pick it back up and shut off the water .', 4: 'turn around and walk to the drawer under the counter .', 5: 'place the fork in the drawer'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46756059634945063
# {0: 'move to the table to the right of the fridge', 1: 'pick up the fork from the counter .', 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3992258400104756
# {0: 'move to the island counter to the left of the fridge', 1: "pick up the fork that ' s in front of you .", 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3992258400104756
# {0: 'move to the island counter to the left of the fridge', 1: "pick up the fork that ' s in front of you .", 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_004008_377860_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-DiningTable-15/trial_T20190909_004008_377860
# Number of subgoals (exlcuding <No-op>): 6
# https://www.youtube.com/watch?v=YBJgvP4Uai8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold pan on the white table.
# {0: 'Turn right and go to the counter with the coffee maker, then turn right to face the counter with the toaster on it.', 1: 'Pick up the pan from the counter in front of you.', 2: 'Turn right and go toward the door, then turn left to face the fridge.', 3: 'Open the fridge, put the pan inside, and take it back out.', 4: 'Turn around and go forward toward the wall, then turn right to face the white table.', 5: 'Put the pan on the white table.'}
#
# Annotation 1
# Put a cold pan on the table.
# {0: 'Take a small step forward then turn right and walk to the counter then turn right.', 1: "Pick up the frying pan that's in front of you.", 2: 'Turn right and walk to the door then turn left to face the fridge.', 3: 'Chill the in the fridge then get it back out and close the door.', 4: 'Turn around and walk to the wall in front of you then turn right.', 5: "Put the pan on the table in front of you near the corner that's nearest you."}
#
# Annotation 2
# Chill the frying pan and put it on the table.
# {0: 'Turn right and walk to the counter.  Turn right again so you are facing the toaster.', 1: 'Pick up the frying pan in front of the toaster.', 2: 'Turn right and walk to the door.  Turn left and face the refrigerator.', 3: 'Open the refrigerator door and place the frying pan on the top shelf in the refrigerator and close the refrigerator door again.  Open the refrigerator door and remove the frying pan from the top shelf, then close the refrigerator door.', 4: 'Turn completely around, walk to the wall, turn to the right so you are facing the white table. ', 5: 'Place the frying pan on the table in front of the stool. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29484429714729943
# {0: 'go to the counter .', 1: 'pick up the pan from the counter .', 2: 'turn right , walk to the fridge .', 3: 'place the pan inside the fridge , remove it , and close the door .', 4: 'turn around , walk to the white table .', 5: 'place the pan on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27023861328315474
# {0: 'turn right and walk to the counter with the coffee maker .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and go to the refrigerator .', 3: 'put the pan in the fridge and close the door , then open the door and take the pan back out .', 4: 'turn around and walk to the wall , then turn right to face the white table .', 5: 'put the pan on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2942387499738611
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge on the left .', 3: 'open the fridge and put the pan inside and close the door and then open the door and take the pan back out .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the frying pan on the white table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24098098788990255
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge .', 3: 'put the pan in the fridge and shut the door and then open the door and take the pan out .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32702438945441714
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge on the left .', 3: 'open the fridge , put the pan inside , close the fridge , open the refrigerator , take the pan out , close the refrigerator .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.431911643588302
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the door , then turn left to face the fridge .', 3: 'open the fridge , put the pan inside , close the refrigerator , open the refrigerator , take the pan out , close the refrigerator', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_072254_824822_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Ladle-Bowl-Cabinet-16/trial_T20190908_072254_824822
# Number of subgoals (exlcuding <No-op>): 7
# https://www.youtube.com/watch?v=GZAUr7AToYY
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a bowl with a spoon inside a cabinet.
# {0: 'Turn around and walk to the counter on the right.', 1: 'Pick up the spoon with the black handle near the edge of the counter.', 2: 'Turn left and hang a left at the wall to face the white table.', 3: 'Put the spoon inside the wooden bowl to the right of the tomato on the table.', 4: 'Pick up the bowl with the spoon on the table.', 5: 'Turn left, hang a left at end of the white table, walk around the angle of the counter and hang a left at the white stove to face the cabinets.', 6: 'Open the far right cabinet, place the bowl with a spoon inside and close the door.'}
#
# Annotation 1
# Put a bowl with a spoon in it into a cabinet.
# {0: 'Turn around 180 degrees and walk to the counter.', 1: 'Pick up the spoon on the counter. ', 2: 'Turn to the left 90 degrees and walk across the room, turning 90 degrees to the left to face the table when you reach it.', 3: 'Place the spoon in the brown cup.', 4: 'Pick up the brown cup with the spoon in it. ', 5: 'Turn to the left 90 degrees, then again after walking to a bit and cross the room, turning another 90 degrees to the left when you reach the end, and walk towards the counter.', 6: 'Put the bowl with the spoon in it into the lower cabinet. '}
#
# Annotation 2
# drop a plate with a spoon in it in the cupboard
# {0: 'turn around to the table', 1: 'pick up the spoon from the table', 2: 'move left to the table ', 3: 'drop the spoon in the plate', 4: 'pick up the plate from the table', 5: 'turn around and move to the cupboard', 6: 'drop the plate in the cupboard'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6712167562558268
# {0: 'turn left and walk to the counter .', 1: 'pick up the spoon from the counter .', 2: 'turn left and walk to the white table .', 3: 'place the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn left and walk back to the white cabinet .', 6: 'place the bowl in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6767985448506239
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the wall then turn left and walk to the wall then turn left to face the table .', 3: 'put the spoon in the bowl .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and walk to the counter then turn left and walk to the counter .', 6: 'place the bowl with the spoon in it in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk around the counter to the counter .', 6: 'open the cupboard and place the bowl with the spoon in it and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter , turning left to face the counter .', 6: 'open the cupboard that is in the cupboard .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter .', 6: 'open the cupboard that is in the right side of the bottom cabinet .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter .', 6: 'open the cupboard that is in the cupboard .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_181954_161870_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Watch-None-Dresser-205/trial_T20190907_181954_161870
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=7uDr2uq7gLs
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two watches on the TV stand.
# {0: 'Walk to the glass dining table on the other side of the red chair.', 1: 'Pick up the watch between the statue and the compute on the table.', 2: 'Turn around and walk to the TV.', 3: 'Place the watch on the middle of the TV stand.', 4: 'Turn around and walk to the far side of the glass dining table.', 5: 'Pick up the watch next to the statue on the dining table.', 6: 'Walk to the TV on the other side of the room.', 7: 'Place the watch to the left of the other watch on the TV stand.'}
#
# Annotation 1
# place two watches on the tv stand
# {0: 'turn left and head towards the dining', 1: 'pick up the watch', 2: 'turn around and locate the tv', 3: 'drop the watch on the tv stand', 4: 'turn around and head for the dining', 5: 'pick up the wrist watch', 6: 'turn around and head for the television stand', 7: 'place the watch on the tv stand'}
#
# Annotation 2
# Put two watches on the tv stand.
# {0: "Walk to stand in front of the chair you can see in front of you to the left that's sitting in front of a statue and laptop.", 1: 'Pick up the watch you see on the table.', 2: 'Turn arouind and walk over to the tv you can see in front of you to the left,', 3: 'Put the watch in the middle of the tv stand.', 4: 'Walk to the opposite side of the table that where you got the first watch.', 5: 'Pick up the watch on that side of the table.', 6: 'Walk back over to the tv.', 7: 'Put this watch ot the left of the first watch.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38372701392389547
# {0: 'turn around , walk forward , turn right , walk to the table .', 1: 'pick up the watch off of the table .', 2: 'turn around , walk forward , turn left , walk to the tv stand .', 3: 'place the watch on the tv stand', 4: 'turn right , walk forward , turn left , walk to the table , turn left to face the table .', 5: 'pick up the watch off of the table .', 6: 'turn right , walk forward , turn left , walk to the tv stand .', 7: 'place the watch on the tv stand'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42289400252044634
# {0: 'turn around and walk to the table .', 1: 'pick up the watch from the table .', 2: 'turn around and walk to the tv .', 3: 'put the watch on the tv stand', 4: 'turn around and go to the dining table', 5: 'pick up the watch from the table .', 6: 'turn right and walk to the tv .', 7: 'put the watch on the tv stand'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining table on the right side .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining table .', 5: 'pick up the watch from the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining side of the dining table .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining side of the dining table .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_113100_297495_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-ArmChair-318/trial_T20190909_113100_297495
# Number of subgoals (exlcuding <No-op>): 4
# https://www.youtube.com/watch?v=1D8TGusmIaQ
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move book from dresser to chair
# {0: 'turn left, walk across the room to the dresser', 1: 'pick up the book that is on the dresser', 2: 'turn left, walk forward, turn left to face floral chair', 3: 'put the book on the chair'}
#
# Annotation 1
# Move a book from the desk to the floral armchair.
# {0: 'Turn right to walk to the desk.', 1: 'Pick up the green book from the desk.', 2: 'Turn around to walk to the floral armchair.', 3: 'Set the green book down on the floral armchair.'}
#
# Annotation 2
# Place a book on a chair.
# {0: 'Turn left and walk to the wooden desk ahead.', 1: 'Pick up the green book from the right side of the desk.', 2: 'Turn around and walk to the floral chair on the right against the wall.', 3: 'Put the book on the middle of the chair.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4962907202726068
# {0: 'turn left and walk forward to the dresser .', 1: 'pick up the book from the desk', 2: 'turn around and walk to the chair .', 3: 'place the book on the chair .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6364760663492011
# {0: 'turn left and walk to the desk .', 1: 'pick up the book from the desk', 2: 'turn around and walk to the chair .', 3: 'put the book on the chair'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8278087268979791
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair on the left .', 3: 'put the book on the chair .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
chosen_train_sanity_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_train_sanity_task_ids, epoch_list = train_sanity_epoch_list, split = 'train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_115507_503798_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-PotatoSliced-None-GarbageCan-28/trial_T20190908_115507_503798
# Number of subgoals (exlcuding <No-op>): 13
# https://www.youtube.com/watch?v=HKKh-4WHSsg&t=7s
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'SliceObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'SliceObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# slice up two potatoes in a green waste basket
# {0: 'turn to the right twice and take a few steps and turn to the left and go to the counter', 1: 'pick up the potato from the counter top', 2: 'turn to the right twice and go to the middle of the room and turn to the left and go to the counter top', 3: 'put the potato in the green waste basket underneath the counter top', 4: 'turn to the left and take a few steps and turn to the left and go to the front of the refrigerator and turn to the right and go to the refrigerator', 5: 'open the refrigerator door and take out the potato on the top shelf and close the door', 6: 'turn to the right and take a step and turn to the right and go to the middle of the room and turn to the left and go to the counter top', 7: 'put the potato in the green waste basket underneath the counter top', 8: 'turn to the left and take a few steps and turn to the right facing the counter', 9: 'pick up the yellow handle knife from the counter top', 10: 'turn to the right and take a few steps and turn to the left facing the counter', 11: 'slice up the two potatoes with the knife in the green waste basket'}
#
# Annotation 1
# put potatoes in a bin and slice the potato with a knife
# {0: 'go to the counter between the fridge and the stove', 1: 'pick up the potato from the counter', 2: 'take the potato to the coffee machine', 3: 'put the potato in the green bin below the counter', 4: 'go the fridge', 5: 'take the potato from the fridge', 6: 'take the potato back to the counter where the coffee machine is', 7: 'put the potato in the green bin below the counter', 8: 'walk over to counter above the dishwasher', 9: 'take the knife from the counter', 10: 'take the knife over to the bin where you put the potatoes', 11: 'cut the potatoes in the bin with the knife'}
#
# Annotation 2
# Put two eggs in a bin and cut them with a knife
# {0: 'Go to the counter between the fridge and the stove', 1: 'Pick up the egg on the counter', 2: 'Go to the green bin', 3: 'Place the egg in the bin', 4: 'Go to the fridge', 5: 'Take an egg out of the fridge', 6: 'Go to the green bin', 7: 'Place the egg in the bin', 8: 'Go to the counter to the left', 9: 'Pick up a knife off the counter', 10: 'Go to the green bin', 11: 'Cut the eggs in the bin'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21969653845034376
# {0: 'turn around , go to the counter .', 1: 'pick up a slice of potato from the counter .', 2: 'turn around , walk to the coffee maker on the counter .', 3: 'place the potato in the trash can .', 4: 'turn left , walk forward , turn right , walk to the fridge .', 5: 'open the fridge and pick up the potato slice from the fridge .', 6: 'turn around , walk to the coffee maker on the counter .', 7: 'place the potato in the trash can .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn right and walk to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21045649865536906
# {0: 'turn around and go to the counter between the stove and the stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin .', 3: 'put the potato in the green bin .', 4: 'turn left and go to the refrigerator .', 5: 'open the fridge and pick up the potato that is on the shelf .', 6: 'turn around and walk to the green trash can .', 7: 'put the potato in the green bin .', 8: 'turn left and go to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn to the right and go to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24402219131372271
# {0: 'turn right , move forward , then turn left to face the counter .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin below the counter .', 4: 'turn left and walk to the fridge .', 5: 'open the fridge and take out the potato from the top shelf and close the door .', 6: 'turn around and walk to the green bin on the right side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife on the counter .', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26494006903027295
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge .', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2936278767702732
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , go forward , turn left at the end of the counter and go to the green bin .', 3: 'put the potato in the green bin under the counter .', 4: 'go to the fridge', 5: 'take the potato from the fridge', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin under the counter .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23611037275070104
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , walk forward , turn left , walk to the green bin', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge', 6: 'turn around and walk to the counter with the coffee maker on it .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green trash can .', 12: 'cut the potato in the green trash can .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_011351_027508_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-HandTowel-None-Toilet-412/trial_T20190907_011351_027508
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=deDf2pnORts
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two towels on a toilet.
# {0: 'Turn right and walk to the right side of the sink.', 1: 'Take the towel on the wall of of the towel rack.', 2: 'Turn left and walk to the toilet.', 3: 'Put the towel on top of the toilet tank.', 4: 'Turn around and face the sink.', 5: 'Take the towel on the left off the towel rack.', 6: 'Turn around and face the toilet.', 7: 'Place the towel on the toilet behind the other towel.'}
#
# Annotation 1
# Put two towels on the toilet tank lid.
# {0: 'Move to the towel rack right of the sink.', 1: 'Pick up the towel from the rack. ', 2: 'Bring the towel to the toilet.', 3: 'Place the towel standing on the toilet tank lid. ', 4: 'Move to the sink.', 5: 'Pick up the towel to the left of the sink. ', 6: 'Bring the towel to the toilet. ', 7: 'Place the towel next to the other towel on the toilet tank lid. '}
#
# Annotation 2
# Place two towels above the toilet
# {0: 'Turn to your right and walk over to the towel on the wall', 1: 'Pick up the towel hanging on the wall', 2: 'Turn around and walk over to the toilet on your right', 3: 'Place the towel above the toilet', 4: 'Turn around and go to the left sink', 5: 'Pick up the towel in front of you', 6: 'Turn around again, and look at the toilet', 7: 'Place the towel behind the other towel, above the toilet'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.517017370949182
# {0: 'walk forward to the wall , turn right to face the wall .', 1: 'pick up the towel from the wall .', 2: 'turn around , walk to the toilet .', 3: 'place the towel on the back of the toilet .', 4: 'turn right and face the counter .', 5: 'pick up the towel from the sink .', 6: 'turn left and face the toilet .', 7: 'place the towel on the back of the toilet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16770228252517308
# {0: 'walk to the towel rack', 1: 'take the towel off of the towel rack', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank .', 4: 'turn around and look up at the sink .', 5: 'take the towel off of the towel rack .', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.20709344286363232
# {0: 'walk forward and turn right towards the towel rack', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'grab the towel on the wall', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29060570191467733
# {0: 'turn right and walk to the towel rack on the wall .', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'grab the towel on the wall', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank behind the other towel .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29060570191467733
# {0: 'turn right and walk to the towel rack on the wall .', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'pick up the towel from the towel holder', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.289473742806432
# {0: 'turn right and walk to the towel rack on the wall', 1: 'pick up the towel from the holder', 2: 'turn around and walk to the toilet .', 3: 'place the towel on the toilet tank lid .', 4: 'turn around and face the sink .', 5: 'pick up the towel from the towel rack', 6: 'turn around and face the toilet .', 7: 'place the towel on the toilet tank lid .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190910_055356_172564_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Mug-None-Cabinet-318/trial_T20190910_055356_172564
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=_ys8HY3G94U
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move two white mugs into a cabinet.
# {0: 'Walk forward, then turn right and walk up to the wooden desk.', 1: 'Pick up the leftmost white mug off of the wooden desk.', 2: 'Turn around and walk forward, then hang a right and take a step forward, turn right to face the desk.', 3: 'Open the cabinet door below the desk and put the white mug inside on the left side.', 4: 'Turn right and walk forward, then turn left and walk up to the desk.', 5: 'Pick up the white mug off of the desk.', 6: 'Turn around and walk forward, then turn right and walk forward, then turn right to face the wooden desk.', 7: 'Open the cabinet door below the desk and put the white mug inside to the right of the mug that is already in there.'}
#
# Annotation 1
# Move two mugs from the desktop to the desk storage space
# {0: 'Walk to stand in front of the desk.', 1: 'Pick up the white mug in front of the electric clock.', 2: 'Move to the right side of the desk and locate the desk storage space door below the drawer.', 3: 'Open the desk door, place the mug at the front left side of the desk storage space, and to the front of the book, close the desk door.', 4: 'Move right to stand in front of the white mug on the far right end of the desktop.', 5: 'Pick up the white mug from the desktop.', 6: 'Move to your left and open the door to the desk storage space.', 7: 'Place the mug to the right of the first mug and close the desk door.'}
#
# Annotation 2
# Pick up the cups on the desk and place them in the desk drawer.
# {0: 'Turn to your right', 1: 'Pick up the leftmost cup on the desk', 2: 'Turn around and take a step before turning back towards the desk', 3: 'Open the desk drawer and place the cup inside before closing the drawer.', 4: 'Turn to your right and then back towards the desk.', 5: "Pick up the cup that's on the desk", 6: 'Turn around and take a step before turning back towards the desk', 7: 'Open the desk drawer and place the cup inside before closing the drawer.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3145272172508477
# {0: 'turn right and walk to the desk .', 1: 'pick up the mug from the desk .', 2: 'turn left and walk to the desk .', 3: 'place the mug in the cabinet .', 4: 'turn right , walk to the desk', 5: 'pick up the mug with the spoon in it .', 6: 'turn around and walk to the desk on the right .', 7: 'place the mug in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5447543677502811
# {0: 'walk forward and turn right to face the desk .', 1: 'pick up the mug from the desk .', 2: 'turn around and take a step forward , then turn right and take a step forward , then turn right and take one step , turn right again and take a step forward , then turn right and take one step , turn right again to face the desk .', 3: 'open the cabinet door and put the mug in the cabinet .', 4: 'turn right and walk to the desk .', 5: 'pick up the mug from the desk', 6: 'turn around and take a step forward , then turn right and take two steps , then turn right to face the desk .', 7: 'open the cabinet and put the mug in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk .', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'open the cabinet and place the mug inside . shut the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'open the cabinet and place the mug inside .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13218944174284883
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk .', 2: 'move to the left side of the desk', 3: 'open the cabinet and put the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'place the mug in the desk cabinet to the left of the other white mug .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13099303415494293
# {0: 'walk to the desk on your right .', 1: 'pick up the white mug from the desk', 2: 'move to the left side of the desk', 3: 'open the cabinet door and place the mug inside .', 4: 'turn right and walk back to the desk .', 5: 'pick up the white mug from the desk', 6: 'turn around and take a step forward , then turn right and take a step forward , turn right to face the desk .', 7: 'place the mug in the desk cabinet .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190919_045956_375063_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spatula-Plate-SinkBasin-3/trial_T20190919_045956_375063
# Number of subgoals (exlcuding <No-op>): 7
# https://www.youtube.com/watch?v=9mE_rLrhAhU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a plate and spatula to the sink.
# {0: 'Move forward and turn left toward the end of the counter.', 1: 'Pick up the spatula from the end of the counter.', 2: 'Carry the spatula and take a few steps to the left.', 3: 'Place the spatula on the plate on the counter.', 4: 'Pick up the plate from the counter.', 5: 'Hold the plate and move a few steps to the left to go to the sink.', 6: 'Place the plate and spatula in the sink.'}
#
# Annotation 1
# Put a plate with a spatula on it in the sink.
# {0: 'Move to the counter to the left of you', 1: 'Pick up spatula from the counter', 2: 'Move to the counter to the right of the sink', 3: 'Put spatula on a plate on the counter.', 4: 'Pick up plate from the counter', 5: 'Move to the sink to the left of you', 6: 'Put plate inside the sink'}
#
# Annotation 2
# Place round plate with spatula in sink
# {0: 'go forward to end of counter with loaf of bread', 1: 'pick up spatula on back of counter to the right of bread', 2: 'go to round plate on counter to the left', 3: 'place spatula on round plate on counter to the left of the bread', 4: 'pick up plate with spatula', 5: 'go to sink to the left', 6: 'place round plate with spatula in sink'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5938750370410806
# {0: 'go to the counter to the right of the stove .', 1: 'pick up the spatula on the counter .', 2: 'turn left and walk to the counter .', 3: 'place the spatula on the plate on the counter .', 4: 'pick up the plate with the spoon on it .', 5: 'turn left and walk to the sink .', 6: 'place the plate with the spoon in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29509789991363017
# {0: 'walk forward and turn left to face the counter .', 1: 'pick up the spatula from the counter .', 2: 'turn left and walk to the counter .', 3: 'put the spatula on the plate .', 4: 'pick up the plate from the counter .', 5: 'turn left and walk to the sink .', 6: 'put the plate in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3976626266897693
# {0: 'walk forward and turn left to face the counter .', 1: 'pick up the spatula from the counter .', 2: 'move to the left a bit and face the counter', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'turn left and walk to the sink .', 6: 'place the plate and spatula in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.39986529147720035
# {0: 'walk forward then turn left to face the counter with the loaf of bread on it .', 1: 'pick up the spatula from the counter .', 2: 'turn left and take a step then turn right to face the counter .', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'turn left and walk to the sink .', 6: 'put the plate in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5218212727594117
# {0: 'move to the counter to the left of the stove', 1: 'pick up the spatula from the counter .', 2: 'move to the counter to the left of the sink', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'move to the sink to the left of you', 6: 'put the plate and spatula in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5218212727594117
# {0: 'move to the counter to the left of the stove', 1: 'pick up the spatula from the counter .', 2: 'move to the counter to the left of the sink', 3: 'put the spatula on the plate on the counter .', 4: 'pick up the plate with the spatula on it .', 5: 'move to the sink to the left of you', 6: 'put the plate and spatula in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190918_173742_042769_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-18/trial_T20190918_173742_042769
# Number of subgoals (exlcuding <No-op>): 13
# https://www.youtube.com/watch?v=7dHM--8H_ws
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Slice a tomato and place in skillet.
# {0: 'Turn left and walk forward to the table. Make a right to face the table. ', 1: 'Pick up the tomato from the table.', 2: 'Turn to the right and then left to walk around the table to the other side.', 3: 'Set the tomato on the table. ', 4: 'Pick up the yellow knife from the table. ', 5: 'Use the knife to slice the tomato. ', 6: 'Set the knife on the table to the right of the sponge. ', 7: 'Pick up a slice of tomato. ', 8: 'Turn around and go to the left. Then make another left at the oven.', 9: 'Place the tomato slice on the skillet.', 10: 'Pick up the skillet with the tomato slice.', 11: 'Turn to the left and walk over to the table. Turn left again to face the table.', 12: 'Place the skillet on the table with the tomato inside. '}
#
# Annotation 1
# Place a frying pan with a tomato slice in it onto the table.
# {0: 'Turn left then head towards the table against the wall.', 1: 'From the table pick up the tomato behind the green sponge.', 2: 'Turn right then head towards the door, turn left then head towards the refrigerator, then left, head towards the table.', 3: 'Place the tomato to the right of the green sponge.', 4: 'Pick up the knife behind the spoon on the table', 5: 'Cut the tomato into slices.', 6: 'Place the knife behind the tomato on the table.', 7: 'Pick up a tomato from the table.', 8: 'Turn left, then head towards the stove.', 9: 'Place the tomato into the frying pan on the stove.', 10: 'Pick up the frying pan from the stove.', 11: 'Turn left then head towards the table against the wall.', 12: 'Place the frying pan to the left of the plant onto the table.'}
#
# Annotation 2
# put a slice of tomato on a pan onto the black table
# {0: 'turn to the left go to the right', 1: 'pick up the tomato from the black table', 2: 'turn left go right left again facing the black table ', 3: 'put the tomato on top of the table', 4: 'pick up the knife from the table ', 5: 'slice the tomato in 2 pieces', 6: 'cut 1 half into many pieces', 7: 'pick up one piece of the tomato', 8: 'turn to the right go left face the stove', 9: 'put the piece of tomato in the pan that is on the stove', 10: 'pick up the pan from the stove', 11: 'turn to the left across the room', 12: 'put the pan on top of the black table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6159033281345802
# {0: 'turn left and walk to the table on the right .', 1: 'pick up a slice of tomato from the table .', 2: 'turn around , walk forward , turn left , walk to the table , turn left to face the table .', 3: 'put the tomato on the table', 4: 'pick up the knife on the table .', 5: 'slice the tomato on the table .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn around and walk to the stove .', 9: 'place the tomato in the pan on the stove .', 10: 'pick up the pan from the stove .', 11: 'turn left and walk to the white table .', 12: 'place the pan on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.10034344765687508
# {0: 'turn left and go to the wall , then turn right and go to the wall , turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn right and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk to the fridge then turn left and walk', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table .', 6: 'put the knife on the table', 7: 'pick up a slice of tomato .', 8: 'turn around and go to the counter to the right of the stove .', 9: 'put the tomato in the pan .', 10: 'pick up the pan with the knife in it .', 11: 'turn left and walk to the table .', 12: 'put the frying pan on the table .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1804957958004903
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn left and walk around the table to the other side of the table .', 3: 'put the tomato on the table', 4: 'pick up the knife on the table .', 5: 'cut the tomato into slices .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn around and walk to the counter to the right of the stove .', 9: 'place the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room to the black table .', 12: 'put the pan on the table'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28126237213837973
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato from the table .', 2: 'turn right and walk to the table , then turn left and walk across the room , then turn left and walk up to the fridge , turn left and walk up to the black table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the counter to the right of the stove .', 9: 'put the tomato in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room to face the black table .', 12: 'put the pan on the table'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2551828884959909
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn left and walk to the table , then turn left and walk across the room , then turn left and walk up to the fridge , turn left and walk up to the black table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table .', 5: 'slice the tomato on the table .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the stove .', 9: 'put the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk across the room , then turn left and walk over to the black round table .', 12: 'put the pan on the table'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14029675321944643
# {0: 'turn left and walk across the room , then turn right to face the table .', 1: 'pick up a slice of tomato .', 2: 'turn right and walk to the other side of the kitchen table .', 3: 'put the tomato on the table', 4: 'pick up the knife from the table', 5: 'cut the tomato into slices .', 6: 'place the knife on the table .', 7: 'pick up a slice of tomato from the table .', 8: 'turn left and walk to the stove .', 9: 'put the tomato slice in the pan on the stove .', 10: 'pick up the pan with the tomato slice in it .', 11: 'turn left and walk over to the black round table .', 12: 'put the pan on the table'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_030909_087593_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Fork-None-Drawer-30/trial_T20190908_030909_087593
# Number of subgoals (exlcuding <No-op>): 6
# https://www.youtube.com/watch?v=kXR2SJ4f47w
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a clean fork in the drawer
# {0: 'move forward towards the table', 1: 'pick up the fork', 2: 'move to the sink ahead', 3: 'drop the fork in the sink and rinse it', 4: 'move to the right of the sink', 5: 'place the fork in the drawer'}
#
# Annotation 1
# Wash a fork in the sink that was left on the counter to be place inside a drawer.
# {0: 'Move slightly to the left side of the  brown counter top island.', 1: 'Pick up the fork that is on the slanted corner. ', 2: 'Move across the kitchen to the sink. ', 3: 'Put the fork in the sink and wash it. Take the fork out of the sink. ', 4: 'Turn to the right and move slightly down the white counter top next to the sink. ', 5: 'Open the drawer that is under the far right of the counter and place the fork inside. C Close the drawer.'}
#
# Annotation 2
# wash the fork and put it in the drawer
# {0: 'go the island and approach the fork', 1: 'pick up the fork', 2: 'take the fork to the sink', 3: 'put the fork in the sink and take back out', 4: 'go the right of the sink at the counter', 5: 'put the knife in the drawer all the way to the right'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4193737480101046
# {0: 'turn right and walk to the counter .', 1: 'pick up the fork from the counter .', 2: 'turn around , go to the sink .', 3: 'place the fork in the sink .', 4: 'turn around and walk to the sink .', 5: 'place the fork in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127425558589731
# {0: 'turn to the right and go to the counter .', 1: 'pick up the fork from the counter .', 2: 'turn around and walk to the sink .', 3: 'wash the fork in the sink .', 4: 'turn around and walk to the counter .', 5: 'put the fork in the drawer'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38774385456396854
# {0: 'move to the island to the left of the fridge', 1: 'pick up the fork that is on the counter .', 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and then pick it back up and shut off the water .', 4: 'turn around and walk to the drawer under the counter .', 5: 'place the fork in the drawer'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46756059634945063
# {0: 'move to the table to the right of the fridge', 1: 'pick up the fork from the counter .', 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3992258400104756
# {0: 'move to the island counter to the left of the fridge', 1: "pick up the fork that ' s in front of you .", 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3992258400104756
# {0: 'move to the island counter to the left of the fridge', 1: "pick up the fork that ' s in front of you .", 2: 'turn right and walk to the sink .', 3: 'wash the fork in the sink and take it out', 4: 'turn around and walk back to the counter next to the sink .', 5: 'place the fork in the drawer'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_004008_377860_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-DiningTable-15/trial_T20190909_004008_377860
# Number of subgoals (exlcuding <No-op>): 6
# https://www.youtube.com/watch?v=YBJgvP4Uai8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold pan on the white table.
# {0: 'Turn right and go to the counter with the coffee maker, then turn right to face the counter with the toaster on it.', 1: 'Pick up the pan from the counter in front of you.', 2: 'Turn right and go toward the door, then turn left to face the fridge.', 3: 'Open the fridge, put the pan inside, and take it back out.', 4: 'Turn around and go forward toward the wall, then turn right to face the white table.', 5: 'Put the pan on the white table.'}
#
# Annotation 1
# Put a cold pan on the table.
# {0: 'Take a small step forward then turn right and walk to the counter then turn right.', 1: "Pick up the frying pan that's in front of you.", 2: 'Turn right and walk to the door then turn left to face the fridge.', 3: 'Chill the in the fridge then get it back out and close the door.', 4: 'Turn around and walk to the wall in front of you then turn right.', 5: "Put the pan on the table in front of you near the corner that's nearest you."}
#
# Annotation 2
# Chill the frying pan and put it on the table.
# {0: 'Turn right and walk to the counter.  Turn right again so you are facing the toaster.', 1: 'Pick up the frying pan in front of the toaster.', 2: 'Turn right and walk to the door.  Turn left and face the refrigerator.', 3: 'Open the refrigerator door and place the frying pan on the top shelf in the refrigerator and close the refrigerator door again.  Open the refrigerator door and remove the frying pan from the top shelf, then close the refrigerator door.', 4: 'Turn completely around, walk to the wall, turn to the right so you are facing the white table. ', 5: 'Place the frying pan on the table in front of the stool. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29484429714729943
# {0: 'go to the counter .', 1: 'pick up the pan from the counter .', 2: 'turn right , walk to the fridge .', 3: 'place the pan inside the fridge , remove it , and close the door .', 4: 'turn around , walk to the white table .', 5: 'place the pan on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27023861328315474
# {0: 'turn right and walk to the counter with the coffee maker .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and go to the refrigerator .', 3: 'put the pan in the fridge and close the door , then open the door and take the pan back out .', 4: 'turn around and walk to the wall , then turn right to face the white table .', 5: 'put the pan on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2942387499738611
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge on the left .', 3: 'open the fridge and put the pan inside and close the door and then open the door and take the pan back out .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the frying pan on the white table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24098098788990255
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge .', 3: 'put the pan in the fridge and shut the door and then open the door and take the pan out .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32702438945441714
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the fridge on the left .', 3: 'open the fridge , put the pan inside , close the fridge , open the refrigerator , take the pan out , close the refrigerator .', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.431911643588302
# {0: 'turn right and walk to the counter then turn right .', 1: 'pick up the pan with the knife in it .', 2: 'turn right and walk to the door , then turn left to face the fridge .', 3: 'open the fridge , put the pan inside , close the refrigerator , open the refrigerator , take the pan out , close the refrigerator', 4: 'turn around and walk to the wall then turn right .', 5: 'place the pan on the table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_072254_824822_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Ladle-Bowl-Cabinet-16/trial_T20190908_072254_824822
# Number of subgoals (exlcuding <No-op>): 7
# https://www.youtube.com/watch?v=GZAUr7AToYY
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a bowl with a spoon inside a cabinet.
# {0: 'Turn around and walk to the counter on the right.', 1: 'Pick up the spoon with the black handle near the edge of the counter.', 2: 'Turn left and hang a left at the wall to face the white table.', 3: 'Put the spoon inside the wooden bowl to the right of the tomato on the table.', 4: 'Pick up the bowl with the spoon on the table.', 5: 'Turn left, hang a left at end of the white table, walk around the angle of the counter and hang a left at the white stove to face the cabinets.', 6: 'Open the far right cabinet, place the bowl with a spoon inside and close the door.'}
#
# Annotation 1
# Put a bowl with a spoon in it into a cabinet.
# {0: 'Turn around 180 degrees and walk to the counter.', 1: 'Pick up the spoon on the counter. ', 2: 'Turn to the left 90 degrees and walk across the room, turning 90 degrees to the left to face the table when you reach it.', 3: 'Place the spoon in the brown cup.', 4: 'Pick up the brown cup with the spoon in it. ', 5: 'Turn to the left 90 degrees, then again after walking to a bit and cross the room, turning another 90 degrees to the left when you reach the end, and walk towards the counter.', 6: 'Put the bowl with the spoon in it into the lower cabinet. '}
#
# Annotation 2
# drop a plate with a spoon in it in the cupboard
# {0: 'turn around to the table', 1: 'pick up the spoon from the table', 2: 'move left to the table ', 3: 'drop the spoon in the plate', 4: 'pick up the plate from the table', 5: 'turn around and move to the cupboard', 6: 'drop the plate in the cupboard'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6712167562558268
# {0: 'turn left and walk to the counter .', 1: 'pick up the spoon from the counter .', 2: 'turn left and walk to the white table .', 3: 'place the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn left and walk back to the white cabinet .', 6: 'place the bowl in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6767985448506239
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the wall then turn left and walk to the wall then turn left to face the table .', 3: 'put the spoon in the bowl .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and walk to the counter then turn left and walk to the counter .', 6: 'place the bowl with the spoon in it in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk around the counter to the counter .', 6: 'open the cupboard and place the bowl with the spoon in it and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter , turning left to face the counter .', 6: 'open the cupboard that is in the cupboard .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter .', 6: 'open the cupboard that is in the right side of the bottom cabinet .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.624239412554308
# {0: 'turn around and walk to the counter .', 1: 'pick up the spoon on the counter .', 2: 'turn left and walk to the table .', 3: 'put the spoon in the bowl on the table .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn around and cross the room , then hang a left and walk over to the end of the counter .', 6: 'open the cupboard that is in the cupboard .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_181954_161870_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Watch-None-Dresser-205/trial_T20190907_181954_161870
# Number of subgoals (exlcuding <No-op>): 8
# https://www.youtube.com/watch?v=7uDr2uq7gLs
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two watches on the TV stand.
# {0: 'Walk to the glass dining table on the other side of the red chair.', 1: 'Pick up the watch between the statue and the compute on the table.', 2: 'Turn around and walk to the TV.', 3: 'Place the watch on the middle of the TV stand.', 4: 'Turn around and walk to the far side of the glass dining table.', 5: 'Pick up the watch next to the statue on the dining table.', 6: 'Walk to the TV on the other side of the room.', 7: 'Place the watch to the left of the other watch on the TV stand.'}
#
# Annotation 1
# place two watches on the tv stand
# {0: 'turn left and head towards the dining', 1: 'pick up the watch', 2: 'turn around and locate the tv', 3: 'drop the watch on the tv stand', 4: 'turn around and head for the dining', 5: 'pick up the wrist watch', 6: 'turn around and head for the television stand', 7: 'place the watch on the tv stand'}
#
# Annotation 2
# Put two watches on the tv stand.
# {0: "Walk to stand in front of the chair you can see in front of you to the left that's sitting in front of a statue and laptop.", 1: 'Pick up the watch you see on the table.', 2: 'Turn arouind and walk over to the tv you can see in front of you to the left,', 3: 'Put the watch in the middle of the tv stand.', 4: 'Walk to the opposite side of the table that where you got the first watch.', 5: 'Pick up the watch on that side of the table.', 6: 'Walk back over to the tv.', 7: 'Put this watch ot the left of the first watch.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38372701392389547
# {0: 'turn around , walk forward , turn right , walk to the table .', 1: 'pick up the watch off of the table .', 2: 'turn around , walk forward , turn left , walk to the tv stand .', 3: 'place the watch on the tv stand', 4: 'turn right , walk forward , turn left , walk to the table , turn left to face the table .', 5: 'pick up the watch off of the table .', 6: 'turn right , walk forward , turn left , walk to the tv stand .', 7: 'place the watch on the tv stand'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42289400252044634
# {0: 'turn around and walk to the table .', 1: 'pick up the watch from the table .', 2: 'turn around and walk to the tv .', 3: 'put the watch on the tv stand', 4: 'turn around and go to the dining table', 5: 'pick up the watch from the table .', 6: 'turn right and walk to the tv .', 7: 'put the watch on the tv stand'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining table on the right side .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining table .', 5: 'pick up the watch from the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining side of the dining table .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4127815015321787
# {0: 'walk to the dining room table', 1: 'pick up the watch on the table .', 2: 'turn around and walk to the tv .', 3: 'place the watch on the tv stand .', 4: 'turn around and walk to the dining side of the dining table .', 5: 'pick up the watch on the table .', 6: 'walk back over to the tv .', 7: 'place the watch on the tv stand .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_113100_297495_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-ArmChair-318/trial_T20190909_113100_297495
# Number of subgoals (exlcuding <No-op>): 4
# https://www.youtube.com/watch?v=1D8TGusmIaQ
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move book from dresser to chair
# {0: 'turn left, walk across the room to the dresser', 1: 'pick up the book that is on the dresser', 2: 'turn left, walk forward, turn left to face floral chair', 3: 'put the book on the chair'}
#
# Annotation 1
# Move a book from the desk to the floral armchair.
# {0: 'Turn right to walk to the desk.', 1: 'Pick up the green book from the desk.', 2: 'Turn around to walk to the floral armchair.', 3: 'Set the green book down on the floral armchair.'}
#
# Annotation 2
# Place a book on a chair.
# {0: 'Turn left and walk to the wooden desk ahead.', 1: 'Pick up the green book from the right side of the desk.', 2: 'Turn around and walk to the floral chair on the right against the wall.', 3: 'Put the book on the middle of the chair.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4962907202726068
# {0: 'turn left and walk forward to the dresser .', 1: 'pick up the book from the desk', 2: 'turn around and walk to the chair .', 3: 'place the book on the chair .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6364760663492011
# {0: 'turn left and walk to the desk .', 1: 'pick up the book from the desk', 2: 'turn around and walk to the chair .', 3: 'put the book on the chair'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8278087268979791
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair on the left .', 3: 'put the book on the chair .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7581098121154471
# {0: 'turn left and walk to the wooden desk .', 1: 'pick up the green book from the desk .', 2: 'turn around and walk to the chair with the credit card on it .', 3: 'put the book on the chair .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
chosen_valid_seen_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_valid_seen_task_ids, epoch_list = valid_seen_epoch_list, split = 'valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190909_150916_682139_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Pillow-None-DeskLamp-302/trial_T20190909_150916_682139
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/FHGCyxlwp8E
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Carry a purple pillow while turning on a lamp
# {0: 'Move to face the head board of the bed where the purple pillow is', 1: 'Pick up the purple pillow on the bed', 2: 'Carry the purple pillow over to the night stand with the lamp on top of it', 3: 'Turn on the lamp'}
#
# Annotation 1
# Look at a pillow under the light of a lamp.
# {0: 'Turn around and walk to the middle of the room, then turn right and walk to the window, then turn left to face the bed.', 1: 'Pick up the purple pillow from the bed.', 2: 'Turn left and walk to the nightstand to the right of the door.', 3: 'Turn on the lamp that is on the nightstand.'}
#
# Annotation 2
# Examine a pillow by the light of a table lamp
# {0: 'Turn left and go to the desk then turn left and go as far as the bed then turn right and go alongside the bed to the nightstand then turn left to face the nightstand', 1: 'Pick up the pillow from the bed', 2: 'Turn left and go past the end of the bed then turn right and go to the safe then turn left and go to the table with the lamp on it', 3: 'Turn on the lamp'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6661926765578389
# {0: 'turn left and walk to the bed , then turn right and walk to the bed .', 1: 'pick up the pillow on the bed', 2: 'turn left and walk to the small table on the right side of the room .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6035070034167676
# {0: 'turn around and walk to the side of the bed .', 1: 'pick up the pillow from the bed', 2: 'turn left and walk to the small lamp on the night stand .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5808770149807904
# {0: 'turn around and walk to the side of the bed .', 1: 'pick up the pillow on the bed .', 2: 'turn left and walk to the lamp on the small table .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5808770149807904
# {0: 'turn around and walk to the side of the bed .', 1: 'pick up the pillow on the bed .', 2: 'turn left and walk to the lamp on the small table .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5765579271939124
# {0: 'turn around and walk to the side of the bed .', 1: 'pick up the pillow on the bed .', 2: 'turn left and walk to the lamp on the small dresser .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5765579271939124
# {0: 'turn around and walk to the side of the bed .', 1: 'pick up the pillow on the bed .', 2: 'turn left and walk to the lamp on the small dresser .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_192636_561572_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Ladle-Pan-SinkBasin-4/trial_T20190908_192636_561572
# Number of subgoals (exlcuding <No-op>): 7
# https://youtu.be/KYG5NEfVbjM
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'OpenObject', 'PutObject', 'PickupObject', 'CloseObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a spoon in a pan on the counter.
# {0: 'Turn around and walk to the table with the  kitchen table.', 1: 'Pick up the spoon.', 2: 'Turn around and walk to the refrigerator.  ', 3: 'Open the refrigerator.  Put the spoon on the pan in the refrigerator.  ', 4: 'Grab the pan out of the refrigerator with the spoon.', 5: 'Close the door and turn left.  Walk to the oven and counter, turn left and walk to the wall.  Turn right before the microwave.', 6: 'Put the pan with the spoon on the counter.'}
#
# Annotation 1
# Put a pan with spoon in it, in the sink.
# {0: 'Turn around, move to the table in front of you.', 1: 'Pick up the spoon on the table.', 2: 'Turn around, bring the spoon to the fridge in front of you.', 3: 'Put the spoon in the pan in the fridge.', 4: 'Pick up the pan with spoon in the fridge. ', 5: 'Bring the pan back to the sink, behind you to the left.', 6: 'Put the pan with spoon in the sink. '}
#
# Annotation 2
# put pan and ladle into kitchen sink
# {0: 'walk to face wooden table', 1: 'pick up ladle from table', 2: 'walk to face fridge', 3: 'put ladle inside pan in fridge', 4: 'take out pan from fridge', 5: 'walk to face sink', 6: 'put ladle into sink basin'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5673198722275974
# {0: 'turn right and walk to the table .', 1: 'pick up the spoon from the table .', 2: 'turn left and walk to the fridge .', 3: 'place the pan in the pan .', 4: 'pick up the pan from the fridge .', 5: 'turn left and walk to the sink .', 6: 'place the pan in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7000700175052517
# {0: 'turn right and walk to the table .', 1: 'pick up the ladle with the spoon .', 2: 'turn around and walk to the fridge .', 3: 'open the fridge and put the spoon in the pan .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.583428477990235
# {0: 'turn right and walk to the brown table .', 1: 'pick up the ladle from the table .', 2: 'turn left and walk to the fridge .', 3: 'open the fridge and put the spoon in the pan .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6296392656936138
# {0: 'turn right and walk to the table .', 1: 'pick up the ladle from the table .', 2: 'turn left and walk to the fridge .', 3: 'open the fridge and put the spoon in the pan .', 4: 'pick up the pan with the spoon in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6296392656936138
# {0: 'turn right and walk to the table .', 1: 'pick up the ladle from the table .', 2: 'turn left and walk to the fridge .', 3: 'open the fridge and put the spoon in the pan .', 4: 'pick up the pan with the ladle in it and close the door .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6296392656936138
# {0: 'turn right and walk to the table .', 1: 'pick up the ladle from the table .', 2: 'turn left and walk to the fridge .', 3: 'open the fridge and put the spoon in the pan .', 4: 'pick up the pan with the ladle in it and close the door .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_013001_399963_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-AppleSliced-None-SideTable-21/trial_T20190907_013001_399963
# Number of subgoals (exlcuding <No-op>): 11
# https://youtu.be/ezmpJhbhCpI
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'SliceObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a sliced apple down on the black table at the end of the kitchen counter
# {0: 'turn left and walk forwards until your reach the sink on your left', 1: 'grab a butter knife out of the sink', 2: 'cut the apple in the sink', 3: 'back up a bit to face the sink again', 4: 'place the butter knife in the cabinet to the bottom left of the sink', 5: 'walk forwards a bit to the sink again', 6: 'grab an apple slice from out of the inside of the sink', 7: 'turn right and walk over to the fridge on your left', 8: 'place the apple slice in the fridge to cool, then take it back out', 9: 'turn around to move forwards a bit, then turn right and walk to the end of the room, then turn right to face the kitchen counter', 10: 'place the apple slice down on the black table at the end of the kitchen counter next to the salt shaker'}
#
# Annotation 1
# Put a piece of an apple on a stand.
# {0: 'Turn left and take a step then turn left to face the  sink.', 1: 'Pick up the knife in the middle of the sink.', 2: 'Cut up the apple in the lower right corner of the sink.', 3: 'Take a step back.', 4: 'Open the cupboard on the left and put the knife down there and close the cupboard.', 5: 'Walk back to the sink.', 6: 'Get the middle piece of apple.', 7: 'Take a few steps to your right to stand in front of the fridge.', 8: 'Open the fridge and put the apple on the top shelf then close the fridge and let it chill for a while before retrieving it and closing the door.', 9: 'Turn left and walk to the table then turn right and face the black stand to the left of the sink.', 10: 'Put the apple to the left of the salt shaker.'}
#
# Annotation 2
# Place the cool slice apple on the small black table.
# {0: 'Turn left and head towards the sink on your left.', 1: 'Pick up  the knife from the sink.', 2: 'Slice the green apple in the sink in half.', 3: 'Take a step backwards.', 4: 'Open the left cabinet below the sink and place the knife on the plate.', 5: 'Close the cabinet and step towards the sink.', 6: 'Pick up the middle apple slice from the sink.', 7: 'Turn right towards the fridge.', 8: 'Open the fridge, place the slice of apple in the fridge, let it cool, and take it out of the fridge.', 9: 'Turn left and walk towards the small black table to your right.', 10: 'Place the slice apple on the table.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3760281677987651
# {0: 'turn left and walk to the sink .', 1: 'pick up the knife in the sink .', 2: 'cut the apple in the sink .', 3: 'turn around , go to the sink .', 4: 'place the knife in the cabinet .', 5: 'turn right and walk to the sink .', 6: 'pick up a piece of apple from the sink .', 7: 'turn around , go to the fridge .', 8: 'place the apple in the fridge .', 9: 'turn around , walk to the white table .', 10: 'place the apple on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.040838239828840425
# {0: 'turn around and walk to the sink .', 1: 'pick up the knife in the sink .', 2: 'cut the apple in the sink .', 3: 'turn around and go to the white table .', 4: 'open the cabinet door and put the knife in it .', 5: 'turn right and walk to the sink .', 6: 'pick up a piece of apple from the sink .', 7: 'turn right and walk to the fridge .', 8: 'chill the apple in the fridge .', 9: 'turn left and walk to the small black table .', 10: 'place the apple on the black table .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.0591579678158787
# {0: 'turn left and walk to the sink .', 1: 'pick up the knife in the sink .', 2: 'slice the apple in the sink .', 3: 'turn around and walk to the white table on the right .', 4: 'open the cabinet door , put the knife in the cabinet , close the cabinet .', 5: 'turn right and go to the sink .', 6: 'pick up the apple from the sink .', 7: 'turn right and walk to the fridge .', 8: 'place the apple on the top shelf of the fridge , close the door , open the door , pick up the apple , and close the door .', 9: 'turn left and walk to the small black table to the left of the counter .', 10: 'place the apple on the black table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.0646834253264569
# {0: 'turn left and walk to the sink .', 1: 'pick up the knife from the sink .', 2: 'slice the apple in the sink .', 3: 'turn around and walk to the table in front of you .', 4: 'open the cabinet door , put the knife in the cabinet , close the cabinet .', 5: 'turn right and go to the sink .', 6: 'pick up a slice of apple from the sink .', 7: 'turn right and walk to the fridge .', 8: 'place the apple slice in the fridge and close the door , after a couple seconds open the fridge back up and remove the now chilled apple , then close the door .', 9: 'turn left and walk to the small black table to the left of the counter .', 10: 'place the apple on the table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09215762226661574
# {0: 'turn left and walk to the sink .', 1: 'pick up the knife from the sink .', 2: 'slice the apple in the sink .', 3: 'turn around and walk back to the counter to the left of the sink .', 4: 'open the cabinet door , put the knife in the cabinet , close the cabinet .', 5: 'turn right and go to the sink .', 6: 'pick up a slice of apple from the sink .', 7: 'turn right and walk to the fridge .', 8: 'place the apple slice in the fridge and close the door , after a couple seconds open the fridge back up and remove the now heated apple then close the door .', 9: 'turn left and walk to the small black table to the left of the counter .', 10: 'place the apple on the table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09215762226661574
# {0: 'turn left and walk to the sink .', 1: 'pick up the knife from the sink .', 2: 'slice the apple in the sink .', 3: 'turn around and walk back to the counter to the left of the sink .', 4: 'open the cabinet door , place the knife inside the cabinet , close the cabinet .', 5: 'turn right and go to the sink .', 6: 'pick up a slice of apple from the sink .', 7: 'turn right and walk to the fridge .', 8: 'place the apple slice in the fridge and close the door , then open the door and take the apple out .', 9: 'turn left and walk to the small black table to the left of the counter .', 10: 'place the apple on the table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074712_870488_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Knife-Bowl-SideTable-28/trial_T20190907_074712_870488
# Number of subgoals (exlcuding <No-op>): 7
# https://youtu.be/civKnURZaR0
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put the cup with the knife on the table
# {0: 'turn to your left turn to your left walk straight turn right at the stove walk straight to the sink', 1: 'pick up the knife on the counter ', 2: 'turn to the right turn to the right turn to the left turn to the left turn to the right walk forward', 3: 'pick up the cup on the table', 4: 'put the knife into the cup ', 5: 'turn to the right turn to the left walk forward turn to the right ', 6: 'walk forward put the cup and knife on the table '}
#
# Annotation 1
# Put a knife in a blue container onto the black table in the corner.
# {0: 'Turn around and walk across the room to the oven, then turn right and walk to the counter to the right of the sink.', 1: 'Pick up the knife that is on the counter to the right of the sink, near the sponge.', 2: 'Turn right and walk across the room to the green table.', 3: 'Place the knife inside of the blue container on the table.', 4: 'Pick up the blue container on the table with the knife in it.', 5: 'Turn right and walk across the room to the black table in the corner.', 6: 'Place the blue container with the knife in it onto the black table in the corner.'}
#
# Annotation 2
# Moving a container with a knife in it
# {0: 'Turn around and head to the sink', 1: 'Grab the large knife that is to the right of the sink', 2: 'Walk to the table on your right', 3: "Place the knife into the container that's on the table", 4: 'Grab the container with the knife inside', 5: 'Turn right and head to the small black table in the corner of the room', 6: 'Place the container on the small black table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46423354530946115
# {0: 'turn left , walk to the sink .', 1: 'pick up the knife on the counter .', 2: 'turn around , go to the white table .', 3: 'place the knife in the bowl with the knife in it .', 4: 'pick up the bowl with the spoon in it .', 5: 'turn right , walk to the table .', 6: 'place the bowl with the knife in the bowl .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22873333269853346
# {0: 'turn around and go to the counter to the right of the sink .', 1: 'pick up the knife from the counter .', 2: 'turn around and go to the round black table .', 3: 'put the knife in the bowl', 4: 'pick up the bowl with the knife in it .', 5: 'turn right and walk to the black table .', 6: 'put the potato in the bowl on the table .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35329706330066335
# {0: 'turn around and walk to the stove , then turn right and walk to the sink .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the black table .', 3: 'put the knife in the bowl on the table .', 4: 'pick up the bowl with the knife in it .', 5: 'turn right and walk over to the black table in the corner of the room .', 6: 'put the potato in the bowl on the left side of the black table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2575229639388146
# {0: 'turn around and go to the counter to the left of the sink .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the table .', 3: 'put the knife in the bowl', 4: 'pick up the bowl with the knife in it .', 5: 'turn around and walk to the black table in the corner .', 6: 'put the potato in the bowl on the black table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24422468522836485
# {0: 'turn around and go to the counter to the left of the sink .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk back to the table .', 3: 'put the knife in the bowl', 4: 'pick up the bowl with the knife in it .', 5: 'turn around and walk to the black table in the corner .', 6: 'put the blue bowl on the black table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16081270381026946
# {0: 'turn around and go to the sink .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk back to the table .', 3: 'put the knife in the bowl', 4: 'pick up the bowl with the knife in it .', 5: 'turn around and walk to the black table in the corner .', 6: 'put the potato in the bowl on the black table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_102840_789300_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-KeyChain-None-Sofa-202/trial_T20190908_102840_789300
# Number of subgoals (exlcuding <No-op>): 8
# https://youtu.be/Dg9dzxXmxB4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two sets of keys on the couch.
# {0: 'Turn around and walk across the room to the side table on your right.', 1: 'Pick the set of keys up off the table.', 2: 'Turn right and walk to the furthest end of the couch on your left.', 3: 'Set the keys on the right couch cushion to the right of the laptop.', 4: 'Turn around and walk to the TV stand on the other side of the room.', 5: 'Pick up the set of keys on the right of the laptop.', 6: 'Turn around and move back to the right side of the couch.', 7: 'Set the second set of keys down on the couch in front of the laptop where the cushions meet.'}
#
# Annotation 1
# Place two sets of keys on the sofa.
# {0: 'Turn around and head towards the wall, then make a right and go to the table.', 1: 'Pick up the keys on the table next to the box.', 2: 'Turn around and step forward, then turn left and go center of the room and turn left in front of the sofa.', 3: 'Place the key on the sofa to the bottom right of the laptop.', 4: 'Turn around,walk forward and go in the space between the TV stand and the coffee table.', 5: 'Pick up the keys off the TV stand to the right of the laptop.', 6: 'Return to the center of the sofa.', 7: 'Place the key to the left of the key already on the sofa.'}
#
# Annotation 2
# TO move two sets of keys to the couch.
# {0: 'Turn to the left and face the table at the end of the couch.', 1: 'Pick up the keys on the end table.', 2: 'Turn right and walk forward and turn to the left to face the right end of the couch.', 3: 'Place the keys on the right side of the couch.', 4: 'Turn around and walk across the room to face the TV stand.', 5: 'Pick up the keys on the TV stand.', 6: 'Turn around and walk forward to face the couch.', 7: 'Place the keys on the couch next to the first set of keys.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4309213841171784
# {0: 'turn around , walk to the wall , turn right to face the table .', 1: 'pick up the keys off of the table .', 2: 'turn around and walk to the couch .', 3: 'place the keys on the couch', 4: 'turn left and walk to the tv stand', 5: 'pick up the keys that are on the tv stand', 6: 'turn around and walk to the couch .', 7: 'place the keys on the couch'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1732711189254247
# {0: 'turn around and walk to the wall , then turn right and walk up to the white table .', 1: 'pick up the keys from the table .', 2: 'turn around and go to the front of the sofa .', 3: 'put the keys on the couch', 4: 'turn around and walk to the tv stand .', 5: 'pick up the keys from the tv stand', 6: 'turn around and walk to the sofa .', 7: 'put the keys on the couch'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29466749220939537
# {0: 'turn around and walk to the wall , then turn right and walk up to the wooden table .', 1: 'pick up the keys from the table .', 2: 'turn around and walk forward , then hang a left and walk over to the blue couch .', 3: 'put the set of keys on the front edge of the right side of the couch .', 4: 'walk to face tv stand', 5: 'pick up the keys from the tv stand .', 6: 'turn around and walk to the sofa .', 7: 'put the keys on the couch to the right of the laptop .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.15015827488552808
# {0: 'turn around and walk to the wall , then turn right and walk up to the wooden table .', 1: 'pick up the keys from the table .', 2: 'turn around and walk back over to the blue couch .', 3: 'put the keys on the sofa', 4: 'walk to the tv stand', 5: 'pick up the keys from the tv stand .', 6: 'turn around and walk to the sofa .', 7: 'put the keys on the couch to the right of the keys .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2245439863527501
# {0: 'turn around and walk to the wall , then turn right and walk up to the wooden table .', 1: 'pick up the keys on the table .', 2: 'turn around and walk back over to the blue couch .', 3: 'put the keys on the right side of the blue couch .', 4: 'walk to the tv stand', 5: 'pick up the keys from the tv stand .', 6: 'turn around and walk to the sofa .', 7: 'put the keys on the couch to the right of the keys .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22430574886172375
# {0: 'turn around and walk to the wall , then turn right and walk up to the wooden table .', 1: 'pick up the keys on the table .', 2: 'turn around and walk back over to the front of the blue couch .', 3: 'put the keys on the left side of the blue couch .', 4: 'walk to the tv stand', 5: 'pick up the keys from the tv stand .', 6: 'turn around and walk to the sofa .', 7: 'put the keys on the couch to the right of the keys .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_031040_889814_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Plunger-None-Cabinet-414/trial_T20190909_031040_889814
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/TpFjTu0nRoA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a plunger to the cabinet.
# {0: 'Turn around and face the toilet.', 1: 'Pick up the plunger from the left side.', 2: 'Carry the plunger and turn to the right, then face the sink on the left.', 3: 'Open the bottom cabinet, second from the left, and place the plunger inside.'}
#
# Annotation 1
# put the plunger away in the cabinet
# {0: 'turn right, walk to the wall, turn right to face the toilet', 1: 'pick up the plunger to the left of the toilet', 2: 'turn right, walk forward a few steps, turn right, take a few steps, turn around, walk to counter', 3: 'open cabinet under sink, put the plunger in the cabinet, close the cabinet'}
#
# Annotation 2
# Put the plunger under the sink.
# {0: 'Turn around and go to the left corner of the room, past the toilet paper holder. ', 1: 'Pick up the plunger to the left of the toilet bowl cleaner, on the floor, in the corner. ', 2: 'Turn around and go to the cabinets under the sink to your left. ', 3: 'Place the plunger under the sink, in the second cabinet from the left, under the sink. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.34487775908269613
# {0: 'turn right , walk to the toilet .', 1: 'pick up the plunger on the floor .', 2: 'turn right and walk to the sink .', 3: 'place the plunger in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.36376204725216965
# {0: 'turn around and walk to the toilet .', 1: 'pick up the plunger on the floor .', 2: 'turn right and walk to the cabinet under the sink .', 3: 'open the second cabinet door from the left and put the plunger inside and close the door .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4662430966599677
# {0: 'turn around and face the toilet .', 1: 'pick up the plunger from the floor .', 2: 'turn right and walk to the sink on the right .', 3: 'open the second cabinet door from the left and put the plunger inside and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4662430966599677
# {0: 'turn around and face the toilet .', 1: 'pick up the plunger from the floor .', 2: 'turn right and walk to the sink on the right .', 3: 'open the second cabinet door from the left and put the plunger inside and close the door .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4662430966599677
# {0: 'turn around and face the toilet .', 1: 'pick up the plunger from the floor .', 2: 'turn right and walk to the sink on the right .', 3: 'open the second cabinet door from the left and put the plunger inside and close the door .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.475362442067502
# {0: 'turn around and face the toilet .', 1: 'pick up the plunger from the floor .', 2: 'turn right and walk to the sink on the right .', 3: 'open the second cabinet door from the plunger in the cabinet and close the door'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_140701_251653_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Cloth-None-Drawer-423/trial_T20190908_140701_251653
# Number of subgoals (exlcuding <No-op>): 6
# https://youtu.be/LQpzGDzww1A
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Get wash rag wet and put it away in drawer.
# {0: 'Turn and go to the counter to the left of the sink.', 1: 'Pick up the green wash rag that is on the counter to the left of the sink.', 2: 'With the wash rag in hand turn and go to the sink.', 3: 'Place the wash rag in the sink.  Turn the water on to get the wash rag wet.  Turn the water off and pick up the wash rag.', 4: 'With the wash rag in hand move to your left to where the toilet paper is on the counter.', 5: 'Open the drawer right under where the toilet paper is on the counter. Place the wash rag in the drawer and shut the drawer.'}
#
# Annotation 1
# Put a cleaned rag in a drawer.
# {0: 'Turn left, go to door, turn right, got to counter left of sink. ', 1: 'Pick up rag on counter. ', 2: 'Bring the rag to the sink on the right.', 3: 'Wash the rag in the sink. ', 4: 'Bring the cleaned rag to the drawer under the sink, to the left.', 5: 'Open that third drawer from the right and put the cleaned rag in there. '}
#
# Annotation 2
# Put a clean cloth in a drawer.
# {0: 'Go left to face the mirror over the counter.', 1: 'Pick the green cloth up from the counter.', 2: 'Move to the left and face the sink.', 3: 'Put the cloth in the sink and turn the water on and then off and pick the cloth up again.', 4: 'Move back and face the drawers under the counter and on the left.', 5: 'Put the cloth in the bottom drawer and shut the drawer.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.37032382050422197
# {0: 'turn left and walk to the counter .', 1: 'pick up the rag on the counter .', 2: 'turn right and walk to the sink .', 3: 'place the rag in the sink .', 4: 'turn around and walk back to the sink .', 5: 'open the drawer and put the rag in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33873002520639145
# {0: 'turn left and walk to the counter , then turn right and walk up to the counter .', 1: 'pick up the dirty rag on the counter .', 2: 'turn right and walk to the sink .', 3: 'put the rag in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean rag .', 4: 'turn around and walk forward , then turn left and take a step forward , then turn left and walk up to the counter .', 5: 'put the rag in the bottom drawer .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35912313793857126
# {0: 'turn left , go forward , turn right , go forward to the counter .', 1: 'pick up the dirty rag on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'place the dirty rag in the sink , turn on the water , turn off the water and pick up the cloth .', 4: 'move to the right a bit and face the drawer', 5: 'open the bottom drawer and put the cloth in it'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.41365881244425606
# {0: 'turn left , go forward , turn right , go forward to the counter .', 1: 'pick up the dirty wash cloth on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'put the cloth in the sink , turn on the water , turn off the water , and pick up the cloth .', 4: 'move to the right side of the sink cabinet', 5: 'open the bottom drawer and put the cloth in there then close the drawer .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3687223043562195
# {0: 'turn left , go forward , turn right , go forward to the counter .', 1: 'pick up the dirty towel on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'place the cloth in the sink , turn on the water , turn off the water and pick up the cloth .', 4: 'move to the sink to the right of the sink', 5: 'open the bottom drawer and put the cloth in there then close the drawer .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.34884394312178185
# {0: 'turn left , go forward , turn right , go to the counter', 1: 'pick up the dirty towel on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'place the cloth in the sink , turn on the water , turn off the water and pick up the cloth .', 4: 'move to the sink to the right of the sink', 5: 'open the bottom drawer and put the cloth in there then close the drawer .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_055649_717880_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-SoapBar-None-GarbageCan-418/trial_T20190909_055649_717880
# Number of subgoals (exlcuding <No-op>): 8
# https://youtu.be/C9gkb77sF14
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two bars of soap into the trash can.
# {0: 'Make a left to reach the sink.', 1: 'Pick up the pink soap next to the sink on the left.', 2: 'Turn around and walk to the trash can next to the toilet.', 3: 'Put the pink soap in the trash can.', 4: 'Turn around to walk to the sink.', 5: 'Pick up the bar of pink soap in the sink basin.', 6: 'Turn around the walk to the trash can.', 7: 'Put the other bar of pink soap in the trash can.'}
#
# Annotation 1
# Put two soap in the trash bin
# {0: 'Turn right then face the sink  counter on your left', 1: 'Pick up the soap on the counter', 2: 'Turn left then head to the trash bin ', 3: 'Put the soap in the trash bin', 4: 'Turn left then head to the sink ', 5: 'Pick up the soap in the sink', 6: 'Turn around then head to the trash bin ', 7: 'Put the soap in the trash bin'}
#
# Annotation 2
# Putting two bars of soap in the trash can
# {0: 'Turn around and go to the left of the sink', 1: 'Grab the bar of soap off of the counter', 2: 'Turn around and go to the trash can', 3: 'Put the soap in the trash can', 4: 'Turn around and go to the sink', 5: 'Grab the bar of soap out of the sink', 6: 'Turn around and go to the trash can', 7: 'Put the soap in the trash can'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5724493469203622
# {0: 'turn right and walk to the sink .', 1: 'pick up the soap bar of soap on the counter .', 2: 'turn around and walk to the toilet .', 3: 'place the soap in the trash bin .', 4: 'turn left and walk to the sink .', 5: 'pick up the soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'place the soap in the trash bin .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4092575783857851
# {0: 'turn right and walk to the wall , then turn right and walk up to the counter .', 1: 'pick up the bar of soap from the counter .', 2: 'turn around and walk to the trash can .', 3: 'put the soap in the trash can .', 4: 'turn around and walk to the sink .', 5: 'pick up the bar of soap from the sink .', 6: 'turn around and walk to the trash can .', 7: 'put the soap in the trash can .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.36572570993934533
# {0: 'turn around and walk to the wall , then turn right and walk up to the counter .', 1: 'pick up the bar of soap on the counter .', 2: 'turn around and walk towards the trash bin .', 3: 'place the bar of soap in the trash bin .', 4: 'turn around and walk to the sink .', 5: 'pick up the bar of soap in the sink .', 6: 'turn around and walk to the trash bin in the corner of the room .', 7: 'put the bar of soap in the trash bin .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3579436206913366
# {0: 'turn around and walk to the sink .', 1: 'pick up the bar of soap from the counter .', 2: 'turn around and walk over to the black bin in the corner of the room', 3: 'place the bar of soap in the trash bin .', 4: 'turn around and walk to the sink .', 5: 'pick up the bar of soap from the sink .', 6: 'turn around and walk to the trash bin in the corner of the room .', 7: 'place the bar of soap in the trash bin .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28333685307960343
# {0: 'turn around and walk to the far left side of the bathroom counter .', 1: 'pick up the bar of soap from the counter .', 2: 'turn around and walk towards the trash bin .', 3: 'place the bar of soap into the trash bin .', 4: 'turn around and walk to the sink .', 5: 'pick up the bar of soap from the sink .', 6: 'turn around and walk to the trash bin in the corner of the room .', 7: 'place the bar of soap in the trash bin .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28333685307960343
# {0: 'turn around and walk to the far left side of the bathroom counter .', 1: 'pick up the bar of soap from the counter .', 2: 'turn around and walk towards the trash bin .', 3: 'place the bar of soap into the trash bin .', 4: 'turn around and walk to the sink on the left .', 5: 'pick up the bar of soap from the sink .', 6: 'turn left and walk to the wall , then turn left and walk up to the small black bin .', 7: 'place the bar of soap in the trash bin .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_151802_277016_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-AppleSliced-None-DiningTable-27/trial_T20190907_151802_277016
# Number of subgoals (exlcuding <No-op>): 12
# https://youtu.be/P9wm8lJwxT4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Slice an apple or vegetable followed by rinsing it
# {0: 'Turn to the right and walk to the white kitchen table on your left', 1: 'Pick up the yellow handled knife on the table', 2: 'Walk to the right end of the kitchen table and face it', 3: 'Slice a apple on the table', 4: 'Walk back to the left side of the kitchen table', 5: 'Place the knife on top of the green lettuce head', 6: 'Walk to the right end of the kitchen table and face it', 7: 'Pick up the slice of apple on the table', 8: 'Turn around and walk to the left and face the kitchen sink', 9: 'Place the slice of apple in the sink and rinse it, then remove it', 10: 'Turn around and walk to the end of the kitchen and face the table on the right', 11: 'Place the apple slice back on the table'}
#
# Annotation 1
# Put a washed slice of apple on the table.
# {0: 'Move to the right and go to the table.', 1: 'Pick up the knife with the yellow handle.', 2: 'Move right to the other end of the table.', 3: 'Slice the apple on the table.', 4: 'Move back to the left side of the table.', 5: 'Put the knife down on the table.', 6: 'Move back to the left side of the table.', 7: 'Pick up a slice of apple.', 8: 'Turn right and go to the sink.', 9: 'Rinse the apple slice in the sink.', 10: 'Turn around and go back to the table.', 11: 'Put the apple slice on the table.'}
#
# Annotation 2
# Cut an apple with a knife, wash the apple slice, place the apple slice on the table
# {0: 'Walk towards the direction of the sink, hang a left at the end of the table with a knife with a yellow handle on it.', 1: 'Pick up the knife with the yellow handle.', 2: 'Turn to your right and walk to the other end of the table where there is a yellow apple.', 3: 'Slice the apple with the knife.', 4: 'Turn to your left and walk to the other end of the table.', 5: 'Place the knife against the head of lettuce, blade end down.', 6: 'Turn to your right to the other end of the table.', 7: 'Pick up the section of cut apple closest to you.', 8: 'Turn around and walk to the sink.', 9: 'Place the section of apple in the front left side of the sink, turn on the faucet, partially fill the sink with water to wash the apple; turn off the faucet, empty the sink, pick up the apple.', 10: 'Turn to your left and walk to stand in front of the middle of the table.', 11: 'Put the apple slice to the right of the gray glass and directly in front of the wide end of the spatula.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5823918508140112
# {0: 'turn right and walk to the white table .', 1: 'pick up the knife on the table .', 2: 'turn right and walk to the white table .', 3: 'cut the apple on the table .', 4: 'turn left and walk to the white table .', 5: 'place the knife on the table .', 6: 'turn right and walk to the white table .', 7: 'pick up the apple slice of the apple .', 8: 'turn right and walk to the sink .', 9: 'place the apple in the sink .', 10: 'turn around and walk to the white table .', 11: 'place the apple on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07898275435937688
# {0: 'turn right and walk to the table .', 1: 'pick up the knife from the table .', 2: 'turn right and go to the white table .', 3: 'cut the apple on the table into slices .', 4: 'turn to the left and face the white table .', 5: 'put the knife on the table', 6: 'turn right and go to the white table .', 7: 'pick up the apple from the table .', 8: 'turn around and walk to the sink .', 9: 'wash the apple in the sink .', 10: 'turn around and go to the white table .', 11: 'put the apple slice on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1278226605080062
# {0: 'turn right and walk to the white table on the left .', 1: 'pick up the knife on the table .', 2: 'turn to the right and go to the table .', 3: 'cut the apple on the table into slices .', 4: 'turn left and go to the table .', 5: 'put the knife on the table .', 6: 'turn right and walk to the white table .', 7: 'pick up a slice of the apple .', 8: 'turn around and walk to the sink on the left .', 9: 'wash the apple in the sink and then pick it back up and shut off the water .', 10: 'turn around and walk to the white table on the right .', 11: 'put the apple slice on the table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11236460088644946
# {0: 'turn right and walk to the table on the left .', 1: 'pick up the knife on the table .', 2: 'turn to the right and go to the table', 3: 'cut the apple on the table into slices .', 4: 'turn left and go to the table .', 5: 'put the knife on the table', 6: 'turn right , go forward , turn left at the table', 7: 'pick up a piece of the apple .', 8: 'turn around and walk to the sink on the left .', 9: 'wash the apple in the sink and then pick it back up and shut off the water .', 10: 'turn around and walk to the white table on your right .', 11: 'put the apple slice on the table in front of the salt shaker .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13711004308277533
# {0: 'turn right and walk to the left side of the white table .', 1: 'pick up the knife on the table .', 2: 'turn to the right and go to the table', 3: 'cut the apple on the table into slices .', 4: 'turn left and go to the table .', 5: 'put the knife on the table .', 6: 'turn right , go forward , turn left at the table', 7: 'pick up a slice of the apple .', 8: 'turn around and walk to the sink on the left .', 9: 'wash the apple in the sink and then pick it back up and shut off the water .', 10: 'turn around and walk to the white table on your right .', 11: 'put the apple slice on the table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13711004308277533
# {0: 'turn right and walk to the left side of the white table .', 1: 'pick up the knife on the table .', 2: 'turn to the right and go to the table', 3: 'cut the apple on the table into slices .', 4: 'turn left and go to the table .', 5: 'place the knife on the table .', 6: 'turn right , go forward , turn left at the table', 7: 'pick up a slice of the apple .', 8: 'turn around and walk to the sink on the left .', 9: 'wash the apple in the sink and then pick it back up and shut off the water .', 10: 'turn around and walk to the white table on your right .', 11: 'put the apple slice on the table'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_032318_169393_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-SideTable-329/trial_T20190909_032318_169393
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/R8fs1wdTMqI
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a mug to a nightstand.
# {0: 'Turn to the left and walk around the bed. Turn to the right and walk to the desk,', 1: 'Pick up the mug from the desk. ', 2: 'Turn to the left then turn right  to head to the night stand.', 3: 'Place the mug on the night stand. '}
#
# Annotation 1
# Move a coffee mug to a nightstand.
# {0: 'Turn left and walk towards the wall, then hang a right and walk forward, turn left and walk up to the table.', 1: 'Pick up the black mug off of the table.', 2: 'Turn left and walk over to the window, then turn left again and walk up to the nightstand next to the bed.', 3: 'Put the coffee mug on the nightstand to the left of the clock.'}
#
# Annotation 2
# to pick up a coffee mug and put it on the night stand
# {0: 'look down at the bed then turn left  walk forward to the edge of the bed and turn right then turn left towards the desk ', 1: 'pick up the coffee mug from the desk ', 2: 'turn left and walk towards the window  then turn left and walk towards the night stand ', 3: 'place the coffee mug on the night stand '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5180036033337413
# {0: 'turn left , walk forward , turn right , walk to the table .', 1: 'pick up the mug with the spoon in it .', 2: 'turn left and walk to the bed , then turn left and walk to the bed .', 3: 'put the mug with the spoon in the middle of the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2976012604039986
# {0: 'turn left and walk to the table .', 1: 'pick up the mug with the pen in it .', 2: 'turn around and walk to the nightstand .', 3: 'put the mug with the pen in it on the nightstand .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5314548586561022
# {0: 'turn left and walk to the end of the bed , then turn right and walk to the desk .', 1: 'pick up the mug with the pen inside from the table .', 2: 'turn around and walk to the wall , then turn left and walk to the nightstand .', 3: 'place the mug on the nightstand .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5309704895881034
# {0: 'turn left and walk to the end of the bed , then turn right and walk to the desk .', 1: 'pick up the mug with the pencil inside from the table .', 2: 'turn around and walk to the nightstand to the right of the bed .', 3: 'place the mug on the nightstand .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3754972707698503
# {0: 'turn left and go to the desk .', 1: 'pick up the mug with the pencil inside it .', 2: 'turn around and walk to the nightstand to the right of the bed .', 3: 'put the mug on the nightstand .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.40901235492172106
# {0: 'turn left and go to the desk .', 1: 'pick up the mug with the pencil inside it .', 2: 'turn around and walk to the wall , then turn left and walk to the nightstand .', 3: 'put the mug on the nightstand .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
chosen_valid_unseen_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_valid_unseen_task_ids, epoch_list = valid_unseen_epoch_list, split = 'valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190909_123918_983775_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123918_983775
# Number of subgoals (exlcuding <No-op>): 12
# https://youtu.be/1Ha8RLnfsBg
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'SliceObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a cooked potato slice in the fridge
# {0: 'move around to the table', 1: 'pick up a knife from the table', 2: 'move forward to the fridge', 3: 'slice the potato in the fridge', 4: 'turn around to the shelf ', 5: 'place the knife on the shelf', 6: 'turn right to the fridge', 7: 'pick up a slice of the potato', 8: 'move right to the oven', 9: ' cook the potato in the oven and take it out', 10: 'move left to the fridge', 11: 'place the cooked slice in the fridge'}
#
# Annotation 1
# To heat a potato slice and place it in the fridge.
# {0: 'Turn around and cross the room and turn around to face the end of the center table.', 1: 'Pick up the knife on the counter.', 2: 'Walk to the right past the center table and turn right to face the fridge.', 3: 'Cut the potato on the bottom in the fridge into slices.', 4: 'Turn left and step forward to face the shelves.', 5: 'Place the knife on the shelf.', 6: 'Turn right to face the fridge.', 7: 'Pick up a slice of potato in the fridge.', 8: 'Turn right and step forward and turn left to face the microwave.', 9: 'Heat the potato slice in the microwave and remove it.', 10: 'Turn left and walk forward and turn right to face the fridge.', 11: 'Place the potato slice in the fridge.'}
#
# Annotation 2
# Put a cooked slice of potato in the fridge.
# {0: 'Turn around, go across the room and turn right to face the end of the counter.', 1: 'Pick up the knife on the counter by the statue.', 2: 'Go back across the room to the fridge.', 3: 'Cut the potato on the second shelf in the fridge.', 4: 'Turn around and go to the brown shelf on the left.', 5: 'Put the knife on the top shelf.', 6: 'Go back to the fridge.', 7: 'Pick up a slice of potato in the fridge.', 8: 'Turn right and go to the microwave.', 9: 'Cook the slice of potato in the microwave and pick it back up.', 10: 'Turn left and go back to the fridge.', 11: 'Put the cooked slice of potato in the fridge between the mug and the potato.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4438454983371682
# {0: 'turn right , walk to the counter , turn right , go to the counter .', 1: 'pick up the butter knife off of the counter .', 2: 'turn right , walk to the fridge .', 3: 'open the fridge and put the potato on the shelf .', 4: 'turn around , walk to the shelf', 5: 'place the knife on the shelf', 6: 'turn around , walk forward , turn left , walk to the fridge .', 7: 'open the fridge and pick up the potato slice of the fridge .', 8: 'turn right , walk to the microwave .', 9: 'heat the potato in the microwave .', 10: 'turn around , go to the fridge .', 11: 'place the potato slice in the fridge .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4058413176341219
# {0: 'turn around and go to the island .', 1: 'pick up the knife from the counter .', 2: 'turn right and walk to the fridge .', 3: 'open the fridge and slice the potato in the fridge .', 4: 'turn around and go to the shelves .', 5: 'put the knife on the shelf', 6: 'turn around and go to the fridge .', 7: 'open the fridge and remove a slice of potato .', 8: 'turn right and walk to the microwave .', 9: 'heat the potato in the microwave .', 10: 'turn left and walk to the fridge .', 11: 'put the potato slice in the fridge'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4665222983545947
# {0: 'turn around and walk to the end of the kitchen island , then turn right and face the island .', 1: 'pick up the knife on the counter .', 2: 'turn right and walk to the fridge .', 3: 'open the fridge and slice the potato on the second shelf .', 4: 'turn around and walk to the shelves on the right .', 5: 'place the knife on the shelf .', 6: 'turn around and walk to the fridge .', 7: 'open the fridge and take a potato slice out of the fridge .', 8: 'turn right and walk to the microwave .', 9: 'heat the potato in the microwave and then remove it .', 10: 'turn left and walk to the fridge .', 11: 'put the potato in the fridge'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3498812683152477
# {0: 'turn around and walk to the end of the kitchen island , then turn right and face the kitchen island .', 1: 'pick up the knife from the counter .', 2: 'turn right , go to the fridge', 3: 'open the fridge and slice the potato inside', 4: 'turn around and go to the shelves .', 5: 'put the knife on the shelf', 6: 'turn around and walk to the fridge .', 7: 'open the fridge and remove a slice of potato .', 8: 'turn right and walk to the microwave above the stove .', 9: 'heat the potato in the microwave and then remove it .', 10: 'turn left and walk to the fridge .', 11: 'put the potato slice in the fridge .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3606089281571099
# {0: 'turn around and walk to the end of the kitchen island , then turn right and face the kitchen island .', 1: 'pick up the knife from the counter .', 2: 'turn right , go forward , turn left , go forward , turn right at the fridge', 3: 'open the fridge and slice the potato inside', 4: 'turn around and go to the shelves .', 5: 'put the knife on the shelf', 6: 'turn around and walk back to the fridge .', 7: 'open the fridge and remove a slice of potato .', 8: 'turn right and walk to the microwave .', 9: 'heat the potato in the microwave and then remove it .', 10: 'turn left and walk to the fridge .', 11: 'put the potato slice in the fridge .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.37256784752720434
# {0: 'turn around and walk to the end of the kitchen island , then turn right and face the counter .', 1: 'pick up the knife from the counter .', 2: 'turn right , go to the fridge', 3: 'open the fridge and slice the potato inside', 4: 'turn around and go to the shelves .', 5: 'put the knife on the shelf', 6: 'turn around and walk to the fridge .', 7: 'open the fridge and remove a slice of potato .', 8: 'turn right and walk to the microwave .', 9: 'heat the potato in the microwave and then remove it .', 10: 'turn left and walk to the fridge .', 11: 'put the potato slice in the fridge .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_123732_489327_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123732_489327
# Number of subgoals (exlcuding <No-op>): 10
# https://youtu.be/4V2hh2cw4No
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'SliceObject', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To heat a potato slice and place it in the fridge.
# {0: 'Walk around the center table to the left and turn right to face the knife on the table.', 1: 'Pick up the knife on the table.', 2: 'Turn left and walk forward and turn around to the right to face the trash can.', 3: 'Cut the potato in the trash can into slices.', 4: 'Place the knife in the trash can.', 5: 'Pick up a slice of potato in the trash can.', 6: 'Turn left and walk to the right around the table and turn left to face the microwave.', 7: 'Heat the potato slice in the microwave and remove it.', 8: 'Turn left and step forward and turn right to face the fridge.', 9: 'Place the potato slice in the fridge.'}
#
# Annotation 1
# Put a cooked slice of potato in the fridge.
# {0: 'Go left and around the counter to the back of the sink.', 1: 'Pick up the knife on the counter.', 2: 'Go to the end of the counter and face the trash can.', 3: 'Cut the potato in the trash can.', 4: 'Put the knife in the trash can.', 5: 'Pick up a slice of potato from the trash can.', 6: 'Turn left and go to the stove.', 7: 'Cook the slice of potato in the microwave above the stove and pick it back up.', 8: 'Turn left and go to the fridge.', 9: 'Put the slice of potato to the left of the potato on the shelf in the fridge.'}
#
# Annotation 2
# Put a slice of heated potato in the fridge.
# {0: 'Turn left and go to the side of the island without the sink.', 1: 'Pick up the gray knife from the table. ', 2: 'Turn left and go to the black trash can on the floor at the end of the island.', 3: 'Slice the potato on the right in the trash can. ', 4: 'Place the knife in the trash can. ', 5: 'Take out one slice of potato from the trash can. ', 6: 'Turn left and go around the island to the microwave above the stove. ', 7: 'Heat the potato slice in the microwave and take it out. ', 8: 'Turn left and go to the refrigerator on the right. ', 9: 'Place the potato slice in the refrigerator. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5513814017830913
# {0: 'turn around , walk forward , turn right , walk to the counter , turn right , face the counter .', 1: 'pick up the butter knife off of the counter .', 2: 'turn around , go to the counter , turn right , go to the counter .', 3: 'cut the potato in the trash can .', 4: 'place the knife in the trash can .', 5: 'pick up a slice of potato from the trash can .', 6: 'turn left , walk to the microwave .', 7: 'heat the potato in the microwave .', 8: 'turn around , go to the fridge .', 9: 'place the potato slice in the fridge .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23360229235755803
# {0: 'turn around and go to the sink .', 1: 'pick up the knife from the counter .', 2: 'turn left and go to the end of the counter .', 3: 'slice the potato in the trash can .', 4: 'put the knife in the trash can .', 5: 'pick up a slice of potato', 6: 'turn left and walk to the microwave .', 7: 'heat the potato in the microwave .', 8: 'turn left and walk to the fridge .', 9: 'put the potato in the fridge'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.41534125448347486
# {0: 'turn around and walk to the door , then turn right and walk over to the kitchen sink .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk to the end of the counter , then turn right and walk to the end of the counter .', 3: 'cut the potato in the trash can .', 4: 'put the knife in the trash can .', 5: 'pick up a slice of potato from the trash can .', 6: 'turn left and walk to the microwave .', 7: 'heat the potato in the microwave .', 8: 'turn left and walk to the fridge .', 9: 'put the potato in the fridge'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.49070499951677193
# {0: 'turn around and walk to the door , then turn right and walk over to the kitchen sink .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk to the end of the counter , then turn right and walk to the end of the counter , turn right to face the trash can .', 3: 'cut the potato in the trash can .', 4: 'put the knife in the trash can .', 5: 'pick up a slice of potato from the trash can .', 6: 'turn left and walk to the microwave .', 7: 'heat the potato in the microwave and then remove it .', 8: 'turn left and walk to the fridge .', 9: 'put the potato in the fridge'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3516884211701485
# {0: 'turn around and go back to the kitchen sink .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk towards the door , then hang a right and walk over to the end of the counter .', 3: 'cut the potato in the trash can .', 4: 'put the knife in the trash can .', 5: 'pick up a slice of potato from the trash can .', 6: 'turn left and walk to the microwave .', 7: 'heat the potato in the microwave .', 8: 'turn left and walk to the fridge .', 9: 'put the potato in the fridge'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5087426051302611
# {0: 'turn around and go to the right , then right again and move to the counter in front of the sink .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk towards the door , then hang a right and walk up to the end of the counter and turn right to face the trash can .', 3: 'cut the potato in the trash can .', 4: 'put the knife in the trash can .', 5: 'pick up the slice of potato from the trash can .', 6: 'turn left and walk to the microwave .', 7: 'heat the potato in the microwave and then remove it .', 8: 'turn left and walk to the fridge .', 9: 'put the potato in the fridge'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_191445_723170_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SaltShaker-None-Cabinet-10/trial_T20190906_191445_723170
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/oZ2goybT4pA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To acquire an odd item as place it where it is not useful.
# {0: 'Turn to the left and make an semi circle as to reach the wooden table. ', 1: 'Take only the salt container from the table.', 2: 'turn left and to your right with the salt container.', 3: 'Place the container under the cabin drawer under in the drawer on the left.'}
#
# Annotation 1
# Place the salt shaker from the wooden shelf into the cabinet.
# {0: 'Turn around and head towards the wooden shelves.', 1: 'Pick up the salt shaker on the top shelf.', 2: 'Turn around and head towards the fridge to your left.', 3: 'Open the lower cabinet to the left of the fridge, place the shaker in it, and close the door.'}
#
# Annotation 2
# Put the salt in the bottom cabinet next to the fridge.
# {0: 'Move to the wooden shelf. ', 1: 'Pick up the salt from the shelf. ', 2: 'Bring the salt to the counter right of the fridge. ', 3: 'Place the salt in the cabinet under the counter. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4027586573989549
# {0: 'turn left and walk forward to the shelf .', 1: 'pick up the salt shaker from the shelf .', 2: 'turn right and walk to the counter .', 3: 'open the cabinet and put the salt shaker inside .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.05069073044454643
# {0: 'turn left and walk to the shelves .', 1: 'pick up the salt shaker from the shelf .', 2: 'turn right and walk to the counter with the toaster on it .', 3: 'put the salt in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.298945223747065
# {0: 'turn left and walk to the wooden shelf .', 1: 'pick up the salt shaker on the shelf .', 2: 'turn right and walk to the end of the room , then turn left and walk up to the counter .', 3: 'open the cabinet door and put the salt shaker in the cabinet , then close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3189370883014063
# {0: 'turn left and walk to the wooden shelf .', 1: 'pick up the salt shaker from the shelf', 2: 'turn right and walk to the end of the room , then turn left and walk up to the counter .', 3: 'put the salt in the cabinet'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38676112525508755
# {0: 'turn left and walk to the wooden shelf .', 1: 'pick up the salt shaker on the shelf .', 2: 'turn right and walk to the end of the room , then turn left and walk up to the counter .', 3: 'put the salt in the cabinet'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30805511088088827
# {0: 'turn left and walk to the wooden shelf .', 1: 'pick up the salt shaker on the shelf', 2: 'turn right and walk to the end of the kitchen island , then turn left and walk to the white cabinet .', 3: 'put the salt in the cabinet'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_020329_050110_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Apple-None-SinkBasin-10/trial_T20190907_020329_050110
# Number of subgoals (exlcuding <No-op>): 6
# https://youtu.be/H-GQkQllSuA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a cooked apple into the sink.
# {0: 'Turn around to face the room and go left past the refrigerator, then turn to face the sink on the right.', 1: 'Pick up the green apple from the left side of the sink.', 2: 'Turn around and take the apple to the microwave behind you.', 3: 'Put the apple in the microwave, cook it, and remove it.', 4: 'Turn around to your left and go back to the sink.', 5: 'Put the apple back in the sink.'}
#
# Annotation 1
# Put a cooked apple in the sink.
# {0: 'Turn around, turn to the left, and go to the sink to your right.', 1: 'Pick up the apple that is to the right of the fork.', 2: 'Turn around to the microwave above the stove.', 3: 'Cook the apple in the microwave.', 4: 'Turn around to the sink behind you.', 5: 'Place the apple in the sink, to the right of the fork.'}
#
# Annotation 2
# Heat the left apple in the microwave.
# {0: 'Move to the sink. ', 1: 'Pick up the apple in the sink on the left. ', 2: 'Bring the apple to the microwave. ', 3: 'Heat the apple in the microwave. ', 4: 'Bring the apple to the sink. ', 5: 'Put the apple in the sink, to the left of the other apple. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5750788436693893
# {0: 'turn around and walk to the sink .', 1: 'pick up a piece of apple from the sink .', 2: 'turn left and walk to the microwave .', 3: 'heat the apple in the microwave .', 4: 'turn left and walk to the sink .', 5: 'put the apple in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5576134440339038
# {0: 'turn right and walk to the sink .', 1: 'pick up a piece of apple from the sink .', 2: 'turn left and walk to the stove .', 3: 'put the apple in the microwave , cook it , then take it out', 4: 'turn left and walk to the sink .', 5: 'put the apple in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38989057714851066
# {0: 'turn right and walk to the kitchen sink .', 1: 'pick up a slice of apple from the sink .', 2: 'turn left and walk to the stove , then turn left and walk up to the microwave .', 3: 'put the apple in the microwave and turn it on . take the apple out and shut the door .', 4: 'turn left and walk to the sink .', 5: 'place the apple in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4033067126244527
# {0: 'turn right and walk to the kitchen sink on the right .', 1: 'pick up a piece of apple from the sink .', 2: 'turn left and walk to the stove , then turn left and walk to the stove .', 3: 'put the apple in the microwave , turn it on , and then remove the apple after close the door .', 4: 'turn left and walk to the sink on the left .', 5: 'place the apple in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.48394975755554537
# {0: 'turn around and walk to the sink on the right .', 1: 'pick up a piece of apple from the sink .', 2: 'turn left and walk to the stove , then turn left and walk to the stove .', 3: 'put the apple in the microwave , turn it on , and then remove the apple after the microwave .', 4: 'turn left and walk to the sink .', 5: 'place the apple in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.39987853137114726
# {0: 'turn around , go forward , turn left , go forward , turn right to face the sink .', 1: 'pick up a piece of apple from the sink .', 2: 'turn left and walk to the stove , then turn left and walk to the stove .', 3: 'put the apple in the microwave , turn it on , and then remove the apple after the microwave .', 4: 'turn left and walk to the sink .', 5: 'place the apple in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_170955_824797_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Newspaper-None-FloorLamp-219/trial_T20190907_170955_824797
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/8zfLGiywP1A
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a newspaper by the light of a floor lamp.
# {0: 'Turn to the left and walk to the sofa.', 1: 'Pick up the newspaper from the sofa.', 2: 'Walk to the floor lamp that is to the left of the sofa.', 3: 'Turn on the lamp.'}
#
# Annotation 1
# Turn on a lamp while carrying a newspaper
# {0: 'Move to the right side of the large tan sofa', 1: 'Pick up the newspaper on top of the sofa', 2: 'Carry the newspaper to the left side of the sofa where the lamp is', 3: 'Turn on the lamp'}
#
# Annotation 2
# Examine a newspaper by the light of a floor lamp
# {0: 'turn to the left twice and take a few steps forward and turn to the right and go to the sofa', 1: 'pick up the newspaper from the sofa', 2: 'turn to the right and go to the blue chair and turn to the right', 3: 'turn on the floor lamp'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4370964032439443
# {0: 'turn left and walk to the couch .', 1: 'pick up the newspaper from the couch .', 2: 'turn left and walk to the lamp on the right .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38341444880781805
# {0: 'turn around and walk to the couch .', 1: 'pick up the newspaper from the couch .', 2: 'turn left and walk to the floor lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2792553987115966
# {0: 'turn around and walk to the couch .', 1: 'pick up the newspaper on the couch .', 2: 'turn left and walk to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2792553987115966
# {0: 'turn around and walk to the couch .', 1: 'pick up the newspaper on the couch .', 2: 'turn left and walk to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3258992824739669
# {0: 'turn to the left and face the couch cushion .', 1: 'pick up the newspaper on the couch .', 2: 'turn left and walk to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2862756620920175
# {0: 'turn to the left sofa and face the couch cushion .', 1: 'pick up the newspaper on the couch .', 2: 'turn left and walk to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_210238_431966_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-Desk-308/trial_T20190909_210238_431966
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/Ti1faQUCSnc
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# take a coffee mug from a book shelf and place it on a desk
# {0: 'go to the desk that is in front of a book shelf with a computer on it', 1: 'pick up the white coffee mug from the book shelf', 2: 'go to the left end of the desk', 3: 'place the mug on the left end of the desk'}
#
# Annotation 1
# Move a cup from the shelf to the desk.
# {0: 'Turn to the right and then the left to the other side of the room, and face the desk on the left side. Look up to the books on the shelf.', 1: 'Pick up the cup from the shelf.', 2: 'Carry the cup and turn to the left and then face the desk on the right side. ', 3: 'Place the cup on the short side of the desk, close to you.'}
#
# Annotation 2
# Pick up a coffee mug from the desk and put it down on the desk.
# {0: 'Turn right at the brown desk and walk between the bed and the desk. Turn left at the orange cylinder on the right of the bed on the floor. Walk to the desk on your left with a laptop on it.', 1: "Pick up the white coffee mug that's on the desk.", 2: 'Turn around and walk to the bed. Turn right at the bed.', 3: 'Put the coffee mug back down on the left side of the desk to the right of the bed.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.49611828357186993
# {0: 'turn right , walk forward , turn left , walk to the wall , turn left to face the desk .', 1: 'pick up the mug from the shelf .', 2: 'turn around and walk to the desk on the right side of the desk .', 3: 'place the mug with the spoon in the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.03865219697184644
# {0: 'turn right and walk to the bed then turn left and walk to the wall then turn right and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up', 1: 'pick up the mug with the pen from the shelf .', 2: 'turn around and walk to the desk .', 3: 'put the mug on the desk'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.0760214640980929
# {0: 'turn right and walk to the bed then turn left and walk to the bed then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the desk , then turn right and walk to the desk .', 3: 'place the cup on the desk to the left of the laptop .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3180772318746444
# {0: 'turn right , walk to the bed , turn left , walk to the wall , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk over to the wooden desk .', 3: 'place the mug on the desk to the left of the laptop .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.37919441616815536
# {0: 'turn right , walk towards the bed , turn left , walk towards the desk , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk to the desk .', 3: 'place the mug on the desk to the left of the laptop .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3035440414643701
# {0: 'turn right , walk to the bed , turn left , walk towards the bed , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk over to the wooden desk .', 3: 'place the mug on the desk to the left of the laptop .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_224843_443882_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-BreadSliced-None-Microwave-10/trial_T20190906_224843_443882
# Number of subgoals (exlcuding <No-op>): 12
# https://youtu.be/z261C5NcQbU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'SliceObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# placed a cooled slice of bread that you cut inside of the microwave
# {0: 'move forwards to the end of the room, then turn left and walk until your reach the left side of the stove on your right', 1: 'pick up the butter knife behind the green cup on the counter to the left of the stove', 2: 'turn right and and walk to the end of the room, then turn right again until you reach the right side of the end o the kitchen island, turn to face the kitchen island', 3: 'cut up the bread on the kitchen island into slices', 4: 'turn right and walk until you reach the end of the room, then turn left and walk to the other end of the room, turn right to face the fridge', 5: 'place the knife inside of the fridge', 6: 'turn right and and walk to the end of the room, then turn right again until you reach the right side of the end o the kitchen island, turn to face the kitchen island', 7: 'grab a slice of bread off of the kitchen island countertop', 8: 'turn right and walk to the end of the room, then turn left and walk to the other end of the room until you reach the fridge on your right, turn to face the fridge', 9: 'place the slice of bread in the fridge to cool, then take it out once it has cooled and close the fridge', 10: 'turn right and walk forwards until your reach the stove on the left side, turn to face the stove and look up towards the microwave above', 11: 'place the cooled slice of bread inside of the microwave'}
#
# Annotation 1
# Place a piece of sliced bread in the microwave.
# {0: 'Move to stand at the counter between the stove and dishwasher.', 1: 'Pick up the butter knife by the green container. ', 2: 'Carry the knife to stand at the edge of the counter beyond the kitchen sink. ', 3: "Slice the loaf of bread that's on the counter. ", 4: 'Carry the knife to the fridge. ', 5: 'Place the knife on the top shelf of the fridge.', 6: 'Move back to the edge of the counter past the sink where the loaf of bread is. ', 7: 'Pick up a slice of bread from the counter. ', 8: 'Carry the slice of bread to the fridge.', 9: 'Open the fridge and place the slice of bread on the top shelf to the right of the apple, close the door, pause, and then open the door and remove the bread. ', 10: 'Move to stand in front of the stove.', 11: 'Open the microwave above the stove and place the slice of bread inside.'}
#
# Annotation 2
# Slice a loaf of bread, put the knife and bread in the refrigerator, take the bread to the microwave.
# {0: 'Go straight, take a left at the counter', 1: 'Turn right and face the statue on the counter.', 2: 'Pick up the knife, go right, take a right at the wall.', 3: 'Turn right towards the counter and slice the bread.', 4: 'Take a right, take a left at the counter, turn to face the refrigerator.', 5: 'Open the refrigerator and set the knife on the shelf to the left of the apple and shut the door.', 6: 'Go right, take another right at the wall, turn left to face the bread on the counter.', 7: 'Grab a slice of bread.', 8: 'Go right, take a left at the counter, turn right to face the refrigerator', 9: 'Open the refrigerator door, set the bread to the right of the apple, shut the door, open the door, and grab the bread.', 10: 'Go right and turn to face the stove.', 11: 'Open the microwave, put the bread in the microwave, and shut the door.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4219282922703509
# {0: 'turn right , walk forward , turn left , walk to the counter .', 1: 'pick up the butter knife from the counter .', 2: 'turn right , walk to the counter , turn right , face the counter .', 3: 'slice the bread on the counter .', 4: 'turn right , walk forward , turn left , go to the fridge .', 5: 'place the knife on the shelf .', 6: 'turn right , walk forward , turn right , walk to the counter , turn right to face the counter .', 7: 'pick up a slice of bread from the counter .', 8: 'turn right , walk to the fridge .', 9: 'place the slice of bread in the fridge .', 10: 'turn right , walk forward , turn left to face the microwave .', 11: 'place the bread in the microwave .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14168093550509273
# {0: 'walk forward to the counter , then turn left and walk to the counter .', 1: 'pick up the knife in the back of the counter .', 2: 'turn right and walk to the counter , then turn right and walk up to the counter .', 3: 'cut the loaf of bread into slices .', 4: 'turn right and walk to the fridge .', 5: 'place the knife in the fridge .', 6: 'turn right and walk to the wall , then turn right and walk up to the wall , then turn right and walk up to the counter .', 7: 'pick up the loaf of bread .', 8: 'turn right and go to the fridge .', 9: 'place the bread in the fridge and close the door , wait a moment , and take it out again .', 10: 'turn right and walk to the microwave .', 11: 'put the slice of bread in the microwave .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.20036622814977126
# {0: 'walk forward to the counter , turn left and walk to the counter on the right .', 1: 'pick up the knife in the glass .', 2: 'turn right and walk to the end of the counter , then turn right and walk to the counter .', 3: 'cut the bread on the counter into slices .', 4: 'turn right and walk to the fridge .', 5: 'open the fridge and place the knife on the top shelf .', 6: 'turn to your right and go to the end of the counter , then turn right to face the counter .', 7: 'pick up a slice of bread from the counter .', 8: 'turn right and walk to the counter , then turn left and walk to the fridge .', 9: 'open the fridge and place the bread inside . shut the door and then open the door and take the bread out and shut the door .', 10: 'turn right and walk to the end of the kitchen , then turn left and walk to the stove and look up at the microwave .', 11: 'put the slice of bread in the microwave .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.18228900880795146
# {0: 'walk forward to the counter , turn left , walk to the counter to the left of the stove .', 1: 'pick up the knife from the counter .', 2: 'turn right and walk to the counter , then turn right and walk to the counter .', 3: 'cut the bread on the counter into slices .', 4: 'turn right , go to the fridge', 5: 'open the fridge and place the knife on the top shelf .', 6: 'turn to your right and go to the end of the counter , then turn right to face the counter .', 7: 'pick up a slice of bread from the counter .', 8: 'turn right and go to the fridge .', 9: 'open the fridge , put the bread in the fridge , close the door , wait a few seconds , open the fridge , take out the slice of bread , and close the door .', 10: 'turn right and go to the microwave .', 11: 'put the slice of bread in the microwave .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2100362885548387
# {0: 'walk forward to the counter , turn left , walk to the counter to the left of the stove .', 1: 'pick up the knife from the counter .', 2: 'turn right and walk to the counter then turn right and walk to the counter then turn right to face the counter .', 3: 'cut the bread on the counter into slices .', 4: 'turn right , go to the fridge', 5: 'open the fridge and place the knife on the top shelf .', 6: 'turn to your right and go back to the counter space between the sink and the sink .', 7: 'pick up a slice of bread from the counter .', 8: 'turn right and go to the fridge .', 9: 'put the bread in the fridge and shut the door and then open the door and take the bread out and shut the door .', 10: 'turn right and go to the microwave .', 11: 'put the slice of bread in the microwave .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16213330561955996
# {0: 'walk forward to the counter , turn left , walk to the counter on the right', 1: 'pick up the knife in the glass .', 2: 'turn right and walk to the end of the counter , then turn right and walk to the counter .', 3: 'cut the bread on the counter into slices .', 4: 'turn right , go to the fridge', 5: 'open the fridge and place the knife on the top shelf .', 6: 'turn to your right and go to the end of the counter , then turn right to face the counter .', 7: 'pick up a slice of bread from the counter .', 8: 'turn right and go to the fridge .', 9: 'put the bread in the fridge and shut the door and then open the door and take the bread out and shut the door .', 10: 'turn right and go to the microwave .', 11: 'put the slice of bread in the microwave .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_214631_761426_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-BaseballBat-None-DeskLamp-308/trial_T20190906_214631_761426
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/6dSWDozBRLU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# turn on a lamp while holding a baseball bat
# {0: 'walk forwards a bit towards the baseball bat', 1: 'grab the baseball bat leading against the wall', 2: 'turn and walk over to the right side of the computer desk', 3: 'turn on the lamp on the computer desk'}
#
# Annotation 1
# Examine a bat by the light of a lamp.
# {0: 'Head towards the bat on the floor in front of you.', 1: 'Pick up the bat from the floor.', 2: 'Turn around, head towards the bed, turn left towards the wall, and then turn left to face the lamp on the desk.', 3: 'Turn on the lamp.'}
#
# Annotation 2
# Examine the bad under the light on the desk.
# {0: 'Move to the corner near the door. ', 1: 'Pick up the bat from the floor. ', 2: 'Bring the bat to the desk', 3: 'Turn on the lamp on the desk. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5906692351478002
# {0: 'turn left and walk to the wall , turn right to face the wall .', 1: 'pick up the bat from the floor .', 2: 'turn around , walk to the wall , turn left to face the desk .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.0631877583029222
# {0: 'turn to the left and go to the wall', 1: 'pick up the bat from the floor .', 2: 'turn around and walk to the wall , then turn left and walk over to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall . turn left and walk up to the desk .', 3: 'turn on the lamp'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35231838540467003
# {0: 'turn left and walk to the wall then turn right and walk to the wall .', 1: 'pick up the baseball bat from the floor .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45684714492356643
# {0: 'turn left and walk to the wall then turn right and walk to the wall .', 1: 'pick up the bat from the floor', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4227782351056109
# {0: 'turn left and walk to the wall then turn right and walk to the baseball bat .', 1: 'pick up the bat from the floor', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45684714492356643
# {0: 'turn left and walk to the wall then turn right and walk to the wall .', 1: 'pick up the bat from the floor', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074524_006355_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Watch-None-Safe-219/trial_T20190907_074524_006355
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/_TobcwcYR9Q
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a watch to the inside of a small safe.
# {0: 'Turn right and take a step forward, then turn left and walk up to the large wooden dresser.', 1: 'Pick up the watch that is on top of the large wooden dresser.', 2: 'Turn right and begin walking across the room, then hang a right and walk up to the small white safe on the ground.', 3: 'Open the small white safe, place the watch inside, then close the safe door.'}
#
# Annotation 1
# Take the watch on top of the chest of drawers  put it inside the safe and lock it up.
# {0: 'Go to the chest of drawers ahead of you.', 1: 'Pick up the brown banded watch.', 2: 'Take the watch across the room toward the safe.', 3: 'Open the safe, set the watch inside the safe, close the safe.'}
#
# Annotation 2
# place a watch in a safe box
# {0: 'turn right then turn left towards the  dresser', 1: 'pick up the watch from the dresser', 2: 'turn right and walk towards the sofa then turn right again towards the  safe box', 3: 'place the watch in the safe box'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3993061380020981
# {0: 'turn right and walk to the counter .', 1: 'pick up the watch from the dresser .', 2: 'turn right , walk forward , turn right , walk to the wall , turn right to face the white table .', 3: 'place the watch in the microwave .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27253458514868856
# {0: 'turn right and walk to the cabinet .', 1: 'pick up the watch from the dresser .', 2: 'turn right and walk to the white shelves on the right .', 3: 'open the safe and put the watch inside of the safe .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2662092991871879
# {0: 'turn right and walk towards the counter .', 1: 'pick up the watch on the dresser .', 2: 'turn right , walk to the couch , turn right , walk to the shelves', 3: 'open the safe and put the watch inside and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22683183355059885
# {0: 'turn right and walk to the counter .', 1: 'pick up the watch on the dresser .', 2: 'turn right , go forward , turn right , go forward to the shelves', 3: 'open the safe and put the watch inside .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2372910912578151
# {0: 'turn right and walk towards the counter .', 1: 'pick up the watch on the dresser .', 2: 'turn right , go forward , turn right , go forward , turn right , go forward to the shelves .', 3: 'open the safe and put the safe inside .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28298920120998156
# {0: 'turn right and walk towards the counter .', 1: 'pick up the watch on the dresser .', 2: 'turn right , go straight , then turn right to go to the shelves .', 3: 'open the safe and put the safe inside .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_114656_768805_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-CounterTop-10/trial_T20190908_114656_768805
# Number of subgoals (exlcuding <No-op>): 6
# https://youtu.be/AOYa3y_0uCU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold pan on the counter top on top of the dishwasher.
# {0: 'Turn around, walk forward, turn right near the fridge, walk straight and turn left to face the stove. ', 1: 'Pick up the pan from on top of the stove. ', 2: 'Turn around, walk to the right to go back to the fridge. ', 3: 'Open the fridge, put the pan in it, close the fridge, let it cool for a while, open the fridge, pick it up again and close the fridge. ', 4: 'Go to the right and turn left to face the dishwasher. ', 5: 'Put the pan on the counter top. '}
#
# Annotation 1
# Chill a pan and put it on a counter.
# {0: 'Walk around the kitchen counter to the stove on your left.', 1: 'Grab a pan from the stove.', 2: 'Walk to the front of the fridge on your left.', 3: 'Place the pan in the fridge, then grab it.', 4: 'Walk to the kitchen counter between the fridge and stove.', 5: 'Place the pan on the counter.'}
#
# Annotation 2
# Put the chilled pan on the counter
# {0: 'Turn around to your left walk straight then turn right head to the  stove on your left', 1: 'Pick up the pan on the  stove', 2: 'Turn left then walk straight head to the fridge', 3: 'Open the fridge put in the pan then take it out and close the fridge', 4: 'Turn right walk straight face the counter beside the toaster', 5: 'Put the pan on the counter beside the toaster'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5883171263666587
# {0: 'turn around , walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn left , walk to the fridge .', 3: 'place the pan inside the fridge , wait a bit , open the fridge , remove the pan from the fridge .', 4: 'turn right and walk to the counter .', 5: 'place the pan on the counter .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4464300822800499
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the fridge .', 3: 'chill the pan in the fridge .', 4: 'turn right and walk to the counter .', 5: 'put the pan down on the counter .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46811090754243445
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the fridge on the right .', 3: 'open the fridge and put the pan on the top shelf and close the door . open the door and take the pan out .', 4: 'turn right and walk to the counter with the toaster on it .', 5: 'put the pan on the counter'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4481791472698991
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the fridge on the right .', 3: 'put the pan in the fridge and close the door , after a couple seconds open the fridge back up and remove the now chilled pan then close the door .', 4: 'turn right and walk to the counter with the toaster on it .', 5: 'put the pan on the counter'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4481791472698991
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the fridge on the right .', 3: 'put the pan in the fridge and close the door , after a couple seconds open the fridge back up and remove the now chilled pan then close the door .', 4: 'turn right and walk to the counter with the toaster on it .', 5: 'put the pan on the counter'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4481791472698991
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the fridge on the right .', 3: 'put the pan in the fridge and close the door , after a couple seconds open the fridge back up and remove the now chilled pan then close the door .', 4: 'turn right and walk to the counter with the toaster on it .', 5: 'put the pan on the counter'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %% [markdown]
# ## SECTION 2: Look at overall best and worst tasks for one epoch

# %%
# compute bleu score for every task
# compute CE for every task

def rank_tasks(epoch, split, k=10, best=True, task_ids=None):
    
    path = os.path.join(args.dout, '{}.debug_epoch_{}.preds.json'.format(split, epoch))
#     path = os.path.join(args.dout, '{}_argmax.debug_epoch_{}.preds.json'.format(split, epoch))
    
    with open(path, 'r') as f:
        debug_dat = json.load(f)
        
    scores = {}
        
    for task_id in debug_dat:
        root = get_root_location(debug_dat[task_id]['root'])
        
        # get referece lang for bleu score
        ref_instrs = get_ref_instrs(root)
        
        gold_num_subgoals = len(debug_dat[task_id]['action_high']) - 1
        pred_list = [debug_dat[task_id]['p_lang_instr'][str(i)] for i in range(gold_num_subgoals)]
        pred_tokens_overall = ' '.join(pred_list).split(' ') 
        bleu_score = sentence_bleu(ref_instrs, pred_tokens_overall)
        
        scores[task_id] = bleu_score
        
    top_k_task_ids = sorted(scores.items(), key=lambda x: x[1], reverse=best)[:k]
    pprint.pprint(top_k_task_ids)
    
    return [x[0] for x in top_k_task_ids], list(scores.values())

# %%
train_sanity_best_epoch = 29
print ("BEST train_sanity")
ranked_train_sanity_ids_best_10, all_train_sanity_bleu_scores = rank_tasks(epoch=train_sanity_best_epoch, split='train_sanity', k=10, best=True)
print ("WORST train_sanity")
ranked_train_sanity_ids_worst_10, _ = rank_tasks(epoch=train_sanity_best_epoch, split='train_sanity', k=10, best=False)

valid_seen_best_epoch = 11
print ("BEST valid_seen")
ranked_valid_seen_ids_best_10, all_valid_seen_bleu_scores = rank_tasks(epoch=valid_seen_best_epoch, split='valid_seen', k=10, best=True)
print ("WORST valid_seen")
ranked_valid_seen_ids_worst_10, _ = rank_tasks(epoch=valid_seen_best_epoch, split='valid_seen', k=10, best=False)

valid_unseen_best_epoch = 11
print ("BEST valid_unseen")
ranked_valid_unseen_ids_best_10, all_valid_unseen_bleu_scores = rank_tasks(epoch=valid_unseen_best_epoch, split='valid_unseen', k=10, best=True)
print ("WORST valid_unseen")
ranked_valid_unseen_ids_worst_10, _ = rank_tasks(epoch=valid_unseen_best_epoch, split='valid_unseen', k=10, best=False)
# Out:
# BEST train_sanity
# [('trial_T20190909_111509_088713_0', 0.961287537184244),
#  ('trial_T20190919_004246_212362_0', 0.9332139756662952),
#  ('trial_T20190907_234526_733036_0', 0.9074813681149694),
#  ('trial_T20190908_230635_560113_0', 0.9015782462176711),
#  ('trial_T20190907_040920_796378_0', 0.8985226466036047),
#  ('trial_T20190908_034518_968653_0', 0.8864546197132421),
#  ('trial_T20190908_154238_160623_0', 0.8795290739538499),
#  ('trial_T20190907_044544_187398_0', 0.8782427539262296),
#  ('trial_T20190907_015237_331804_0', 0.868394852474527),
#  ('trial_T20190908_155247_137362_0', 0.8593791072130912)]
# WORST train_sanity
# [('trial_T20190908_040645_145153_0', 0.22158847479138624),
#  ('trial_T20190908_131037_058357_0', 0.3342383925858411),
#  ('trial_T20190907_162319_309721_0', 0.35731267607238937),
#  ('trial_T20190907_171656_314313_0', 0.36536489324658056),
#  ('trial_T20190907_200441_879615_0', 0.3684146814791245),
#  ('trial_T20190908_115507_503798_0', 0.3725088812956408),
#  ('trial_T20190908_111526_967564_0', 0.3837565048158573),
#  ('trial_T20190909_091643_467064_0', 0.3838328532642946),
#  ('trial_T20190908_221843_169317_0', 0.4020221038783786),
#  ('trial_T20190906_213353_632634_0', 0.4131142104672669)]
# BEST valid_seen
# [('trial_T20190906_201007_149137_0', 0.8295909942632151),
#  ('trial_T20190908_071602_531614_0', 0.8134927763524316),
#  ('trial_T20190909_055248_059513_0', 0.8112997567209711),
#  ('trial_T20190909_101835_683416_0', 0.810014047769922),
#  ('trial_T20190909_150719_492274_0', 0.8091899401586357),
#  ('trial_T20190909_051813_197569_0', 0.8026384880789047),
#  ('trial_T20190908_232929_254246_0', 0.8005559081131497),
#  ('trial_T20190908_125930_920681_0', 0.7969473430964341),
#  ('trial_T20190909_154521_553270_0', 0.7783386946000591),
#  ('trial_T20190909_124425_112757_0', 0.7735862042822425)]
# WORST valid_seen
# [('trial_T20190908_050633_745514_0', 0.16229399444549233),
#  ('trial_T20190908_173610_612042_0', 0.21199626888392847),
#  ('trial_T20190906_192823_237997_0', 0.23739496247314493),
#  ('trial_T20190907_114323_767231_0', 0.25618662154612126),
#  ('trial_T20190906_162502_940304_0', 0.2626430761185537),
#  ('trial_T20190908_201550_622420_0', 0.3017441818652155),
#  ('trial_T20190908_055221_984342_0', 0.3202624681997078),
#  ('trial_T20190906_202340_749336_0', 0.33571622606081875),
#  ('trial_T20190907_060234_011675_0', 0.3404204637766612),
#  ('trial_T20190907_224451_655673_0', 0.3404634135342341)]
# BEST valid_unseen
# [('trial_T20190907_194015_037530_0', 0.7649313072066681),
#  ('trial_T20190908_235816_620828_0', 0.759042729808627),
#  ('trial_T20190908_032543_712058_0', 0.7464744105399567),
#  ('trial_T20190909_042101_443154_0', 0.7271723802281618),
#  ('trial_T20190908_201421_021646_0', 0.7251416979112557),
#  ('trial_T20190908_214946_567644_0', 0.7126007810244084),
#  ('trial_T20190907_194052_908074_0', 0.7115978580501359),
#  ('trial_T20190909_025529_706272_0', 0.6989346128540768),
#  ('trial_T20190909_103526_341991_0', 0.6948226340394245),
#  ('trial_T20190909_025512_298420_0', 0.6828170306202965)]
# WORST valid_unseen
# [('trial_T20190909_210238_431966_0', 0.08183174159000516),
#  ('trial_T20190906_185530_954329_0', 0.0824233266233741),
#  ('trial_T20190908_203635_515565_0', 0.14509904726626335),
#  ('trial_T20190908_022436_073995_0', 0.19284608939572234),
#  ('trial_T20190908_125200_737896_0', 0.22543358740886965),
#  ('trial_T20190908_161733_213242_0', 0.24394905930520905),
#  ('trial_T20190908_205221_748352_0', 0.24928532548807147),
#  ('trial_T20190906_213926_964767_0', 0.2541513260021671),
#  ('trial_T20190908_205246_776817_0', 0.2595571878578312),
#  ('trial_T20190908_141958_463362_0', 0.26096423708503536)]

# %%
plt.hist(all_train_sanity_bleu_scores, density=False, bins=50, alpha=0.5)
plt.hist(all_valid_seen_bleu_scores, density=False, bins=50, alpha=0.5)
plt.hist(all_valid_unseen_bleu_scores, density=False, bins=50, alpha=0.5)
plt.xlim(0.0, 1.0)
plt.title('(Blue, train_sanity epoch {})\n(Orange, valid_seen epoch {})\n (Green, valid_unseen epoch {})'.format(train_sanity_best_epoch, valid_seen_best_epoch, valid_unseen_best_epoch))
plt.ylabel('Count')
plt.xlabel('BLEU score');

# %%
# BEST train_sanity
best_train_sanity_res = examine_sampled_tasks(sampled_task_ids=ranked_train_sanity_ids_best_10, epoch_list=train_sanity_epoch_list, split='train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190909_111509_088713_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Mug-None-CoffeeMachine-15/trial_T20190909_111509_088713
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a clean mug in a coffee maker.
# {0: 'Walk ahead to the counter, then turn left and walk to the coffee maker.', 1: 'Take the mug out of the coffee maker.', 2: 'Turn right and walk to the sink.', 3: 'Wash the mug in the sink.', 4: 'Turn left and walk back to the coffee maker.', 5: 'Place the coffee mug back in the coffee maker.'}
#
# Annotation 1
# clean the mug then put it back under the coffee machine
# {0: 'go to the coffee machine on the counter', 1: 'pick up the mug from the machine', 2: 'take the mug to the sink', 3: 'clean the mug in the sink', 4: 'take the mug back to the coffee machine', 5: 'put the mug back under the machine'}
#
# Annotation 2
# Put a clean mug under the coffee maker.
# {0: 'Walk forward to the counter then turn left and walk to the coffee maker.', 1: "Pick up the dirty mug that's at it's spot under the coffee maker.Turn around and walk to the sink then turn left to face it.", 2: 'Turn around and walk to the sink on your left then turn left to face it.', 3: 'Wash the mug in the sink and then pick it back up and shut off the water.', 4: 'Go back to the coffee maker.', 5: 'Put the mug back where you got it from.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7971073118840378
# {0: 'turn left and walk to the counter .', 1: 'pick up the mug from the coffee maker .', 2: 'turn right and walk to the sink .', 3: 'place the mug in the sink .', 4: 'turn left and walk to the counter .', 5: 'put the mug back on the coffee maker .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7082204097665474
# {0: 'walk to the counter to the right of the coffee maker .', 1: 'pick up the mug from the coffee maker .', 2: 'turn around and walk to the sink .', 3: 'wash the mug in the sink .', 4: 'turn left and walk to the coffee maker .', 5: 'put the mug back in the coffee machine .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8703623561868022
# {0: 'walk forward to the coffee machine on the counter .', 1: 'pick up the mug from the coffee maker .', 2: 'turn around and walk to the sink on the left .', 3: 'wash the mug in the sink and then pick it back up and shut off the water .', 4: 'turn left and walk to the coffee maker .', 5: 'put the mug back where you got it .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8142280635254773
# {0: 'walk forward to the counter , then turn left and walk up to the coffee maker .', 1: 'pick up the mug from the coffee maker .', 2: 'turn around and walk to the sink on your left .', 3: 'wash the mug in the sink and then pick it back up and shut off the water .', 4: 'turn left and walk to the coffee maker .', 5: 'put the mug back where you got it .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9843293571277907
# {0: 'walk forward to the counter , then turn left and walk to the coffee maker .', 1: 'pick up the mug from the coffee maker .', 2: 'turn around and walk to the sink .', 3: 'wash the mug in the sink and then pick it back up and shut off the water .', 4: 'turn left and walk to the coffee maker .', 5: 'put the mug back where you got it .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9843293571277907
# {0: 'walk forward to the counter , then turn left and walk to the coffee maker .', 1: 'pick up the mug from the coffee maker .', 2: 'turn around and walk to the sink .', 3: 'wash the mug in the sink and then pick it back up and shut off the water .', 4: 'turn left and walk to the coffee maker .', 5: 'put the mug back where you got it .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190919_004246_212362_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spoon-Mug-SinkBasin-13/trial_T20190919_004246_212362
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'OpenObject', 'PutObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the mug with spoon in the kitchen sink
# {0: 'Walk forward to the kitchen sink', 1: 'Pick up the spoon from the sink', 2: 'Turn around and walk over to the fridge', 3: 'Open the fridge and put the spoon in the white mug', 4: 'Pick up the white mug from the fridge and close it', 5: 'Turn around and walk forward to the sink', 6: 'Put the mug in the kitchen sink'}
#
# Annotation 1
# Put the mug with spoon in the sink
# {0: 'Walk forward towards the sink', 1: 'Pick up the spoon in the sink', 2: 'Turn right then head to the fridge', 3: 'Open the fridge then put the spoon in the mug', 4: 'Pick up the mug with spoon then close the fridge', 5: 'Turn right head to the sink', 6: 'Put the mug with spoon in the sink'}
#
# Annotation 2
# Put a mug with a spoon in it in the sink.
# {0: 'Go forward to the sink.', 1: 'Pick up the spoon from the sink.', 2: 'Turn around and go to the fridge in front of you.', 3: 'Open the fridge and put the spoon in the white mug in the fridge.', 4: 'Pick up the white mug with the spoon in it.', 5: 'Turn around and go straight to the sink.', 6: 'Put the mug in the sink.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8031062197082631
# {0: 'go forward to the sink .', 1: 'pick up the spoon in the sink .', 2: 'turn around , walk to the fridge .', 3: 'place the spoon in the mug .', 4: 'pick up the mug with the spoon in it .', 5: 'turn around and walk to the sink .', 6: 'put the mug in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4287959822860464
# {0: 'turn to the sink', 1: 'pick up the spoon from the sink .', 2: 'turn around and go to the fridge .', 3: 'open the fridge and put the spoon in the mug .', 4: 'pick up the mug with the spoon in it .', 5: 'turn around and walk to the sink .', 6: 'put the mug in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5392500331404095
# {0: 'walk forward to the sink .', 1: 'pick up the spoon from the sink .', 2: 'turn around and walk to the fridge .', 3: 'open the fridge and put the spoon in the mug that is on the top shelf of the fridge .', 4: 'pick up the mug with the spoon in it and close the fridge .', 5: 'turn around and walk to the sink .', 6: 'put the mug in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5705677072611137
# {0: 'walk forward to the sink .', 1: 'pick up the spoon in the sink .', 2: 'turn around and go to the fridge .', 3: 'open the fridge and put the spoon in the mug that is on the top shelf of the fridge .', 4: 'pick up the mug with spoon in it .', 5: 'turn around and walk to the sink .', 6: 'put the mug in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4851606475101482
# {0: 'walk forward to the sink .', 1: 'pick up the spoon in the sink .', 2: 'turn around and go to the fridge .', 3: 'open the fridge and put the spoon in the mug', 4: 'pick up the mug with spoon in it .', 5: 'turn around and walk over to the sink .', 6: 'put the mug in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4851606475101482
# {0: 'walk forward to the sink .', 1: 'pick up the spoon in the sink .', 2: 'turn around and go to the fridge .', 3: 'open the fridge and put the spoon in the mug', 4: 'pick up the mug with spoon in it .', 5: 'turn around and walk over to the sink .', 6: 'put the mug in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_234526_733036_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-CellPhone-None-Safe-323/trial_T20190907_234526_733036
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the cellphone in the safe.
# {0: 'Go to the dresser in front of you.', 1: 'Pick up the cell phone on the edge of the dresser behind the coffee cup. ', 2: 'Turn around and go towards the wall on your left to the safe sitting on the dresser.', 3: 'Open the safe between the wall and clock. Place the phone in the safe next to the keys and close the safe.'}
#
# Annotation 1
# Place a cell phone inside a safe.
# {0: 'Walk forward to the dresser.', 1: 'Pick up the cell phone from the dresser.', 2: 'Walk slightly to the left to the safe on the dresser.', 3: 'Put the cell phone in the safe and close it.'}
#
# Annotation 2
# Place a cell phone in the safe.
# {0: 'Go straight ahead to the brown dresser.', 1: 'Pick up the cell phone from the back rear of the dresser.', 2: 'Hold the cell phone and take a step to the left.', 3: 'Open the safe and put the cell phone inside. Shut the safe.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4516285688933991
# {0: 'turn right and walk to the dresser .', 1: 'pick up the phone from the dresser .', 2: 'turn right and walk to the dresser .', 3: 'place the phone in the safe .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8665750235297899
# {0: 'walk forward to the dresser .', 1: 'pick up the cell phone from the dresser .', 2: 'turn around and face the safe on the dresser .', 3: 'open the safe and put the cell phone inside and close the safe .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.770449706066956
# {0: 'walk straight to the dresser .', 1: 'pick up the cell phone on the right .', 2: 'turn around and walk towards the safe on the dresser .', 3: 'open the safe and put the phone inside . shut the safe .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5889224026956283
# {0: 'walk to the dresser .', 1: 'pick up the cell phone on the dresser .', 2: 'turn around and walk towards the wall , then turn right and walk up to the safe .', 3: 'open the safe and put the phone inside . shut the safe .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9933551137765035
# {0: 'walk forward to the dresser .', 1: 'pick up the cell phone on the dresser .', 2: 'hold the cell phone and take a step to the left .', 3: 'open the safe and put the cell phone inside . shut the safe .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9074813681149694
# {0: 'go to the dresser in front of you .', 1: 'pick up the cell phone on the dresser .', 2: 'hold the cell phone and take a step to the left .', 3: 'open the safe and put the cell phone inside . shut the safe .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_230635_560113_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Bowl-None-DeskLamp-316/trial_T20190908_230635_560113
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a wooden bowl in the light of a small lamp.
# {0: 'Turn right and walk forward, then hang a right and walk up to the wooden desk.', 1: 'Pick up the closest wooden bowl off of the wooden desk.', 2: 'Turn right and walk towards the bed, then turn left to face the small lamp on the desk.', 3: 'Turn on the light of the small lamp.'}
#
# Annotation 1
# Examine a bowl in the lamp light.
# {0: 'Turn around and go to the desk in front of you.', 1: 'Pick up the bowl nearest to you on the desk.', 2: 'Turn right and go to the bed, then turn left to face the lamp on the desk.', 3: 'Turn on the lamp.'}
#
# Annotation 2
# Examine a bowl using the light from the lamp on the desk.
# {0: 'Turn right, move a couple steps forward, then head right to stand behind the office chair, facing the desk.', 1: "Pick up the bowl from the desk that's closest to the chair.", 2: 'Carry the desk a few steps to your right to stand at the end of the desk, which is next to a plant.', 3: 'Turn on the lamp on the corner of the desk.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4296378507902311
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl with the blue up from the desk .', 2: 'turn right and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.43019005983963415
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl with the cd in it .', 2: 'turn right and walk to the lamp on the desk .', 3: 'turn on the light .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8464656820582321
# {0: 'turn right and walk forward , then hang a right and walk up to the wooden desk .', 1: 'pick up the bowl from the desk .', 2: 'turn right and walk to the end of the desk , then turn left to face the lamp on the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9015782462176711
# {0: 'turn right and walk forward , then hang a right and walk up to the wooden desk .', 1: 'pick up the bowl from the desk .', 2: 'turn right and walk to the end of the desk , then turn left to face the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9015782462176711
# {0: 'turn right and walk forward , then hang a right and walk up to the wooden desk .', 1: 'pick up the bowl from the desk .', 2: 'turn right and walk to the end of the desk , then turn left to face the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9015782462176711
# {0: 'turn right and walk forward , then hang a right and walk up to the wooden desk .', 1: 'pick up the bowl from the desk .', 2: 'turn right and walk to the end of the desk , then turn left to face the lamp .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_040920_796378_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-TennisRacket-None-SideTable-310/trial_T20190907_040920_796378
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a racket on a night stand next to a bed.
# {0: 'Go to the right and face the racket in the corner.', 1: 'Pick the racket up from off of the floor.', 2: 'Turn around and go to the black night stand beside the bed.', 3: 'Put the racket on the night stand.'}
#
# Annotation 1
# Move a tennis racket from the corner of the room to the night stand
# {0: 'Move to the corner of the room where the tennis racket is', 1: 'Pick up the tennis racket that is sitting on the floor', 2: 'Move the racket to the night stand that is to the right of the bed', 3: 'Place the tennis racket on the night stand in front of the blue pen'}
#
# Annotation 2
# Move a tennis racket from the floor to a side table.
# {0: 'Turn right and walk to the tennis racket on the floor.', 1: 'Pick up the tennis racket from the floor.', 2: 'Turn around and walk to the side table to the right of the bed.', 3: 'Put the racket on the table, leaning it against the wall.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4622046437945728
# {0: 'turn right and walk to the wall , turn the the room .', 1: 'pick up the tennis racket from the floor .', 2: 'turn left and walk to the bed , then turn left and walk to the bed .', 3: 'place the book on the nightstand'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6254864723112762
# {0: 'turn right and walk to the wall , turn turn the lamp', 1: 'pick up the tennis racket from the floor .', 2: 'turn around and walk to the bed .', 3: 'put the racket on the night stand'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8985226466036047
# {0: 'turn right and walk to the tennis racket on the floor .', 1: 'pick up the tennis racket that is on the floor .', 2: 'turn around and walk to the night stand to the right of the bed .', 3: 'put the racket on the night stand'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5627150971833141
# {0: 'turn right and walk to the tennis racket on the floor .', 1: 'pick up the tennis racket that is on the floor .', 2: 'turn left and walk to the desk , then hang a left and walk over to the small black table .', 3: 'put the tennis racket on the night stand'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6158133470950448
# {0: 'turn right and walk to the tennis racket on the floor .', 1: 'pick up the tennis racket that is on the floor .', 2: 'turn left and walk to the desk , then turn left and walk over to the small black table .', 3: 'put the racket on the night stand'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8985226466036047
# {0: 'turn right and walk to the tennis racket on the floor .', 1: 'pick up the tennis racket that is on the floor .', 2: 'turn around and walk to the night stand to the right of the bed .', 3: 'put the racket on the night stand'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_034518_968653_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-PotatoSliced-Pan-Fridge-27/trial_T20190908_034518_968653
# Number of subgoals (exlcuding <No-op>): 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To put a pan with a potato slice in the fridge.
# {0: 'Turn around and walk forward to face the knife on the counter.', 1: 'Pick up the knife on the counter.', 2: 'Turn around and walk across the room to face the potato on the table.', 3: 'Cut the potato on the table into slices.', 4: 'Turn around and walk across the room to face the fridge.', 5: 'Place the knife in the fridge.', 6: 'Turn around and walk forward to face the potato on the table.', 7: 'Pick up a slice of the potato on the table.', 8: 'Turn around and walk forward to face the stove.', 9: 'Place the potato slice on the pan on the back left burner.', 10: 'Pick up the Pan with the potato slice on the back left burner.', 11: 'Step to the right to face the fridge.', 12: 'Place the pan with the potato slice on the middle shelf in the fridge.'}
#
# Annotation 1
# Putting pan with a sliced potato in it in the fridge
# {0: 'Turn around and go to the counter to the left of the stove', 1: 'Grab the knife off of the counter', 2: 'Turn around and go to the right of the white table', 3: 'Cut the potato on the table into slices', 4: 'Turn around and go to the fridge', 5: 'Put the knife in the fridge', 6: 'Turn around and go to the right of the white table', 7: 'Grab a slice of potato off of the table', 8: 'Turn around and go to the oven', 9: 'Put the potato in the pan in the top left stove', 10: 'Grab the pan from the top left stove', 11: 'Turn right and go to the fridge', 12: 'Put the pan in the fridge'}
#
# Annotation 2
# Place a sliced potato in the silver pan into the refrigerator.
# {0: 'Turn around and move to the counter between the coffee maker and the stove.', 1: 'Pick up the knife on the counter.', 2: 'Turn right and move to the white table.', 3: 'Use the knife to slice the potato on the white table.', 4: 'Turn left and head to the refrigerator.', 5: 'Place the knife inside the refrigerator.', 6: 'Turn left and go back to the white table.', 7: 'Pick up a potato slice on the white table.', 8: 'Turn around and go to the stove.', 9: 'Place the potato slice in to the silver pan on the stove.', 10: 'Pick up the silver pan on the stove.', 11: 'Turn right and move to the refrigerator.', 12: 'Place the silver pan inside the refrigerator.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7020720915350859
# {0: 'turn right and walk to the stove .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the white table .', 3: 'slice the potato on the table .', 4: 'turn left , walk to the fridge .', 5: 'put the knife in the fridge .', 6: 'turn left and walk to the white table .', 7: 'pick up a slice of potato from the table .', 8: 'turn right and walk to the stove .', 9: 'place the potato in the pan on the stove .', 10: 'pick up the pan from the stove .', 11: 'turn right , walk to the fridge .', 12: 'place the plate in the fridge .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.10725245955904121
# {0: 'turn right and walk to the counter then turn right and walk up to the counter .', 1: 'pick up the knife from the counter .', 2: 'turn around and go to the white table .', 3: 'slice the potato on the table', 4: 'turn around and go to the fridge .', 5: 'put the knife in the fridge', 6: 'turn around and go to the white table .', 7: 'pick up the potato slice from the table .', 8: 'turn around and go to the stove .', 9: 'put the potato in the pan on the front left burner .', 10: 'pick up the pan with the knife in it .', 11: 'turn right and walk to the fridge .', 12: 'put the pan in the fridge'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14928875986854087
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the white table .', 3: 'cut the potato on the table into slices .', 4: 'turn left , go forward , turn left , go forward to the fridge .', 5: 'put the knife in the fridge', 6: 'turn around and walk to the white table .', 7: 'pick up a slice of potato on the table .', 8: 'turn around and walk to the stove .', 9: 'place the potato in the pan on the back left burner .', 10: 'pick up the pan from the stove .', 11: 'turn right and walk to the fridge .', 12: 'put the pan in the fridge'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14928875986854087
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the white table .', 3: 'cut the potato on the table into slices .', 4: 'turn around and go to the fridge .', 5: 'put the knife in the fridge', 6: 'turn around and go to the white table .', 7: 'pick up a slice of potato .', 8: 'turn around and go to the stove .', 9: 'place the potato slice in the pan on the back left burner .', 10: 'pick up the pan from the stove .', 11: 'turn right and walk to the fridge .', 12: 'put the pan in the fridge'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1591468185738905
# {0: 'turn around and go to the counter to the left of the oven .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk back to the white table .', 3: 'cut the potato on the table into slices .', 4: 'turn around and go to the fridge .', 5: 'put the knife in the fridge', 6: 'turn around and go back to the white table .', 7: 'pick up a slice of potato on the table .', 8: 'turn around and go to the stove .', 9: 'place the potato slice in the pan on the back left burner .', 10: 'pick up the pan from the stove .', 11: 'turn right and walk to the fridge .', 12: 'put the pan in the fridge'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14817872927198217
# {0: 'turn around and go to the counter to the left of the oven .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the white table .', 3: 'cut the potato on the table into slices .', 4: 'turn around and go to the fridge .', 5: 'put the knife in the fridge', 6: 'turn around and go to the white table .', 7: 'pick up a slice of potato on the table .', 8: 'turn around and go to the stove .', 9: 'place the potato slice in the pan on the back left burner .', 10: 'pick up the pan from the stove .', 11: 'turn right and walk to the fridge .', 12: 'put the pan in the fridge'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_154238_160623_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-Cabinet-310/trial_T20190908_154238_160623
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a book into a cabinet.
# {0: 'Walk up to the bed.', 1: 'Pick up the book off of the bed.', 2: 'Turn left and walk towards the wall, then turn left, walk up to the wooden table and look up at the cabinets.', 3: 'Open the leftmost cabinet door and put the book inside, then close the door.'}
#
# Annotation 1
# To move a book from the bed to the cabinet.
# {0: 'Walk to the bed in front of you. ', 1: 'Pick up the book behind the cushion on the bed. ', 2: 'turn around and walk to the desk, and look up at cabinets above the desk. ', 3: 'Open the cabinet door on the left side, place the book inside of the cabinet, close the door. '}
#
# Annotation 2
# Put the book from the bed in the upper left cabinet over the desk.
# {0: 'Walk forward and stand at the bed.', 1: 'Pick up the book from the bed.', 2: 'Turn around and go to the desk.', 3: 'Put the book in the upper left cabinet over the desk.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4279294650057183
# {0: 'turn right , walk to the bed', 1: 'pick up the book on the bed', 2: 'turn left and walk to the desk .', 3: 'place the book in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7816727591351541
# {0: 'turn right and walk to the bed .', 1: 'pick up the book from the bed', 2: 'turn around and walk to the desk .', 3: 'open the cabinet door and put the book in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.794340478804373
# {0: 'walk to the bed .', 1: 'pick up the book on the bed .', 2: 'turn left and walk to the desk .', 3: 'open the left cabinet door and put the book inside and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8033190088633058
# {0: 'walk to the bed .', 1: 'pick up the book that is on the bed', 2: 'turn around and walk to the desk .', 3: 'open the left cabinet door and put the book inside , then close the door .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8517733228507113
# {0: 'walk to the bed .', 1: 'pick up the book from the bed .', 2: 'turn around and walk to the desk .', 3: 'open the left cabinet door and put the book inside and close the door .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8795290739538499
# {0: 'walk up to the bed .', 1: 'pick up the book from the bed .', 2: 'turn around and walk to the desk .', 3: 'open the left cabinet door and put the book inside and close the door .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_044544_187398_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Pencil-Mug-Dresser-322/trial_T20190907_044544_187398
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cup with a pencil in it on the dresser.
# {0: 'Go left and stand in front of the night stand on the left of the bed.', 1: 'Pick up the pencil from the night stand.', 2: 'Put the pencil in the black cup.', 3: 'Pick the cup up from the night stand.', 4: 'Turn around and go left and then right to face the black dresser.', 5: 'Put the mug on the dresser.'}
#
# Annotation 1
# Place a mug with a pencil in it onto the black cabinet.
# {0: 'Turn left, walk to the trash can, then turn right and walk to the lamp.', 1: 'Pick up the pencil resting on the bottom of the lamp.', 2: 'Place the pencil into the black mug that is between the lamp and the bed.', 3: 'Pick up the black mug with the pencil in it.', 4: 'Turn around and walk to the large black cabinet.', 5: 'Place the mug with the pencil in it on the large black cabinet.'}
#
# Annotation 2
# Put a mug with pencil on the black dresser.
# {0: 'Turn left and go to the small table on the left side of the bed. ', 1: 'Pick up the pencil on the table. ', 2: 'Put the pencil in the mug on the table. ', 3: 'Pick up the mug with pencil.', 4: 'Turn around and bring the mug with pencil to the black dresser. ', 5: 'Put the mug on the black dresser. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6678295699732212
# {0: 'turn left and walk to the bed , then turn right and walk to the bed .', 1: 'pick up the pencil on the table .', 2: 'place the pencil in the white mug .', 3: 'pick up the mug from the table .', 4: 'turn around and walk to the dresser on the left .', 5: 'put the mug with the spoon in it on the dresser .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5151847188483573
# {0: 'turn left and walk to the wall , then turn right and walk up to the night stand .', 1: 'pick up the pencil on the night stand .', 2: 'put the pencil in the mug .', 3: 'pick up the mug with the pencil in it .', 4: 'turn around and walk to the black dresser .', 5: 'put the mug on the dresser .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5783481809608249
# {0: 'turn left and walk to the wall then turn right and walk to the night stand .', 1: 'pick up the pencil on the night stand .', 2: 'put the pencil in the mug on the night stand .', 3: 'pick up the mug with the pencil in it .', 4: 'turn around and walk to the black dresser .', 5: 'put the mug on the dresser .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5425623037065161
# {0: 'turn left and walk to the wall then turn right and walk to the night stand .', 1: 'pick up the pencil on the nightstand .', 2: 'put the pencil in the mug on the night stand .', 3: 'pick up the mug with the pencil in it .', 4: 'turn around and walk to the black dresser .', 5: 'put the mug on the dresser .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6731259254247277
# {0: 'turn left and walk to the wall then turn right and walk to the night stand .', 1: 'pick up the pencil from the night stand .', 2: 'put the pencil in the mug on the left side of the table .', 3: 'pick up the mug with the pencil in it .', 4: 'turn around and walk to the black dresser .', 5: 'put the mug on the dresser .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6589206477501497
# {0: 'turn left and walk to the wall then turn right and walk to the night stand .', 1: 'pick up the pencil on the night stand .', 2: 'put the pencil in the mug on the left side of the table .', 3: 'pick up the mug with the pencil in it .', 4: 'turn around and walk to the black dresser .', 5: 'put the mug on the black dresser .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_015237_331804_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Box-None-FloorLamp-223/trial_T20190907_015237_331804
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine an empty box by the light of a floor lamp
# {0: 'turn left, go towards the couch, turn right, go forward along the couch until the box, and turn to face the empty box', 1: 'take the empty box', 2: 'turn right, head towards the television, turn right at the television, head to the lamp in the corner', 3: 'turn on the floor lamp'}
#
# Annotation 1
# Inspect a box near a lit lamp.
# {0: 'Go to the right side of the couch on the left.', 1: 'Take the box from the couch cushion.', 2: 'Turn around, go to the lamp in the corner next to the chair.', 3: 'Turn the lamp on.'}
#
# Annotation 2
# Turn on the lamp.
# {0: 'Move to the white couch.', 1: 'Pick up the box on the couch. ', 2: 'Bring the box to lamp in the corner. ', 3: 'Turn on the lamp.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5441131268832174
# {0: 'turn left and walk to the couch .', 1: 'pick up the box from the couch .', 2: 'turn right , walk to the lamp', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.426053167108506
# {0: 'turn left and walk to the couch .', 1: 'pick up the box from the couch .', 2: 'turn right and walk to the wall , then turn right and walk up to the floor lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3862531748140021
# {0: 'turn left and walk to the couch , then turn right and walk over to the white box on the couch .', 1: 'pick up the box on the couch .', 2: 'turn right , walk towards the tv , turn right , walk straight , turn left to face the lamp', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6435667453234997
# {0: 'turn left and walk to the couch , then turn right and walk over to the white box on the couch .', 1: 'pick up the box from the couch .', 2: 'turn right , go to the lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.868394852474527
# {0: 'go to the white couch', 1: 'pick up the box on the couch .', 2: 'turn right , go to the lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.868394852474527
# {0: 'go to the white couch', 1: 'pick up the box on the couch .', 2: 'turn right , go to the lamp in the corner .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_155247_137362_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SprayBottle-None-Toilet-426/trial_T20190908_155247_137362
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a spray bottle on the back of the toilet.
# {0: 'Turn around and go to the counter behind you. ', 1: 'Pick up the yellow spray bottle closest to the green rag, on the counter. ', 2: 'Turn around and go to the toilet. ', 3: 'Place the yellow spray bottle on the back of the toilet, to the left of the candle. '}
#
# Annotation 1
# Put a spray bottle on the toilet.
# {0: 'Turn around and walk to the white topped table.', 1: "Pick up the yellow spray bottle that's in front of you.", 2: 'Turn around and take a step to your left then walk to the toilet.', 3: 'Put the spray bottle on the toilet tank.'}
#
# Annotation 2
# Put a bottle on the back of the toilet.
# {0: 'Turn around and face the white counter with the green drawers underneath.', 1: 'Pink the spray bottle up from the white counter.', 2: 'Turn around and face the toilet.', 3: 'Put the bottle on the back of the toilet.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6650854651247268
# {0: 'turn around and walk to the counter .', 1: 'pick up the spray bottle from the counter .', 2: 'turn around and walk to the toilet .', 3: 'place the spray bottle on the back of the toilet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8302664110449529
# {0: 'turn around and walk to the white table .', 1: 'pick up the yellow spray bottle from the counter .', 2: 'turn around and go to the toilet .', 3: 'put the spray bottle on the back of the toilet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8184319049652661
# {0: 'turn around and walk to the white dresser .', 1: 'pick up the yellow spray bottle closest to the edge of the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the spray bottle on the back of the toilet .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7997940776787956
# {0: 'turn around and walk to the white counter .', 1: 'pick up the yellow spray bottle closest to the edge of the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the spray bottle on the toilet tank lid .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8100538122333915
# {0: 'turn around and walk to the white dresser .', 1: 'pick up the yellow spray bottle closest to the edge of the counter .', 2: 'turn around and go to the toilet .', 3: 'put the spray bottle on the toilet tank lid .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8593791072130912
# {0: 'turn around and walk to the white dresser .', 1: 'pick up the yellow spray bottle closest to the edge of the counter .', 2: 'turn around and go to the toilet .', 3: 'put the spray bottle on the back of the toilet .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# BEST valid_seen
best_valid_seen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_seen_ids_best_10, epoch_list=valid_seen_epoch_list, split='valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190906_201007_149137_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Pillow-None-FloorLamp-223/trial_T20190906_201007_149137
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# hold a pillow while turning on a lamp
# {0: 'Take right, take another right, walk to chair', 1: 'Grab pillow from chair', 2: 'Take right, walk forward to the television stand, turn to face chair on right', 3: 'Turn on lamp next to chair'}
#
# Annotation 1
# Examine a pillow in the light of a tall lamp.
# {0: 'Turn right and take a step, then turn right again, walk up to the wall, and turn right to face the chair.', 1: 'Pick up the white pillow off of the seat of the chair.', 2: 'Turn right and walk over to the tall lamp in the corner of the room.', 3: 'Turn on the light of the tall lamp.'}
#
# Annotation 2
# Turn on the tall lamp in the corner while carrying a white cushion.
# {0: 'Turn around and walk to the left side of the white chair.', 1: 'Pick up the white cushion from the chair.', 2: 'Turn right and walk to the tall lamp in the corner.', 3: 'Turn on the lamp.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.48118868568437895
# {0: 'turn right and walk to the white table .', 1: 'pick up the pillow on the chair .', 2: 'turn right and walk to the lamp on the right .', 3: 'turn the lamp on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09835556765669314
# {0: 'turn right and walk to the wall , then turn right and walk up to the window .', 1: 'pick up the pillow from the chair .', 2: 'turn right and walk to the tall lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5476550138733194
# {0: 'turn right and walk to the wall , then turn right again to face the chair .', 1: 'pick up the pillow from the chair .', 2: 'turn right and walk to the tall lamp in the corner of the room .', 3: 'turn on the tall lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6458635500564464
# {0: 'turn around and go to the chair .', 1: 'pick up the pillow from the chair .', 2: 'turn right and walk to the tall lamp in the corner of the room .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5956226126211587
# {0: 'turn right and walk to the wall , then turn right again to face the chair .', 1: 'pick up the pillow from the chair .', 2: 'turn right and walk to the tall lamp in the corner of the room .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6137858406097411
# {0: 'turn right and walk to the wall , then turn right again to face the chair .', 1: 'pick up the pillow from the chair .', 2: 'turn right and walk to the tall lamp in the corner of the room .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_071602_531614_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-SoapBar-None-Toilet-412/trial_T20190908_071602_531614
# Number of subgoals (exlcuding <No-op>): 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To move two bars of soap to the back of the toilet.
# {0: 'Walk to the sink on the left side. ', 1: 'Pick up the bar of soap from the left side of the sink. ', 2: 'Turn around to face the back of the toilet. ', 3: 'Place the soap on the back of the toilet. ', 4: 'Turn around and face the sink on the right side. ', 5: 'Pick up the bar of soap from the left side of the sink. ', 6: 'Turn around and face the back of the toilet. ', 7: 'Place the soap on the back of the toilet, to the right of the first bar of soap. '}
#
# Annotation 1
# Put the soap bars on top of the toilet
# {0: 'Walk forward and around the toilet to left bathroom sink', 1: 'Pick up the soap bar from the sink', 2: 'Turn around and walk up to the right side of the toilet', 3: 'Put the soap bar on top of the back of the toilet', 4: 'Turn around and walk up to the right bathroom sink', 5: 'Pick up the soap bar from the sink', 6: 'Turn around and walk back to the right side of the toilet', 7: 'Put the soap bar on top of the back of the toilet'}
#
# Annotation 2
# Place two bars of soap on a toilet tank.
# {0: 'Walk around the toilet to the leftmost sink.', 1: 'Pick up the soap from inside the sink.', 2: 'Turn around and face the side of the toilet.', 3: 'Place the bar of soap on the toilet tank, close to the front left corner.', 4: 'Turn left and walk to the rightmost sink.', 5: 'Pick up the soap from inside the sink.', 6: 'Turn left and walk again to the closest side of the toilet.', 7: 'Place the bar of soap on the toilet tank behind the other bar of soap.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6211546138423371
# {0: 'turn right , walk forward , turn left , walk to the sink .', 1: 'pick up the soap from the sink .', 2: 'turn left and face the toilet .', 3: 'place the soap on the back of the toilet .', 4: 'turn left , walk to the counter , turn left to face the counter .', 5: 'pick up the soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'place the soap on the back of the toilet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5631934987295328
# {0: 'turn around and go to the left side of the sink .', 1: 'pick up the bar of soap from the sink .', 2: 'turn around and face the toilet .', 3: 'put the bar of soap on the back of the toilet .', 4: 'turn around and go to the left side of the sink .', 5: 'pick up the bar of soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'put the bar of soap on the back of the toilet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6229053396907098
# {0: 'walk around the toilet to the left side of the sink .', 1: 'pick up the bar of soap from the sink .', 2: 'turn around and face the toilet .', 3: 'place the bar of soap on the back of the toilet .', 4: 'turn around and walk to the sink on the left .', 5: 'pick up the bar of soap from the sink .', 6: 'turn around and walk to the toilet .', 7: 'place the bar of soap on the back of the toilet .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5661303072918835
# {0: 'walk around the toilet to the left side of the sink .', 1: 'pick up the bar of soap from the sink .', 2: 'turn around and face the toilet .', 3: 'place the bar of soap on the back of the toilet .', 4: 'turn around and walk to the counter .', 5: 'pick up the bar of soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'place the bar of soap on the back of the toilet .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5613602525143572
# {0: 'walk around the toilet to the left side of the sink .', 1: 'pick up the bar of soap from the sink .', 2: 'turn around and face the toilet .', 3: 'put the bar of soap on the back of the toilet .', 4: 'turn around and walk to the far end of the vanity .', 5: 'pick up the bar of soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'place the bar of soap on the back of the toilet .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5119201330447023
# {0: 'walk around the toilet to the left side of the sink .', 1: 'pick up the bar of soap from the sink .', 2: 'turn around and face the toilet .', 3: 'put the bar of soap on the toilet tank .', 4: 'turn around and walk to the far end of the vanity .', 5: 'pick up the bar of soap from the sink .', 6: 'turn left and walk to the toilet .', 7: 'place the bar of soap on the back of the toilet .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_055248_059513_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Candle-None-Toilet-407/trial_T20190909_055248_059513
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a candle on the back of a toilet.
# {0: 'Turn around and face the counter between the two sinks.', 1: 'Pick the candle up from in front of the sink on the right.', 2: 'Turn around and face the toilet.', 3: 'Put the candle on the back of the toilet.'}
#
# Annotation 1
# Move a candle from a counter to the top of a toilet.
# {0: 'Turn around and walk forward to the candle on the counter in front of the sink on the right.', 1: 'Pick up the candle from the counter.', 2: 'Turn around and walk to the toilet.', 3: 'Put the candle on the top of the toilet, to the left of the closest spray bottle.'}
#
# Annotation 2
# Move candle from counter to toilet
# {0: 'Turn around, walk to sink, ', 1: 'Pick up candle in between two sinks', 2: 'Turn around, walk to toilet', 3: 'Place candle on top of toilet'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6517517241337123
# {0: 'turn around , walk to the sink .', 1: 'pick up the candle off of the counter .', 2: 'turn right , walk to the toilet .', 3: 'place the candle on the back of the toilet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5171874764346485
# {0: 'turn around and walk to the counter .', 1: 'pick up the candle on the counter .', 2: 'turn right and walk to the toilet .', 3: 'put the candle on the back of the toilet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5957988858482599
# {0: 'turn around and walk to the counter between the two sinks .', 1: 'pick up the candle on the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the candle on the back of the toilet .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.760169343659297
# {0: 'turn around and walk to the counter between the two sinks .', 1: 'pick up the candle on the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the candle on the back of the toilet .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.760169343659297
# {0: 'turn around and walk to the counter between the two sinks .', 1: 'pick up the candle on the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the candle on the back of the toilet .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7393400066865161
# {0: 'turn around and walk over to the counter between the two sinks .', 1: 'pick up the candle on the counter .', 2: 'turn around and walk to the toilet .', 3: 'put the candle on the back of the toilet .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_101835_683416_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-LettuceSliced-None-SinkBasin-15/trial_T20190909_101835_683416
# Number of subgoals (exlcuding <No-op>): 12
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put a chilled, cut slice of lettuce in the sink
# {0: 'go to the counter to the left of the sink', 1: 'pick up the knife', 2: 'take the knife to the table', 3: 'cut the head of lettuce on the table', 4: 'take the knife to the fridge', 5: 'put the knife in the fridge', 6: 'go back to the table with the lettuce', 7: 'pick up one slice of lettuce', 8: 'take the slice to the fridge', 9: 'chill the slice then remove', 10: 'take the slice to the sink', 11: 'put the chilled slice in the sink'}
#
# Annotation 1
# Put a cold piece of lettuce in the sink.
# {0: 'Go to the counter to the left of the stove.', 1: 'Pick up the knife on the counter.', 2: 'Go past the door on the right to the table.', 3: 'Slice the lettuce on the table.', 4: 'Take the knife to the fridge.', 5: 'Put the knife in the fridge.', 6: 'Go back past the stove on the right to the table.', 7: 'Pick up a lettuce slice on the table.', 8: 'Take the lettuce to the fridge.', 9: 'Chill the lettuce in the fridge.', 10: 'Go to the sink.', 11: 'Put the cold lettuce in the sink.'}
#
# Annotation 2
# Chill a knife and place a chilled slice of lettuce in a sink.
# {0: 'Turn around and walk to the counter to the left of the white stove.', 1: 'Pick up the knife with the yellow handle on the counter.', 2: 'Turn around and walk to the white table on the right.', 3: 'Slice the head of lettuce on the table.', 4: 'Turn left, take a right and walk to the black fridge on the left.', 5: 'Put the knife inside the fridge on the bottom shelf and close the door.', 6: 'Turn left, hang a left at the counter and walk to the white table on the left.', 7: 'Pick up a slice of lettuce from the table.', 8: 'Turn left, take a right and walk to the black fridge on the left.', 9: 'Put the slice of lettuce on the top shelf inside the fridge, chill it, remove it and close the door.', 10: 'Turn left and walk to the sink on the right.', 11: 'Put the slice of chilled lettuce inside the sink.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6666893503675398
# {0: 'turn right , walk forward , turn right , walk to the counter .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk to the white table .', 3: 'slice the lettuce on the table .', 4: 'turn left , walk to the fridge', 5: 'place the knife in the fridge .', 6: 'turn left , walk forward , turn left , walk to the white table .', 7: 'pick up a slice of lettuce from the table .', 8: 'turn left and walk to the fridge .', 9: 'place the lettuce slice in the fridge .', 10: 'turn left and walk to the sink .', 11: 'place the lettuce in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4691048638657837
# {0: 'turn around and go to the counter to the left of the stove .', 1: 'pick up the knife from the counter .', 2: 'turn around and go to the white table .', 3: 'slice the lettuce on the table', 4: 'turn left and go to the fridge .', 5: 'put the knife in the fridge .', 6: 'turn left and go to the white table .', 7: 'pick up the lettuce on the table .', 8: 'turn left and go to the fridge .', 9: 'put the lettuce in the fridge and close the door and then open the door and pick up the lettuce then close the door .', 10: 'turn left and go to the sink .', 11: 'put the cabbage in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5070170530505996
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife on the counter .', 2: 'turn around and walk to the table .', 3: 'cut the lettuce on the table into slices .', 4: 'turn left and walk to the fridge .', 5: 'open the fridge and place the knife inside .', 6: 'turn left and walk to the end of the table , then turn left and walk to the wall then turn left to face the table .', 7: 'pick up the head of lettuce on the table .', 8: 'turn left and walk to the fridge .', 9: 'chill the lettuce in the fridge and then take it out .', 10: 'go to the sink', 11: 'place the lettuce in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5929858813480127
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife with the yellow handle from the counter .', 2: 'turn around and walk to the table .', 3: 'cut the lettuce on the table into slices .', 4: 'turn left and walk to the fridge .', 5: 'put the knife in the fridge .', 6: 'turn left and go to the table .', 7: 'pick up the head of lettuce on the table .', 8: 'turn left and walk to the fridge .', 9: 'chill the lettuce in the fridge and then take it out .', 10: 'go left to the sink', 11: 'place the slice of lettuce in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6121419305731065
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife with the yellow handle from the counter .', 2: 'turn around and walk to the table .', 3: 'slice the lettuce on the table .', 4: 'turn left and go to the fridge .', 5: 'put the knife in the fridge .', 6: 'turn left and go to the right side of the table .', 7: 'pick up the head of lettuce on the table .', 8: 'turn left and go to the fridge .', 9: 'cool the lettuce slice in the fridge and remove it .', 10: 'go left to the sink', 11: 'put the slice of lettuce in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5564788309182602
# {0: 'turn around and walk to the counter to the left of the stove .', 1: 'pick up the knife with the yellow handle from the counter .', 2: 'turn around and walk to the table .', 3: 'cut the lettuce on the table into slices .', 4: 'turn left and go to the fridge .', 5: 'put the knife in the fridge', 6: 'turn left and go to the right side of the table .', 7: 'pick up the head of lettuce on the table .', 8: 'turn left and go to the fridge .', 9: 'cool the lettuce slice in the fridge and remove it .', 10: 'go left to the sink', 11: 'put the slice of lettuce in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_150719_492274_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Bowl-None-DeskLamp-301/trial_T20190909_150719_492274
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# take the bowl to the lamp
# {0: 'go to the desk', 1: 'take the bowl from the desk', 2: 'take the bowl to the lamp', 3: 'turn on the lamp'}
#
# Annotation 1
# Look at a grey bowl under a lit lamp.
# {0: 'Make a right to walk to the white desk.', 1: 'Pick up the large grey bowl from the desk.', 2: 'Make a right to walk to the white dresser.', 3: 'Turn on the lamp on the dresser.'}
#
# Annotation 2
# Look at a bowl by the light of a lamp.
# {0: 'Turn right and walk past the desk chair, and face the desk.', 1: 'Pick up the gray bowl on the desk.', 2: 'Turn right and walk to the dresser at the foot of the bed.', 3: 'Turn on the lamp on the dresser.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.31485887809356117
# {0: 'turn right , walk to the desk , turn right to face the desk .', 1: 'pick up the bowl with the spoon in it .', 2: 'turn around , walk to the shelf , turn right , walk to the wall , turn right to face the dresser .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42912271837635974
# {0: 'turn right and walk to the wall , then turn right and walk up to the desk .', 1: 'pick up the bowl from the desk .', 2: 'turn right and walk to the white dresser .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.52101908806209
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl from the desk .', 2: 'turn around and walk to the white dresser .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5542267333907968
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl from the desk .', 2: 'turn around and walk to the dresser .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5732356967616637
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl from the desk .', 2: 'turn around and walk to the dresser .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5542267333907968
# {0: 'turn right and walk to the desk .', 1: 'pick up the bowl from the desk .', 2: 'turn around and walk to the dresser .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_051813_197569_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Watch-None-SideTable-222/trial_T20190909_051813_197569
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put one watch on the end tale.
# {0: 'Turn around and go to the coffee table. ', 1: 'Pick up the watch on the front, right corner of the table. ', 2: 'Go around the coffee table, through the couch to your right, to the end table across from you, between the couch and the chair. ', 3: 'Place the watch on the front, left corner of the end table. '}
#
# Annotation 1
# Put a watch on the corner table.
# {0: 'Turn around and walk to the coffee table, then turn left to face the other side of the room.', 1: 'Pick up the closest watch from the table.', 2: 'Turn right and walk to the small table in the corner between the chair and the couch.', 3: 'Put the watch on the left near corner of the table.'}
#
# Annotation 2
# Move the watch from table to end table
# {0: 'Turn around, walk to table, turn left, ', 1: 'Pick up watch off of table', 2: 'Turn right, walk to end of table', 3: 'Place watch on end table beside chair'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7134618492818114
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the watch off of the coffee table .', 2: 'turn right and walk to the chair .', 3: 'place the watch on the right side of the blue table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5201476887714397
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the coffee table .', 2: 'turn right and walk to the couch .', 3: 'put the watch on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5239058725611361
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the coffee table .', 2: 'turn right and walk over to the chair .', 3: 'place the watch on the right side of the table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4776499310431295
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the table .', 2: 'turn right and walk over to the black chair .', 3: 'put the watch on the end table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4776499310431295
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the table .', 2: 'turn right and walk over to the black chair .', 3: 'put the watch on the end table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4734082572272963
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the table .', 2: 'turn right and walk over to the black table .', 3: 'put the watch on the end table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_232929_254246_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-RemoteControl-None-FloorLamp-202/trial_T20190908_232929_254246
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a remote control by the light of a floor lamp.
# {0: 'Turn left towards the remote control on the coffee table.', 1: 'Pick up the remote control from the coffee table.', 2: 'Turn right and walk to the tall lamp in the corner.', 3: 'Turn on the lamp.'}
#
# Annotation 1
# Examine the remote control under the light of the floor lamp
# {0: 'Walk slightly forward and turn left to face the coffee table', 1: 'Pick up the remote control from the coffee table', 2: 'Turn right and walk up to the floor lamp in the corner', 3: 'Turn on the floor lamp'}
#
# Annotation 2
# Examine the remote by the light of the lamp.
#
# {0: 'Turn around to face the coffee table.', 1: 'Pick up the remote control from the coffee table.', 2: 'Turn right and carry the remote to the wall, then head right again to the lamp in the corner.', 3: 'Turn on the lamp in the corner to look at the remote.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7067576115339109
# {0: 'turn right , walk forward , turn left to face the coffee table .', 1: 'pick up the remote control from the coffee table .', 2: 'turn right , walk to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5128403605192852
# {0: 'walk to the coffee table', 1: 'pick up the remote control from the table .', 2: 'turn right and walk to the wall , then turn right and walk up to the tall lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.550332889176173
# {0: 'walk forward and turn left to face the coffee table .', 1: 'pick up the remote on the coffee table .', 2: 'turn to the right and walk to the tall lamp in the corner .', 3: 'turn on the tall lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6021906789503176
# {0: 'walk forward and turn left to face the coffee table .', 1: 'pick up the remote on the coffee table .', 2: 'turn to the right and walk to the tall lamp in the corner .', 3: 'turn on the tall lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6021906789503176
# {0: 'walk forward and turn to the left to face the coffee table .', 1: 'pick up the remote on the coffee table .', 2: 'turn right and walk to the tall lamp in the corner .', 3: 'turn on the tall lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6021906789503176
# {0: 'walk forward and turn to the left to face the coffee table .', 1: 'pick up the remote on the coffee table .', 2: 'turn right and walk to the tall lamp in the corner .', 3: 'turn on the tall lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_125930_920681_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Book-None-Desk-313/trial_T20190908_125930_920681
# Number of subgoals (exlcuding <No-op>): 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move two books from the bed to the desk.
# {0: 'Take a step forward then turn left and walk over to the bed.', 1: 'Pick up the closest book off of the bed.', 2: 'Turn around and walk towards the wall, then turn right to face the desk.', 3: 'Put the book on the desk to the left of the leftmost tissue box.', 4: 'Turn right and walk over to the bed, then turn left and walk to the window, turn right and walk up to the wall then turn right again to face the bed.', 5: 'Pick up the book off of the bed.', 6: 'Turn right and walk back over to the front of the desk.', 7: 'Put the book on the desk to the left of the coffee mug.'}
#
# Annotation 1
# Move the two textbooks from the bed to the desk.
# {0: 'Turn around and move to the long edge of the bed.', 1: 'Pick up the first textbook nearest to you on the side of the bed.', 2: 'Turn around and move to the desk in the corner of the room.', 3: 'Place the first textbook down on the desk to the left of the tissue box.', 4: 'Turn right and move to the short edge of the bed.', 5: 'Pick up the second textbook next to the smartphone on the bed.', 6: 'Turn around and go back to the desk.', 7: 'Place the second textbook on the desk above the tissue box.'}
#
# Annotation 2
# Put the two book on the desk
# {0: 'Turn left move forward to the side of the bed', 1: 'Pick up the book closer to you', 2: 'Turn left then head to the desk', 3: 'Put the book on the desk', 4: 'Turn right walk forward the bed then stand on the end of the bed', 5: 'Pick up the book on the bed beside the cell phone', 6: 'Turn right then head to in front of the desk', 7: 'Put the book in between the lamp and mug'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5804731739435299
# {0: 'turn left , walk to the bed', 1: 'pick up the book on the bed', 2: 'turn around and walk to the desk .', 3: 'place the book on the desk', 4: 'turn right , walk to the bed , turn right , walk to the bed , turn right to face the bed .', 5: 'pick up the book from the bed', 6: 'turn right , walk to the desk , turn right to face the desk .', 7: 'place the book on the desk'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7393295244220685
# {0: 'turn left and walk to the bed .', 1: 'pick up the book from the bed .', 2: 'turn around and go to the desk .', 3: 'put the book on the desk', 4: 'turn right and walk to the bed , then turn left and walk to the wall , then turn right and walk up to the end of the bed .', 5: 'pick up the book from the bed .', 6: 'turn right and walk to the desk .', 7: 'put the book on the desk'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7621533238767668
# {0: 'turn left and walk to the bed .', 1: 'pick up the book on the bed .', 2: 'turn around and walk to the desk .', 3: 'put the book on the desk', 4: 'turn right and walk to the bed then turn left and walk to the end of the bed then turn right and walk to the wall then turn right and walk to the end of the bed .', 5: 'pick up the book on the bed .', 6: 'turn right and walk to the desk , then turn right and walk to the desk .', 7: 'put the book on the desk to the right of the chair .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6438122740449651
# {0: 'turn left and walk to the bed .', 1: 'pick up the book from the bed .', 2: 'turn around and walk to the desk .', 3: 'put the book on the desk', 4: 'turn right and walk to the bed then turn left and walk to the end of the bed then turn right and walk to the end of the bed .', 5: 'pick up the book from the bed .', 6: 'turn right and walk to the desk , then turn right and walk to the desk .', 7: 'place the book on the desk in front of the chair .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6074342434746606
# {0: 'turn left and walk to the bed .', 1: 'pick up the book on the bed .', 2: 'turn around and go to the desk .', 3: 'put the book on the desk', 4: 'turn right and walk to the bed then turn left and walk to the end of the bed .', 5: 'pick up the book on the bed .', 6: 'turn right and walk to the desk .', 7: 'place the book on the desk in front of the chair .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6074342434746606
# {0: 'turn left and walk to the bed .', 1: 'pick up the book on the bed .', 2: 'turn around and go to the desk .', 3: 'put the book on the desk', 4: 'turn right and walk to the bed then turn left and walk to the end of the bed .', 5: 'pick up the book on the bed .', 6: 'turn around and go to the desk .', 7: 'place the book on the desk in front of the chair .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_154521_553270_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-402/trial_T20190909_154521_553270
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a clean wash cloth in the tub.
# {0: 'Turn around and walk to the garbage then turn left and walk to the wall then turn left.', 1: "Pick up the dirty purple wash cloth that's in front of you.", 2: 'Turn left and walk to the closest sink then turn left to face it.', 3: 'Wash the cloth in the sink and then pick it back up and shut off the water.', 4: 'Turn around and take three steps then turn right and walk to the tub.', 5: 'Put the wash cloth in the tub.'}
#
# Annotation 1
# rinse the rag from the tub then put it back
# {0: 'go to the tub', 1: 'take the purple rag from the basin', 2: 'take the rag to the sink', 3: 'rinse the rag in the sink then remove', 4: 'take the rag back to the tub', 5: 'put the rag in the tub'}
#
# Annotation 2
# Put a clean cloth in a tub.
# {0: 'Turn around and face the end of the tub where the faucet is.', 1: 'Pick the purple cloth up from the tub.', 2: 'Turn left and then to the left again to face the sink on the left.', 3: 'Put the cloth in the sink and turn the water on and then off and pick the cloth up again.', 4: 'Turn around and go right to face the tub.', 5: 'Put the cloth in the tub.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07817058205984675
# {0: 'turn around , walk forward , turn left to face the tub .', 1: 'pick up the rag in the tub .', 2: 'turn left and walk to the sink .', 3: 'place the rag in the sink .', 4: 'turn around , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward ,', 5: 'place the rag in the tub .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38021025491656274
# {0: 'turn right and walk to the bathtub .', 1: 'pick up the rag from the bathtub .', 2: 'turn left and walk to the sink .', 3: 'put the rag in the sink , turn on the water , turn off the water , and remove the clean rag .', 4: 'turn left and walk to the bathtub .', 5: 'put the rag in the bathtub .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7863227001645914
# {0: 'turn around and walk to the tub .', 1: 'pick up the rag from the tub .', 2: 'turn left and walk to the sink on the left .', 3: 'wash the rag in the sink .', 4: 'turn left and walk to the bathtub .', 5: 'put the rag in the tub .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8212059102925581
# {0: 'turn around and walk to the tub .', 1: 'pick up the rag from the tub .', 2: 'turn left and walk to the sink on the left .', 3: 'wash the rag in the sink .', 4: 'turn left and walk to the tub .', 5: 'put the rag in the tub .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7965287407063729
# {0: 'turn around and walk to the tub .', 1: 'pick up the rag from the tub .', 2: 'turn left and walk to the sink .', 3: 'wash the rag in the sink .', 4: 'turn left and walk to the tub .', 5: 'put the rag in the tub .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7000271276280399
# {0: 'turn around and walk to the tub .', 1: 'pick up the rag from the tub .', 2: 'turn left and walk to the sink on the left .', 3: 'wash the rag in the sink .', 4: 'turn left and walk to the bathtub .', 5: 'put the rag in the tub , left of the other rag .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_124425_112757_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-ButterKnife-None-Drawer-8/trial_T20190909_124425_112757
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a clean knife in a drawer.
# {0: 'Walk ahead, and then veer right to the sink.', 1: 'Pick up the knife to the left of the sink.', 2: 'Take a step right.', 3: 'Wash the knife in the sink.', 4: 'Turn left.', 5: 'Open the drawer in the corner, the one on the right side counter. Place the knife in it.'}
#
# Annotation 1
# Put a clean butter knife in a drawer.
# {0: 'Walk forward, then hang a left and walk over to the sink.', 1: 'Pick up the butter knife off of the counter to the left of the sink.', 2: 'Turn right and walk forward, then turn left to face the sink.', 3: 'Put the butter knife in the sink and turn on the water, after a couple seconds turn the water off and remove the now clean butter knife.', 4: 'Turn left to face the counter.', 5: 'Open the last drawer on your right and put the clean butter knife inside, then close the drawer.'}
#
# Annotation 2
# Put a rinsed off knife in the drawer.
# {0: 'Turn right and go to the sink.', 1: 'Pick up the knife on the left side of the sink. ', 2: 'Go to the right side of the sink.', 3: 'Rinse off the knife in the sink and pick it back up.', 4: 'Turn left toward the bread on the counter.', 5: 'Put the knife in the drawer below the bread.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5354275186545985
# {0: 'turn right and walk to the sink .', 1: 'pick up the knife in the sink .', 2: 'turn right and walk to the sink .', 3: 'place the knife in the sink .', 4: 'turn left to face the counter .', 5: 'place the knife in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7909002643361273
# {0: 'turn right and walk to the sink .', 1: 'pick up the knife from the sink .', 2: 'turn right and walk to the sink .', 3: 'put the knife in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean knife .', 4: 'turn left to face the counter .', 5: 'open the drawer and put the knife in it .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7726791420801226
# {0: 'walk to the counter to the left of the sink .', 1: 'pick up the knife on the counter .', 2: 'move to the right side of the sink .', 3: 'wash the knife in the sink .', 4: 'turn left to face the counter .', 5: 'open the drawer on the left , put the knife in the drawer , close the drawer .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6973941967843806
# {0: 'walk to the counter to the left of the sink', 1: 'pick up the knife on the counter .', 2: 'move to the right and face the sink .', 3: 'wash the knife in the sink .', 4: 'turn left to face the counter .', 5: 'open the drawer on the left , put the knife in the drawer , close the drawer .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6421973106053331
# {0: 'walk to the counter to the left of the sink', 1: 'pick up the knife on the counter .', 2: 'move to the right side of the sink .', 3: 'wash the knife in the sink .', 4: 'turn left to face the counter .', 5: 'put the knife in the drawer'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5460830702460205
# {0: 'walk to the counter to the left of the sink', 1: 'pick up the knife on the counter .', 2: 'move right to the sink', 3: 'wash the knife in the sink .', 4: 'turn left to face the counter .', 5: 'put the knife in the drawer'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# BEST valid_unseen
best_valid_unseen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_unseen_ids_best_10, epoch_list=valid_unseen_epoch_list, split='valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190907_194015_037530_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-ButterKnife-Pan-SinkBasin-10/trial_T20190907_194015_037530
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a pan with a knife in it in the sink.
# {0: 'Turn around, go to the end of the kitchen island, then turn left.', 1: 'Pick up the butter knife on the kitchen island, in front of the fork.', 2: 'Turn left, go straight, then turn left to face the stove.', 3: 'Put the butter knife in the pan on the stove.', 4: 'Pick up the pan on the stove, with the butter knife in it.', 5: 'Turn left, move forward, then turn left to face the sink.', 6: 'Put the pan in the sink.'}
#
# Annotation 1
# put the knife to the pan on the stove, move the pan into the sink
# {0: 'turn around, walk to the counter at the end on the left', 1: 'grab the knife from the counter', 2: 'turn around to the stove', 3: 'put the knife in the pan on the stove', 4: 'grab the pan with the knife', 5: 'turn around to the sink', 6: 'put the pan in the sink'}
#
# Annotation 2
# Put the pan and knife in the sink.
# {0: 'Turn around and go to the end of the island.', 1: 'Pick up the knife from the counter.', 2: 'Turn around and take the knife to the stove.', 3: 'Put the knife in the pan on the front left of the stove.', 4: 'Pick up the pan and knife from the stove.', 5: 'Turn around to the sink.', 6: 'Put the pan and knife in the sink.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6405254214882081
# {0: 'turn left , walk forward , turn left to face the counter .', 1: 'pick up the knife from the counter .', 2: 'turn left and walk to the stove .', 3: 'place the knife in the pan on the stove .', 4: 'pick up the pan from the stove .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6956072835617279
# {0: 'turn around and go to the counter to the right of the sink .', 1: 'pick up the knife from the counter .', 2: 'turn left and walk to the stove .', 3: 'put the knife in the pan on the back left burner .', 4: 'pick up the pan with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5884893991552206
# {0: 'turn around and walk to the end of the counter , then turn left and walk to the end of the counter .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk to the stove .', 3: 'put the knife in the pan on the back left burner .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'place the pan in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6759927661744912
# {0: 'turn around and walk to the end of the counter , then turn left and walk to the end of the counter .', 1: 'pick up the knife on the counter .', 2: 'turn left , go to the stove', 3: 'put the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'place the pan in the sink'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7567095016342187
# {0: 'turn around and walk to the end of the counter , then turn left to face the sink .', 1: 'pick up the knife on the counter .', 2: 'turn left , go to the stove', 3: 'put the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'place the pan in the sink'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6747543021740523
# {0: 'turn around and walk to the end of the counter on your left .', 1: 'pick up the knife on the counter .', 2: 'turn left , go to the stove', 3: 'put the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'place the pan in the sink'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_235816_620828_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-ButterKnife-Cup-CounterTop-10/trial_T20190908_235816_620828
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put a cup and knife on a counter top
# {0: 'walk to face counter to left of stove', 1: 'pick up butter knife from counter', 2: 'turn around to face sink', 3: 'put knife into green cup inside sink', 4: 'pick up green cup from sink basin', 5: 'turn around to face counter top', 6: 'put cup on counter top'}
#
# Annotation 1
# Put a cup with knife in it, on the counter.
# {0: 'Turn right, move to face the tomato on the counter, left of the stove. ', 1: 'Pick up the smaller silver knife on the counter.', 2: 'Turn around, bring the knife to the sink.', 3: 'Put the knife in the green cup in the sink. ', 4: 'Pick up the cup with knife in the sink. ', 5: 'Turn around, bring the cup to the counter.', 6: 'Put the cup with knife on the counter, in front of the spoon and plate. '}
#
# Annotation 2
# Put the butter knife into a green cup and place the cup onto the counter.
# {0: 'Turn around and walk to the counter on the left of the room, on the left side of the stove. ', 1: 'Pick up the butter knife beside the tomato on the counter.', 2: 'Turn around and move to the sink directly in front of you.', 3: 'Put the butter knife into the green cup in the sink.', 4: 'Pick up the green cup with the butter knife in it.', 5: 'Turn around and move to the counter above the dishwasher. ', 6: 'Put the cup with the butter knife down onto the counter above the dishwasher. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5344320282579377
# {0: 'turn right , walk to the counter .', 1: 'pick up the knife on the counter .', 2: 'turn right , walk to the sink .', 3: 'place the knife in the glass in the sink .', 4: 'pick up the glass with the spoon in the sink .', 5: 'turn right and walk to the counter .', 6: 'put the glass on the counter .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6976552559104457
# {0: 'turn around and go to the counter .', 1: 'pick up the knife from the counter .', 2: 'turn around and face the sink .', 3: 'put the knife in the green cup in the sink .', 4: 'pick up the green cup with the fork in it .', 5: 'turn right and walk to the counter .', 6: 'put the green cup on the counter .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6876937805001683
# {0: 'turn around and face the counter to the left of the stove .', 1: 'pick up the knife on the counter .', 2: 'turn around and face the sink .', 3: 'put the knife in the glass in the sink .', 4: 'pick up the cup with the knife in it .', 5: 'turn right and walk to the counter .', 6: 'place the cup on the counter .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7354410984931022
# {0: 'turn around and face the counter to the left of the stove .', 1: 'pick up the gray knife on the counter .', 2: 'turn around and walk to the sink .', 3: 'put the knife in the glass in the sink .', 4: 'pick up the cup with the knife in it .', 5: 'turn right and walk to the counter .', 6: 'put the cup on the counter .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5297878625800816
# {0: 'turn to the right and go to the counter to the left of the stove .', 1: 'pick up the gray knife on the counter .', 2: 'turn around and face the sink .', 3: 'put the knife in the cup in the sink .', 4: 'pick up the cup with the knife in it .', 5: 'turn right and walk to the counter .', 6: 'put the cup on the counter .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7142292362810896
# {0: 'turn around and go to the counter to the left of the stove .', 1: 'pick up the gray knife on the counter .', 2: 'turn around and face the sink .', 3: 'put the knife in the glass in the sink .', 4: 'pick up the cup with the knife in it .', 5: 'turn right and walk to the counter .', 6: 'put the cup on the counter .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_032543_712058_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Pan-None-CounterTop-10/trial_T20190908_032543_712058
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cleaned pan on a counter top.
# {0: 'Turn left and walk to the stove top on the left side of the room.', 1: 'Pick up the pan from the stove top.', 2: 'Turn around and walk to the sink.', 3: 'Put the pan in the sink, rinse it off, and take it back out of the sink.', 4: 'Turn around and walk to the counter top by the toaster.', 5: 'Put the pan on the counter top, in front of and to the right of the toaster.'}
#
# Annotation 1
# Place a washed pan on a counter.
# {0: 'Turn around, walk, turn right to enter the kitchen, and walk to the stove.', 1: 'Pick up the pan from the front right burner of the stove.', 2: 'Turn around and walk to the sink.', 3: 'Wash the pan in the sink and pick it up again.', 4: 'Turn around and walk to the counter to the left of the sink.', 5: 'Place the pan on the counter to the right of the toaster.'}
#
# Annotation 2
# Put a clean skillet on a counter to the right of a toaster.
# {0: 'Turn left and go to the left of the kitchen island, moving forward until you reach the stove on the left, then turn to face the stove.', 1: 'Pick up the dirty skillet from the stove.', 2: 'Turn around to your left and go to the sink.', 3: 'Wash the skillet in the sink.', 4: 'Face the opposite direction and go the the opposite counter.', 5: 'Put the skillet on the counter above the dishwasher, to the right of the toaster.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4359950430535309
# {0: 'turn left , walk forward , turn left , walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn left and walk to the sink .', 3: 'place the pan in the sink .', 4: 'turn right and walk to the counter .', 5: 'place the pan on the counter .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5529976205861857
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn around and walk to the sink .', 3: 'put the pan in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean pan .', 4: 'turn around and walk to the counter .', 5: 'put the pan down on the counter .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6051368524199965
# {0: 'turn around and walk to the kitchen stove .', 1: 'pick up the pan from the stove .', 2: 'turn left and walk to the sink .', 3: 'place the pan in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean pan .', 4: 'turn around and walk to the counter to the right of the toaster .', 5: 'put the pan on the counter'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6506751070439998
# {0: 'turn around and walk to the kitchen stove on the left .', 1: 'pick up the pan from the stove .', 2: 'turn left and walk to the sink .', 3: 'put the pan in the sink and turn on the water . turn off the water and pick up the pan .', 4: 'turn around and walk to the counter to the right of the toaster .', 5: 'put the pan on the counter'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5862096707253279
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn left and walk to the sink .', 3: 'put the pan in the sink and turn on the water . turn off the water and pick up the pan .', 4: 'turn around and walk to the counter with the toaster on it .', 5: 'put the pan on the counter .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7931726252160145
# {0: 'turn around and walk to the stove .', 1: 'pick up the pan from the stove .', 2: 'turn left and walk to the sink .', 3: 'put the pan in the sink , rinse it off , and take it out of the sink .', 4: 'turn around and walk to the counter to the right of the toaster .', 5: 'put the pan on the counter .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_042101_443154_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-KeyChain-Box-ArmChair-219/trial_T20190909_042101_443154
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a box with a set of keys on a chair.
# {0: 'Turn around and walk to the wooden dresser ahead.', 1: 'Pick up the set of keys from the back left side of the dresser.', 2: 'Turn around and walk to the white couch on the left.', 3: 'Put the set of keys inside the box on the middle of the couch.', 4: 'Pick up the box with the keys inside from the couch.', 5: 'Turn around and walk to the blue chair on the right.', 6: 'Put the box with the keys inside on the left side of the chair.'}
#
# Annotation 1
# Place a box with keys in it on a chair.
# {0: 'Turn around and walk to the dresser.', 1: 'Pick up the set of keys on the dresser.', 2: 'Turn to the right and walk to the couch.', 3: 'Place the keys in the box on the couch.', 4: 'Pick up the box.', 5: 'Turn left and walk to the blue chair.', 6: 'Put the box on the chair to the left of the yellow pillow.'}
#
# Annotation 2
# Put a box with keys in it on the chair.
# {0: 'Turn around and walk to the brown cabinet.', 1: 'Pick up the keys that are on top of the cabinet.', 2: 'Turn around and take a step then turn left and walk to the cream colored couch with the box on it.', 3: 'Put the keys in the box.', 4: 'Pick up the box with the keys in it.', 5: 'Turn left and take a tiny step left then walk forward to the chair.', 6: 'Put the box to the left of the plaid pillow.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.12452196604889429
# {0: 'turn right and walk to the dresser .', 1: 'pick up the keys on the right side of the dresser .', 2: 'turn around , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward ,', 3: 'put the box in the box .', 4: 'pick up the box with the box in it .', 5: 'turn around and walk to the couch .', 6: 'place the box on the chair .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6945949694006859
# {0: 'turn around and go to the cabinet .', 1: 'pick up the keys from the dresser .', 2: 'turn around and go to the couch with the box on it .', 3: 'put the keys in the cardboard box .', 4: 'pick up the box with keys on the couch .', 5: 'turn around and walk to the couch .', 6: 'put the box on the chair .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7091425870485127
# {0: 'turn around and walk to the counter .', 1: 'pick up the keys on the dresser .', 2: 'turn around and walk forward , then hang a left and walk over to the couch with the box on it .', 3: 'put the keys in the box on the couch .', 4: 'pick up the box with keys on the couch .', 5: 'turn around and walk to the front of the couch .', 6: 'put the box on the chair .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7346921713677017
# {0: 'turn around and walk to the cabinet .', 1: 'pick up the keys that are on the dresser .', 2: 'turn around and walk forward , then hang a left and walk over to the couch with the cardboard box on it .', 3: 'put the keys in the box on the couch .', 4: 'pick up the box from the couch .', 5: 'turn around and walk to the sofa .', 6: 'put the box on the chair .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6834815821076223
# {0: 'turn around and walk to the dresser .', 1: 'pick up the keys that are on the dresser', 2: 'turn around and walk forward , then hang a left and walk over to the couch with the cardboard box on it .', 3: 'put the keys in the box on the couch .', 4: 'pick up the box from the couch .', 5: 'turn around and go to the front of the couch .', 6: 'put the box on the chair .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6604154428513835
# {0: 'turn around and walk to the dresser .', 1: 'pick up the keys that are on the dresser', 2: 'turn around , walk forward a few steps , turn left , walk forward to the couch', 3: 'put the keys in the box on the couch .', 4: 'pick up the cardboard box with the keys in it off of the couch .', 5: 'turn around and walk to the front of the couch .', 6: 'put the box on the chair .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_201421_021646_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Mug-None-DeskLamp-308/trial_T20190908_201421_021646
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Turn on the desk lamp.
# {0: 'Turn to your left and go to the desk in front of you. ', 1: 'Pick up the white coffee cup, between the computer and the lamp, on the desk. ', 2: 'Move over to your right so that you are at the right end of the desk. ', 3: 'Turn on the lamp on the front, right corner of the desk. '}
#
# Annotation 1
# turn on a desk lamp with a mug in hand
# {0: 'walk to face the desk', 1: ' pick up the white mug from the desk', 2: 'step back slightly to continue to face desk', 3: 'turn on desk lamp on the desk'}
#
# Annotation 2
# Pick up a mug from the desk, turn on the lamp
# {0: 'Turn to your left and walk to the desk.', 1: 'Pick up the white mug sitting behind the blue pencil between the laptop and the lamp.', 2: 'Move to your right and stand in front of the lamp.', 3: 'Turn the lamp on.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6897484668011622
# {0: 'turn left and walk to the desk .', 1: 'pick up the mug from the desk .', 2: 'turn right and face the desk .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38875355601602346
# {0: 'turn left and walk to the desk .', 1: 'pick up the white mug from the desk', 2: 'turn to the right and face the desk .', 3: 'turn on the lamp'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3522964324907114
# {0: 'turn around and walk to the desk .', 1: 'pick up the black mug from the desk .', 2: 'move to the right to face the desk .', 3: 'turn on the lamp'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.43930316819355303
# {0: 'turn around and walk to the desk .', 1: 'pick up the white mug off of the desk .', 2: 'move to the right a bit and face the desk', 3: 'turn on the light'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4113287436750124
# {0: 'turn left and walk to the desk .', 1: 'pick up the white mug off of the desk .', 2: 'move to the right a bit and face the desk', 3: 'turn on the light on the desk .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3605238009199348
# {0: 'turn left and walk to the wall then turn left and walk to the desk .', 1: 'pick up the white mug off of the desk .', 2: 'move to the right a bit and face the desk', 3: 'turn on the light'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_214946_567644_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-SoapBar-None-Cabinet-424/trial_T20190908_214946_567644
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a clean bar of soap in a cabinet.
# {0: 'Walk up to the right side of the sink counter.', 1: 'Pick up the bar of soap off of the toilet tank to your right.', 2: 'Walk over to the rightmost sink.', 3: 'Put the bar of soap in the sink and turn on the water, after a couple seconds turn the water off and remove the now clean bar of soap.', 4: 'Turn around and walk towards the wall, then turn left and walk towards the shower, turn left again to face the counter.', 5: 'Open the second cabinet door from the right below the counter and put the clean bar of soap inside, then close the cabinet.'}
#
# Annotation 1
# Put washed soap away in a cabinet.
# {0: 'Move forward to the toilet.', 1: 'Pick up the soap on the toilet. ', 2: 'Bring the soap to the right sink.', 3: 'Wash the soap in the right sink. ', 4: 'Bring the washed soap to the cabinet under the right sink.', 5: 'Put the washed soap in the left cabinet under the right sink. '}
#
# Annotation 2
# Put the clean soap in the cabinet
# {0: 'Walk forward to the sink counter', 1: 'Pick up the soap on the right side of sink counter', 2: 'Turn left then face the sink ', 3: 'Put the soap in the sink and rinse it ', 4: 'Turn around to your right then move a little ', 5: 'Open the cabinet on your left and put it the soap '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4298891809754308
# {0: 'turn right and walk to the sink .', 1: 'pick up the soap bar of soap on the back of the toilet .', 2: 'turn around and face the sink .', 3: 'place the soap in the sink .', 4: 'turn around , walk to the sink .', 5: 'open the cabinet under the sink and put the soap in the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.461694302231763
# {0: 'walk forward to the sink .', 1: 'pick up the bar of soap from the back of the toilet .', 2: 'turn left and walk to the sink .', 3: 'put the soap in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean bar of soap .', 4: 'turn right and walk to the sink .', 5: 'open the cabinet door below the sink and put the soap in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5347085256090883
# {0: 'walk forward to the toilet .', 1: 'pick up the bar of soap from the back of the toilet .', 2: 'move to the right to face the sink .', 3: 'put the bar of soap in the sink , turn the water on and then off and pick the soap back up .', 4: 'move to the right side of the sink .', 5: 'open the cabinet under the sink and put the soap in it'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4822681073653483
# {0: 'walk forward to the toilet .', 1: 'pick up the bar of soap from the back of the toilet .', 2: 'move to the sink to the left of the sink', 3: 'put the soap in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean bar of soap .', 4: 'turn right and walk to the sink on the left .', 5: 'open the cabinet under the sink and put the soap in it'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4869623191815698
# {0: 'walk forward to the toilet .', 1: 'pick up the bar of soap from the back of the toilet .', 2: 'move to the sink to the left of the sink', 3: 'put the soap in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean bar of soap .', 4: 'move to the right side of the sink', 5: 'open the cabinet under the sink and put the soap in it'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4744990307847316
# {0: 'walk forward to the toilet .', 1: 'pick up the bar of soap from the toilet tank .', 2: 'move to the left side of the sink .', 3: 'put the soap in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean bar of soap .', 4: 'move to the right side of the sink', 5: 'open the cabinet under the sink and put the soap in it'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_194052_908074_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-ButterKnife-Pan-SinkBasin-10/trial_T20190907_194052_908074
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a pan with a knife in it, in the sink.
# {0: 'Go right, right again and then right to face the counter with the tomato on it.', 1: 'Pick the knife up from the counter.', 2: 'Go to the left and then turn left to face the stove.', 3: 'Put the knife in the pan.', 4: 'Pick the pan up from the stove.', 5: 'Turn around and face the sink.', 6: 'Put the pan in the sink.'}
#
# Annotation 1
# Put a frying pan with a knife in it into the sink.
# {0: 'Take a step forward, then turn right and walk towards the door, hang a right and walk around the kitchen island to to the far side.', 1: 'Pick up the butter knife off of the right side of the kitchen island.', 2: 'Turn left and walk forward, then hang a left and walk up to the stove.', 3: 'Put the knife handle down in the frying pan that is on the front left burner of the stove.', 4: 'Pick up the frying pan with the knife in it off of the stove.', 5: 'Turn left and take a step forward, then turn left again and walk up to the sink.', 6: 'Put the frying pan with the knife in it into the sink basin to the right of the potato.'}
#
# Annotation 2
# put the fork in the pan, move the pan to the sink
# {0: 'turn right, turn right, walk to the refrigerator, turn around', 1: 'grab the knife on the counter', 2: 'turn around, walk to the stove,', 3: 'put the knife in the pan on the stove', 4: 'grab the pan from the stove', 5: 'turn around to the sink', 6: 'put the pan in the sink'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6881426774714218
# {0: 'turn right , walk forward , turn right , walk to the counter .', 1: 'pick up the knife from the counter .', 2: 'turn left , walk to the stove .', 3: 'place the knife in the pan on the stove .', 4: 'pick up the pan from the stove .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.636866094024308
# {0: 'turn right and walk to the counter , then turn right and walk to the wall , then turn right and walk up to the kitchen island .', 1: 'pick up the knife from the counter .', 2: 'turn left and walk to the stove .', 3: 'place the knife in the pan on the back left burner .', 4: 'pick up the pan with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'put the pan in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.723113825339216
# {0: 'turn right and walk towards the door , then hang a right and walk up to the fridge , turn right and walk up to the kitchen island .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk to the stove .', 3: 'place the knife in the pan on the back left burner .', 4: 'pick up the pan with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'put the pan in the sink'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6263399498498913
# {0: 'turn right and walk towards the fridge , then turn right and walk to the fridge , then turn right and walk to the counter .', 1: 'pick up the knife from the counter .', 2: 'turn left , go to stove . turn left to face stove .', 3: 'place the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.690223112204491
# {0: 'turn right and walk around the counter to the left side of the kitchen sink .', 1: 'pick up the knife from the counter .', 2: 'turn left and walk to the stove .', 3: 'place the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7254817711752215
# {0: 'turn right and go past the counter to the left , then turn right and go to the left side of the kitchen island .', 1: 'pick up the knife from the counter .', 2: 'turn left and walk to the stove .', 3: 'put the knife in the pan on the stove .', 4: 'pick up the pan with the knife in it .', 5: 'turn left and walk to the sink .', 6: 'put the pan in the sink'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_025529_706272_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-TomatoSliced-None-SinkBasin-10/trial_T20190909_025529_706272
# Number of subgoals (exlcuding <No-op>): 12
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'SliceObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a warm tomato slice in the sink.
# {0: 'Turn around then turn left and face the counter by the stove in front of you.', 1: 'Take the silver knife off of the counter in front of you.', 2: 'Turn left and face the counter on your right.', 3: 'Slice the tomato on the counter in front of you.', 4: 'Turn around and face the sink in front of you.', 5: 'Place the knife in the sink in front of you.', 6: 'Turn around and face the counter in front of you.', 7: 'Take a tomato slice off of the counter in front of you.', 8: 'Turn right and face the microwave on top of the stove to your left.', 9: 'Heat up the tomato slice in the microwave and take it out.', 10: 'Turn around and face the sink in front of you.', 11: 'Place the warm tomato slice in the sink.'}
#
# Annotation 1
# Heat up a tomato slice in the microwave to put in the sink.
# {0: 'Turn left to walk around the kitchen island, hanging a left and stopping at the counter on the left of the stove.', 1: 'Pick up the smaller knife on the counter to the left of the stove.', 2: 'Turn to face the tomato on the counter.', 3: 'Slice the tomato with the smaller knife.', 4: 'Turn around to face the sink.', 5: 'Put the knife in the sink.', 6: 'Turn around to face the counter to the left of the stove.', 7: 'Pick up a slice of tomato from the countertop.', 8: 'Turn right and walk to the microwave.', 9: 'Heat up the slice of tomato in the microwave, removing it afterwards.', 10: 'Turn left to walk back to the sink.', 11: 'Put the slice of tomato in the sink.'}
#
# Annotation 2
# To heat a tomato slice and place it in the sink.
# {0: 'Turn around and cross the room to face the counter on the left side of stove.', 1: 'Pick up the knife on the counter.', 2: 'Look to the left to face the tomato on the counter.', 3: 'Cut the tomato on the counter into slices.', 4: 'Turn around to face the sink.', 5: 'Place the knife in the sink.', 6: 'Turn around to face the tomato on the counter.', 7: 'Pick up a slice of tomato on the counter.', 8: 'Take a step to the right to face the microwave.', 9: 'Heat the tomato slice in the microwave and remove it.', 10: 'Turn around and step forward to face the sink.', 11: 'Place the tomato slice in the sink.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5188142595616271
# {0: 'turn around and walk to the counter .', 1: 'pick up the knife on the counter .', 2: 'turn left and face the counter .', 3: 'slice the tomato on the counter .', 4: 'turn right and walk to the sink .', 5: 'place the knife in the sink .', 6: 'turn right and walk to the counter .', 7: 'pick up the tomato on the counter .', 8: 'turn right and walk to the microwave .', 9: 'heat the tomato in the microwave .', 10: 'turn left and walk to the sink .', 11: 'place the tomato in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2927606709197253
# {0: 'turn around and go to the counter to the left of the stove .', 1: 'pick up the knife from the counter .', 2: 'turn to the left and face the counter .', 3: 'slice the tomato on the counter .', 4: 'turn around and walk to the sink .', 5: 'put the knife in the sink .', 6: 'turn right and walk to the counter .', 7: 'pick up the tomato from the counter .', 8: 'turn right and walk to the microwave .', 9: 'heat the tomato in the microwave .', 10: 'turn left and walk to the sink .', 11: 'put the tomato in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3371951558061045
# {0: 'turn around and walk to the counter on the right side of the stove .', 1: 'pick up the butter knife that is on the counter .', 2: 'turn left and walk to the counter .', 3: 'slice the tomato on the counter .', 4: 'turn around and walk to the sink .', 5: 'place the knife in the sink .', 6: 'turn around and walk to the counter to the left of the stove .', 7: 'pick up a slice of tomato from the counter .', 8: 'turn right and walk to the stove then turn left and look up to the microwave .', 9: 'heat the tomato slice in the microwave and then remove it .', 10: 'turn left and walk to the sink .', 11: 'place the tomato in the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3145177554762806
# {0: 'turn around and walk to the counter on the right side of the stove .', 1: 'pick up the butter knife that is on the counter .', 2: 'turn left and walk to the counter .', 3: 'slice the tomato on the counter .', 4: 'turn around and walk to the sink .', 5: 'place the knife in the sink .', 6: 'turn right and walk to the counter on the right of the stove .', 7: 'pick up a slice of tomato from the counter .', 8: 'turn right and walk over to the microwave on the left side of the kitchen', 9: 'heat the tomato slice in the microwave and then remove it .', 10: 'turn left and walk to the sink on the left .', 11: 'place the tomato in the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30525757877110943
# {0: 'turn around and walk to the left side of the stove .', 1: 'pick up the butter knife that is on the counter .', 2: 'move to the left to face the counter .', 3: 'slice the tomato on the counter .', 4: 'turn around and walk to the sink .', 5: 'place the knife in the sink .', 6: 'move to the counter to the left of the stove .', 7: 'pick up a slice of tomato from the counter .', 8: 'turn right and walk over to the stove , then turn left and face the microwave .', 9: 'heat the tomato slice in the microwave and then remove it .', 10: 'turn left and walk to the sink .', 11: 'place the tomato in the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2717615424024102
# {0: 'turn around and walk to the left side of the kitchen island .', 1: 'pick up the butter knife that is on the counter .', 2: 'move to the left to face the drawer .', 3: 'slice the tomato on the counter .', 4: 'turn around and walk to the sink .', 5: 'place the knife in the sink .', 6: 'move to the counter to the left of the stove', 7: 'pick up a slice of tomato from the counter .', 8: 'turn right and walk over to the stove , then turn left and face the microwave .', 9: 'heat the tomato slice in the microwave and then remove it .', 10: 'turn left and walk to the sink .', 11: 'place the tomato in the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_103526_341991_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-KeyChain-None-FloorLamp-219/trial_T20190909_103526_341991
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a set of keys by the light of a tall lamp.
# {0: 'Turn around and walk to the blue chair on the right.', 1: 'Pick up the set of keys in the back right corner of the chair.', 2: 'Turn right to face the couch next to the tall lamp.', 3: 'Turn on the tall lamp to the left.'}
#
# Annotation 1
# pick up the keys and view them in the lamp light
# {0: 'turn around and walk straight then turn right and walk straight towards the blue chair', 1: 'pick up the keys on the chair', 2: 'turn right and look up at the lamp', 3: 'turn the lamp on '}
#
# Annotation 2
# Examine a set of keys in the lamp light.
# {0: 'Turn around and move forward, then turn right and go straight to the blue chair.', 1: 'Pick up the keys from the blue chair.', 2: 'Turn right and look up to face the lamp.', 3: 'Turn on the lamp.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6807032383618872
# {0: 'turn around and walk to the chair .', 1: 'pick up the keys from the right side of the couch .', 2: 'turn right to face the lamp .', 3: 'turn the lamp on the floor .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.49033220927970816
# {0: 'turn around and walk to the chair .', 1: 'pick up the keys from the couch .', 2: 'turn right to face the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.44595732409333555
# {0: 'turn around and walk to the couch .', 1: 'pick up the keys from the couch .', 2: 'turn right and look up at the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5411436336445552
# {0: 'turn around and walk to the chair .', 1: 'pick up the keys from the couch .', 2: 'turn right and look up at the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5286916799281683
# {0: 'turn around and walk to the chair .', 1: 'pick up the keys from the couch .', 2: 'turn right , look up to face the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5072307918144695
# {0: 'turn around and walk to the chair .', 1: 'pick up the keys from the couch .', 2: 'turn right , look up to face the lamp .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_025512_298420_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-ButterKnife-Cup-SinkBasin-10/trial_T20190909_025512_298420
# Number of subgoals (exlcuding <No-op>): 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put green cup and knife into sink basin
# {0: 'walk to face counter behind sink', 1: 'pick up butter knife from under sponge on counter', 2: 'walk to face counter to left of stove', 3: 'put knife into green cup on the left on the counter', 4: 'pick up the green cup from counter', 5: 'turn to face the kitchen sink', 6: 'put green cup into sink basin'}
#
# Annotation 1
# Place a glass with a knife in a sink.
# {0: 'Turn right, hang a left at the wall and walk to the counter on the left.', 1: 'Pick up the knife under the green sponge on the counter.', 2: 'Turn around, hang a right at the wall, turn right towards the fridge, turn right and walk to the counter on the left.', 3: 'Put the knife inside the green glass in front of the spatula in the middle of the counter.', 4: 'Pick up the green glass with the knife on the counter.', 5: 'Turn around and walk to the sink.', 6: 'Put the glass with the knife inside the sink.'}
#
# Annotation 2
# Move a knife in a cup to the sink.
# {0: 'Turn right to move around the island to stand facing the counter and centered between the two chairs.', 1: 'Pick up the butter knife from beneath the sponge.', 2: 'Turn left to move around to the other side of the island and stop facing the counter above the dishwasher.', 3: 'Place the knife in the green cup closest to the wall behind the counter.', 4: 'Pick up the cup with the knife in it from the counter.', 5: 'Turn around and face the sink.', 6: 'Place the cup with the knife inside in the sink.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5894377863771401
# {0: 'turn right , walk forward , turn left , walk to the sink .', 1: 'pick up the knife from the counter .', 2: 'turn around , go to the counter , turn right , go to the counter .', 3: 'place the knife in the glass on the counter .', 4: 'pick up the plate with the knife in it .', 5: 'turn right and walk to the sink .', 6: 'put the glass in the sink .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6142484700730766
# {0: 'turn right and go to the sink .', 1: 'pick up the knife from the counter .', 2: 'turn left and go to the counter with the knife .', 3: 'put the knife in the glass .', 4: 'pick up the glass with the knife in it .', 5: 'turn right and walk to the sink .', 6: 'place the cup in the sink .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5265950662446085
# {0: 'turn right and walk to the sink .', 1: 'pick up the knife on the counter .', 2: 'turn left and walk towards the door , then hang a right and walk over to the kitchen counter on the left side of the kitchen .', 3: 'place the knife in the glass on the counter .', 4: 'pick up the glass with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'place the cup with the knife in it into the sink .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5215293899964633
# {0: 'turn right and walk to the sink .', 1: 'pick up the knife on the counter .', 2: 'turn left , go to the counter , turn right , go forward , turn left at the sink , go forward to the counter .', 3: 'place the knife in the glass on the counter .', 4: 'pick up the glass with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'place the cup with the knife in it into the sink .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6689359861400033
# {0: 'go to the sink', 1: 'pick up the knife on the counter .', 2: 'turn left , move to the counter left of the stove .', 3: 'put the knife in the glass on the counter .', 4: 'pick up the glass with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'place the cup with the knife in it into the sink .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6689359861400033
# {0: 'go to the sink', 1: 'pick up the knife on the counter .', 2: 'turn left , move to the counter left of the stove .', 3: 'put the knife in the glass on the counter .', 4: 'pick up the glass with the knife in it .', 5: 'turn around and walk to the sink .', 6: 'place the cup with the knife in it into the sink .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# WORST train_sanity
worst_train_sanity_res = examine_sampled_tasks(sampled_task_ids=ranked_train_sanity_ids_worst_10, epoch_list=train_sanity_epoch_list, split='train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_040645_145153_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Bowl-None-Desk-327/trial_T20190908_040645_145153
# Number of subgoals (exlcuding <No-op>): 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two bowls on the desk.
# {0: 'Turn to your left and go to the far, left end of the night stand between the bed and the wall. ', 1: 'Pick up the bowl on the night stand, between the lamp and the CD. ', 2: 'Turn around and go to the white desk with the black office chair. ', 3: 'Place the bowl on the white desk, between the book and the cell phone. ', 4: 'Go back to the night stand to your right. ', 5: 'Pick up the bowl on the night stand, to the right of the CD. ', 6: 'Turn to your left and go back to the white desk with the black office chair. ', 7: 'Put the bowl on the white desk, to the left of the book. '}
#
# Annotation 1
# Place two bowls on a desk.
# {0: 'Turn left and walk to the dresser at the foot at the bed.', 1: 'Pick up the bowl near the lamp.', 2: 'Turn around and walk to the side of the desk with the chair.', 3: 'Put the bowl on the desk to the right of the book.', 4: 'Turn right and walk back to the dresser at the foot of the bed.', 5: 'Pick up the bowl on the dresser.', 6: 'Turn around and walk back to the front of the desk.', 7: 'Place the bowl on the desk to the left of the book.'}
#
# Annotation 2
# Put two bowls on the desk.,
# {0: 'Turn left and walk to the bed then turn left and walk to the desk then turn right and walk to the dresser then take a step to your left.', 1: "Pick up the bowl that's left of the other bowl.", 2: 'Turn right and walk to the bed then turn right and take a step then turn left and take a step then turn right and walk to the wall then turn right.', 3: 'Put the bowl to the left of the phone.', 4: 'Go back to where you got the first bowl.', 5: "Pick up the bowl that's in front of you.", 6: 'Go back to where you put the first bowl.', 7: 'Put this bowl on the left side of the desk.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.40601607905869697
# {0: 'turn left and walk to the dresser .', 1: 'pick up the bowl with the spoon in it .', 2: 'turn right and walk to the desk on the right .', 3: 'place the bowl on the desk', 4: 'turn right , walk to the bed , turn right , face the dresser .', 5: 'pick up the bowl with the spoon in it .', 6: 'turn left and walk to the desk on the right .', 7: 'place the bowl on the desk'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09127889692898863
# {0: 'turn around and walk to the dresser .', 1: 'pick up the bowl with the pencil in it .', 2: 'turn around and walk to the desk .', 3: 'put the bowl on the desk', 4: 'turn right and walk to the dresser .', 5: 'pick up the bowl from the dresser .', 6: 'turn around and walk to the desk .', 7: 'put the bowl on the desk'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.480473643758618
# {0: 'turn to the left and walk to the bed , then turn left and walk to the dresser , then turn right and walk up to the dresser , then turn right and walk up to the dresser , turn right again to face the dresser .', 1: 'pick up the bowl that is on the dresser', 2: 'turn around and walk to the desk .', 3: 'place the bowl on the desk to the left of the book .', 4: 'go back to the dresser .', 5: 'pick up the bowl that is on the dresser .', 6: 'turn around and walk to the desk .', 7: 'place the bowl on the desk to the left of the book .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16672698045678494
# {0: 'turn left and walk to the bed then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk', 1: 'pick up the bowl that is on the dresser .', 2: 'turn around and walk to the desk .', 3: 'place the bowl on the desk , to the left of the book .', 4: 'go back to the dresser where the lamp is .', 5: 'pick up the bowl that is on the dresser .', 6: 'turn around and walk back to the desk .', 7: 'place the bowl on the desk , to the left of the book .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1583423935611577
# {0: 'turn left and walk to the bed then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk', 1: 'pick up the bowl with the cd in it .', 2: 'turn around and walk to the desk .', 3: 'place the bowl on the desk , to the left of the book .', 4: 'go back to the dresser where the lamp is .', 5: 'pick up the bowl on the dresser .', 6: 'turn around and walk to the desk .', 7: 'place the bowl on the desk , to the left of the book .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1794869066989962
# {0: 'turn left and walk to the bed then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk to the dresser then turn left and walk', 1: "pick up the bowl that ' s in front of you .", 2: 'turn around and walk to the white desk .', 3: 'place the bowl on the desk to the left of the book .', 4: 'go back to the dresser where the lamp is .', 5: 'pick up the bowl on the dresser .', 6: 'turn around and walk to the white desk .', 7: 'place the bowl on the desk to the left of the book .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_131037_058357_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Cloth-None-Drawer-427/trial_T20190908_131037_058357
# Number of subgoals (exlcuding <No-op>): 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two towels in a drawer
# {0: 'Go to the bath tub', 1: 'Take a towel from the tub', 2: 'Go to the bathroom cabinet drawers', 3: 'Place the towel in a cabinet drawer', 4: 'Face the top of the cabinet', 5: 'Pick up a towel from the top of the bathroom cabinet', 6: 'Turn around and face the drawer', 7: 'Place the towel in the same drawer'}
#
# Annotation 1
# Pick up cloths and place them in drawer.
# {0: 'Walk forward, turn right at bath tub', 1: 'Pick up cloth on right side', 2: 'Turn around, turn right', 3: 'open drawer, place cloth in drawer', 4: 'Close drawer, walk forward to counter', 5: 'Pick up cloth on top of counter', 6: 'Turn around, walk forward, turn around', 7: 'Open drawer, place cloth in drawer'}
#
# Annotation 2
# Move wash rags to drawer.
# {0: 'Turn and go to the center of the tub.', 1: 'Pick up the pink wash rag that is in the center of the tub.', 2: 'With the wash rag in hand turn and go to the dresser.', 3: 'Open the top right drawer and place the wash rag in there. Close the drawer.', 4: 'Move over so you are in front of the pink wash rag that is on the dresser.', 5: 'Pick up the pink wash rag on the dresser.', 6: 'With the wash rag in hand move over so you can open the top dresser drawer on the right.', 7: 'Open the drawer and place the wash rag behind the one that is in there.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.37059286170779543
# {0: 'turn right and walk to the tub .', 1: 'pick up the rag in the tub .', 2: 'turn around , walk forward , turn right to face the toilet .', 3: 'open the drawer and put the drawer in the drawer .', 4: 'turn right and walk forward to the counter .', 5: 'pick up the white rag on the counter .', 6: 'turn around , walk to the toilet .', 7: 'open the drawer and put the drawer in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16402978441522226
# {0: 'walk forward to the bath tub .', 1: 'pick up the rag from the bathtub .', 2: 'turn around and walk to the white dresser .', 3: 'put the rag in the drawer .', 4: 'turn right and walk to the counter .', 5: 'pick up the rag on the left side of the counter .', 6: 'turn around and walk forward , then turn right and take a step forward , then turn right again and walk up to the white dresser .', 7: 'put the rag in the drawer .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3270491238692962
# {0: 'walk forward to the bath tub , then turn right to face the bath tub .', 1: 'pick up the pink rag on the right .', 2: 'turn around and walk to the dresser on the right .', 3: 'open the bottom drawer and put the cloth in it', 4: 'walk forward to the dresser .', 5: 'pick up the cloth on the left of the dresser .', 6: 'turn around and walk forward , then turn around to face the dresser .', 7: 'open the bottom drawer and put the cloth in it'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4445405072829502
# {0: 'walk forward to the bath tub , then turn right to face the tub .', 1: 'pick up the pink rag on the right side of the tub .', 2: 'turn around and walk to the dresser on the right .', 3: 'open the drawer below the dresser and put the towel in there .', 4: 'walk forward to the dresser .', 5: 'pick up the towel on the left of the dresser .', 6: 'turn around , walk forward , turn around', 7: 'open the drawer below the dresser and put the towel in it'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4437066205362944
# {0: 'walk forward to the bath tub , then turn right to face the tub .', 1: 'pick up the cloth from the tub .', 2: 'turn around and walk forward , then turn right to face the dresser .', 3: 'open the drawer and place the towel in there .', 4: 'walk forward to the dresser .', 5: 'pick up the towel on the left of the dresser .', 6: 'turn around , walk forward , turn around to face the dresser .', 7: 'open the drawer below the dresser and put the towel in it'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4065839708623245
# {0: 'walk forward to the bath tub , then turn right to face the tub .', 1: 'pick up the pink rag on the right side of the tub .', 2: 'turn around and walk forward , then turn right to face the dresser .', 3: 'place the towel in the second drawer from the left .', 4: 'walk forward to the dresser .', 5: 'pick up the cloth from the dresser .', 6: 'turn around , walk forward , turn around to face the dresser .', 7: 'open the drawer below the dresser and put the towel in it'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_162319_309721_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Statue-None-FloorLamp-202/trial_T20190907_162319_309721
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a small statue of a man by the light of a floor lamp
# {0: 'turn to the right and go forward to the coffee table', 1: 'pick up the small stature of a man from the coffee table', 2: 'turn to the right and go a few steps forward and turn to the left and go to the wall and turn to the right and face the floor lamp', 3: 'turn on the floor lamp'}
#
# Annotation 1
# Turn a lamp on with a statue in hand.
# {0: 'Go right and face the table with a computer on it.', 1: 'Pick the statue up from the table.', 2: 'Go right and then left and cross the room to face the lamp on the right.', 3: 'Turn the lamp on.'}
#
# Annotation 2
# Examine the figurine by the light
# {0: 'Turn to your right walk straight  towards the table', 1: 'Pick up the figurine beside the laptop on the table', 2: 'Turn to your right, turn left then walk toward the wall, then face the lamp', 3: 'Turn on the lamp'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3342032007291566
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the statue on the table .', 2: 'turn right , walk to the lamp , turn right , walk to the lamp .', 3: 'turn the lamp on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3726927806537155
# {0: 'turn to the right and go to the coffee table .', 1: 'pick up the statue from the table .', 2: 'turn right and walk to the wall , then turn left and walk up to the wall , then turn right and walk up to the floor lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30971431233513924
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the statue on the coffee table .', 2: 'turn right , walk to the wall , turn left , walk to the wall , turn right to face the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35844009148925715
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the statue on the table .', 2: 'turn right , walk to the wall , turn left , walk to the lamp', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35844009148925715
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the statue on the table .', 2: 'turn right , walk to the wall , turn left , walk to the lamp', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35731267607238937
# {0: 'turn right and walk to the coffee table .', 1: 'pick up the statue on the coffee table .', 2: 'turn right , walk to the wall , turn left , walk to the lamp', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_171656_314313_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-AppleSliced-None-DiningTable-27/trial_T20190907_171656_314313
# Number of subgoals (exlcuding <No-op>): 10
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'SliceObject', 'PutObject', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To chill a piece of apple and put it down on the white table.
# {0: 'Turn left and face the right side of the white table. ', 1: 'Pick up the knife in front of the pepper shaker on the left. ', 2: 'Turn around and walk to the counter to the right of the stove with the green apple on it. ', 3: 'Slice the green apple to the left of the toaster. ', 4: 'Put the knife down on the right edge of the counter. ', 5: 'Pick up half of the green apple. ', 6: 'Turn and walk to the front of the fridge on the right. ', 7: 'Place the piece of apple inside of the fridge next to the tomato, close the door, wait a few seconds to chill half the apple, take the apple out of the fridge, and close the door. ', 8: 'Turn around and walk back to the white table and facing the middle of the table. ', 9: 'Place the piece of apple down on the white table to the right of the whole apple. '}
#
# Annotation 1
# Cut an apple slice, chill it to place on a table
# {0: 'Move to the white table top to the left of the microwave', 1: 'Pick up the knife on the edge of the table', 2: 'Move to the countertop to the left of the fridge ', 3: 'Slice the apple to the left of the toaster on top of the counter', 4: 'Place the knife to the right of the toaster on the counter', 5: 'Pick up an apple slice to the left of the toaster', 6: 'Carry the apple slice to the black fridge', 7: 'Open the fridge, place the apple on the shelf by the tomato, close the fridge, open and remove apple slice', 8: 'Carry the apple slice to the white table', 9: 'Place the apple slice on the white table in front of the plate'}
#
# Annotation 2
# Slice, chill and place an apple on a kitchen table
# {0: 'Walk forward and then turn to your right so you are facing the kitchen table', 1: 'Pick up a knife off of the kitchen table', 2: 'Turn around so that you are now facing the toaster', 3: 'Use the knife so slice the apple that is sitting to the left of the toaster', 4: 'Place the knife down on the kitchen counter to the right of the toaster', 5: 'Now pick up a piece of the sliced apple', 6: 'Maneuver yourself so that you are now facing the fridge to the right of you', 7: 'Open the fridge and put the apple in it to chill for a few seconds, and then retrieve it', 8: 'Turn around and walk back to the first kitchen table', 9: 'Set the sliced apple down on the kitchen table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32955110505727603
# {0: 'turn right , walk forward , turn left to face the white table .', 1: 'pick up the knife on the table .', 2: 'turn left and walk to the counter .', 3: 'cut the apple on the counter .', 4: 'place the knife on the counter .', 5: 'pick up a piece of apple from the counter .', 6: 'turn around and walk to the fridge .', 7: 'put the apple in the fridge .', 8: 'turn left and walk to the table .', 9: 'place the apple on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.026843400959975866
# {0: 'walk to the white table', 1: 'pick up the knife from the table .', 2: 'turn around and go to the counter with the toaster .', 3: 'slice the apple on the counter .', 4: 'put the knife on the counter .', 5: 'pick up a piece of apple .', 6: 'turn around and go to the fridge .', 7: 'chill the apple in the fridge .', 8: 'turn around and go to the white table .', 9: 'put the apple piece on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.048416568570430224
# {0: 'walk to the table on the left .', 1: 'pick up the knife on the table .', 2: 'turn around and walk to the toaster on the counter .', 3: 'slice the apple on the counter', 4: 'place the knife on the counter .', 5: 'pick up a slice of the apple .', 6: 'turn around and go to the fridge', 7: 'chill the apple in the fridge and then take it out .', 8: 'turn around and walk to the white table .', 9: 'put the apple on the table'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.06999456834487434
# {0: 'walk to the table on the left .', 1: 'pick up the knife on the table .', 2: 'turn around and walk to the counter to the left of the fridge .', 3: 'slice the apple on the counter', 4: 'put the knife down on the counter', 5: 'pick up a piece of the sliced apple .', 6: 'turn around and walk to the fridge .', 7: 'chill the apple in the fridge and then remove it .', 8: 'turn around and go back to the white table .', 9: 'put the apple slice on the table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.048416568570430224
# {0: 'walk to the table on the left .', 1: 'pick up the knife on the table .', 2: 'turn around and walk to the toaster on the counter .', 3: 'slice the apple on the counter', 4: 'put the knife down on the counter', 5: 'pick up a slice of the apple .', 6: 'turn around and walk to the fridge', 7: 'chill the apple in the fridge and then remove it .', 8: 'turn around and go back to the white table .', 9: 'put the apple slice on the table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.048416568570430224
# {0: 'walk to the table on the left .', 1: 'pick up the knife on the table .', 2: 'turn around and walk to the toaster on the counter .', 3: 'slice the apple on the counter', 4: 'put the knife down on the counter', 5: 'pick up a slice of the apple', 6: 'turn around and walk to the fridge', 7: 'chill the apple in the fridge and then remove it .', 8: 'turn around and go back to the white table .', 9: 'put the apple slice on the table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_200441_879615_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-CD-None-Shelf-303/trial_T20190907_200441_879615
# Number of subgoals (exlcuding <No-op>): 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two cds on a shelf.
# {0: "Walk to stand in front of the dresser that's in front of you to the left of the bed.", 1: 'Pick up the cd to the left of the mug you see on the desk.', 2: 'Take a step to your right so you are looking at the shelves hanging on the wall.', 3: 'Put the cd on the second shelf from the bottom of the shelves hanging on the wall.', 4: 'Turn right and walk to the bed then turn left and walk to the dresser.', 5: 'Pick up the cd to the right of the mug.', 6: 'Go back to the shelves where you put the first cd.', 7: 'Put this sc to the right of the first cd.'}
#
# Annotation 1
# Put two discs on a shelf.
# {0: 'Go to the left and face the dresser.', 1: 'Pick up the disc on the left on the dresser.', 2: 'Go left and face the brown shelves on the wall.', 3: 'Put the disc on the middle shelf.', 4: 'Go to the right and face the small dresser.', 5: 'Pick the disc up from the dresser.', 6: 'Go left and turn to face the brown shelves on the wall.', 7: 'Put the disc down on the right of the other disc on the shelf.'}
#
# Annotation 2
# Move two CDs to a shelf below some books.
# {0: 'Move to stand in front of the dresser that has a mirror above it. ', 1: "Pick up the CD from the dresser that's to the left of the coffee mug in the center. ", 2: 'Carry the CD to the closest section of the book shelves. ', 3: 'Place the CD on the empty shelf below the shelf of books. ', 4: 'Move back to the dresser by the mirror. ', 5: "Pick up the remaining CD from the dresser that's to the right of the centered mug.", 6: 'Carry the CD back over to the closest section of the book shelves.', 7: 'Place the CD on the shelf to the right of the last CD you put there.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45895414796073125
# {0: 'turn left and walk to the dresser .', 1: 'pick up the cd from the dresser .', 2: 'turn left and walk to the shelf .', 3: 'place the cd on the shelf', 4: 'turn right , walk forward , turn left to face the dresser .', 5: 'pick up the cd from the dresser .', 6: 'turn left , walk forward , turn right to face the shelf .', 7: 'place the cd on the shelf'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1763104038135416
# {0: 'turn left and walk to the dresser .', 1: 'pick up the cd from the dresser .', 2: 'turn left and walk to the shelves on the wall .', 3: 'put the disc on the shelf', 4: 'turn right and walk to the dresser .', 5: 'pick up the cd from the dresser .', 6: 'turn left and walk to the shelves on the wall .', 7: 'put the disc on the shelf'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1736248762263477
# {0: 'go to the dresser to the left of the bed', 1: 'pick up the cd from the dresser', 2: 'turn left and walk to the shelves on the wall .', 3: 'put the disc on the shelf', 4: 'turn right , walk to the bed , turn left to face the dresser', 5: 'pick up the cd from the dresser', 6: 'turn left and walk to the shelves on the wall .', 7: 'put the disc on the shelf'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.10614195471942124
# {0: 'go to the dresser under the mirror .', 1: 'pick up the cd from the dresser .', 2: 'turn left , go forward a bit , turn right', 3: 'put the disc on the shelf', 4: 'turn right , walk to the bed , turn left to face the dresser', 5: 'pick up the cd from the dresser', 6: 'turn left , go forward a bit , turn right', 7: 'put the disc on the shelf'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13973666207808305
# {0: 'go to the dresser .', 1: 'pick up the cd from the dresser .', 2: 'turn left and walk forward , then turn right to face the shelves .', 3: 'put the disc on the shelf', 4: 'turn right , move to the dresser , turn left .', 5: 'pick up the cd from the dresser', 6: 'turn left , go forward a bit , turn right', 7: 'put the cd on the shelf'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.14458060952110494
# {0: 'go to the dresser under the mirror .', 1: 'pick up the cd from the dresser', 2: 'turn left and walk forward , then turn right to face the shelves .', 3: 'put the disc on the shelf', 4: 'turn right , go forward a bit , turn left to face the dresser', 5: 'pick up the cd from the dresser', 6: 'turn left , go forward a bit , turn right', 7: 'put the cd on the shelf'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_115507_503798_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-PotatoSliced-None-GarbageCan-28/trial_T20190908_115507_503798
# Number of subgoals (exlcuding <No-op>): 13
# https://www.youtube.com/watch?v=HKKh-4WHSsg&t=7s
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'SliceObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'SliceObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# slice up two potatoes in a green waste basket
# {0: 'turn to the right twice and take a few steps and turn to the left and go to the counter', 1: 'pick up the potato from the counter top', 2: 'turn to the right twice and go to the middle of the room and turn to the left and go to the counter top', 3: 'put the potato in the green waste basket underneath the counter top', 4: 'turn to the left and take a few steps and turn to the left and go to the front of the refrigerator and turn to the right and go to the refrigerator', 5: 'open the refrigerator door and take out the potato on the top shelf and close the door', 6: 'turn to the right and take a step and turn to the right and go to the middle of the room and turn to the left and go to the counter top', 7: 'put the potato in the green waste basket underneath the counter top', 8: 'turn to the left and take a few steps and turn to the right facing the counter', 9: 'pick up the yellow handle knife from the counter top', 10: 'turn to the right and take a few steps and turn to the left facing the counter', 11: 'slice up the two potatoes with the knife in the green waste basket'}
#
# Annotation 1
# put potatoes in a bin and slice the potato with a knife
# {0: 'go to the counter between the fridge and the stove', 1: 'pick up the potato from the counter', 2: 'take the potato to the coffee machine', 3: 'put the potato in the green bin below the counter', 4: 'go the fridge', 5: 'take the potato from the fridge', 6: 'take the potato back to the counter where the coffee machine is', 7: 'put the potato in the green bin below the counter', 8: 'walk over to counter above the dishwasher', 9: 'take the knife from the counter', 10: 'take the knife over to the bin where you put the potatoes', 11: 'cut the potatoes in the bin with the knife'}
#
# Annotation 2
# Put two eggs in a bin and cut them with a knife
# {0: 'Go to the counter between the fridge and the stove', 1: 'Pick up the egg on the counter', 2: 'Go to the green bin', 3: 'Place the egg in the bin', 4: 'Go to the fridge', 5: 'Take an egg out of the fridge', 6: 'Go to the green bin', 7: 'Place the egg in the bin', 8: 'Go to the counter to the left', 9: 'Pick up a knife off the counter', 10: 'Go to the green bin', 11: 'Cut the eggs in the bin'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21969653845034376
# {0: 'turn around , go to the counter .', 1: 'pick up a slice of potato from the counter .', 2: 'turn around , walk to the coffee maker on the counter .', 3: 'place the potato in the trash can .', 4: 'turn left , walk forward , turn right , walk to the fridge .', 5: 'open the fridge and pick up the potato slice from the fridge .', 6: 'turn around , walk to the coffee maker on the counter .', 7: 'place the potato in the trash can .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn right and walk to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21045649865536906
# {0: 'turn around and go to the counter between the stove and the stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin .', 3: 'put the potato in the green bin .', 4: 'turn left and go to the refrigerator .', 5: 'open the fridge and pick up the potato that is on the shelf .', 6: 'turn around and walk to the green trash can .', 7: 'put the potato in the green bin .', 8: 'turn left and go to the counter .', 9: 'pick up the knife from the counter .', 10: 'turn to the right and go to the coffee maker .', 11: 'cut the potato in the trash can .', 12: 'cut the potato in the trash can .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24402219131372271
# {0: 'turn right , move forward , then turn left to face the counter .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin below the counter .', 4: 'turn left and walk to the fridge .', 5: 'open the fridge and take out the potato from the top shelf and close the door .', 6: 'turn around and walk to the green bin on the right side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter .', 9: 'pick up the knife on the counter .', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26494006903027295
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around and walk to the green bin on the left side of the room .', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge .', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin below the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the green bin .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2936278767702732
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , go forward , turn left at the end of the counter and go to the green bin .', 3: 'put the potato in the green bin under the counter .', 4: 'go to the fridge', 5: 'take the potato from the fridge', 6: 'turn around and walk to the green bin on the left side of the room .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green bin .', 12: 'cut the potato in the green bin under the counter .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23611037275070104
# {0: 'turn right , move to the counter between the fridge and stove .', 1: 'pick up the potato from the counter .', 2: 'turn around , walk forward , turn left , walk to the green bin', 3: 'put the potato in the green bin under the counter .', 4: 'turn left and walk to the fridge .', 5: 'take the potato from the fridge', 6: 'turn around and walk to the counter with the coffee maker on it .', 7: 'put the potato in the green bin under the counter .', 8: 'turn left and walk to the counter above the dishwasher .', 9: 'pick up the knife from the counter', 10: 'turn to the right and walk to the counter with the coffee maker .', 11: 'cut the potato in the green trash can .', 12: 'cut the potato in the green trash can .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_111526_967564_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pot-None-DiningTable-24/trial_T20190908_111526_967564
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move pot from stove to refrigerator, chill pot, move pot to counter.
# {0: 'Turn left, proceed across room to stove.', 1: 'Remove pot from bottom left burner.', 2: 'Turn around, proceed across room to refrigerator.', 3: 'Open refrigerator, put pot on second shelf down, close refrigerator.  Close door, wait five seconds, open refrigerator.  Remove pot, close refrigerator door.', 4: 'Turn around, proceed to table on right.  Turn right, proceed to table.', 5: 'Place pot on table in front of coffee maker, to the right of tomato.'}
#
# Annotation 1
# Put a chilled pan on a white table.
# {0: 'Walk forward, then hang a left and walk over to the oven.', 1: 'Pick up the large metal pan that is on the front left burner of the stove.', 2: 'Turn left and walk towards the door, then hang a left and walk up to the fridge.', 3: 'Put the metal pan in the fridge for a couple seconds then take it out and close the fridge door.', 4: 'Walk over to the small white table with the coffee maker on it.', 5: 'Put the chilled metal pan on the white table in front of the coffee maker.'}
#
# Annotation 2
# put a chilled pan on the table
# {0: 'turn left, walk forward to counter, turn right, take a step, turn left to face the stove', 1: 'pick up the pan that is on the stove', 2: 'turn around, walk to fridge', 3: 'open fridge, put pan in, close fridge, wait a minute, take pan out of fridge', 4: 'turn around, take a few steps, turn right to face the table', 5: 'put the pan on the table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29618792943258493
# {0: 'turn left and walk to the stove .', 1: 'pick up the pot with the stove on the stove .', 2: 'turn left and walk to the fridge .', 3: 'place the pot inside the fridge , wait a bit , open the fridge , remove the pot .', 4: 'turn around and walk to the white table .', 5: 'place the pot on the table'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09817553494674862
# {0: 'turn left and walk to the stove .', 1: 'pick up the pot with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the pot in the fridge .', 4: 'turn around and walk to the table .', 5: 'put the pot on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.18385818460842115
# {0: 'turn left , walk to the stove , turn right , walk to stove .', 1: 'pick up the pot on the left front burner .', 2: 'turn around and walk to the fridge .', 3: 'chill the pan in the fridge .', 4: 'turn around and take a step then turn right and walk to the table .', 5: 'put the pot on the table in front of the coffee maker .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16012918876948964
# {0: 'turn left , walk to the stove , turn right , walk to stove', 1: 'pick up the pot with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the pan in the fridge .', 4: 'turn around and take a step then turn right and walk to the table .', 5: 'put the pot on the table in front of the coffee maker .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11317829990077814
# {0: 'turn left , walk to the stove', 1: 'pick up the pot with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the pan in the fridge .', 4: 'turn around and take a step then turn right and walk to the table .', 5: 'put the chilled pot on the table in front of the coffee maker .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11317829990077814
# {0: 'turn left , walk to the stove', 1: 'pick up the pot with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the pan in the fridge .', 4: 'turn around and take a step then turn right and walk to the table .', 5: 'put the chilled metal pot on the table in front of the coffee maker .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_091643_467064_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Newspaper-None-DeskLamp-224/trial_T20190909_091643_467064
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# pick up newspaper, turn on lamp
# {0: 'turn left, go to brown dresser with television on the right', 1: 'pick up newspaper from in front of television on brown dresser', 2: 'turn right, go left at end of dresser, go to small table with lamp to the left', 3: 'turn on lamp on small table'}
#
# Annotation 1
# Examine a newspaper by the light of a desk lamp.
# {0: 'Turn left, walk forward to the door, then turn right and walk to the newspaper by the TV.', 1: 'Pick up the newspaper from the TV stand.', 2: 'Turn right, walk forward past the TV, then turn left and go into the other room. Turn left and walk to the small chair, then turn right and walk to the lamp on the small dresser.', 3: 'Turn on the lamp.'}
#
# Annotation 2
# turn on lamp on side table while holding newspaper
# {0: 'walk to face bureau', 1: 'pick up newspaper from bureau top', 2: 'walk to face side table with lamp', 3: 'turn on lamp on side table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07309898207159538
# {0: 'turn left , walk forward , turn right , walk to the dresser , turn right , walk to the dresser .', 1: 'pick up the newspaper from the dresser .', 2: 'turn right , walk forward , turn left , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the', 3: 'turn on the lamp on the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6792970694495849
# {0: 'turn left and walk to the dresser .', 1: 'pick up the newspaper from the dresser .', 2: 'turn right and walk to the small table in the corner .', 3: 'turn on the lamp'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5791044263867822
# {0: 'turn left and walk across the room , then turn right and walk up to the wooden dresser .', 1: 'pick up the newspaper from the tv stand .', 2: 'turn right , walk around the bed to the small table with the lamp on it .', 3: 'turn on the lamp on the small table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33290715170669133
# {0: 'turn left , go forward , turn right at the tv stand', 1: 'pick up newspaper from tv stand', 2: 'turn right and walk back over to the small table with the lamp on it .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3825168711806138
# {0: 'turn left , go forward , turn right at the tv stand', 1: 'pick up newspaper from dresser', 2: 'turn right and walk back to the small table with the lamp on it .', 3: 'turn on the lamp on the small table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3838328532642946
# {0: 'turn left , go forward , turn right at the tv stand', 1: 'pick up newspaper from dresser', 2: 'turn right and walk back over to the small table with the lamp on it .', 3: 'turn on the lamp on the small table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_221843_169317_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Watch-None-FloorLamp-203/trial_T20190908_221843_169317
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a watch by the light of a tall lamp.
# {0: 'Turn around, move to the ottoman, turn right, move to the other side of the coffee table, near the wall, turn to face the remote on the coffee table. ', 1: 'Pick up the watch on the table.', 2: 'Turn right, bring the watch over to the lamp behind the chair in the corner. ', 3: 'Turn on the tall lamp in the corner.'}
#
# Annotation 1
# Examine a watch by the light of a tall lamp.
# {0: 'Turn around and walk to the back of the wooden coffee table closest to the wall on the right.', 1: 'Pick up the watch to the right of the remote control on the coffee table.', 2: 'Turn right, hang a left at the ottoman, turn right at the couch and walk to the tall lamp in the corner on the right.', 3: 'Turn on the tall lamp.'}
#
# Annotation 2
# Examine a watch in the light of a tall lamp.
# {0: 'Turn left and take a step forward, then turn left and walk over to the far side of the coffee table.', 1: 'Pick up the watch off of the coffee table.', 2: 'Turn right and walk around the purple chair to the tall lamp in the corner of the room.', 3: 'Turn on the light of the tall lamp.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3937865113530433
# {0: 'turn left and walk to the coffee table .', 1: 'pick up the watch off of the coffee table .', 2: 'turn right , walk forward , turn right , walk to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08145888797520091
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch from the coffee table .', 2: 'turn right and walk to the ottoman then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk to the wall . turn right and walk', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4315974560258617
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch that is on the coffee table .', 2: 'turn right , walk around the ottoman to the tall lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4303660819164937
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch from the coffee table .', 2: 'turn right and walk around the ottoman to the tall lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4404622477803391
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the coffee table .', 2: 'turn right , walk around the ottoman to the tall lamp in the corner .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4020221038783786
# {0: 'turn around and walk to the coffee table .', 1: 'pick up the watch on the coffee table .', 2: 'turn right , walk around the ottoman to the lamp in the corner .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_213353_632634_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-PepperShaker-None-SideTable-21/trial_T20190906_213353_632634
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a salt shaker on the table.
# {0: 'Move towards the silver trash bin next to the microwave then turn left and move to the sink next to the coffee maker.', 1: 'Open the cabinet underneath the sink and to the left of the refrigerator, pick up the salt shaker, and close the cabinet door.', 2: 'Turn right and move to the table next to the stove then turn right and move to the table next to the trash bin in the corner of the room.', 3: 'Place the salt shaker in front of the apple and cup on the top of the table.'}
#
# Annotation 1
# Put the salt from under the sink on the small black table.
# {0: 'Move to the sink.', 1: 'Take out the salt from under the sink.', 2: 'Bring the salt to the small black table.', 3: 'Put the salt on the small black table.'}
#
# Annotation 2
# Place the salt shaker from the cabinet on to the black table.
# {0: 'Turn left and head towards the sink.', 1: 'Open the cabinet door beneath the sink, take out the salt shaker, and close the cabinet door.', 2: 'Turn left, head towards the white table, turn left and head towards the black table.', 3: 'Place the salt shaker in front of the metal vase on the table.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5189836938183434
# {0: 'turn right and walk to the sink .', 1: 'open the right cabinet under the sink and pick up the salt shaker .', 2: 'turn around and walk to the white table .', 3: 'place the salt shaker on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5939681832467243
# {0: 'turn left and walk to the sink .', 1: 'open the cabinet door below the sink and take out the salt shaker .', 2: 'turn around and walk to the small black table .', 3: 'put the salt shaker on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6261231357787919
# {0: 'turn left and walk to the sink .', 1: 'open the cabinet door below the sink and take out the salt shaker , then close the cabinet door .', 2: 'turn around and walk towards the small black table .', 3: 'place the salt shaker on the black table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.47331852081559295
# {0: 'go forward , turn left to go to the sink .', 1: 'open the cabinet door below the sink and take out the salt shaker , then close the door .', 2: 'turn around and walk towards the white table , then turn right to face the black table .', 3: 'place the salt shaker on the black table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4131142104672669
# {0: 'move forward to the sink .', 1: 'open the cabinet door below the sink and take out the salt shaker , then close the door .', 2: 'turn around and walk towards the table , then turn right to face the black table .', 3: 'place the salt shaker on the black table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4131142104672669
# {0: 'move forward to the sink .', 1: 'open the cabinet door below the sink and take out the salt shaker , then close the door .', 2: 'turn around and walk towards the table , then turn right to face the black table .', 3: 'place the salt shaker on the black table .'}
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# WORST valid_seen
worst_valid_seen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_seen_ids_worst_10, epoch_list=valid_seen_epoch_list, split='valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190908_050633_745514_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-SideTable-329/trial_T20190908_050633_745514
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move a magazine from the bed to the table
# {0: 'turn left, take a few steps, turn right to face bed', 1: 'pick up magazine that was on the bed', 2: 'turn right, walk forward, turn left after the bed, walk forward to small table', 3: 'put magazine on to small table'}
#
# Annotation 1
# Place book on right bedside table
# {0: 'go to left end of bed', 1: 'pick up book on left, front corner of bed', 2: 'go to empty bedside table to the right of bed', 3: 'place book on bedside table'}
#
# Annotation 2
# Move a game from the bed to the bedside table
# {0: 'Turn left and go to the bottom left edge of the bed', 1: 'Pick up the game that is on the bottom left edge of the bed', 2: 'Go right and around the bed to the bedside table', 3: 'Put the game on top of the table'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4050263676958805
# {0: 'turn left and walk to the bed .', 1: 'pick up the book on the bed', 2: 'turn right , walk forward , turn left , walk to the bed , turn left to face the bed .', 3: 'place the book on the bed'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23033915913006958
# {0: 'turn left and go to the bed .', 1: 'pick up the book that is closest to you .', 2: 'turn right and walk to the bed , then turn left and walk up to the night stand .', 3: 'put the book on the night stand'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2356211499349146
# {0: 'turn left and walk to the bed .', 1: 'pick up the book that is on the bed', 2: 'turn right and walk to the wall then turn left and walk to the night stand .', 3: 'put the book on the nightstand .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.17901108879561117
# {0: 'turn left and walk to the end of the bed .', 1: 'pick up the book that is on the bed .', 2: 'turn right and walk to the wall then turn left and walk to the night stand .', 3: 'put the book on the nightstand .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22446383586206337
# {0: 'turn left and go to the bed .', 1: 'pick up the book on the bed .', 2: 'turn right and walk to the wall then turn left and walk to the night stand .', 3: 'put the book on the nightstand .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22446383586206337
# {0: 'turn left and go to the bed .', 1: 'pick up the book on the bed .', 2: 'turn right and walk to the wall then turn left and walk to the night stand .', 3: 'put the book on the nightstand .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_173610_612042_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CreditCard-None-FloorLamp-227/trial_T20190908_173610_612042
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# examine the credit card under a lamp
# {0: 'go to the coffee table', 1: 'pick up the credit card from the table ', 2: 'take the card to the lamp', 3: 'turn on the lamp'}
#
# Annotation 1
# turn on a living room floor lamp while holding credit card
# {0: 'walk to face round coffee table', 1: 'pick up blue credit card from table', 2: 'walk to the floor lamp behind the couches', 3: 'turn on the floor lamp'}
#
# Annotation 2
# examine the credit card with the lamp
# {0: 'turn left, walk forward, turn right after round black table, turn right to face the table', 1: 'pick up the credit card that is on the table', 2: 'turn around, walk to dining table, turn right, walk past couch, turn right, walk forward to lamp in the left corner, hold credit card up', 3: 'turn the lamp on'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07828899431746954
# {0: 'turn left , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward ,', 1: 'pick up the credit card on the table .', 2: 'turn around and walk to the lamp on the right .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.430706455546399
# {0: 'turn left and walk to the coffee table .', 1: 'pick up the credit card from the coffee table .', 2: 'turn around and walk to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22650943651874522
# {0: 'walk over to the coffee table .', 1: 'pick up the credit card from the coffee table .', 2: 'turn around and walk to the table , then turn right and walk to the lamp in the corner of the room .', 3: 'turn on the lamp in the corner .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24412428405087305
# {0: 'walk over to the coffee table .', 1: 'pick up the credit card from the coffee table .', 2: 'turn around and walk to the table , then turn right and walk across the room , then turn right and walk up to the lamp in the corner of the room .', 3: 'turn on the lamp in the corner .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26565158158141833
# {0: 'go to the left side of the coffee table', 1: 'pick up the credit card from the coffee table .', 2: 'turn around and walk to the table , then turn right and walk around the couch to the lamp in the corner .', 3: 'turn on the lamp in the corner .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24152021297950246
# {0: 'go to the left side of the coffee table', 1: 'pick up the credit card from the coffee table .', 2: 'turn around and go to the right and then turn right again and go to the lamp in the corner .', 3: 'turn on the lamp in the corner .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_192823_237997_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Cup-None-SideTable-21/trial_T20190906_192823_237997
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a chilled cup on the table.
# {0: 'Turn left and move towards the refrigerator, then turn left and move to the table with the toaster on top.', 1: 'Pick up the cup between the knife and the egg from the rear of the table.', 2: 'Turn around and move to the refrigerator and then turn around to face the door of the refrigerator.', 3: 'Open the refrigerator, place the cup on the top shelf to the left of the lettuce, chill the cup, open the refrigerator, pick up the cup from the top shelf, then close the refrigerator.', 4: 'Turn to the right, move past the sink to the table next to the oven, then turn towards the small table in between the garbage bag and the counter.', 5: 'Place the cup on the front center of the table; to the right of the salt shaker and in front of the cup.'}
#
# Annotation 1
# Put a cold cup on a stand.
# {0: 'Turn left, go to the refrigerator, turn left, go to the white table with the toaster on it.', 1: 'Take the cup on the table closest to the wall.', 2: 'Turn around, go to the refrigerator.', 3: 'Put the cup to the right of the lettuce in the refrigerator. Close then open the refrigerator. Take the cup from the refrigerator.', 4: 'Turn left, go to the black stand next to the end of the sink counter and a black trash bag.', 5: 'Put the cup in front of and to the left of the cup on the stand.'}
#
# Annotation 2
# Put a chilled vase on the three tiered black table.
# {0: 'Turn right and move across the room to the white table on the right.', 1: 'Pick up the gray vase at the back of the table, closest to the wall.', 2: 'Turn around and move to the refrigerator on the left.', 3: 'Open the fridge and place the vase on the top shelf. close the door, wait a moment, and take the vase out of the fridge', 4: 'Turn left and move across the room to the black three tiered table on the right.', 5: 'Put the vase on the top shelf of the table in front and slightly left of the other vase.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11038972989476437
# {0: 'turn left , walk to the table .', 1: 'pick up the glass with the spoon in it .', 2: 'turn around and walk to the fridge .', 3: 'place the cup with the spoon in the fridge .', 4: 'turn around and walk to the white table .', 5: 'put the glass on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07023176152272036
# {0: 'turn left and walk to the fridge then turn left and walk to the white table .', 1: 'pick up the green cup with the spoon in it .', 2: 'turn right and walk to the fridge .', 3: 'chill the cup in the fridge .', 4: 'turn left and walk to the black table .', 5: 'put the clean green cup on the black table .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.09414265722040412
# {0: 'turn left and walk to the fridge then turn left and walk to the white table .', 1: 'pick up the cup from the table .', 2: 'turn around and walk to the fridge .', 3: 'chill the cup in the fridge .', 4: 'turn left and walk to the small black table to the left of the sink .', 5: 'place the cup on the black table .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08112312025433199
# {0: 'turn left , walk across the room , turn left and walk to the white table .', 1: 'pick up the cup with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the cup in the fridge .', 4: 'turn left and walk to the small black table in the corner of the room .', 5: 'place the cup on the black table .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1321371130044726
# {0: 'turn left and walk across the room , then turn left and walk across the room to the white table .', 1: 'pick up the cup with the knife in it .', 2: 'turn around and walk back to the fridge .', 3: 'chill the cup in the fridge .', 4: 'turn left and walk to the small black table in the corner .', 5: 'put the cup on the black table .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.12784753210034377
# {0: 'turn left and walk across the room , then turn left and walk across the room to the white table .', 1: 'pick up the cup with the knife in it .', 2: 'turn around and walk to the fridge .', 3: 'chill the cup in the fridge .', 4: 'bring the cup to the small black table .', 5: 'place the cup on the black table .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_114323_767231_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CD-None-DeskLamp-314/trial_T20190907_114323_767231
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a CD by a lamp
# {0: 'Turn right and walk to the green stand then take a left and walk to the trash can that is on the right in the corner of the room', 1: 'Pick up the CD that is in the trash can', 2: 'Turn around and cross the room the green stand then turn right and head to the desk.', 3: 'Turn on the lamp that is sitting on the desk'}
#
# Annotation 1
# Examine a disc in the light of a lamp.
# {0: 'Turn right and begin walking across the room, then hang a left and walk over to the small bin below the mirror to the right of the door.', 1: 'Pick up the disc that is in the small bin in the corner of the room.', 2: 'Turn right and walk towards the bed, then hang a left and walk over to the lamp on the wooden desk.', 3: 'Turn on the lamp on the wooden desk.'}
#
# Annotation 2
# examine a CD with a lamp
# {0: 'turn right, walk across room towards dresser, turn left, walk across room, turn right, turn left, go to the mirror', 1: 'pick up the CD that is in the trash below the mirror', 2: 'turn around, walk across the room, turn right, walk across the room to the dresser', 3: 'turn the lamp on'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08457802678621126
# {0: 'turn right , walk forward , turn left , walk to the wall , turn left , walk to the wall , turn left to face the trash can .', 1: 'pick up the cd from the trash can .', 2: 'turn left , walk forward , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the', 3: 'turn on the lamp on the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3694985680711311
# {0: 'turn right and walk to the door , then turn left and walk to the wall , then turn left and walk up to the wall .', 1: 'pick up the cd in the trash can .', 2: 'turn around and walk to the bed .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3771163186579958
# {0: 'walk towards the door , turn left , walk towards the wall , turn left , walk to the door', 1: 'pick up the cd in the trash can .', 2: 'turn around and walk to the bed .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2674976391853438
# {0: 'walk to the left side of the room', 1: 'pick up the cd in the trash can .', 2: 'turn around and walk to the bed .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24150096829782575
# {0: 'walk to the left side of the room', 1: 'pick up the cd in the trash can .', 2: 'turn around and head to the drawer', 3: 'turn on the lamp on the desk .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24598644602010847
# {0: 'walk to the left side of the room', 1: 'pick up the cd in the trash can .', 2: 'turn around and head to the bed', 3: 'turn on the lamp on the desk .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_162502_940304_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Cloth-None-BathtubBasin-405/trial_T20190906_162502_940304
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move the red cloth from the cabinet to the tub
# {0: 'turn right to the vanity', 1: 'open the left cabinet door, take the red cloth out of the cabinet', 2: 'turn right, walk to the tub', 3: 'put the cloth in the tub'}
#
# Annotation 1
# move a rag from cabinet to the tub
# {0: 'turn right, walk towards counter in front of you', 1: 'open the cabinet under the counter, take out a red rag, close cabinet', 2: 'turn right, walk towards the toilet, turn right, walk towards tub,', 3: 'put the red rag in the tub'}
#
# Annotation 2
# place a rag inside the tub
# {0: 'turn right towards the shelf', 1: 'pick up the rag', 2: 'turn around and head for the bath tub', 3: 'place the rag inside the tub'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32969644917254126
# {0: 'turn right and walk to the counter .', 1: 'open the cabinet under the right and take out the rag out .', 2: 'turn right and walk to the tub .', 3: 'place the rag in the tub .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.737442992456842e-78
# {0: 'turn right and walk to the counter .', 1: 'open the cabinet door below the counter and remove the red rag .', 2: 'turn right and walk to the bath tub .', 3: 'put the rag in the bath tub .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.29083084630965494
# {0: 'turn right and walk to the counter .', 1: 'open the cabinet door below the counter and take out the rag .', 2: 'turn right and walk to the tub .', 3: 'put the cloth in the bath tub .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.466105731698673e-78
# {0: 'turn right and walk to the counter .', 1: 'open the cabinet door on the left , take out the dirty rag , and close the door .', 2: 'turn right and walk to the toilet .', 3: 'put the red towel into the tub .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16483094399223003
# {0: 'walk to the counter to the left of the sink .', 1: 'open the cabinet door below the counter and take out the rag .', 2: 'turn right and walk to the toilet . turn right and walk to the tub .', 3: 'put the red cloth into the bath tub basin .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1690653646485627
# {0: 'walk to the counter to the left of the sink .', 1: 'open the cabinet door below the counter and take out the red rag .', 2: 'turn right and walk to the toilet . turn right and walk to the tub .', 3: 'put the red cloth into the bath tub basin .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_201550_622420_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Laptop-None-DeskLamp-328/trial_T20190908_201550_622420
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'CloseObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Pick up a laptop and turn on a lamp
# {0: 'Turn right and go to the desk', 1: 'Close the laptop and pick it up from the desk', 2: 'Turn left and go to the lamp on the desk', 3: 'Turn on the lamp'}
#
# Annotation 1
# Pick up the laptop and turn on the lamp
# {0: 'Turn around and go to the table with a laptop', 1: 'Close the laptop and pick it up from the table', 2: 'Go to the end of the table by the wall', 3: 'Turn on the lamp that is on far left end of the table'}
#
# Annotation 2
# pick up the lap top from the desk and turn on the lamp
# {0: 'Look down and turn right towards the trash can  then turn right towards the desk ', 1: 'close the lap top and pick it up from the desk ', 2: 'go left then right towards the desk again ', 3: 'turn on the lamp '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21467162058045175
# {0: 'turn right and walk to the desk .', 1: 'close the laptop of the laptop .', 2: 'turn left and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3178956058171238
# {0: 'turn around and walk to the desk .', 1: 'pick up the laptop from the desk', 2: 'turn left and walk to the wall , then turn right and walk up to the wooden desk .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3017441818652155
# {0: 'turn around and walk to the desk .', 1: 'pick up the computer from the desk .', 2: 'turn left and walk to the wall then turn right and walk to the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2734803421070419
# {0: 'turn around and walk to the desk .', 1: 'pick up the computer from the desk .', 2: 'turn left and walk to the wall , then turn right and walk up to the wooden desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27936759390398475
# {0: 'turn around and walk to the desk .', 1: 'pick up the laptop from the desk .', 2: 'turn left and walk to the wall , then turn right and walk up to the wooden desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27936759390398475
# {0: 'turn around and walk to the desk .', 1: 'pick up the laptop from the desk .', 2: 'turn left and walk to the wall , then turn right and walk up to the wooden desk .', 3: 'turn on the lamp on the desk .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_055221_984342_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-SoapBar-None-Cabinet-402/trial_T20190908_055221_984342
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a clean bar of soap under the sink.
# {0: 'Turn to the garbage can, on the floor to your right.', 1: 'Pull out the bar of soap inside the garbage can. ', 2: 'Move to your right, away from the sink, then go across the room to the last sink on your left.', 3: 'Place the bar of soap in the sink, turn the water on, rinse the soap off, turn the water off, and remove the bar of soap from the sink. ', 4: 'Step back from the sink. ', 5: 'Place the bar of soap in the right cabinet, under the sink. '}
#
# Annotation 1
# wash the pink bar, put the pink bar in the cabinet
# {0: 'turn right, walk to the trash bin', 1: 'grab the pink bar from the trash bin', 2: 'turn right, walk to the sink', 3: 'put the pink bar in the sink, wash the bar, take it out', 4: 'turn around, turn around to the cabinet under the sink', 5: 'open the right door, put the pink bar in'}
#
# Annotation 2
# drop a wet soap in the cupboard under the sink
# {0: 'turn right and head for the bin', 1: 'pick up the soap from the bin', 2: 'head right towards the sink', 3: 'wet the soap in the sink', 4: 'move below the sink to the cupboard', 5: 'drop the soap in the cupboard below the sink'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.492086802750059
# {0: 'turn right and walk to the trash can .', 1: 'pick up the soap from the bin .', 2: 'turn around , walk forward , turn left to face the sink .', 3: 'place the soap in the sink , wash the soap , turn the water off and remove the soap from the sink .', 4: 'turn left and walk back to the sink .', 5: 'open the cabinet under the sink and place the soap inside .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4543910984695557
# {0: 'turn right and walk to the trash can .', 1: 'pick up the bar of soap in the trash can .', 2: 'turn right and walk to the sink .', 3: 'put the soap in the sink , turn on the water , turn off the water , and pick up the soap .', 4: 'turn around and walk to the sink .', 5: 'put the soap in the cabinet .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46581725651165784
# {0: 'turn right and walk to the trash can on the left .', 1: 'pick up the soap in the trash can .', 2: 'turn right and walk to the sink on the left .', 3: 'place the soap in the sink , turn the water on , then turn the water off and pick up the soap .', 4: 'turn around and face the cabinet below the sink .', 5: 'open the right cabinet door and put the soap inside and close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.39227455995302746
# {0: 'turn right and walk to the trash can on the floor .', 1: 'pick up the soap from the bin .', 2: 'turn to the right and walk to the sink .', 3: 'put the soap in the sink , turn on the water , turn off the water , and pick up the soap .', 4: 'walk back to face the cabinet below the sink .', 5: 'open the right cabinet door and put the soap inside , then close the door .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5685408863397762
# {0: 'walk to the trash can', 1: 'pick up the soap from inside the garbage can .', 2: 'turn right and walk to the sink on the left .', 3: 'put the soap in the sink , turn the water on , then turn the water off and pick up the soap .', 4: 'move back from the sink and look down at the cabinet below the sink .', 5: 'open the right cabinet door below the sink and put the soap inside , then close the door .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4544315576698548
# {0: 'turn right and walk to the trash can on the floor .', 1: 'pick up the soap from inside the trash can .', 2: 'turn right and walk to the sink on the right .', 3: 'put the soap in the sink , turn the water on , then turn the water off and pick up the soap .', 4: 'step back from the sink and look down at the cabinet below the sink .', 5: 'open the cabinet door on the right and put the soap in it'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_202340_749336_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-SoapBar-None-Drawer-423/trial_T20190906_202340_749336
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put away clean soap.
# {0: 'Go to your left, and then turn right to the counter with the soap.', 1: 'Pick up the soap on the left.', 2: 'Turn to your right and go to the sink', 3: 'Wash the soap in the sink.', 4: 'Turn around and go to the counter next to the sink.', 5: 'Open the bottom left drawer and place the soap in.'}
#
# Annotation 1
# Put wet soap in the cabinet under the sink to the left.
# {0: 'Move to the counter left of the sink. ', 1: 'Pick up the soap on the left from the counter. ', 2: 'Bring the soap to the sink. ', 3: 'Wet the soap in the sink with water. ', 4: 'Bring the soap to the cabinet left of the sink. ', 5: 'Put the soap in the lower cabinet left of the sink. '}
#
# Annotation 2
# rinse the soap to put it in a drawer
# {0: 'walk on over to the bathroom counter to the left of the sink', 1: 'grab a bar of soap', 2: 'walk over to the kitchen sink', 3: 'put the soap inside the sink and rinse it off, then pick the soap back up', 4: 'back up a bit to face the kitchen sink again', 5: 'open the top left drawer of the black cabinets below the sink, and put the soap in there.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.41529490015989245
# {0: 'turn left and walk to the counter .', 1: 'pick up the soap bar of soap on the counter .', 2: 'turn right and walk to the sink .', 3: 'place the soap in the sink .', 4: 'turn around and walk back to the sink .', 5: 'place the soap in the drawer .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33885794289204213
# {0: 'turn left and walk to the counter .', 1: 'pick up the bar of soap from the counter .', 2: 'turn right and walk to the sink .', 3: 'put the soap in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean bar of soap .', 4: 'turn around and walk to the cabinet under the sink .', 5: 'put the bar of soap in the bottom left drawer .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3080015952190998
# {0: 'turn left and walk to the toilet , then turn right and walk up to the counter .', 1: 'pick up the bar of soap that is on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'place the soap in the sink , turn on the water , turn off the water and pick up the soap .', 4: 'turn around and take a step forward , then turn back around to face the sink .', 5: 'open the bottom left drawer and put the soap inside and close the drawer .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3106342508402174
# {0: 'turn left and walk to the toilet , then turn right and walk up to the counter .', 1: 'pick up the bar of soap that is on the counter .', 2: 'turn right and walk to the sink on the left .', 3: 'place the soap in the sink , turn on the water , turn off the water , and pick up the soap .', 4: 'turn around and take a step forward , then turn back around to face the counter .', 5: 'open the second drawer from the left and put the soap inside .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32332003640458523
# {0: 'turn left and walk to the toilet , then turn right and walk to the counter .', 1: 'pick up the bar of soap that is on the counter .', 2: 'turn right and walk to the sink .', 3: 'place the soap in the sink , turn on the faucet , turn the water off , and pick up the soap .', 4: 'back up and face the drawers under the sink .', 5: 'open the second drawer from the left and put the soap inside and close the drawer .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3654602700996687
# {0: 'turn left and go to the sink .', 1: 'pick up the bar of soap that is on the counter .', 2: 'turn right and walk to the sink .', 3: 'place the soap in the sink , turn on the faucet , turn off the faucet , and pick up the soap .', 4: 'turn around , go forward , turn around to face the sink .', 5: 'open the second drawer from the left and put the soap in the drawer , then close the drawer .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_060234_011675_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Apple-None-DiningTable-26/trial_T20190907_060234_011675
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a heated apple on the table.
# {0: 'Turn left and go to the table.', 1: 'Pick up the apple on the table. ', 2: 'Go right and bring the apple to the microwave. ', 3: 'Heat the apple in the microwave. ', 4: 'Bring the heated apple back to the table on the side. ', 5: 'Put the heated apple on the table in front of the salt. '}
#
# Annotation 1
# Put a cooked apple on the table.
# {0: 'Turn around, will forward, then turn right to face the table.', 1: 'Pick up the apple from the table.', 2: 'Turn right, move forward, turn left, then move forward and to approach the microwave.', 3: 'Cook the apple in the microwave.', 4: 'Turn right, move forward, turn right, move forward, then turn right into approach the table.', 5: 'Place the apple on the table, in front of the pepper and to the right of the soap.'}
#
# Annotation 2
# Put a heated apple on the table by the stove.
# {0: 'Move to the table to the left of the door to the right of the stove.', 1: 'Pick up an apple from the table.', 2: 'Move to the microwave to the right of the door.', 3: 'Heat the apple with the microwave before removing it and closing the door.', 4: 'Move to the table to the right of the stove from before.', 5: 'Place the apple on top of the table.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4932886574617446
# {0: 'turn around and walk to the white table .', 1: 'pick up the apple piece of the apple .', 2: 'turn right and walk to the microwave .', 3: 'heat the apple in the microwave .', 4: 'turn right , walk to the white table .', 5: 'place the apple on the table .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3406934660343956
# {0: 'turn around and go to the white table .', 1: 'pick up the apple from the table .', 2: 'turn right and walk to the microwave .', 3: 'put the apple in the microwave , heat it up , then remove it', 4: 'turn around and walk to the white table on your right .', 5: 'put the apple on the table'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33060947085688835
# {0: 'turn around and go to the white table .', 1: 'pick up the apple on the table .', 2: 'turn right and walk to the sink .', 3: 'open the microwave and place the apple inside . shut the door and then open the door and take the apple out and shut the door .', 4: 'turn around and walk to the white table on the right .', 5: 'put the apple on the table , to the left of the salt .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2838692895237877
# {0: 'turn around , go to white table with toaster', 1: 'pick up the apple on the table .', 2: 'turn right and walk to the sink on the right .', 3: 'open the microwave , place the apple inside , close the microwave , turn on the microwave , open the microwave , take the apple out , close the microwave', 4: 'turn around and walk to the white table on the right .', 5: 'put the apple on the table'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3185393183493126
# {0: 'turn around , go to white table with apple on it .', 1: 'pick up the apple on the table .', 2: 'turn right and walk to the sink on the right .', 3: 'open the microwave and place the apple inside . shut the door and then open the door and take the apple out and shut the door .', 4: 'turn around and walk to the white table on the right .', 5: 'put the apple on the table'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3185393183493126
# {0: 'turn around , go to white table with apple on it .', 1: 'pick up the apple on the table .', 2: 'turn right and walk to the sink on the right .', 3: 'open the microwave and place the apple inside . shut the door and then open the door and take the apple out and shut the door .', 4: 'turn around and walk to the white table on the right .', 5: 'put the apple on the table'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_224451_655673_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CD-None-DeskLamp-320/trial_T20190907_224451_655673
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Carry a CD while turning on a lamp
# {0: 'Move across the room to face the white desk top next to the window', 1: 'Pick up the CD on top of the white desk', 2: 'Carry the CD over to the lamp on top of the wood desk shelf', 3: 'Turn on the lamp'}
#
# Annotation 1
# Take the CD from the table, turn on the desk lamp
# {0: 'Turn left, head across the room to the white table', 1: 'Take the CD from the table', 2: 'Turn around, head to the desk across the room', 3: 'Turn on the lamp'}
#
# Annotation 2
# Put a CD on a desk
# {0: 'turn around and go to the white low table directly behind you', 1: 'pick up the CD that is on the table', 2: 'turn back around and carry the CD to the desk next to the bed', 3: 'place the CD on the table on top of the book'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2202865375055792
# {0: 'turn right , walk forward , turn right , walk forward , turn right to face the desk .', 1: 'pick up the cd from the desk .', 2: 'turn left and walk to the bed , then turn left and walk to the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.41009522359691103
# {0: 'turn right and walk to the white table .', 1: 'pick up the cd on the table .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4242794280772795
# {0: 'turn right and walk to the white table .', 1: 'pick up the cd on the table .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33272941183891763
# {0: 'turn right and walk to the white table with the white credit card on it .', 1: 'pick up the cd on the table .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33272941183891763
# {0: 'turn right and walk to the white table with the white credit card on it .', 1: 'pick up the cd on the table .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4242794280772795
# {0: 'turn right and walk to the white table .', 1: 'pick up the cd on the table .', 2: 'turn around and walk to the desk .', 3: 'turn on the lamp on the desk .'}
# ---------------------------
# --------------------------------------------------------------------------------------
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
# WORST valid_unseen
worst_valid_unseen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_unseen_ids_worst_10, epoch_list=valid_unseen_epoch_list, split='valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190909_210238_431966_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-Desk-308/trial_T20190909_210238_431966
# Number of subgoals (exlcuding <No-op>): 4
# https://youtu.be/Ti1faQUCSnc
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# take a coffee mug from a book shelf and place it on a desk
# {0: 'go to the desk that is in front of a book shelf with a computer on it', 1: 'pick up the white coffee mug from the book shelf', 2: 'go to the left end of the desk', 3: 'place the mug on the left end of the desk'}
#
# Annotation 1
# Move a cup from the shelf to the desk.
# {0: 'Turn to the right and then the left to the other side of the room, and face the desk on the left side. Look up to the books on the shelf.', 1: 'Pick up the cup from the shelf.', 2: 'Carry the cup and turn to the left and then face the desk on the right side. ', 3: 'Place the cup on the short side of the desk, close to you.'}
#
# Annotation 2
# Pick up a coffee mug from the desk and put it down on the desk.
# {0: 'Turn right at the brown desk and walk between the bed and the desk. Turn left at the orange cylinder on the right of the bed on the floor. Walk to the desk on your left with a laptop on it.', 1: "Pick up the white coffee mug that's on the desk.", 2: 'Turn around and walk to the bed. Turn right at the bed.', 3: 'Put the coffee mug back down on the left side of the desk to the right of the bed.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.49611828357186993
# {0: 'turn right , walk forward , turn left , walk to the wall , turn left to face the desk .', 1: 'pick up the mug from the shelf .', 2: 'turn around and walk to the desk on the right side of the desk .', 3: 'place the mug with the spoon in the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.06874014717456459
# {0: 'turn right and walk to the bed then turn left and walk to the wall then turn right and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up', 1: 'pick up the mug with the pen from the shelf .', 2: 'turn around and walk to the desk .', 3: 'put the mug on the desk'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.07733905051040162
# {0: 'turn right and walk to the bed then turn left and walk to the bed then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk to the wall then turn left and walk', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the desk , then turn right and walk to the desk .', 3: 'place the cup on the desk to the left of the laptop .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3540583063911729
# {0: 'turn right , walk to the bed , turn left , walk to the wall , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk over to the wooden desk .', 3: 'place the mug on the desk to the left of the laptop .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.38294812394708894
# {0: 'turn right , walk towards the bed , turn left , walk towards the desk , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk to the desk .', 3: 'place the mug on the desk to the left of the laptop .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3580727738713529
# {0: 'turn right , walk to the bed , turn left , walk towards the bed , turn left , walk to the wall , turn left to face the shelf .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk over to the wooden desk .', 3: 'place the mug on the desk to the left of the laptop .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_185530_954329_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-BaseballBat-None-Bed-308/trial_T20190906_185530_954329
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the baseball bat on the bed
# {0: 'Turn left and walk to the opposite corner of the room by the door', 1: 'Pick up the baseball bat from the corner of the room', 2: 'Turn around and walk over to the side of the bed', 3: 'Put the bat down on the bed just right of the green books'}
#
# Annotation 1
# To put a bat on a bed.
# {0: 'Left away from the desk, right at the bed and take a left at the end of the bed then take a right and go forward to the wall.', 1: 'Pick up the bat leaning against the wall.', 2: 'Turn right and go to the desk take a right at the desk and a left at the bed, go forward take a right and turn around to the right to the bed.', 3: 'Place the bat on the bed in front of the right laptop.'}
#
# Annotation 2
# Bring bat from the wall to the bed.
# {0: 'Take left, walk toward bed, take right, take left at end of bed, take right to bat', 1: 'Pick up the bat on the wall', 2: 'take right, walk to desk, take right to side of bed', 3: 'Set the bat down on the bed'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.022185691715815567
# {0: 'turn left , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk to the wall , turn right , walk', 1: 'pick up the bat from the floor .', 2: 'turn around , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk to the bed , turn right , walk', 3: 'place the blue pillow on the bed'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45075915749897877
# {0: 'turn left and walk to the wall then turn right and walk to the wall then turn right and walk to the wall .', 1: 'pick up the bat from the floor .', 2: 'turn right and walk to the bed , then turn right and walk to the bed .', 3: 'put the bat on the bed'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08288106733547182
# {0: 'turn left and walk to the bed then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk', 1: 'pick up the baseball bat from the floor .', 2: 'turn right and walk to the bed , then turn right and walk to the wall , then turn right to face the bed .', 3: 'place the bat on the bed to the left of the laptop .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08647417434485374
# {0: 'turn left and walk to the bed then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk', 1: 'pick up the bat from the floor', 2: 'turn right and walk to the bed , then hang a right and walk over to the far side of the bed .', 3: 'place the bat on the bed to the left of the laptop .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08566359378162287
# {0: 'turn left and walk to the bed then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk', 1: 'pick up the bat from the floor', 2: 'turn right and walk to the bed , then hang a right and walk over to the far end of the bed .', 3: 'place the bat on the bed to the left of the first bat .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.08647417434485374
# {0: 'turn left and walk to the bed then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk to the wall then turn right and walk', 1: 'pick up the bat from the floor', 2: 'turn right and walk to the bed , then hang a right and walk over to the far side of the bed .', 3: 'place the bat on the bed to the left of the laptop .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_203635_515565_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Vase-None-FloorLamp-219/trial_T20190908_203635_515565
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# grab the vase from the cabinet, turn on the lamp
# {0: 'turn left, walk to the  cabinet', 1: 'open the second door from the right, take the vase out', 2: 'turn right walk to the corner', 3: 'turn on the lamp on the end table'}
#
# Annotation 1
# Turn on a lamp while holding a vase
# {0: 'Move to the middle wood cupboard of the wood table', 1: 'Open the middle cupboard, remove the gold vase in the cupboard, shut the cupboard', 2: 'Carry the gold vase to the floor lamp on the left ', 3: 'Turn on the lamp'}
#
# Annotation 2
# Inspect a vase with a lamp.
# {0: 'move to the end table dresser to the left of the blue arm chair', 1: 'pick up a vase from the cabinet', 2: 'move to the lamp to the right', 3: 'turn on the lamp'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.13757515242207927
# {0: 'turn left and walk to the dresser .', 1: 'open the cabinet and take out the gold .', 2: 'turn right and walk to the wall , then turn right and walk up to the wall , then turn right to face the lamp .', 3: 'turn the lamp on the floor .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16297584715137045
# {0: 'turn to the left and go to the front of the dresser .', 1: 'open the cabinet door and remove the gold , then close the cabinet .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.19560847786212954
# {0: 'turn left and walk to the end of the room , then turn left to face the dresser .', 1: 'open the cabinet and take out the gold , then close the cabinet .', 2: 'turn right and walk over to the lamp on the floor .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11578004334848788
# {0: 'turn left and walk forward , then turn left to face the dresser .', 1: 'open the cabinet and take out the green bowl , then close the door .', 2: 'turn right and walk over to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11578004334848788
# {0: 'turn left and walk forward , then turn left to face the dresser .', 1: 'open the cabinet and take out the green bowl , then close the door .', 2: 'turn right and walk over to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.11578004334848788
# {0: 'turn left and walk forward , then turn left to face the dresser .', 1: 'open the cabinet and take out the green bowl , then close the door .', 2: 'turn right and walk over to the end of the room , then turn right and walk up to the lamp .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_022436_073995_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Cloth-None-Cabinet-424/trial_T20190908_022436_073995
# Number of subgoals (exlcuding <No-op>): 6
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# wash the cloth from the cabinet, put it back
# {0: 'turn around, walk to the vanity on the right', 1: 'open the second from the right cabinet door, take the green cloth out', 2: 'turn right, turn left to the counter', 3: 'put the cloth in the sink, wash the cloth, take the cloth out', 4: 'turn around, turn around', 5: 'open the second from the right cabinet door, put the cloth in, close the cabinet'}
#
# Annotation 1
# Place the clean cloth back in the original cabinet.
# {0: 'Turn left and face the sink.', 1: 'Take the green cloth from the cabinet below the sink.', 2: 'Place the green cloth in the sink.', 3: 'Rinse the green cloth in the sink.', 4: 'Back up from the sink.', 5: 'Place the cloth back in the cabinet.'}
#
# Annotation 2
# Get a towel out of the drawer to soak it, then put it back in the drawer.
# {0: 'Walk to the sink on the right.', 1: 'Open the lower left drawer, and take the green towel out.', 2: 'Position yourself in front of the sink.', 3: 'Place the towel under the faucet to soak it.', 4: 'Go back to the drawer that you got the towel out of.', 5: 'Place the wet towel back in the drawer.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3361375173482971
# {0: 'turn around , walk to the sink .', 1: 'open the cabinet under the sink and pick it back up .', 2: 'turn around , walk to the sink .', 3: 'place the rag in the sink , wash the rag , and remove it back out .', 4: 'turn around , walk to the sink .', 5: 'open the cabinet under the sink and put the rag inside the cabinet .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16611269095843448
# {0: 'turn around and walk to the sink .', 1: 'open the cabinet door below the sink and take out the rag from the cabinet .', 2: 'turn around and take a step forward , then turn left and take a step forward , then turn left and walk up to the counter .', 3: 'put the dirty rag in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean rag .', 4: 'turn around and walk to the sink .', 5: 'open the cabinet door below the sink and put the rag in it .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.16194917537157527
# {0: 'turn around and go to the sink .', 1: 'open the cabinet under the sink and pick up the rag inside .', 2: 'turn right and take a step forward , then turn left and walk up to the counter .', 3: 'put the dirty cloth in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean rag .', 4: 'turn around and walk to the sink on the left .', 5: 'open the cabinet door below the sink and put the cloth in it'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21243559573367732
# {0: 'turn left and go to the sink .', 1: 'open the cabinet under the sink and pick up the rag inside .', 2: 'turn right and take a step forward , then turn left and walk up to the counter .', 3: 'wash the dirty cloth in the sink .', 4: 'turn around and walk back to the sink .', 5: 'open the cabinet door below the sink and put the cloth in it'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.15913770959772933
# {0: 'turn left and go to the sink .', 1: 'open the cabinet under the sink and pick up the rag inside .', 2: 'turn right and take a step forward , then turn left and walk up to the counter .', 3: 'put the dirty cloth in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean rag .', 4: 'turn right and walk to the sink .', 5: 'open the cabinet under the sink and put the cloth in it'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.15913770959772933
# {0: 'turn left and go to the sink .', 1: 'open the cabinet under the sink and pick up the rag inside .', 2: 'turn right and take a step forward , then turn left and walk up to the counter .', 3: 'put the dirty cloth in the sink , turn on the water , after a couple seconds turn the water off and remove the now clean rag .', 4: 'turn right and walk to the sink .', 5: 'open the cabinet under the sink and put the cloth in it'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_125200_737896_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-Desk-308/trial_T20190908_125200_737896
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a mug from the shelves to the desk.
# {0: 'Cross the room and move over to the left side of it, then face the desk with the blue chair and the black laptop and look at the shelves above it.', 1: 'Grab the white mug sitting on the shelf between the books.', 2: 'Bring the mug with you and move around the desk so that you are between it and the bed, then turn right and face the end of the desk.', 3: "Put the mug down on the desk so it's between the water bottle and the disc."}
#
# Annotation 1
# Put a cup on the desk, by the chcair.
# {0: 'Turn around and go to the bed, then turn left to go around to the other side of the bed, turn to your left just before the  laundry hamper, and go to the end of the desk, on your left.', 1: 'Pick up the white cup on the second shelf up, on the right side of the desk, between the books. ', 2: 'Move over to the left end of the desk.', 3: 'Place the white cup back on the desk, directly in front of the blue office chair. '}
#
# Annotation 2
# put a mug on a desk
# {0: 'turn to face the desk top and shelves above desk', 1: 'pick up the white mug from the shelf second from the desk top', 2: 'walk to the left side of the desk', 3: 'put the mug on the desk top on the cd'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5609369616807878
# {0: 'turn around , walk to the wall , turn left to face the desk .', 1: 'pick up the mug from the shelf .', 2: 'turn around and walk to the desk on the right side of the desk .', 3: 'place the mug on the desk'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.06394391958943889
# {0: 'turn around and walk to the wall , then turn left and walk to the wall , then turn left and walk to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and walk up to the wall , then turn left and', 1: 'pick up the mug from the shelf .', 2: 'turn around and walk to the desk .', 3: 'put the mug on the desk'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26530667838426364
# {0: 'turn around and walk to the other side of the room , then turn left and walk to the wall , then turn left and walk to the wall , then turn left and walk up to the wall , then turn left and walk up to the wooden shelving unit .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the desk , then turn right and walk to the desk .', 3: 'place the cup on the desk to the left of the laptop .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2709048824011217
# {0: 'turn around and walk to the bed , then turn left and walk to the wall , then turn left and walk over to the wall , then turn left and walk up to the wooden shelving unit .', 1: 'pick up the mug with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk to the desk .', 3: 'put the mug on the desk'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.25683391297447217
# {0: 'turn around and walk to the desk , then turn left and walk to the wall , then turn left and walk up to the wall , then turn left and walk up to the wooden desk .', 1: 'pick up the cup with the pencil in it .', 2: 'turn around and walk to the bed , then turn right and walk to the desk .', 3: 'put the mug on the desk'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46279168622187106
# {0: 'turn around and walk to the other side of the room , then turn left and walk to the wall , then turn left and walk up to the wooden desk .', 1: 'pick up the cup from the shelf .', 2: 'turn around and walk to the bed , then turn right and walk to the desk .', 3: 'put the mug on the desk'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_161733_213242_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Mug-None-DeskLamp-308/trial_T20190908_161733_213242
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Look at a mug in lamp light.
# {0: 'Go to the desk in front of you, then look up to the shelves.', 1: 'Pick up the mug from the shelf.', 2: 'Look down to the lamp on the desk.', 3: 'Turn on the lamp.'}
#
# Annotation 1
# Examine a mug by the light of a desk lamp.
# {0: 'Walk forward to the mug on the desk in front of you.', 1: 'Pick up the mug from the desk.', 2: 'Walk slightly to the right and stand in front of the lamp on the desk.', 3: 'Turn on the lamp.'}
#
# Annotation 2
# Examine a cup under a lamp.
# {0: 'Walk to the computer desk in front of you.', 1: 'Grab a cup from the shelf on the desk.', 2: 'Go to the right of the desk.', 3: 'Turn the lamp on.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4790513687672153
# {0: 'turn left and walk to the shelf .', 1: 'pick up the mug from the shelf .', 2: 'turn right and face the desk .', 3: 'turn on the lamp .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.31887624670918086
# {0: 'turn left and walk to the wall , then turn right and walk up to the wooden desk .', 1: 'pick up the mug from the shelf .', 2: 'turn right and take a step forward , then turn left and take a step forward , then turn left to face the desk .', 3: 'turn on the lamp'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33393426006613797
# {0: 'turn left and take a step then turn right and walk to the desk .', 1: 'pick up the cup with the pencil in it .', 2: 'turn right and walk to the wall , then turn left to face the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3312661294574541
# {0: 'turn left and walk to the wall then turn right and walk to the desk .', 1: 'pick up the cup with the pencil in it .', 2: 'turn right and walk to the wall , then turn left to face the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3794524640474425
# {0: 'turn left and walk to the desk .', 1: 'pick up the cup with the pencil in it .', 2: 'turn right and walk to the wall , then turn left to face the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30620490882364876
# {0: 'turn left and walk to the wall , then look up at the top of the desk .', 1: 'pick up the cup with the pencil in it .', 2: 'turn right and walk to the wall , then turn left to face the desk .', 3: 'turn on the light on the desk .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_205221_748352_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Vase-None-Safe-219/trial_T20190908_205221_748352
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a vase in a safe.
# {0: 'Go right and then left to cross the room and face the dresser with the computer on it.', 1: 'Pick the gold vase up from the dresser.', 2: 'Go right and the turn right again and stand at the white safe on the floor.', 3: 'Put the gold vase in the safe and shut the door.'}
#
# Annotation 1
# Move a vase from the dresser to the safe.
# {0: 'Turn to the right and then the left to find the computer.', 1: 'Pick up the vase from the back of the dresser.', 2: 'Carry the vase and turn to the right, then right again to find the tall white bookshelf.', 3: 'Open the safe on the floor and place the vase inside. Shut the door.'}
#
# Annotation 2
# Store a vase in a safe.
# {0: 'Walk to the dresser ahead of you.', 1: 'Grab a vase from the dresser.', 2: 'Walk to the shelf behind you on your right.', 3: 'Place the vase in the safe.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.03661910884116126
# {0: 'turn right , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward , turn left , walk forward ,', 1: 'pick up the blue vase from the table .', 2: 'turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk forward , turn right , walk to the shelf .', 3: 'place the vase in the safe .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.33998776744327536
# {0: 'turn right and walk to the dresser .', 1: 'pick up the yellow spray bottle from the table .', 2: 'turn right and walk to the shelves .', 3: 'put the keys in the safe .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.18244652457705232
# {0: 'turn right and walk to the dresser .', 1: 'pick up the gold object from the table', 2: 'turn right , walk to the couch , turn right , walk to the shelves', 3: 'open the white safe and put the keys inside , then close the door .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.22078534241268935
# {0: 'turn right and walk to the dresser on the left .', 1: 'pick up the gold object from the table', 2: 'turn right and walk to the couch , then turn right again and walk over to the shelves .', 3: 'put the white keys inside of the white box on the right side of the shelf .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.1789763461661411
# {0: 'turn right and walk to the dresser .', 1: 'pick up the gold object from the table', 2: 'turn right and walk to the couch then turn right and walk to the shelves .', 3: 'put the white keys inside of the white box on the right side of the shelf .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.21873737522199224
# {0: 'turn right and walk to the dresser .', 1: 'pick up the gold object from the table', 2: 'turn right and walk to the couch , then turn right again and walk over to the shelves .', 3: 'put the white keys inside of the white box on the right side of the keys .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_213926_964767_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-TissueBox-None-FloorLamp-219/trial_T20190906_213926_964767
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Grab the tissue box from the closet, turn on the lamp by the sofa
# {0: 'Turn right, and turn left, walk to the cabinet', 1: 'Open the closet at the right bottom, take the tissue box out, close the closet', 2: 'Turn right, walk to the white sofa', 3: 'Turn on the lamp by the sofa'}
#
# Annotation 1
# Examine a box of tissues using the light from a floor lamp.
# {0: 'Move to the dresser to the left of the blue chair.', 1: 'Open the bottom cabinet door of the dresser to the left of the blue chair, pick up the box of tissues in front of the gold vase, and then close the cabinet door.', 2: 'Turn to the right and move to the left arm of the white couch and look up at the lampshade.', 3: 'Turn on the floor lamp in between the blue chair and the white couch.'}
#
# Annotation 2
# turn on the lamp while holding a box of tissues
# {0: 'walk over to the wooden cabinets next to the couch', 1: 'grab a box of tissues out from the bottom right cabinet', 2: 'walk over to the lamp in the corner of the room', 3: 'turn on the lamp in the corner of the room'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.18347529670507132
# {0: 'turn right and walk forward , then turn left and walk to the white dresser .', 1: 'open the right side of the sink and take out of the box .', 2: 'turn right and walk to the lamp on the right .', 3: 'turn the lamp on the floor .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2411431576629156
# {0: 'turn right and walk to the large wooden dresser .', 1: 'open the cabinet door and remove the tissue box .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23464940330889303
# {0: 'move to the right to the right of the brown cabinet', 1: 'open the cabinet and take out the green tissues .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.24969796252450738
# {0: 'move to the right to the right of the brown cabinet', 1: 'open the cabinet and take out the tissue box .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2593613259540653
# {0: 'move to the right to the front of the brown cabinet', 1: 'open the cabinet and take out the tissue box .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.23951324968645074
# {0: 'move to the right to the right of the brown chair', 1: 'open the cabinet and take out the tissue box .', 2: 'turn right and walk to the couch .', 3: 'turn on the lamp .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_205246_776817_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Vase-None-Safe-219/trial_T20190908_205246_776817
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the gold vase into the white safe
# {0: 'Go forward to the table then turn left and walk straight until you reach the white shelves in front of you. Face the shelf on your right.', 1: 'Pick up the gold vase that is on the shelf', 2: 'Turn in a circle and face the white safe on the floor next to the shelf.', 3: 'Open the safe, place the vase inside the safe, and shut the safe'}
#
# Annotation 1
# Place a gold bottle in a safe.
# {0: 'Take a left at the black table ahead and walk to the white book case to the right of the couch.', 1: 'Pick up the gold bottle on the shelf above the black statue on the book case.', 2: 'Turn around, take a left at the couch and turn left to face the white safe next to the fireplace.', 3: 'Put the gold bottle inside the safe and close the door.'}
#
# Annotation 2
# Put the golden object from the shelf into the safe.
# {0: 'Move forward, turn left at the end table, walk forward and turn right to face the white shelf.', 1: 'Grab the golden object from the shelf.', 2: 'Turn to the right to face the safe.', 3: 'Place the golden object into the safe.'}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.44204157378454206
# {0: 'turn left , walk to the shelf , turn right , walk to the shelf .', 1: 'pick up the blue vase from the shelf .', 2: 'turn around , walk forward , turn left to face the shelf .', 3: 'place the vase in the safe .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2403864485946064
# {0: 'walk to the shelves on the left .', 1: 'pick up the blue vase from the shelf .', 2: 'turn right and walk to the shelves .', 3: 'put the vase in the safe .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.34822618509674436
# {0: 'walk straight to the wall , then turn right to face the shelves .', 1: 'pick up the red vase from the shelf .', 2: 'turn around and walk to the middle of the shelves .', 3: 'open the white door and place the keys inside .'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3174930317595012
# {0: 'walk to the white shelves on the wall .', 1: 'pick up the red vase from the shelf .', 2: 'turn around and walk to the middle of the shelves on the left .', 3: 'put the keys in the white safe .'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26433336113690975
# {0: 'walk to the white shelves on the wall .', 1: 'pick up the blue vase from the shelf .', 2: 'turn around and go to the shelves .', 3: 'put the keys in the white safe .'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3874137883800816
# {0: 'walk to the white shelves on the wall .', 1: 'pick up the gold vase from the shelf .', 2: 'turn around and go to the shelves on the left .', 3: 'open the white open the white door and place the keys inside , then close the door .'}
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_141958_463362_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CD-None-DeskLamp-308/trial_T20190908_141958_463362
# Number of subgoals (exlcuding <No-op>): 4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Turn on the desk lamp.
# {0: 'Go to the garbage can on the floor, to the right of the desk, in front of you. ', 1: 'Remove the CD from the garbage bin. ', 2: 'Turn to your right and walk across the room, turn right at the wall and go to the end of the desk on your left.', 3: 'Turn on the lamp on the front, far, right corner of the desk. '}
#
# Annotation 1
# examine a CD with a lamp
# {0: 'walk forward to the gray trash can', 1: 'take the CD out of the gray trash can', 2: 'turn right, walk across the room, turn left, walk to the wall, turn left to face the lamp on the desk', 3: 'turn the lamp on'}
#
# Annotation 2
# Look at the CD in the light.
# {0: 'Walk across the room. ', 1: 'Pick up the CD that is in the bin on the floor. ', 2: 'Turn right and take three steps, then turn left and walk across the room, then turn left to face the desk. ', 3: 'Turn on the lamp. '}
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6976090973593619
# {0: 'turn right and walk to the trash can .', 1: 'pick up the cd from the trash can .', 2: 'turn right , walk forward , turn left , walk to the desk , turn left to face the desk .', 3: 'turn on the lamp on the desk .'}
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5016213820769282
# {0: 'walk straight to the trash can', 1: 'pick up the cd in the trash can .', 2: 'turn right and walk to the wall , then turn left and walk up to the wall . turn left and walk to the desk .', 3: 'turn on the lamp .'}
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6054753395065066
# {0: 'walk straight to the trash can', 1: 'pick up the cd in the trash can .', 2: 'turn right and walk to the wall , then turn left and walk to the wall , turn left to face the desk .', 3: 'turn on the lamp'}
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.26096423708503536
# {0: 'walk straight to the trash can', 1: 'pick up the cd in the trash can .', 2: 'turn right and walk to the desk .', 3: 'turn on the lamp'}
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2898145355940467
# {0: 'walk straight to the trash can .', 1: 'pick up the cd in the trash can .', 2: 'turn right and walk to the desk .', 3: 'turn on the lamp'}
#
# Epoch 29 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2898145355940467
# {0: 'walk straight to the trash can .', 1: 'pick up the cd in the trash can .', 2: 'turn right and walk to the desk .', 3: 'turn on the lamp'}
# ---------------------------
# --------------------------------------------------------------------------------------
