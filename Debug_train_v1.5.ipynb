# %% [markdown]
# # Look at debugging outputs

# %%
import os
import json
import numpy as np
from collections import defaultdict
import pprint
from nltk.translate.bleu_score import sentence_bleu

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import Image
import matplotlib.image as mpimg

# %%
class args:
    pass

args.dout = '/root/data/home/hoyeung/blob_alfred_data/exp_all/model:seq2seq_nl_with_frames,name:v1.5_epoch_50_high_level_instrs'

# %%
# !ls -l /root/data/home/hoyeung/blob_alfred_data/exp_all/model:seq2seq_nl_with_frames,name:v1.5_epoch_50_high_level_instrs

# %%
train_sanity_epoch_list = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 49]
valid_seen_epoch_list = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 49]
valid_unseen_epoch_list = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 49]

# %% [markdown]
# # Examine Outputs across Epochs
#
# - across epochs
# - random selection
# - rank by CE, BLEU

# %% [markdown]
# ### SECTION 1: Select a random set of tasks to look at

# %% [markdown]
# #### Real Data

# %%
np.random.seed(42)

path = os.path.join(args.dout, 'valid_seen_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_valid_seen = json.load(f)
chosen_valid_seen_task_ids = np.random.choice(list(debug_valid_seen.keys()), size=10, replace=False)

path = os.path.join(args.dout, 'valid_unseen_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_valid_unseen = json.load(f)
chosen_valid_unseen_task_ids = np.random.choice(list(debug_valid_unseen.keys()), size=10, replace=False)

path = os.path.join(args.dout, 'train_sanity_argmax.debug_epoch_0.preds.json')
with open(path, 'r') as f:
    debug_train_sanity = json.load(f)
chosen_train_sanity_task_ids = np.random.choice(list(debug_train_sanity.keys()), size=10, replace=False)

def find_num_high_level_goals(chosen_task_ids, debug_dat):
    '''number of high level goals (complexity) of these chosen tasks'''
    for t in chosen_task_ids:
        print (t, '\t\t\t', len(debug_dat[t]['action_high']))

print("\nRandomly Selected for Train Sanity: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_train_sanity_task_ids, debug_train_sanity)
print("\nRandomly Selected for Valid Seen: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_valid_seen_task_ids, debug_valid_seen)
print("\nRandomly Selected for Valid Unseen: (task, number of planner subgoals)")
find_num_high_level_goals(chosen_valid_unseen_task_ids, debug_valid_unseen)
# Out:
# Randomly Selected for Train Sanity: (task, number of planner subgoals)
# trial_T20190908_115507_503798_0 			 14
# trial_T20190907_011351_027508_0 			 9
# trial_T20190910_055356_172564_0 			 9
# trial_T20190919_045956_375063_0 			 8
# trial_T20190918_173742_042769_0 			 14
# trial_T20190908_030909_087593_0 			 7
# trial_T20190909_004008_377860_0 			 7
# trial_T20190908_072254_824822_0 			 8
# trial_T20190907_181954_161870_0 			 9
# trial_T20190909_113100_297495_0 			 5
#
# Randomly Selected for Valid Seen: (task, number of planner subgoals)
# trial_T20190909_150916_682139_0 			 5
# trial_T20190908_192636_561572_0 			 8
# trial_T20190907_013001_399963_0 			 12
# trial_T20190907_074712_870488_0 			 8
# trial_T20190908_102840_789300_0 			 9
# trial_T20190909_031040_889814_0 			 5
# trial_T20190908_140701_251653_0 			 7
# trial_T20190909_055649_717880_0 			 9
# trial_T20190907_151802_277016_0 			 13
# trial_T20190909_032318_169393_0 			 5
#
# Randomly Selected for Valid Unseen: (task, number of planner subgoals)
# trial_T20190909_123918_983775_0 			 13
# trial_T20190909_123732_489327_0 			 11
# trial_T20190906_191445_723170_0 			 5
# trial_T20190907_020329_050110_0 			 7
# trial_T20190907_170955_824797_0 			 5
# trial_T20190909_210238_431966_0 			 5
# trial_T20190906_224843_443882_0 			 13
# trial_T20190906_214631_761426_0 			 5
# trial_T20190907_074524_006355_0 			 5
# trial_T20190908_114656_768805_0 			 7

# %%
chosen_train_sanity_task_ids = [
'trial_T20190908_115507_503798_0',
'trial_T20190907_011351_027508_0',
'trial_T20190910_055356_172564_0',
'trial_T20190919_045956_375063_0',
'trial_T20190918_173742_042769_0',
'trial_T20190908_030909_087593_0',
'trial_T20190909_004008_377860_0',
'trial_T20190908_072254_824822_0',
'trial_T20190907_181954_161870_0',
'trial_T20190909_113100_297495_0',
]

chosen_valid_seen_task_ids = [
'trial_T20190909_150916_682139_0', 
'trial_T20190908_192636_561572_0', 
'trial_T20190907_013001_399963_0', 
'trial_T20190907_074712_870488_0', 
'trial_T20190908_102840_789300_0', 
'trial_T20190909_031040_889814_0', 
'trial_T20190908_140701_251653_0', 
'trial_T20190909_055649_717880_0', 
'trial_T20190907_151802_277016_0', 
'trial_T20190909_032318_169393_0'
]

chosen_valid_unseen_task_ids = [
'trial_T20190909_123918_983775_0',
'trial_T20190909_123732_489327_0',
'trial_T20190906_191445_723170_0',
'trial_T20190907_020329_050110_0',
'trial_T20190907_170955_824797_0',
'trial_T20190909_210238_431966_0',
'trial_T20190906_224843_443882_0',
'trial_T20190906_214631_761426_0',
'trial_T20190907_074524_006355_0',
'trial_T20190908_114656_768805_0'
]

# %%
urls = {
    'trial_T20190909_150916_682139_0' : 'https://youtu.be/FHGCyxlwp8E',
    'trial_T20190908_192636_561572_0': 'https://youtu.be/KYG5NEfVbjM', 
    'trial_T20190907_013001_399963_0' : 'https://youtu.be/ezmpJhbhCpI',
    'trial_T20190907_074712_870488_0':  'https://youtu.be/civKnURZaR0',
    'trial_T20190908_102840_789300_0': 'https://youtu.be/Dg9dzxXmxB4',
    'trial_T20190909_031040_889814_0': 'https://youtu.be/TpFjTu0nRoA',
    'trial_T20190908_140701_251653_0': 'https://youtu.be/LQpzGDzww1A',
    'trial_T20190909_055649_717880_0': 'https://youtu.be/C9gkb77sF14',
    'trial_T20190907_151802_277016_0': 'https://youtu.be/P9wm8lJwxT4',
    'trial_T20190909_032318_169393_0': 'https://youtu.be/R8fs1wdTMqI',
    'trial_T20190909_123918_983775_0': 'https://youtu.be/1Ha8RLnfsBg',
    'trial_T20190909_123732_489327_0': 'https://youtu.be/4V2hh2cw4No',
    'trial_T20190906_191445_723170_0': 'https://youtu.be/oZ2goybT4pA',
    'trial_T20190907_020329_050110_0': 'https://youtu.be/H-GQkQllSuA',
    'trial_T20190907_170955_824797_0': 'https://youtu.be/8zfLGiywP1A',
    'trial_T20190909_210238_431966_0': 'https://youtu.be/Ti1faQUCSnc',
    'trial_T20190906_224843_443882_0': 'https://youtu.be/z261C5NcQbU',
    'trial_T20190906_214631_761426_0': 'https://youtu.be/6dSWDozBRLU',
    'trial_T20190907_074524_006355_0': 'https://youtu.be/_TobcwcYR9Q',
    'trial_T20190908_114656_768805_0': 'https://youtu.be/AOYa3y_0uCU'
}

# %%
def get_language_annotations(root):
    lang_goals = []
    lang_instrs = []
    path = os.path.join(root, 'pp', 'ann_%d.json' % 0)
    with open(path, 'r') as f:
        ex = json.load(f)
        for i in range(3):
            lang_goals.append(ex['turk_annotations']['anns'][i]['task_desc'])
            lang_instrs.append(ex['turk_annotations']['anns'][i]['high_descs'])
        action_low = [a['discrete_action']['action'] for a in ex['plan']['low_actions']]
        action_high = [a['discrete_action']['action'] for a in ex['plan']['high_pddl']]
    return lang_goals, lang_instrs, action_high, action_low  

def get_ref_instrs(root):
    flatten_isntr = lambda instr: [word.strip() for word in instr]
    ref_instrs = []
    for i in range(3):
        path = os.path.join(root, 'pp', 'ann_%d.json' % i)
        if os.path.exists(path):
            with open(path, 'r') as f:
                ex = json.load(f)
                ref_instrs.append(flatten_isntr(ex['ann']['goal']))
    return ref_instrs

def get_root_location(root):
    return root.replace('data/', '/root/data_alfred/')

def examine_sampled_tasks(sampled_task_ids, epoch_list, split):
    sampled_results = defaultdict(dict)

    for epoch in epoch_list:

        path = os.path.join(args.dout, '{}_argmax.debug_epoch_{}.preds.json'.format(split, epoch))
        path_sampled = os.path.join(args.dout, '{}_sampled.debug_epoch_{}.preds.json'.format(split, epoch))
        with open(path, 'r') as f:
            debug_dat = json.load(f)
        with open(path_sampled, 'r') as f:
            debug_dat_sampled = json.load(f)
            
        for task_id in sampled_task_ids:
            if epoch == 0:
                root = get_root_location(debug_dat[task_id]['root'])
                sampled_results[task_id]['root'] = root
                
                # get all language and action annotations
                sampled_results[task_id]['lang_goal'], sampled_results[task_id]['lang_instr'],\
                sampled_results[task_id]['action_high'], sampled_results[task_id]['action_low'] \
                = get_language_annotations(root)

                sampled_results[task_id]['num_subgoals'] = len(sampled_results[task_id]['action_high'])

                # get referece lang for bleu score
                sampled_results[task_id]['ref_instrs'] = get_ref_instrs(root)
            
            sampled_results[task_id]['p_lang_instr_{}'.format(epoch)] = debug_dat[task_id]['p_lang_instr']
            sampled_results[task_id]['bleu_score_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], debug_dat[task_id]['p_lang_instr'].split(' '))

            sampled_results[task_id]['p_lang_instr_sampled_{}'.format(epoch)] = debug_dat_sampled[task_id]['p_lang_instr']
            sampled_results[task_id]['bleu_score_sampled_{}'.format(epoch)] = sentence_bleu(sampled_results[task_id]['ref_instrs'], debug_dat_sampled[task_id]['p_lang_instr'].split(' '))            
            
    print('SPLIT: {}\n\n\n'.format(split))
    for task_id in sampled_task_ids:
        print("TASK :", task_id)
        print("ROOT:", sampled_results[task_id]['root'])
        print("Number of subgoals :", sampled_results[task_id]['num_subgoals'])
        if task_id in urls:
            print(urls[task_id])
        print ('---------------------------')
        print("Gold Input high-level action description:\n\n", sampled_results[task_id]['action_high'])
        print ('---------------------------')
        print("Gold Input low-level action description:\n\n", sampled_results[task_id]['action_low'])
        print ('---------------------------')
        print("Gold instruction descriptions:\n")
        for i in range(3):
            print('Annotation', i)
            print(sampled_results[task_id]['lang_goal'][i])
            print(sampled_results[task_id]['lang_instr'][i], '\n')
        print ('---------------------------')
        for e in epoch_list:
            print("\nEpoch {} Prediction Output".format(e))
            print("- Decoding by Argmax:")
            print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_{}'.format(e)]))
            print(sampled_results[task_id]['p_lang_instr_{}'.format(e)])
            print("- Decoding by Sampling:")
            print("BLEU score: {}".format(sampled_results[task_id]['bleu_score_sampled_{}'.format(e)]))
            print(sampled_results[task_id]['p_lang_instr_sampled_{}'.format(e)])
        print ('---------------------------')            
        print ('--------------------------------------------------------------------------------------\n\n\n\n\n')
    return sampled_results

# %%
chosen_train_sanity_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_train_sanity_task_ids, epoch_list = train_sanity_epoch_list, split = 'train_sanity')
# Out:
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/site-packages/nltk/translate/bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_115507_503798_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-PotatoSliced-None-GarbageCan-28/trial_T20190908_115507_503798
# Number of subgoals : 14
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'SliceObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'SliceObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# slice up two potatoes in a green waste basket
# ['turn to the right twice and take a few steps and turn to the left and go to the counter', 'pick up the potato from the counter top', 'turn to the right twice and go to the middle of the room and turn to the left and go to the counter top', 'put the potato in the green waste basket underneath the counter top', 'turn to the left and take a few steps and turn to the left and go to the front of the refrigerator and turn to the right and go to the refrigerator', 'open the refrigerator door and take out the potato on the top shelf and close the door', 'turn to the right and take a step and turn to the right and go to the middle of the room and turn to the left and go to the counter top', 'put the potato in the green waste basket underneath the counter top', 'turn to the left and take a few steps and turn to the right facing the counter', 'pick up the yellow handle knife from the counter top', 'turn to the right and take a few steps and turn to the left facing the counter', 'slice up the two potatoes with the knife in the green waste basket']
#
# Annotation 1
# put potatoes in a bin and slice the potato with a knife
# ['go to the counter between the fridge and the stove', 'pick up the potato from the counter', 'take the potato to the coffee machine', 'put the potato in the green bin below the counter', 'go the fridge', 'take the potato from the fridge', 'take the potato back to the counter where the coffee machine is', 'put the potato in the green bin below the counter', 'walk over to counter above the dishwasher', 'take the knife from the counter', 'take the knife over to the bin where you put the potatoes', 'cut the potatoes in the bin with the knife']
#
# Annotation 2
# Put two eggs in a bin and cut them with a knife
# ['Go to the counter between the fridge and the stove', 'Pick up the egg on the counter', 'Go to the green bin', 'Place the egg in the bin', 'Go to the fridge', 'Take an egg out of the fridge', 'Go to the green bin', 'Place the egg in the bin', 'Go to the counter to the left', 'Pick up a knife off the counter', 'Go to the green bin', 'Cut the eggs in the bin']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.306679579551995e-155
# put two egg on the table
# - Decoding by Sampling:
# BLEU score: 5.023587836914362e-155
# put two pencils on the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.164444051541174e-155
# slice potatoes potatoes in the garbage can , and put them in the garbage can .
# - Decoding by Sampling:
# BLEU score: 2.483402656397483e-78
# slice potatoes potatoes potatoes with a knife slice in to the slice in and to the , in and in potato and put knife and slice of
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.595942941090377
# slice up potatoes in a green waste basket
# - Decoding by Sampling:
# BLEU score: 0.23901088824528133
# slice up potatoes in a green of by to the green in green
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# slice up two potatoes in a green waste basket
# - Decoding by Sampling:
# BLEU score: 0.537284965911771
# slice potatoes in a bin and slice them of them
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.4671379777282001
# put potatoes eggs in a bin and and a it
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.9391044157537525
# put potatoes in a bin and cut them with a green
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.3305757413649846
# put potatoes in a garbage and cut the green with a knife
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.6606328636027614
# put potatoes in a bin and cut one slice slice
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.7677331684336531
# put potatoes in a bin and cut them potato with a knife
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.6716877364745231
# put potatoes in a bin and cut bowl slice
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put potatoes in a bin and cut them with a knife
# - Decoding by Sampling:
# BLEU score: 0.3413065354365521
# put potatoes in a garbage and cut knife slice
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_011351_027508_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-HandTowel-None-Toilet-412/trial_T20190907_011351_027508
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two towels on a toilet.
# ['Turn right and walk to the right side of the sink.', 'Take the towel on the wall of of the towel rack.', 'Turn left and walk to the toilet.', 'Put the towel on top of the toilet tank.', 'Turn around and face the sink.', 'Take the towel on the left off the towel rack.', 'Turn around and face the toilet.', 'Place the towel on the toilet behind the other towel.']
#
# Annotation 1
# Put two towels on the toilet tank lid.
# ['Move to the towel rack right of the sink.', 'Pick up the towel from the rack. ', 'Bring the towel to the toilet.', 'Place the towel standing on the toilet tank lid. ', 'Move to the sink.', 'Pick up the towel to the left of the sink. ', 'Bring the towel to the toilet. ', 'Place the towel next to the other towel on the toilet tank lid. ']
#
# Annotation 2
# Place two towels above the toilet
# ['Turn to your right and walk over to the towel on the wall', 'Pick up the towel hanging on the wall', 'Turn around and walk over to the toilet on your right', 'Place the towel above the toilet', 'Turn around and go to the left sink', 'Pick up the towel in front of you', 'Turn around again, and look at the toilet', 'Place the towel behind the other towel, above the toilet']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.072841446586652e-78
# put two towels in the trash can .
# - Decoding by Sampling:
# BLEU score: 5.072841446586652e-78
# put two towels in on the the trash trash
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8694417438899829
# put two towels on the toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.5623413251903491
# put two towels on the toilet of the toilet .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.29502343631964034
# place two towels on s of on the toilet of the toilet
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.846481724890614
# place two towels above the toilet
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# place two towels above the toilet
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.846481724890614
# place two towels above the toilet
# - Decoding by Sampling:
# BLEU score: 0.4671379777282001
# place two towels above a toilet tank .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.5946035575013605
# place two towels on a of the toilet
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.6803749333171202
# place two towels on the toilet tank . a .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# place two towels on the toilet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# place two towels on the toilet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# place two towels on a toilet tank .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# place two towels on the toilet
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190910_055356_172564_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Mug-None-Cabinet-318/trial_T20190910_055356_172564
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move two white mugs into a cabinet.
# ['Walk forward, then turn right and walk up to the wooden desk.', 'Pick up the leftmost white mug off of the wooden desk.', 'Turn around and walk forward, then hang a right and take a step forward, turn right to face the desk.', 'Open the cabinet door below the desk and put the white mug inside on the left side.', 'Turn right and walk forward, then turn left and walk up to the desk.', 'Pick up the white mug off of the desk.', 'Turn around and walk forward, then turn right and walk forward, then turn right to face the wooden desk.', 'Open the cabinet door below the desk and put the white mug inside to the right of the mug that is already in there.']
#
# Annotation 1
# Move two mugs from the desktop to the desk storage space
# ['Walk to stand in front of the desk.', 'Pick up the white mug in front of the electric clock.', 'Move to the right side of the desk and locate the desk storage space door below the drawer.', 'Open the desk door, place the mug at the front left side of the desk storage space, and to the front of the book, close the desk door.', 'Move right to stand in front of the white mug on the far right end of the desktop.', 'Pick up the white mug from the desktop.', 'Move to your left and open the door to the desk storage space.', 'Place the mug to the right of the first mug and close the desk door.']
#
# Annotation 2
# Pick up the cups on the desk and place them in the desk drawer.
# ['Turn to your right', 'Pick up the leftmost cup on the desk', 'Turn around and take a step before turning back towards the desk', 'Open the desk drawer and place the cup inside before closing the drawer.', 'Turn to your right and then back towards the desk.', "Pick up the cup that's on the desk", 'Turn around and take a step before turning back towards the desk', 'Open the desk drawer and place the cup inside before closing the drawer.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.467133248249545e-155
# put two cup in a cabinet
# - Decoding by Sampling:
# BLEU score: 1.384292958842266e-231
# put two cup in in in in cabinet cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.36741454942156665
# put two mugs in the desk drawer
# - Decoding by Sampling:
# BLEU score: 5.649668284632948e-78
# put two mugs to the desk table to the desk drawer the desk .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 5.572079302093865e-78
# move two mugs in a desk cabinet .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 4.663684423129405e-78
# move two mugs in a desk .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 4.487375970393454e-78
# move two mugs mugs a desk .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 0.7546930988815487
# move two mugs from the desktop to the desk cabinet space
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 0.5607900239988007
# move two mugs mugs from the desktop to the desk desk of the desk
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 5.572079302093865e-78
# move two mugs in a desk cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 6.886705081558736e-78
# move two mugs mugs into a desk .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 0.6985342056580097
# move two mugs from the desktop to a desk space
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# move two mugs from the desktop to the desk cabinet
# - Decoding by Sampling:
# BLEU score: 5.572079302093865e-78
# move two mugs in a desk cabinet .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190919_045956_375063_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spatula-Plate-SinkBasin-3/trial_T20190919_045956_375063
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a plate and spatula to the sink.
# ['Move forward and turn left toward the end of the counter.', 'Pick up the spatula from the end of the counter.', 'Carry the spatula and take a few steps to the left.', 'Place the spatula on the plate on the counter.', 'Pick up the plate from the counter.', 'Hold the plate and move a few steps to the left to go to the sink.', 'Place the plate and spatula in the sink.']
#
# Annotation 1
# Put a plate with a spatula on it in the sink.
# ['Move to the counter to the left of you', 'Pick up spatula from the counter', 'Move to the counter to the right of the sink', 'Put spatula on a plate on the counter.', 'Pick up plate from the counter', 'Move to the sink to the left of you', 'Put plate inside the sink']
#
# Annotation 2
# Place round plate with spatula in sink
# ['go forward to end of counter with loaf of bread', 'pick up spatula on back of counter to the right of bread', 'go to round plate on counter to the left', 'place spatula on round plate on counter to the left of the bread', 'pick up plate with spatula', 'go to sink to the left', 'place round plate with spatula in sink']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.54286932954127
# put a plate with a spatula in it on the sink .
# - Decoding by Sampling:
# BLEU score: 0.5475857123833053
# put a plate with a spatula in it in the on the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.518020345386123e-78
# put the plate with spatula on the kitchen sink
# - Decoding by Sampling:
# BLEU score: 0.37991784282579627
# put a plate with the in the sink sink sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9554427922043668
# put a plate and spatula to the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.7121043131712586
# put a plate and and spatula to the sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.31614875844889434
# put put a spatula in a plate and put them in the sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a plate with a spatula on it in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190918_173742_042769_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-18/trial_T20190918_173742_042769
# Number of subgoals : 14
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'SliceObject', 'PutObject', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Slice a tomato and place in skillet.
# ['Turn left and walk forward to the table. Make a right to face the table. ', 'Pick up the tomato from the table.', 'Turn to the right and then left to walk around the table to the other side.', 'Set the tomato on the table. ', 'Pick up the yellow knife from the table. ', 'Use the knife to slice the tomato. ', 'Set the knife on the table to the right of the sponge. ', 'Pick up a slice of tomato. ', 'Turn around and go to the left. Then make another left at the oven.', 'Place the tomato slice on the skillet.', 'Pick up the skillet with the tomato slice.', 'Turn to the left and walk over to the table. Turn left again to face the table.', 'Place the skillet on the table with the tomato inside. ']
#
# Annotation 1
# Place a frying pan with a tomato slice in it onto the table.
# ['Turn left then head towards the table against the wall.', 'From the table pick up the tomato behind the green sponge.', 'Turn right then head towards the door, turn left then head towards the refrigerator, then left, head towards the table.', 'Place the tomato to the right of the green sponge.', 'Pick up the knife behind the spoon on the table', 'Cut the tomato into slices.', 'Place the knife behind the tomato on the table.', 'Pick up a tomato from the table.', 'Turn left, then head towards the stove.', 'Place the tomato into the frying pan on the stove.', 'Pick up the frying pan from the stove.', 'Turn left then head towards the table against the wall.', 'Place the frying pan to the left of the plant onto the table.']
#
# Annotation 2
# put a slice of tomato on a pan onto the black table
# ['turn to the left go to the right', 'pick up the tomato from the black table', 'turn left go right left again facing the black table ', 'put the tomato on top of the table', 'pick up the knife from the table ', 'slice the tomato in 2 pieces', 'cut 1 half into many pieces', 'pick up one piece of the tomato', 'turn to the right go left face the stove', 'put the piece of tomato in the pan that is on the stove', 'pick up the pan from the stove', 'turn to the left across the room', 'put the pan on top of the black table']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.939425925209436e-78
# put a tomato and pan on the table .
# - Decoding by Sampling:
# BLEU score: 1.0182455573372486e-154
# put a tomato tomato on put it on the table table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6529942057256104
# put a pan with a tomato slice in it on the table .
# - Decoding by Sampling:
# BLEU score: 1.0499412182717021e-154
# put a pan tomato with with a on the kitchen .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.831173435395861
# put a pan with a tomato slice in it onto the black table .
# - Decoding by Sampling:
# BLEU score: 0.3706866381788037
# put a pan and a tomato and place in pan pan pan on
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.963273987908844e-78
# slice a tomato , put in the pan on the table
# - Decoding by Sampling:
# BLEU score: 0.345720784641941
# slice a tomato and put in in a pan on
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.54286932954127
# slice a tomato and place in a pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.22686182598679874
# slice a tomato and the pan and place in the pan pan on place place on the the table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.5988059642324198
# slice a tomato and place in in a pan .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.54286932954127
# slice a slice of tomato on a pan on the table table
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.5137480412538583
# slice a tomato and place in the pan on the table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# slice a tomato and place in skillet .
# - Decoding by Sampling:
# BLEU score: 0.5678708310963577
# slice a frying tomato slice a tomato slice in it onto the pan onto the table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_030909_087593_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Fork-None-Drawer-30/trial_T20190908_030909_087593
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a clean fork in the drawer
# ['move forward towards the table', 'pick up the fork', 'move to the sink ahead', 'drop the fork in the sink and rinse it', 'move to the right of the sink', 'place the fork in the drawer']
#
# Annotation 1
# Wash a fork in the sink that was left on the counter to be place inside a drawer.
# ['Move slightly to the left side of the  brown counter top island.', 'Pick up the fork that is on the slanted corner. ', 'Move across the kitchen to the sink. ', 'Put the fork in the sink and wash it. Take the fork out of the sink. ', 'Turn to the right and move slightly down the white counter top next to the sink. ', 'Open the drawer that is under the far right of the counter and place the fork inside. C Close the drawer.']
#
# Annotation 2
# wash the fork and put it in the drawer
# ['go the island and approach the fork', 'pick up the fork', 'take the fork to the sink', 'put the fork in the sink and take back out', 'go the right of the sink at the counter', 'put the knife in the drawer all the way to the right']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# put a clean fork in the drawer .
# - Decoding by Sampling:
# BLEU score: 4.098508578387282e-78
# put a clean fork on the drawer . the on put in the drawer of the sink of the sink . the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.373421126552421
# wash a clean fork in a drawer . to the sink .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.43242270754632145
# wash a fork in the drawer . the it black by the sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 1.0
# wash the fork and put it in the drawer
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.6223329772884784
# wash a clean fork in the drawer . that .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.7860753021519787
# wash the fork and put it in the drawer drawer table
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.4237210172803333
# wash a clean fork in the drawer . that of the counter . . wash
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.7952707287670506
# wash a clean fork in the drawer .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.7952707287670506
# wash a clean fork in the drawer .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.4817712540970702
# wash the fork in put it in the drawer . that .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# - Decoding by Sampling:
# BLEU score: 1.0
# wash the fork and put it in the drawer
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_004008_377860_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-DiningTable-15/trial_T20190909_004008_377860
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold pan on the white table.
# ['Turn right and go to the counter with the coffee maker, then turn right to face the counter with the toaster on it.', 'Pick up the pan from the counter in front of you.', 'Turn right and go toward the door, then turn left to face the fridge.', 'Open the fridge, put the pan inside, and take it back out.', 'Turn around and go forward toward the wall, then turn right to face the white table.', 'Put the pan on the white table.']
#
# Annotation 1
# Put a cold pan on the table.
# ['Take a small step forward then turn right and walk to the counter then turn right.', "Pick up the frying pan that's in front of you.", 'Turn right and walk to the door then turn left to face the fridge.', 'Chill the in the fridge then get it back out and close the door.', 'Turn around and walk to the wall in front of you then turn right.', "Put the pan on the table in front of you near the corner that's nearest you."]
#
# Annotation 2
# Chill the frying pan and put it on the table.
# ['Turn right and walk to the counter.  Turn right again so you are facing the toaster.', 'Pick up the frying pan in front of the toaster.', 'Turn right and walk to the door.  Turn left and face the refrigerator.', 'Open the refrigerator door and place the frying pan on the top shelf in the refrigerator and close the refrigerator door again.  Open the refrigerator door and remove the frying pan from the top shelf, then close the refrigerator door.', 'Turn completely around, walk to the wall, turn to the right so you are facing the white table. ', 'Place the frying pan on the table in front of the stool. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a chilled pan on the table .
# - Decoding by Sampling:
# BLEU score: 4.966097853332116e-78
# put a chilled on the white .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.7801157731069053
# put a cold pan on the table table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.831173435395861
# put a frying pan and put it on the table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 5.185404073830853e-78
# put a pan pan to the table .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 1.046685547397662e-154
# put a frying pan from the counter to the table table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.7801157731069053
# put a cold pan on the table table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 5.333384990808849e-78
# put a frying and store it on the kitchen table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.3628241434631103
# put a pan on the table table table
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.831173435395861
# put a frying pan and put it on the table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_072254_824822_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Ladle-Bowl-Cabinet-16/trial_T20190908_072254_824822
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a bowl with a spoon inside a cabinet.
# ['Turn around and walk to the counter on the right.', 'Pick up the spoon with the black handle near the edge of the counter.', 'Turn left and hang a left at the wall to face the white table.', 'Put the spoon inside the wooden bowl to the right of the tomato on the table.', 'Pick up the bowl with the spoon on the table.', 'Turn left, hang a left at end of the white table, walk around the angle of the counter and hang a left at the white stove to face the cabinets.', 'Open the far right cabinet, place the bowl with a spoon inside and close the door.']
#
# Annotation 1
# Put a bowl with a spoon in it into a cabinet.
# ['Turn around 180 degrees and walk to the counter.', 'Pick up the spoon on the counter. ', 'Turn to the left 90 degrees and walk across the room, turning 90 degrees to the left to face the table when you reach it.', 'Place the spoon in the brown cup.', 'Pick up the brown cup with the spoon in it. ', 'Turn to the left 90 degrees, then again after walking to a bit and cross the room, turning another 90 degrees to the left when you reach the end, and walk towards the counter.', 'Put the bowl with the spoon in it into the lower cabinet. ']
#
# Annotation 2
# drop a plate with a spoon in it in the cupboard
# ['turn around to the table', 'pick up the spoon from the table', 'move left to the table ', 'drop the spoon in the plate', 'pick up the plate from the table', 'turn around and move to the cupboard', 'drop the plate in the cupboard']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9146912192286945
# put a bowl with a spoon in it in the cabinet
# - Decoding by Sampling:
# BLEU score: 0.29420957081163696
# put a bowl bowl with a spoon it cabinet . the to the sink
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8672378180697351
# put a plate with a spoon in it in the cupboard .
# - Decoding by Sampling:
# BLEU score: 0.5844356470407898
# put a plate with a spoon in a the cupboard cabinet
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# place a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.4581217604914856
# place a bowl with a in it cabinet .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.6433351856152976
# drop a bowl with a spoon inside a the
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.7315254958027825
# drop put a bowl with a spoon in it into the cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.5491004867761125
# drop a bowl with a spoon inside it inside the cabinet
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.7226568811456053
# drop a bowl with a spoon inside a into a cabinet
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.7400828044922853
# drop a bowl with a spoon in it inside a cabinet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.646622768701772
# drop a bowl with a spoon inside it into a cabinet . to cabinet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8420460979216616
# drop a bowl with a spoon inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.6262844962765468
# drop a bowl with a spoon in it into the the cabinet cabinet
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_181954_161870_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Watch-None-Dresser-205/trial_T20190907_181954_161870
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place two watches on the TV stand.
# ['Walk to the glass dining table on the other side of the red chair.', 'Pick up the watch between the statue and the compute on the table.', 'Turn around and walk to the TV.', 'Place the watch on the middle of the TV stand.', 'Turn around and walk to the far side of the glass dining table.', 'Pick up the watch next to the statue on the dining table.', 'Walk to the TV on the other side of the room.', 'Place the watch to the left of the other watch on the TV stand.']
#
# Annotation 1
# place two watches on the tv stand
# ['turn left and head towards the dining', 'pick up the watch', 'turn around and locate the tv', 'drop the watch on the tv stand', 'turn around and head for the dining', 'pick up the wrist watch', 'turn around and head for the television stand', 'place the watch on the tv stand']
#
# Annotation 2
# Put two watches on the tv stand.
# ["Walk to stand in front of the chair you can see in front of you to the left that's sitting in front of a statue and laptop.", 'Pick up the watch you see on the table.', 'Turn arouind and walk over to the tv you can see in front of you to the left,', 'Put the watch in the middle of the tv stand.', 'Walk to the opposite side of the table that where you got the first watch.', 'Pick up the watch on that side of the table.', 'Walk back over to the tv.', 'Put this watch ot the left of the first watch.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5578002860768766
# place two watches on the dresser .
# - Decoding by Sampling:
# BLEU score: 4.797597231912944e-78
# place two watches of the of the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.2722589423069702
# place up two watches and place it on the tv stand . . . . .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.5946035575013605
# place two watch on the tv stand .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 1.0
# place two watches on the tv stand .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.7165313105737893
# place two watches on the tv
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.5156626918239822
# place two watches on on the tv stand . the tv .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 1.0
# place two watches on the tv stand .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 1.0
# place two watches on the tv stand .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.6132297420585351
# place two watches on the tv stand . the the table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.5698363775444273
# place two watches on the stand
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place two watches on the tv stand .
# - Decoding by Sampling:
# BLEU score: 0.6132297420585351
# place two watches on the tv stand . the tv . .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_113100_297495_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-ArmChair-318/trial_T20190909_113100_297495
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move book from dresser to chair
# ['turn left, walk across the room to the dresser', 'pick up the book that is on the dresser', 'turn left, walk forward, turn left to face floral chair', 'put the book on the chair']
#
# Annotation 1
# Move a book from the desk to the floral armchair.
# ['Turn right to walk to the desk.', 'Pick up the green book from the desk.', 'Turn around to walk to the floral armchair.', 'Set the green book down on the floral armchair.']
#
# Annotation 2
# Place a book on a chair.
# ['Turn left and walk to the wooden desk ahead.', 'Pick up the green book from the right side of the desk.', 'Turn around and walk to the floral chair on the right against the wall.', 'Put the book on the middle of the chair.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a book on a chair .
# - Decoding by Sampling:
# BLEU score: 0.6389431042462724
# place a book on a chair . a chair .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a book on a chair .
# - Decoding by Sampling:
# BLEU score: 9.905379076004965e-155
# place book book to the chair . a .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8891397050194614
# move a book from the desk to the chair
# - Decoding by Sampling:
# BLEU score: 0.9306048591020996
# move a book on a chair .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.846481724890614
# move book from dresser to chair
# - Decoding by Sampling:
# BLEU score: 7.070325777244754e-155
# move a on the chair
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4760116549244004
# place a book on the chair
# - Decoding by Sampling:
# BLEU score: 0.5115078115793242
# place a from dresser to chair
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a book on a chair .
# - Decoding by Sampling:
# BLEU score: 0.8408964152537145
# place a book from the desk to the chair
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a book on a chair .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# place a book on a chair
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a book on a chair .
# - Decoding by Sampling:
# BLEU score: 0.36889397323344053
# place a book on the chair . window .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4760116549244004
# place a book on the chair
# - Decoding by Sampling:
# BLEU score: 0.4417918226831577
# place a book on the chair armchair .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4760116549244004
# place a book on the chair
# - Decoding by Sampling:
# BLEU score: 0.631196907822589
# place book book from the desk to the chair
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4760116549244004
# place a book on the chair
# - Decoding by Sampling:
# BLEU score: 0.631196907822589
# place the book from the desk to the chair
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
chosen_valid_seen_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_valid_seen_task_ids, epoch_list = valid_seen_epoch_list, split = 'valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190909_150916_682139_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Pillow-None-DeskLamp-302/trial_T20190909_150916_682139
# Number of subgoals : 5
# https://youtu.be/FHGCyxlwp8E
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Carry a purple pillow while turning on a lamp
# ['Move to face the head board of the bed where the purple pillow is', 'Pick up the purple pillow on the bed', 'Carry the purple pillow over to the night stand with the lamp on top of it', 'Turn on the lamp']
#
# Annotation 1
# Look at a pillow under the light of a lamp.
# ['Turn around and walk to the middle of the room, then turn right and walk to the window, then turn left to face the bed.', 'Pick up the purple pillow from the bed.', 'Turn left and walk to the nightstand to the right of the door.', 'Turn on the lamp that is on the nightstand.']
#
# Annotation 2
# Examine a pillow by the light of a table lamp
# ['Turn left and go to the desk then turn left and go as far as the bed then turn right and go alongside the bed to the nightstand then turn left to face the nightstand', 'Pick up the pillow from the bed', 'Turn left and go past the end of the bed then turn right and go to the safe then turn left and go to the table with the lamp on it', 'Turn on the lamp']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# examine a pillow by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 1.0
# examine a pillow by the light of a lamp .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# examine a purple pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.49616830003403634
# examine at the purple pillow by the light of a small .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 6.269681580989379e-78
# examine at a purple pillow by a lamp on .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 6.10669334877734e-78
# examine at a purple pillow by a lit lamp .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.4933885363281902
# examine at a purple pillow by a light of a lamp .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 6.10669334877734e-78
# examine at a purple pillow by a lit lamp .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 6.10669334877734e-78
# examine at a purple pillow by a lit lamp .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 9.367929145127228e-155
# examine up a pillow and turn a lamp on .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# examine a pillow by the light of a small lamp .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_192636_561572_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Ladle-Pan-SinkBasin-4/trial_T20190908_192636_561572
# Number of subgoals : 8
# https://youtu.be/KYG5NEfVbjM
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'OpenObject', 'PutObject', 'PickupObject', 'CloseObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a spoon in a pan on the counter.
# ['Turn around and walk to the table with the  kitchen table.', 'Pick up the spoon.', 'Turn around and walk to the refrigerator.  ', 'Open the refrigerator.  Put the spoon on the pan in the refrigerator.  ', 'Grab the pan out of the refrigerator with the spoon.', 'Close the door and turn left.  Walk to the oven and counter, turn left and walk to the wall.  Turn right before the microwave.', 'Put the pan with the spoon on the counter.']
#
# Annotation 1
# Put a pan with spoon in it, in the sink.
# ['Turn around, move to the table in front of you.', 'Pick up the spoon on the table.', 'Turn around, bring the spoon to the fridge in front of you.', 'Put the spoon in the pan in the fridge.', 'Pick up the pan with spoon in the fridge. ', 'Bring the pan back to the sink, behind you to the left.', 'Put the pan with spoon in the sink. ']
#
# Annotation 2
# put pan and ladle into kitchen sink
# ['walk to face wooden table', 'pick up ladle from table', 'walk to face fridge', 'put ladle inside pan in fridge', 'take out pan from fridge', 'walk to face sink', 'put ladle into sink basin']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3945881255591767
# put a pan with a spoon in it on the kitchen counter .
# - Decoding by Sampling:
# BLEU score: 8.288618157420982e-78
# put a pan pan with a spoon in it sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.32774568052975916
# put a plate with a large spoon in it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.29615165360116247
# put a plate pan with a large in it in the sink .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.43167001068522526
# put the the with spoon in the sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.37817904276524744
# put the pan with spoon in in the sink sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.3814165616365676
# put a pan with the in the kitchen .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.4012671145009053
# put the pan with a spoon in it in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.37200908038405156
# put the pan with spoon in the sink sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.37200908038405156
# put the pan with spoon in the sink sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.2722589423069702
# put the metal pan with spoon ice cream scoop in it in the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.34172334076593075
# put the pan with spoon spoon in the in the sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5969491792019646
# put the pan with spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.34172334076593075
# put the pan with spoon spoon in in in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_013001_399963_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-AppleSliced-None-SideTable-21/trial_T20190907_013001_399963
# Number of subgoals : 12
# https://youtu.be/ezmpJhbhCpI
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'SliceObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a sliced apple down on the black table at the end of the kitchen counter
# ['turn left and walk forwards until your reach the sink on your left', 'grab a butter knife out of the sink', 'cut the apple in the sink', 'back up a bit to face the sink again', 'place the butter knife in the cabinet to the bottom left of the sink', 'walk forwards a bit to the sink again', 'grab an apple slice from out of the inside of the sink', 'turn right and walk over to the fridge on your left', 'place the apple slice in the fridge to cool, then take it back out', 'turn around to move forwards a bit, then turn right and walk to the end of the room, then turn right to face the kitchen counter', 'place the apple slice down on the black table at the end of the kitchen counter next to the salt shaker']
#
# Annotation 1
# Put a piece of an apple on a stand.
# ['Turn left and take a step then turn left to face the  sink.', 'Pick up the knife in the middle of the sink.', 'Cut up the apple in the lower right corner of the sink.', 'Take a step back.', 'Open the cupboard on the left and put the knife down there and close the cupboard.', 'Walk back to the sink.', 'Get the middle piece of apple.', 'Take a few steps to your right to stand in front of the fridge.', 'Open the fridge and put the apple on the top shelf then close the fridge and let it chill for a while before retrieving it and closing the door.', 'Turn left and walk to the table then turn right and face the black stand to the left of the sink.', 'Put the apple to the left of the salt shaker.']
#
# Annotation 2
# Place the cool slice apple on the small black table.
# ['Turn left and head towards the sink on your left.', 'Pick up  the knife from the sink.', 'Slice the green apple in the sink in half.', 'Take a step backwards.', 'Open the left cabinet below the sink and place the knife on the plate.', 'Close the cabinet and step towards the sink.', 'Pick up the middle apple slice from the sink.', 'Turn right towards the fridge.', 'Open the fridge, place the slice of apple in the fridge, let it cool, and take it out of the fridge.', 'Turn left and walk towards the small black table to your right.', 'Place the slice apple on the table.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.0757394012695e-155
# put a chilled apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 9.6212612450095e-155
# put cool a piece piece of piece place it on the trash .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.43361890903486755
# put a cold piece of apple on the black table .
# - Decoding by Sampling:
# BLEU score: 5.789883300596636e-78
# put a cold apple slice on the of the black table
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 7.906906991230994e-155
# place an apple , put one knife , slice , put slice , put it on a black table
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 8.200856307228175e-155
# place a cooled apple slice on a black .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 0.31702331385234306
# place a cold of cold apple on a stand stand .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 0.4353152270198899
# place a cold slice of apple on a stand .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 6.836365931062249e-155
# place a of , cut apple , place in yellow table . top one them to .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 4.601359000402709e-78
# place a slice piece of apple next a black table . the corner .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 0.2978201796359045
# place a knife , place a chilled slice on the black table .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30541450699432376
# place a cooled apple slice on a stand .
# - Decoding by Sampling:
# BLEU score: 0.4353152270198899
# place a cold slice of apple on a stand .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074712_870488_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Knife-Bowl-SideTable-28/trial_T20190907_074712_870488
# Number of subgoals : 8
# https://youtu.be/civKnURZaR0
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put the cup with the knife on the table
# ['turn to your left turn to your left walk straight turn right at the stove walk straight to the sink', 'pick up the knife on the counter ', 'turn to the right turn to the right turn to the left turn to the left turn to the right walk forward', 'pick up the cup on the table', 'put the knife into the cup ', 'turn to the right turn to the left walk forward turn to the right ', 'walk forward put the cup and knife on the table ']
#
# Annotation 1
# Put a knife in a blue container onto the black table in the corner.
# ['Turn around and walk across the room to the oven, then turn right and walk to the counter to the right of the sink.', 'Pick up the knife that is on the counter to the right of the sink, near the sponge.', 'Turn right and walk across the room to the green table.', 'Place the knife inside of the blue container on the table.', 'Pick up the blue container on the table with the knife in it.', 'Turn right and walk across the room to the black table in the corner.', 'Place the blue container with the knife in it onto the black table in the corner.']
#
# Annotation 2
# Moving a container with a knife in it
# ['Turn around and head to the sink', 'Grab the large knife that is to the right of the sink', 'Walk to the table on your right', "Place the knife into the container that's on the table", 'Grab the container with the knife inside', 'Turn right and head to the small black table in the corner of the room', 'Place the container on the small black table']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.47718970758108814
# put a bowl with a knife in it on the table .
# - Decoding by Sampling:
# BLEU score: 9.013778876140909e-155
# put a bottle to a table . the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.423660437707094e-78
# put a bottle of wine on the black table .
# - Decoding by Sampling:
# BLEU score: 5.185404073830853e-78
# put a bottle knife on the end table
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.89149694578813e-155
# put a bottle on a table .
# - Decoding by Sampling:
# BLEU score: 1.0547686614863434e-154
# put a bottle sponge on the black end .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.53091075863908e-155
# put a wine bottle on the end table .
# - Decoding by Sampling:
# BLEU score: 6.111565467761957e-235
# put
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 6.532035914650002e-78
# put a wine away was a knife on the black table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 9.487289885028994e-155
# put a wine slice on on on on the black .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 1.0031587692359528e-154
# put a wine in a bowl on move the the table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 1.0962103931192249e-154
# put a wine in a black black table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 1.151858371222192e-154
# put a wine in a bowl on the black .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 6.501553757486207e-155
# put a wine in the wine
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.046685547397662e-154
# put a wine away in a bowl on the black shelf .
# - Decoding by Sampling:
# BLEU score: 9.212002349967284e-155
# put a wine in a table . a black knife .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_102840_789300_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-KeyChain-None-Sofa-202/trial_T20190908_102840_789300
# Number of subgoals : 9
# https://youtu.be/Dg9dzxXmxB4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two sets of keys on the couch.
# ['Turn around and walk across the room to the side table on your right.', 'Pick the set of keys up off the table.', 'Turn right and walk to the furthest end of the couch on your left.', 'Set the keys on the right couch cushion to the right of the laptop.', 'Turn around and walk to the TV stand on the other side of the room.', 'Pick up the set of keys on the right of the laptop.', 'Turn around and move back to the right side of the couch.', 'Set the second set of keys down on the couch in front of the laptop where the cushions meet.']
#
# Annotation 1
# Place two sets of keys on the sofa.
# ['Turn around and head towards the wall, then make a right and go to the table.', 'Pick up the keys on the table next to the box.', 'Turn around and step forward, then turn left and go center of the room and turn left in front of the sofa.', 'Place the key on the sofa to the bottom right of the laptop.', 'Turn around,walk forward and go in the space between the TV stand and the coffee table.', 'Pick up the keys off the TV stand to the right of the laptop.', 'Return to the center of the sofa.', 'Place the key to the left of the key already on the sofa.']
#
# Annotation 2
# TO move two sets of keys to the couch.
# ['Turn to the left and face the table at the end of the couch.', 'Pick up the keys on the end table.', 'Turn right and walk forward and turn to the left to face the right end of the couch.', 'Place the keys on the right side of the couch.', 'Turn around and walk across the room to face the TV stand.', 'Pick up the keys on the TV stand.', 'Turn around and walk forward to face the couch.', 'Place the keys on the couch next to the first set of keys.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.4606369751099829
# put two sets of keys the couch
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# move two sets of keys to the couch .
# - Decoding by Sampling:
# BLEU score: 0.6865890479690392
# move two sets of keys on the in the couch
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5506953149031837
# move two sets of keys to a sofa
# - Decoding by Sampling:
# BLEU score: 0.5814307369682193
# move two sets of keys to a couch couch .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.6610079036990795
# put two sets of keys to the table to the couch
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.5783569866465142
# put two sets of keys on the table top to the couch sofa
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.5555238068023582
# put two sets of keys to table to table sofa
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.6132297420585351
# put two sets of keys to the table to the couch sofa
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.8948393168143697
# put two sets of keys on the couch .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_031040_889814_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Plunger-None-Cabinet-414/trial_T20190909_031040_889814
# Number of subgoals : 5
# https://youtu.be/TpFjTu0nRoA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a plunger to the cabinet.
# ['Turn around and face the toilet.', 'Pick up the plunger from the left side.', 'Carry the plunger and turn to the right, then face the sink on the left.', 'Open the bottom cabinet, second from the left, and place the plunger inside.']
#
# Annotation 1
# put the plunger away in the cabinet
# ['turn right, walk to the wall, turn right to face the toilet', 'pick up the plunger to the left of the toilet', 'turn right, walk forward a few steps, turn right, take a few steps, turn around, walk to counter', 'open cabinet under sink, put the plunger in the cabinet, close the cabinet']
#
# Annotation 2
# Put the plunger under the sink.
# ['Turn around and go to the left corner of the room, past the toilet paper holder. ', 'Pick up the plunger to the left of the toilet bowl cleaner, on the floor, in the corner. ', 'Turn around and go to the cabinets under the sink to your left. ', 'Place the plunger under the sink, in the second cabinet from the left, under the sink. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.453946401578459e-155
# put a plunger in a cabinet .
# - Decoding by Sampling:
# BLEU score: 5.474607971919403e-155
# put a handle in the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.453946401578459e-155
# put a plunger in a cabinet .
# - Decoding by Sampling:
# BLEU score: 6.130783336563573e-78
# put a plunger from the cabinet . the sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8408964152537145
# to put the plunger away in the cabinet .
# - Decoding by Sampling:
# BLEU score: 9.013778876140909e-155
# to a plunger from the floor to a cabinet .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 5.047284757449962e-78
# to put a plunger from the floor to the cabinet
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 5.047284757449962e-78
# to up the plunger and put it in the cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 8.909555824566607e-155
# to put a plunger from the floor to a cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0719249972567852e-154
# to the plunger and put it in a cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 5.047284757449962e-78
# to up the plunger and put it in the cabinet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 5.047284757449962e-78
# to up the plunger and put it in the cabinet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.44162179929626e-78
# to put the plunger in the cabinet .
# - Decoding by Sampling:
# BLEU score: 8.909555824566607e-155
# to put a plunger from the floor to a cabinet .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_140701_251653_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Cloth-None-Drawer-423/trial_T20190908_140701_251653
# Number of subgoals : 7
# https://youtu.be/LQpzGDzww1A
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Get wash rag wet and put it away in drawer.
# ['Turn and go to the counter to the left of the sink.', 'Pick up the green wash rag that is on the counter to the left of the sink.', 'With the wash rag in hand turn and go to the sink.', 'Place the wash rag in the sink.  Turn the water on to get the wash rag wet.  Turn the water off and pick up the wash rag.', 'With the wash rag in hand move to your left to where the toilet paper is on the counter.', 'Open the drawer right under where the toilet paper is on the counter. Place the wash rag in the drawer and shut the drawer.']
#
# Annotation 1
# Put a cleaned rag in a drawer.
# ['Turn left, go to door, turn right, got to counter left of sink. ', 'Pick up rag on counter. ', 'Bring the rag to the sink on the right.', 'Wash the rag in the sink. ', 'Bring the cleaned rag to the drawer under the sink, to the left.', 'Open that third drawer from the right and put the cleaned rag in there. ']
#
# Annotation 2
# Put a clean cloth in a drawer.
# ['Go left to face the mirror over the counter.', 'Pick the green cloth up from the counter.', 'Move to the left and face the sink.', 'Put the cloth in the sink and turn the water on and then off and pick the cloth up again.', 'Move back and face the drawers under the counter and on the left.', 'Put the cloth in the bottom drawer and shut the drawer.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46199933699457096
# put a clean cloth in the cabinet
# - Decoding by Sampling:
# BLEU score: 0.3203558799120807
# put put a clean cloth in alarm the in the sink
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6101950432112578
# put a clean rag in a drawer .
# - Decoding by Sampling:
# BLEU score: 0.42846977766678973
# put a clean rag in a drawer . a sink .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5313746898412453
# put a cloth in a drawer .
# - Decoding by Sampling:
# BLEU score: 0.5313746898412453
# put a cloth in a drawer .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 6.5806869883189804e-155
# put a dirty rag from the drawer cabinet the the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 6.2890526274212064e-155
# put up dirty from counter , wash cloth put in drawer
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 0.4412484512922977
# put a clean towel in a drawer .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 6.227170448085464e-155
# put a dirty from and the drawer
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 8.190757052088229e-155
# put up dirty cloth from , wash cloth and put in drawer
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 5.0877407661795914e-155
# put the dirty dirty a drawer
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.791005615992361e-78
# put a clean rag in the drawer .
# - Decoding by Sampling:
# BLEU score: 0.3646285861936467
# put a clean cloth in the drawer . the sink . .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_055649_717880_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-SoapBar-None-GarbageCan-418/trial_T20190909_055649_717880
# Number of subgoals : 9
# https://youtu.be/C9gkb77sF14
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two bars of soap into the trash can.
# ['Make a left to reach the sink.', 'Pick up the pink soap next to the sink on the left.', 'Turn around and walk to the trash can next to the toilet.', 'Put the pink soap in the trash can.', 'Turn around to walk to the sink.', 'Pick up the bar of pink soap in the sink basin.', 'Turn around the walk to the trash can.', 'Put the other bar of pink soap in the trash can.']
#
# Annotation 1
# Put two soap in the trash bin
# ['Turn right then face the sink  counter on your left', 'Pick up the soap on the counter', 'Turn left then head to the trash bin ', 'Put the soap in the trash bin', 'Turn left then head to the sink ', 'Pick up the soap in the sink', 'Turn around then head to the trash bin ', 'Put the soap in the trash bin']
#
# Annotation 2
# Putting two bars of soap in the trash can
# ['Turn around and go to the left of the sink', 'Grab the bar of soap off of the counter', 'Turn around and go to the trash can', 'Put the soap in the trash can', 'Turn around and go to the sink', 'Grab the bar of soap out of the sink', 'Turn around and go to the trash can', 'Put the soap in the trash can']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash bin
# - Decoding by Sampling:
# BLEU score: 1.0
# put two bars of soap in the trash
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.20149416157064579
# put to two soap pink place out in soap sponges in the trash can bin .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 6.458654791343583e-155
# put away bars bars the trash
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.7825422900366437
# put away bars of soap into the trash can .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 5.094696780347207e-155
# throw away two soap bars
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 0.5706745777055999
# throw two soap in the trash can . the . .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.5
# place two bars of in the trash can
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 0.32466791547509893
# throw two bars in in bin in the trash can
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.21972813874997157
# place move two bars in and the shelf and and the trash can .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 8.909555824566607e-155
# throw away two bars in into the small black bin .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.6989307622784944
# place two bars of soap in the trash bin bin .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_151802_277016_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-AppleSliced-None-DiningTable-27/trial_T20190907_151802_277016
# Number of subgoals : 13
# https://youtu.be/P9wm8lJwxT4
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Slice an apple or vegetable followed by rinsing it
# ['Turn to the right and walk to the white kitchen table on your left', 'Pick up the yellow handled knife on the table', 'Walk to the right end of the kitchen table and face it', 'Slice a apple on the table', 'Walk back to the left side of the kitchen table', 'Place the knife on top of the green lettuce head', 'Walk to the right end of the kitchen table and face it', 'Pick up the slice of apple on the table', 'Turn around and walk to the left and face the kitchen sink', 'Place the slice of apple in the sink and rinse it, then remove it', 'Turn around and walk to the end of the kitchen and face the table on the right', 'Place the apple slice back on the table']
#
# Annotation 1
# Put a washed slice of apple on the table.
# ['Move to the right and go to the table.', 'Pick up the knife with the yellow handle.', 'Move right to the other end of the table.', 'Slice the apple on the table.', 'Move back to the left side of the table.', 'Put the knife down on the table.', 'Move back to the left side of the table.', 'Pick up a slice of apple.', 'Turn right and go to the sink.', 'Rinse the apple slice in the sink.', 'Turn around and go back to the table.', 'Put the apple slice on the table.']
#
# Annotation 2
# Cut an apple with a knife, wash the apple slice, place the apple slice on the table
# ['Walk towards the direction of the sink, hang a left at the end of the table with a knife with a yellow handle on it.', 'Pick up the knife with the yellow handle.', 'Turn to your right and walk to the other end of the table where there is a yellow apple.', 'Slice the apple with the knife.', 'Turn to your left and walk to the other end of the table.', 'Place the knife against the head of lettuce, blade end down.', 'Turn to your right to the other end of the table.', 'Pick up the section of cut apple closest to you.', 'Turn around and walk to the sink.', 'Place the section of apple in the front left side of the sink, turn on the faucet, partially fill the sink with water to wash the apple; turn off the faucet, empty the sink, pick up the apple.', 'Turn to your left and walk to stand in front of the middle of the table.', 'Put the apple slice to the right of the gray glass and directly in front of the wide end of the spatula.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5814307369682193
# put a clean piece of apple on the table .
# - Decoding by Sampling:
# BLEU score: 0.5911602603314157
# put a clean of apple on the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 4.513300825451574e-78
# put a clean apple of apple on on on the of the white
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a washed slice of apple on the table .
# - Decoding by Sampling:
# BLEU score: 0.45511450645045187
# put a washed slice of apple on the table table . with the left of the fridge .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 0.1659267281059304
# put put a rinsed and rinsed a piece slice on place it on the table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 0.7071067811865475
# put a clean slice of apple on the table .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 1.0213377082240812e-154
# put put a piece of apple and place it on the white table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 8.38826642100846e-155
# put put a rinsed of apple in the top room table from the table to
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 4.627283175378585e-78
# put a clean apple of apple on a fork on the white table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 6.511781295909997e-78
# put a washed apple slice to the table . a glass
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5911602603314157
# put a clean apple slice on the table .
# - Decoding by Sampling:
# BLEU score: 0.5558391766749284
# put a clean slice of apple on the table table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_032318_169393_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-SideTable-329/trial_T20190909_032318_169393
# Number of subgoals : 5
# https://youtu.be/R8fs1wdTMqI
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a mug to a nightstand.
# ['Turn to the left and walk around the bed. Turn to the right and walk to the desk,', 'Pick up the mug from the desk. ', 'Turn to the left then turn right  to head to the night stand.', 'Place the mug on the night stand. ']
#
# Annotation 1
# Move a coffee mug to a nightstand.
# ['Turn left and walk towards the wall, then hang a right and walk forward, turn left and walk up to the table.', 'Pick up the black mug off of the table.', 'Turn left and walk over to the window, then turn left again and walk up to the nightstand next to the bed.', 'Put the coffee mug on the nightstand to the left of the clock.']
#
# Annotation 2
# to pick up a coffee mug and put it on the night stand
# ['look down at the bed then turn left  walk forward to the edge of the bed and turn right then turn left towards the desk ', 'pick up the coffee mug from the desk ', 'turn left and walk towards the window  then turn left and walk towards the night stand ', 'place the coffee mug on the night stand ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.0053498901414167e-78
# put a mug with a pencil in it on the coffee table .
# - Decoding by Sampling:
# BLEU score: 0.36889397323344053
# put a mug with put it on the stand
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0873582350992668e-154
# put a mug on the nightstand .
# - Decoding by Sampling:
# BLEU score: 1.0547686614863434e-154
# put a mug mug on the nightstand stand
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6147881529512643
# move a mug to a night stand .
# - Decoding by Sampling:
# BLEU score: 0.30181358455294277
# move a mug to a night end of table the bed .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 5.95379722075358e-78
# put a mug to the nightstand .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 8.38826642100846e-155
# put up a mug from the desk to the end , end of the nightstand .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 9.032704947274394e-155
# put a mug on the bedside table
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 0.392814650900513
# put a mug to the desk to a nightstand .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 5.95379722075358e-78
# put a mug on a nightstand .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0905741632475476e-154
# put a mug on a night stand .
# - Decoding by Sampling:
# BLEU score: 3.7963218261733912e-78
# put move a mug cup to the desk to the nightstand .
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
chosen_valid_unseen_samp_res = examine_sampled_tasks(sampled_task_ids = chosen_valid_unseen_task_ids, epoch_list = valid_unseen_epoch_list, split = 'valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190909_123918_983775_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123918_983775
# Number of subgoals : 13
# https://youtu.be/1Ha8RLnfsBg
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'SliceObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a cooked potato slice in the fridge
# ['move around to the table', 'pick up a knife from the table', 'move forward to the fridge', 'slice the potato in the fridge', 'turn around to the shelf ', 'place the knife on the shelf', 'turn right to the fridge', 'pick up a slice of the potato', 'move right to the oven', ' cook the potato in the oven and take it out', 'move left to the fridge', 'place the cooked slice in the fridge']
#
# Annotation 1
# To heat a potato slice and place it in the fridge.
# ['Turn around and cross the room and turn around to face the end of the center table.', 'Pick up the knife on the counter.', 'Walk to the right past the center table and turn right to face the fridge.', 'Cut the potato on the bottom in the fridge into slices.', 'Turn left and step forward to face the shelves.', 'Place the knife on the shelf.', 'Turn right to face the fridge.', 'Pick up a slice of potato in the fridge.', 'Turn right and step forward and turn left to face the microwave.', 'Heat the potato slice in the microwave and remove it.', 'Turn left and walk forward and turn right to face the fridge.', 'Place the potato slice in the fridge.']
#
# Annotation 2
# Put a cooked slice of potato in the fridge.
# ['Turn around, go across the room and turn right to face the end of the counter.', 'Pick up the knife on the counter by the statue.', 'Go back across the room to the fridge.', 'Cut the potato on the second shelf in the fridge.', 'Turn around and go to the brown shelf on the left.', 'Put the knife on the top shelf.', 'Go back to the fridge.', 'Pick up a slice of potato in the fridge.', 'Turn right and go to the microwave.', 'Cook the slice of potato in the microwave and pick it back up.', 'Turn left and go back to the fridge.', 'Put the cooked slice of potato in the fridge between the mug and the potato.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6580370064762462
# put a cooked slice of tomato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6101950432112578
# put a cooked slice of the fridge .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6360188027707555
# put heat a slice of potato and place it in the fridge .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.7083397532288122
# place a cooked slice of potato in the fridge . a can .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5623413251903491
# place a cooked of cooked potato in the fridge .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 5.471968861960635e-78
# place a chill and a slice of potato . heat it slice in the microwave
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6511928252400603
# place a cooked slice of potato in the fridge . a the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_123732_489327_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123732_489327
# Number of subgoals : 11
# https://youtu.be/4V2hh2cw4No
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'SliceObject', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To heat a potato slice and place it in the fridge.
# ['Walk around the center table to the left and turn right to face the knife on the table.', 'Pick up the knife on the table.', 'Turn left and walk forward and turn around to the right to face the trash can.', 'Cut the potato in the trash can into slices.', 'Place the knife in the trash can.', 'Pick up a slice of potato in the trash can.', 'Turn left and walk to the right around the table and turn left to face the microwave.', 'Heat the potato slice in the microwave and remove it.', 'Turn left and step forward and turn right to face the fridge.', 'Place the potato slice in the fridge.']
#
# Annotation 1
# Put a cooked slice of potato in the fridge.
# ['Go left and around the counter to the back of the sink.', 'Pick up the knife on the counter.', 'Go to the end of the counter and face the trash can.', 'Cut the potato in the trash can.', 'Put the knife in the trash can.', 'Pick up a slice of potato from the trash can.', 'Turn left and go to the stove.', 'Cook the slice of potato in the microwave above the stove and pick it back up.', 'Turn left and go to the fridge.', 'Put the slice of potato to the left of the potato on the shelf in the fridge.']
#
# Annotation 2
# Put a slice of heated potato in the fridge.
# ['Turn left and go to the side of the island without the sink.', 'Pick up the gray knife from the table. ', 'Turn left and go to the black trash can on the floor at the end of the island.', 'Slice the potato on the right in the trash can. ', 'Place the knife in the trash can. ', 'Take out one slice of potato from the trash can. ', 'Turn left and go around the island to the microwave above the stove. ', 'Heat the potato slice in the microwave and take it out. ', 'Turn left and go to the refrigerator on the right. ', 'Place the potato slice in the refrigerator. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5954165059120786
# put a cooked slice of tomato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5773502691896257
# put heat a slice of potato and place it in the fridge . the the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.335783404331301
# put a cooked slice the fridge .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.335783404331301
# put a cooked slice in the fridge
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 3.917372151449784e-155
# put a microwaved slice slice fridge
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.7941386679207173
# put a cooked slice of potato potato in the fridge .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 3.573006738452943e-155
# put a cut of potato
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6113082296626929
# put a cooked slice of potato to the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_191445_723170_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SaltShaker-None-Cabinet-10/trial_T20190906_191445_723170
# Number of subgoals : 5
# https://youtu.be/oZ2goybT4pA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To acquire an odd item as place it where it is not useful.
# ['Turn to the left and make an semi circle as to reach the wooden table. ', 'Take only the salt container from the table.', 'turn left and to your right with the salt container.', 'Place the container under the cabin drawer under in the drawer on the left.']
#
# Annotation 1
# Place the salt shaker from the wooden shelf into the cabinet.
# ['Turn around and head towards the wooden shelves.', 'Pick up the salt shaker on the top shelf.', 'Turn around and head towards the fridge to your left.', 'Open the lower cabinet to the left of the fridge, place the shaker in it, and close the door.']
#
# Annotation 2
# Put the salt in the bottom cabinet next to the fridge.
# ['Move to the wooden shelf. ', 'Pick up the salt from the shelf. ', 'Bring the salt to the counter right of the fridge. ', 'Place the salt in the cabinet under the counter. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.255495473556936e-232
# place a candles in a drawer .
# - Decoding by Sampling:
# BLEU score: 4.181960984818763e-155
# place a candles in in the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.5837621674212146e-78
# put the salt shaker in the drawer
# - Decoding by Sampling:
# BLEU score: 2.567968747812476e-78
# put the salt away of of the kitchen
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# place a salt shaker inside of the kitchen cabinet
# - Decoding by Sampling:
# BLEU score: 3.272561325903966e-155
# place a salt shaker inside of drawer
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# place a salt shaker inside of the kitchen cabinet
# - Decoding by Sampling:
# BLEU score: 4.127681278534973e-155
# place a salt shaker inside of the kitchen
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 1.0733342226651737e-231
# pick a salt of the inside of the kitchen cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 7.806161490833773e-155
# pick up the salt from of the dresser dresser and put it in the drawer .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 4.643380996943939e-155
# pick a salt shaker inside of the kitchen cabinet
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 7.535860277359515e-155
# pick up the salt and place it inside the the black side
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 0.33644253392320406
# pick the salt shaker from the bed to the drawer table
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 4.2883569351812218e-78
# pick up the salt shaker and place it inside in the drawer
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.17593936422147e-78
# pick up the salt shaker and place it in the drawer
# - Decoding by Sampling:
# BLEU score: 1.9325751796698558e-78
# pick the salt shaker inside cabinet
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_020329_050110_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Apple-None-SinkBasin-10/trial_T20190907_020329_050110
# Number of subgoals : 7
# https://youtu.be/H-GQkQllSuA
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a cooked apple into the sink.
# ['Turn around to face the room and go left past the refrigerator, then turn to face the sink on the right.', 'Pick up the green apple from the left side of the sink.', 'Turn around and take the apple to the microwave behind you.', 'Put the apple in the microwave, cook it, and remove it.', 'Turn around to your left and go back to the sink.', 'Put the apple back in the sink.']
#
# Annotation 1
# Put a cooked apple in the sink.
# ['Turn around, turn to the left, and go to the sink to your right.', 'Pick up the apple that is to the right of the fork.', 'Turn around to the microwave above the stove.', 'Cook the apple in the microwave.', 'Turn around to the sink behind you.', 'Place the apple in the sink, to the right of the fork.']
#
# Annotation 2
# Heat the left apple in the microwave.
# ['Move to the sink. ', 'Pick up the apple in the sink on the left. ', 'Bring the apple to the microwave. ', 'Heat the apple in the microwave. ', 'Bring the apple to the sink. ', 'Put the apple in the sink, to the left of the other apple. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a warm apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a warm apple in the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a microwaved apple in the sink .
# - Decoding by Sampling:
# BLEU score: 4.482229907656296e-155
# put a apple inside sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a microwaved apple in the sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.36741454942156665
# put a apple in the sink apple
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 9.911891170885795e-155
# put a microwaved apple in a sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.4518010018049224
# put a heated apple in the sink . . .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 9.911891170885795e-155
# put a heated apple in a sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a heated apple in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_170955_824797_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Newspaper-None-FloorLamp-219/trial_T20190907_170955_824797
# Number of subgoals : 5
# https://youtu.be/8zfLGiywP1A
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a newspaper by the light of a floor lamp.
# ['Turn to the left and walk to the sofa.', 'Pick up the newspaper from the sofa.', 'Walk to the floor lamp that is to the left of the sofa.', 'Turn on the lamp.']
#
# Annotation 1
# Turn on a lamp while carrying a newspaper
# ['Move to the right side of the large tan sofa', 'Pick up the newspaper on top of the sofa', 'Carry the newspaper to the left side of the sofa where the lamp is', 'Turn on the lamp']
#
# Annotation 2
# Examine a newspaper by the light of a floor lamp
# ['turn to the left twice and take a few steps forward and turn to the right and go to the sofa', 'pick up the newspaper from the sofa', 'turn to the right and go to the blue chair and turn to the right', 'turn on the floor lamp']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# place a newspaper on the newspaper .
# - Decoding by Sampling:
# BLEU score: 7.741858597040875e-232
# place a on the newspaper
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.013778876140909e-155
# pick up the newspaper and turn on the lamp .
# - Decoding by Sampling:
# BLEU score: 6.5806869883189804e-155
# pick the newspaper from the couch and the turn on the lamp
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.367929145127228e-155
# pick up a newspaper and turn a lamp on .
# - Decoding by Sampling:
# BLEU score: 0.3872015705071016
# pick a newspaper by the light of the lamp on the black . .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.855526185871245
# examine a newspaper by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 9.367929145127228e-155
# examine up a newspaper and turn on lamp on .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 7.208781414766327e-155
# examine the newspaper from the sofa , turn on the lamp
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 7.208781414766327e-155
# examine the newspaper from the sofa , turn on the lamp
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.855526185871245
# examine a newspaper by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.7420884818558928
# examine a newspaper by the light of the
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 0.7825422900366437
# examine a newspaper by the light of a small .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7419446627365011
# examine a newspaper by the light of a small lamp .
# - Decoding by Sampling:
# BLEU score: 5.974540365813254e-155
# examine the newspaper from the sofa and turn on the lamp on the black stand table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_210238_431966_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-Desk-308/trial_T20190909_210238_431966
# Number of subgoals : 5
# https://youtu.be/Ti1faQUCSnc
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# take a coffee mug from a book shelf and place it on a desk
# ['go to the desk that is in front of a book shelf with a computer on it', 'pick up the white coffee mug from the book shelf', 'go to the left end of the desk', 'place the mug on the left end of the desk']
#
# Annotation 1
# Move a cup from the shelf to the desk.
# ['Turn to the right and then the left to the other side of the room, and face the desk on the left side. Look up to the books on the shelf.', 'Pick up the cup from the shelf.', 'Carry the cup and turn to the left and then face the desk on the right side. ', 'Place the cup on the short side of the desk, close to you.']
#
# Annotation 2
# Pick up a coffee mug from the desk and put it down on the desk.
# ['Turn right at the brown desk and walk between the bed and the desk. Turn left at the orange cylinder on the right of the bed on the floor. Walk to the desk on your left with a laptop on it.', "Pick up the white coffee mug that's on the desk.", 'Turn around and walk to the bed. Turn right at the bed.', 'Put the coffee mug back down on the left side of the desk to the right of the bed.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.16437745974496e-155
# examine a mug with a pencil in it on the end table .
# - Decoding by Sampling:
# BLEU score: 8.468803013029909e-155
# examine a cup and a mug cup and the desk to the coffee table . with the white . a coffee .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.80154124704578e-155
# put a mug with a pencil in it on the counter .
# - Decoding by Sampling:
# BLEU score: 7.15819034963064e-155
# put a white in the cup , turn on the lamp .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5773502691896258
# pick up a mug and place it on the desk .
# - Decoding by Sampling:
# BLEU score: 8.372804113024658e-155
# pick the cup in the cup , the coffee mug , put it to the counter table
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.657922819542466e-232
# examine a mug with a lamp
# - Decoding by Sampling:
# BLEU score: 3.7604422602850247e-78
# examine put a pencil with a cup and move the cup to the left of the desk .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on the desk .
# - Decoding by Sampling:
# BLEU score: 7.154403670282264e-232
# pick a mug with a lamp
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on the desk .
# - Decoding by Sampling:
# BLEU score: 7.788457610711883e-155
# pick the mug and a mug and move it on on the kitchen counter
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.206470625226315e-78
# pick up a mug and put it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on a desk .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on the desk .
# - Decoding by Sampling:
# BLEU score: 0.43361890903486755
# pick up a mug and put it on a desk table
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.206470625226315e-78
# pick up a mug and put it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.2545093860020286
# pick put a pencil with a pen in it on the desk .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on the desk .
# - Decoding by Sampling:
# BLEU score: 6.975255010667348e-155
# pick on the lamp . to the left
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on the desk .
# - Decoding by Sampling:
# BLEU score: 0.4591497693322866
# pick up a mug and put it on a desk .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_224843_443882_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-BreadSliced-None-Microwave-10/trial_T20190906_224843_443882
# Number of subgoals : 13
# https://youtu.be/z261C5NcQbU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'SliceObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# placed a cooled slice of bread that you cut inside of the microwave
# ['move forwards to the end of the room, then turn left and walk until your reach the left side of the stove on your right', 'pick up the butter knife behind the green cup on the counter to the left of the stove', 'turn right and and walk to the end of the room, then turn right again until you reach the right side of the end o the kitchen island, turn to face the kitchen island', 'cut up the bread on the kitchen island into slices', 'turn right and walk until you reach the end of the room, then turn left and walk to the other end of the room, turn right to face the fridge', 'place the knife inside of the fridge', 'turn right and and walk to the end of the room, then turn right again until you reach the right side of the end o the kitchen island, turn to face the kitchen island', 'grab a slice of bread off of the kitchen island countertop', 'turn right and walk to the end of the room, then turn left and walk to the other end of the room until you reach the fridge on your right, turn to face the fridge', 'place the slice of bread in the fridge to cool, then take it out once it has cooled and close the fridge', 'turn right and walk forwards until your reach the stove on the left side, turn to face the stove and look up towards the microwave above', 'place the cooled slice of bread inside of the microwave']
#
# Annotation 1
# Place a piece of sliced bread in the microwave.
# ['Move to stand at the counter between the stove and dishwasher.', 'Pick up the butter knife by the green container. ', 'Carry the knife to stand at the edge of the counter beyond the kitchen sink. ', "Slice the loaf of bread that's on the counter. ", 'Carry the knife to the fridge. ', 'Place the knife on the top shelf of the fridge.', 'Move back to the edge of the counter past the sink where the loaf of bread is. ', 'Pick up a slice of bread from the counter. ', 'Carry the slice of bread to the fridge.', 'Open the fridge and place the slice of bread on the top shelf to the right of the apple, close the door, pause, and then open the door and remove the bread. ', 'Move to stand in front of the stove.', 'Open the microwave above the stove and place the slice of bread inside.']
#
# Annotation 2
# Slice a loaf of bread, put the knife and bread in the refrigerator, take the bread to the microwave.
# ['Go straight, take a left at the counter', 'Turn right and face the statue on the counter.', 'Pick up the knife, go right, take a right at the wall.', 'Turn right towards the counter and slice the bread.', 'Take a right, take a left at the counter, turn to face the refrigerator.', 'Open the refrigerator and set the knife on the shelf to the left of the apple and shut the door.', 'Go right, take another right at the wall, turn left to face the bread on the counter.', 'Grab a slice of bread.', 'Go right, take a left at the counter, turn right to face the refrigerator', 'Open the refrigerator door, set the bread to the right of the apple, shut the door, open the door, and grab the bread.', 'Go right and turn to face the stove.', 'Open the microwave, put the bread in the microwave, and shut the door.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
# - Decoding by Sampling:
# BLEU score: 3.2683416997819595e-78
# put a bread in the cabinet . . a water the . . room .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a chilled slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.30374414220764573
# put a chilled slice of potato in the microwave .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.12659548344706545
# put a potato , put it of of bread , put bowl fridge , put bread , and put into cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 7.291706957915611e-155
# put a potato , put it in the fridge
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4895914832758051
# put a chilled slice of bread in the microwave .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4895914832758051
# put a cold slice of bread in the microwave .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.30374414220764573
# put a cold slice of potato in the microwave .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_214631_761426_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-BaseballBat-None-DeskLamp-308/trial_T20190906_214631_761426
# Number of subgoals : 5
# https://youtu.be/6dSWDozBRLU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# turn on a lamp while holding a baseball bat
# ['walk forwards a bit towards the baseball bat', 'grab the baseball bat leading against the wall', 'turn and walk over to the right side of the computer desk', 'turn on the lamp on the computer desk']
#
# Annotation 1
# Examine a bat by the light of a lamp.
# ['Head towards the bat on the floor in front of you.', 'Pick up the bat from the floor.', 'Turn around, head towards the bed, turn left towards the wall, and then turn left to face the lamp on the desk.', 'Turn on the lamp.']
#
# Annotation 2
# Examine the bad under the light on the desk.
# ['Move to the corner near the door. ', 'Pick up the bat from the floor. ', 'Bring the bat to the desk', 'Turn on the lamp on the desk. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7071067811865475
# examine a pencil by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 8.57273414893938e-155
# examine a pencil with a lamp in the table , turn
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# turn on a lamp while holding a baseball bat
# - Decoding by Sampling:
# BLEU score: 4.6278283821851e-155
# turn on lamp on with while
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 8.275646700927604e-155
# examine up a bat bat and the corner and turn on the lamp . bin turn it bat bat .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# examine a bat by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.49616830003403634
# examine a bat bat by the light of the lamp on
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 6.646444782720929e-155
# examine on the lamp on the night .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 7.171697481695543e-155
# examine on the lamp on the night stand .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 0.7506238537503395
# examine a baseball by the light of a lamp .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 7.453472598117588e-155
# examine on the lamp on the bat . .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 6.646444782720929e-155
# examine at the bat in the light .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 7.10442605073702e-155
# examine the bat in the light .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6076795808137692
# examine a baseball bat by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 5.785902629078803e-78
# examine a bat in the light of the lamp on the table stand .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074524_006355_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Watch-None-Safe-219/trial_T20190907_074524_006355
# Number of subgoals : 5
# https://youtu.be/_TobcwcYR9Q
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a watch to the inside of a small safe.
# ['Turn right and take a step forward, then turn left and walk up to the large wooden dresser.', 'Pick up the watch that is on top of the large wooden dresser.', 'Turn right and begin walking across the room, then hang a right and walk up to the small white safe on the ground.', 'Open the small white safe, place the watch inside, then close the safe door.']
#
# Annotation 1
# Take the watch on top of the chest of drawers  put it inside the safe and lock it up.
# ['Go to the chest of drawers ahead of you.', 'Pick up the brown banded watch.', 'Take the watch across the room toward the safe.', 'Open the safe, set the watch inside the safe, close the safe.']
#
# Annotation 2
# place a watch in a safe box
# ['turn right then turn left towards the  dresser', 'pick up the watch from the dresser', 'turn right and walk towards the sofa then turn right again towards the  safe box', 'place the watch in the safe box']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.014508691042773e-155
# put a slice of potato in a drawer .
# - Decoding by Sampling:
# BLEU score: 6.237049021538533e-232
# put a slice of
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.53091075863908e-155
# place a slice of potato in a cabinet .
# - Decoding by Sampling:
# BLEU score: 6.9457064195067245e-155
# place a slice of potato in the cabinet of the sink . bin . window . put it in the cabinet table the . the left .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.619863157690489e-231
# put a potato slice in the sink to
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.5319719891192393e-231
# put a bench potato in the cabinet tub
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.241926111174567e-155
# place a potato slice in the cabinet by the sink
# - Decoding by Sampling:
# BLEU score: 7.183445846156676e-155
# place a potato in the cabinet cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.451891777777915e-231
# put a potato in the cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 6.164444051541174e-155
# put a potato slice in the microwave sink , put it potato in the cabinet of
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 3.795218485083911e-78
# put a potato slice the cabinet from the top of the sink to
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 6.538304094864068e-155
# put take the potato out of the red , place it in the cabinet to well sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.451891777777915e-231
# put a potato in the cabinet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 7.065448889524842e-155
# put a bench potato of the top of of the cabinet in the cabinet to the right of
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_114656_768805_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-CounterTop-10/trial_T20190908_114656_768805
# Number of subgoals : 7
# https://youtu.be/AOYa3y_0uCU
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold pan on the counter top on top of the dishwasher.
# ['Turn around, walk forward, turn right near the fridge, walk straight and turn left to face the stove. ', 'Pick up the pan from on top of the stove. ', 'Turn around, walk to the right to go back to the fridge. ', 'Open the fridge, put the pan in it, close the fridge, let it cool for a while, open the fridge, pick it up again and close the fridge. ', 'Go to the right and turn left to face the dishwasher. ', 'Put the pan on the counter top. ']
#
# Annotation 1
# Chill a pan and put it on a counter.
# ['Walk around the kitchen counter to the stove on your left.', 'Grab a pan from the stove.', 'Walk to the front of the fridge on your left.', 'Place the pan in the fridge, then grab it.', 'Walk to the kitchen counter between the fridge and stove.', 'Place the pan on the counter.']
#
# Annotation 2
# Put the chilled pan on the counter
# ['Turn around to your left walk straight then turn right head to the  stove on your left', 'Pick up the pan on the  stove', 'Turn left then walk straight head to the fridge', 'Open the fridge put in the pan then take it out and close the fridge', 'Turn right walk straight face the counter beside the toaster', 'Put the pan on the counter beside the toaster']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.562069055463047e-78
# put a chilled bowl on the counter .
# - Decoding by Sampling:
# BLEU score: 9.032704947274394e-155
# put a chilled bowl put a pan
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42728700639623407
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 1.133422688662942e-154
# put a chilled pan of on the stove .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42728700639623407
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.42383656282787796
# put a chilled pan on the stove
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 1.254338396921439e-154
# put a chilled pan to the counter .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.5193071778680676
# put a pan and put it back on the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.5193071778680676
# put a pan and put it back on the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 9.696727898117387e-155
# put a pan pan to the fridge .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.42383656282787796
# put a chilled pan on the stove
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6434588841607617
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4063798282013443
# put a chilled pan on the counter . the the stove .
# ---------------------------
# --------------------------------------------------------------------------------------

# %% [markdown]
# ### SECTION 2: Look at overall best and worst tasks for one epoch

# %%
# compute bleu score for every task
# compute CE for every task

def rank_tasks(epoch, split, k=10, best=True, task_ids=None):
    
    path = os.path.join(args.dout, '{}_argmax.debug_epoch_{}.preds.json'.format(split, epoch))
    with open(path, 'r') as f:
        debug_dat = json.load(f)
        
    scores = {}
        
    for task_id in debug_dat:
        root = get_root_location(debug_dat[task_id]['root'])

        # get referece lang for bleu score
        ref_instrs = get_ref_instrs(root)
        bleu_score = sentence_bleu(ref_instrs, debug_dat[task_id]['p_lang_instr'].split(' '))
        
        scores[task_id] = bleu_score
        
    top_k_task_ids = sorted(scores.items(), key=lambda x: x[1], reverse=best)[:k]
    pprint.pprint(top_k_task_ids)
    
    return [x[0] for x in top_k_task_ids], list(scores.values())

# %%
train_sanity_best_epoch = 49
print ("BEST train_sanity")
ranked_train_sanity_ids_best_10, all_train_sanity_bleu_scores = rank_tasks(epoch=train_sanity_best_epoch, split='train_sanity', k=10, best=True)
print ("WORST train_sanity")
ranked_train_sanity_ids_worst_10, _ = rank_tasks(epoch=train_sanity_best_epoch, split='train_sanity', k=10, best=False)

valid_seen_best_epoch = 49
print ("BEST valid_seen")
ranked_valid_seen_ids_best_10, all_valid_seen_bleu_scores = rank_tasks(epoch=valid_seen_best_epoch, split='valid_seen', k=10, best=True)
print ("WORST valid_seen")
ranked_valid_seen_ids_worst_10, _ = rank_tasks(epoch=valid_seen_best_epoch, split='valid_seen', k=10, best=False)

valid_unseen_best_epoch = 49
print ("BEST valid_unseen")
ranked_valid_unseen_ids_best_10, all_valid_unseen_bleu_scores = rank_tasks(epoch=valid_unseen_best_epoch, split='valid_unseen', k=10, best=True)
print ("WORST valid_unseen")
ranked_valid_unseen_ids_worst_10, _ = rank_tasks(epoch=valid_unseen_best_epoch, split='valid_unseen', k=10, best=False)
# Out:
# BEST train_sanity
# [('trial_T20190908_154238_160623_0', 1.0),
#  ('trial_T20190908_155247_137362_0', 1.0),
#  ('trial_T20190908_174001_568929_0', 1.0),
#  ('trial_T20190908_102743_595985_0', 1.0),
#  ('trial_T20190910_152759_264561_0', 1.0),
#  ('trial_T20190908_221042_476220_0', 1.0),
#  ('trial_T20190909_144907_367045_0', 1.0),
#  ('trial_T20190907_002819_330666_0', 1.0),
#  ('trial_T20190907_031131_996875_0', 1.0),
#  ('trial_T20190909_091158_217271_0', 1.0)]
# WORST train_sanity
# [('trial_T20190908_042518_905827_0', 8.863722645159635e-155),
#  ('trial_T20190908_185723_946017_0', 9.975386110402101e-155),
#  ('trial_T20190906_224412_871995_0', 1.133422688662942e-154),
#  ('trial_T20190909_011730_702236_0', 1.3478743256634661e-154),
#  ('trial_T20190907_202335_083129_0', 3.693972364924616e-78),
#  ('trial_T20190911_191424_759852_0', 3.980096073289859e-78),
#  ('trial_T20190908_062121_532423_0', 4.618846890203085e-78),
#  ('trial_T20190908_143948_082471_0', 5.17862905677001e-78),
#  ('trial_T20190918_152439_600414_0', 5.225756395596991e-78),
#  ('trial_T20190907_123042_656948_0', 5.85232962827326e-78)]
# BEST valid_seen
# [('trial_T20190908_165525_911839_0', 1.0),
#  ('trial_T20190909_001852_804129_0', 1.0),
#  ('trial_T20190909_120047_968274_0', 1.0),
#  ('trial_T20190909_012524_159092_0', 1.0),
#  ('trial_T20190908_234112_645480_0', 1.0),
#  ('trial_T20190908_212725_836398_0', 1.0),
#  ('trial_T20190909_062333_424779_0', 1.0),
#  ('trial_T20190906_215856_374127_0', 1.0),
#  ('trial_T20190909_002804_564168_0', 0.9457416090031758),
#  ('trial_T20190908_083541_210340_0', 0.9200444146293233)]
# WORST valid_seen
# [('trial_T20190908_001247_096796_0', 5.189523011169849e-232),
#  ('trial_T20190909_005709_232606_0', 8.324264127738903e-232),
#  ('trial_T20190906_181531_703961_0', 8.676910262183261e-232),
#  ('trial_T20190908_122858_883968_0', 9.537683887743056e-232),
#  ('trial_T20190909_055649_717880_0', 1.2778269941762074e-231),
#  ('trial_T20190907_034437_413802_0', 1.4147351699132998e-231),
#  ('trial_T20190907_154618_526741_0', 1.4256605770826504e-231),
#  ('trial_T20190908_055221_984342_0', 4.142116741145382e-155),
#  ('trial_T20190909_023218_500741_0', 4.909777631374571e-155),
#  ('trial_T20190908_201550_622420_0', 5.5034464391059774e-155)]
# BEST valid_unseen
# [('trial_T20190907_033157_424297_0', 1.0),
#  ('trial_T20190909_124126_852630_0', 1.0),
#  ('trial_T20190908_225359_617900_0', 1.0),
#  ('trial_T20190909_123133_763972_0', 0.9621954581957615),
#  ('trial_T20190909_123918_983775_0', 0.9621954581957615),
#  ('trial_T20190907_155109_353266_0', 0.9200444146293233),
#  ('trial_T20190908_201444_037645_0', 0.9048374180359595),
#  ('trial_T20190909_123732_489327_0', 0.9048374180359595),
#  ('trial_T20190908_032434_013084_0', 0.9036020036098449),
#  ('trial_T20190907_173120_648218_0', 0.8824969025845955)]
# WORST valid_unseen
# [('trial_T20190909_021728_339782_0', 1.1008876702055895e-231),
#  ('trial_T20190909_103507_522012_0', 1.1077199809555581e-231),
#  ('trial_T20190908_073749_086690_0', 1.113314581389163e-231),
#  ('trial_T20190909_110445_675754_0', 1.1911125736103481e-231),
#  ('trial_T20190909_011850_153676_0', 1.1931009847695213e-231),
#  ('trial_T20190909_203041_433487_0', 1.3109733799909448e-231),
#  ('trial_T20190908_205246_776817_0', 1.3519605352440902e-231),
#  ('trial_T20190909_032721_511027_0', 1.5319719891192393e-231),
#  ('trial_T20190907_074045_109439_0', 1.5319719891192393e-231),
#  ('trial_T20190907_074524_006355_0', 1.6034157163765524e-231)]

# %%
plt.hist(all_train_sanity_bleu_scores, density=False, bins=50, alpha=0.5)
plt.hist(all_valid_seen_bleu_scores, density=False, bins=50, alpha=0.5)
plt.hist(all_valid_unseen_bleu_scores, density=False, bins=50, alpha=0.5)
plt.xlim(0.0, 1.0)
plt.title('(Blue, train_sanity epoch {})\n(Orange, valid_seen epoch {})\n (Green, valid_unseen epoch {})'.format(train_sanity_best_epoch, valid_seen_best_epoch, valid_unseen_best_epoch))
plt.ylabel('Count')
plt.xlabel('BLEU score');

# %%
# BEST train_sanity
best_train_sanity_res = examine_sampled_tasks(sampled_task_ids=ranked_train_sanity_ids_best_10, epoch_list=train_sanity_epoch_list, split='train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_154238_160623_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Book-None-Cabinet-310/trial_T20190908_154238_160623
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a book into a cabinet.
# ['Walk up to the bed.', 'Pick up the book off of the bed.', 'Turn left and walk towards the wall, then turn left, walk up to the wooden table and look up at the cabinets.', 'Open the leftmost cabinet door and put the book inside, then close the door.']
#
# Annotation 1
# To move a book from the bed to the cabinet.
# ['Walk to the bed in front of you. ', 'Pick up the book behind the cushion on the bed. ', 'turn around and walk to the desk, and look up at cabinets above the desk. ', 'Open the cabinet door on the left side, place the book inside of the cabinet, close the door. ']
#
# Annotation 2
# Put the book from the bed in the upper left cabinet over the desk.
# ['Walk forward and stand at the bed.', 'Pick up the book from the bed.', 'Turn around and go to the desk.', 'Put the book in the upper left cabinet over the desk.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.121328445417258e-155
# place a book in a cabinet
# - Decoding by Sampling:
# BLEU score: 0.39005788655345264
# place a book from the desk desk the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.397771473596286e-78
# put a book in the cabinet .
# - Decoding by Sampling:
# BLEU score: 5.728716644827669e-78
# put two book in the cabinet .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.608275356562258e-78
# move a book in a cabinet .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.7740443718000138
# move a book from the bed to the cabinet . left cabinet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.6850836912969523
# move move a book from the bed to the cabinet cabinet cabinet .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.608275356562258e-78
# move a book in a cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.608275356562258e-78
# move a book in a cabinet .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.608275356562258e-78
# move a book in a cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.608275356562258e-78
# move a book in a cabinet .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# move a book from the bed to the cabinet .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_155247_137362_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SprayBottle-None-Toilet-426/trial_T20190908_155247_137362
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a spray bottle on the back of the toilet.
# ['Turn around and go to the counter behind you. ', 'Pick up the yellow spray bottle closest to the green rag, on the counter. ', 'Turn around and go to the toilet. ', 'Place the yellow spray bottle on the back of the toilet, to the left of the candle. ']
#
# Annotation 1
# Put a spray bottle on the toilet.
# ['Turn around and walk to the white topped table.', "Pick up the yellow spray bottle that's in front of you.", 'Turn around and take a step to your left then walk to the toilet.', 'Put the spray bottle on the toilet tank.']
#
# Annotation 2
# Put a bottle on the back of the toilet.
# ['Turn around and face the white counter with the green drawers underneath.', 'Pink the spray bottle up from the white counter.', 'Turn around and face the toilet.', 'Put the bottle on the back of the toilet.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet
# - Decoding by Sampling:
# BLEU score: 0.6606328636027614
# put a spray bottle on the back . on .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6580370064762462
# put a spray bottle on top of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.393755531055134
# put a spray bottle on top of the toilet . top . top . the .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.785629301801026
# put a spray on the back of the toilet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 7.051402097550211e-78
# put a spray on the toilet tank . .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.767279645960659
# put a spray bottle on the toilet the
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.7506238537503395
# put a spray bottle on the back . .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 6.886705081558736e-78
# put a spray on the toilet tank .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.38163309113713373
# put a spray bottle on top toilet tank top top .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 0.785629301801026
# put a spray on the back of the toilet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a spray bottle on the back of the toilet .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_174001_568929_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Tomato-None-Microwave-5/trial_T20190908_174001_568929
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the tomato in the microwave
# ['Turn around and walk up to the sink', 'Pick up the tomato from the sink', 'Turn left and walk up to the microwave', 'Put the tomato in the microwave']
#
# Annotation 1
# Move a tomato from the sink to the microwave.
# ['Walk to the kitchen sink on your left.', 'Grab a tomato from the sink.', 'Walk to the microwave on your left.', 'Put the tomato in the microwave.']
#
# Annotation 2
# Put a tomato in the microwave.
# ['Face the sink to the left.', 'Pick the tomato up from the sink.', 'Go to the left and face the microwave.', 'Put the tomato in the microwave.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# put a tomato in the microwave
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.488923022434901
# put a tomato in a microwave .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.8706304540397798
# put a tomato from the sink to the microwave .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.488923022434901
# put a tomato in a microwave .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a tomato in the microwave .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# put a tomato in the microwave
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_102743_595985_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-KeyChain-None-Sofa-202/trial_T20190908_102743_595985
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# put two sets of keys on a sofa
# ['turn to face the coffee table', 'pick up the set of keys on the right on the top of the coffee table', 'walk to face the sofa', 'put the keys on the sofa to the left of the box', 'walk to face the coffee table', 'pick up the set of keys from the coffee table', 'walk to face the sofa', 'put the keys to the right of the box on the sofa']
#
# Annotation 1
# Move two sets of keys from the coffee table to the couch.
# ['Turn around and look down at the coffee table.', 'Pick up the rightmost set of keys off of the coffee table.', 'Turn left and walk towards the wall, then turn right and walk around the coffee table to the blue couch.', 'Put the set of keys on the middle of the front edge of the blue couch.', 'Walk back around to the far side of the coffee table.', 'Pick up the set of keys off of the coffee table.', 'Walk around the coffee table to the blue couch.', 'Put the set of keys on the front edge of the blue couch to the right of the cardboard box.']
#
# Annotation 2
# Put two sets of keys on a couch.
# ['Turn around to the table where the plant is. ', 'Pick up the rightmost set of keys from the table. ', 'Turn to the left, go forward, hang a right, go forward, hang a right, go forward, turn to the left where the cardboard box is on the couch.', 'Put the keys down on the couch in front of the left side of the cardboard box.', 'Turn to the left, go forward, turn to the left, go forward, hang a left and go to the table where the plant is. ', 'Pick up the set of keys that is on the table. ', 'Turn to the left, go forward, turn to the right, go forward, turn to the right, go forward turn to the left where the cardboard box is on the couch.', 'Put the keys down on the couch in front of the right side of the cardboard box.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7476743906106103
# put two sets of keys on the couch .
# - Decoding by Sampling:
# BLEU score: 0.3356891925037239
# put two keys to the couch . the couch .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7476743906106103
# move two sets of keys to the couch .
# - Decoding by Sampling:
# BLEU score: 0.7476743906106103
# move two sets of keys to the couch .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7476743906106103
# move two sets of keys to the couch .
# - Decoding by Sampling:
# BLEU score: 0.4333207865423752
# move two sets of keys on the couch . to a closed of it .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.7476743906106103
# put two sets of keys to the couch .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put two sets of keys on a couch
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put two sets of keys on a couch
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 1.0
# put two sets of keys on a couch .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.5773502691896257
# put two sets of keys from a coffee table to a sofa
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put two sets of keys on a sofa
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put two sets of keys on a sofa
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.8694417438899827
# put two sets of keys from the couch .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two sets of keys on a couch .
# - Decoding by Sampling:
# BLEU score: 0.8694417438899827
# put two sets of keys from the couch .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190910_152759_264561_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-25/trial_T20190910_152759_264561
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'SliceObject', 'CloseObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'OpenObject', 'PickupObject', 'CloseObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cooked slice of tomato in the trash can.
# ['Turn right and go to the dishwasher.', 'Pick up the knife to the left of the tomato.', 'Turn right and go to the fridge.', 'Cut the tomato on the second shelf of the fridge.', 'Move left and go to the fridge.', 'Put the knife on the second shelf of the fridge.', 'Move right and go to the fridge.', 'Pick up a slice of tomato in the fridge.', 'Turn left and go to the microwave.', 'Cook the slice of tomato in the microwave and pick it back up.', 'Turn around and go to the green trash can in the corner.', 'Put the slice of tomato in the trash can.']
#
# Annotation 1
# heat a chilled slice of tomato followed by putting it in the trash can
# ['turn to the right and move to the counter with the dishwasher below', 'pick up the sharp knife with the yellow handle', 'turn to the right and move to the fridge on the left, turn to face the fridge', 'open the door of the fridge, cut the tomato in the back right corner of the second shelf with the knife and close the door', 'stay in front of the refrigerator for a few seconds', 'open the door to the fridge again and put the knife on the second shelf and close the door', 'stay in front of the refrigerator for a few seconds', 'open the door and pick up one slice of the tomato that was sliced and close the door', 'move to the left of the fridge to face the microwave', 'open the microwave door, put the slice of tomato in to it, close the door, cook for 3 seconds, open the door, remove the tomato slice and close the door.', 'turn to the right, moving passed the fridge and at the wall turn right and move to the trash can ahead', 'put the slice of tomato in to the trash can']
#
# Annotation 2
# Cook a slice of tomato and put it in the bin
# ['Turn right, go to the counter', 'Pick up the knife from the counter', 'Turn right, go forward, turn left at the fridge', 'Slice the tomato in the fridge', 'Move a bit  to the left', 'Put the knife in the fridge', 'Move a bit to the right', 'Pick up a tomato slice from the fridge', 'Turn left, go forward, turn right at the microwave', 'Put the tomato slice in the microwave, start the microwave, wait, pick up the tomato slice from the microwave', 'Turn right, go forward, turn right, go to the bin', 'Put the tomato slice in the bin']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.773199749582945e-78
# put a cooked tomato slice in the trash bin .
# - Decoding by Sampling:
# BLEU score: 0.27447938256311044
# put a cooked tomato of tomato in the trash bin . the slice . in the trash bin .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4548244246960421
# put a cooked tomato slice in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.4412739850976206
# put a cooked of cooked in the trash can . the
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3013040489278569
# cook a tomato slice in the microwave , put the tomato in the trash can
# - Decoding by Sampling:
# BLEU score: 4.1152056401223838e-78
# cook a cooked tomato slice in the trash
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7611606003349892
# cook a slice of tomato and place it in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.6493358309501979
# cook a slice of tomato and place it in the trash .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 0.34823528327578535
# cook a a slice slice and place it in the trash can . from the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 0.4641208291870617
# cook a tomato in the trash can .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 5.133181122362587e-78
# cook a cooked tomato slice in the bin can .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 0.4604061366599648
# cook a cooked slice slice in the trash can .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 3.1652718119850744e-78
# cook a chilled with cut the tomato slice the microwave , put the one slice and throw the slice of tomato
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 3.5608750821685696e-78
# cook away a heated slice of tomato . a green can . . some
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# cook a slice of tomato and put it in the trash can
# - Decoding by Sampling:
# BLEU score: 1.2542725803459687e-231
# cook away a heated slice slice . the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_221042_476220_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SprayBottle-None-Cabinet-403/trial_T20190908_221042_476220
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a spray bottle away under the sink.
# ['Turn right to go to the shower, then head right again to stand in front of the two sinks.', 'Pick up the spray bottle from the counter between the two sinks.', 'Take a step back from the vanity while carrying the spray bottle so you have room to open a cupboard.', 'Open the second rightmost cupboard and place the spray bottle inside.']
#
# Annotation 1
# Move the spray bottle to the cabinet beneath the right sink.
# ['Turn right, walk to the wall, turn right, and walk to the counter.', 'Pick up the spray bottle between the two sinks.', 'Turn around, walk to the  tub, then turn around again.', 'Open the rightmost cabinet, place the bottle inside, then close the cabinet door.']
#
# Annotation 2
# Put the spray bottle in the bathroom cabinet
# ['Turn right and go forward then turn right and walk up to the sink', 'Pick up the spray bottle from the counter between the sinks', 'Walk slightly away from the counter then turn back to face it', 'Open the left cabinet below the right sink and put the spray bottle in it']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4173070202953371
# put a spray bottle in a cabinet .
# - Decoding by Sampling:
# BLEU score: 5.572079302093865e-78
# put a spray in bottles in the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6101950432112578
# put the spray bottle under the sink .
# - Decoding by Sampling:
# BLEU score: 0.17846877279661646
# put the spray bottle from the counter to the cabinet to the counter the toilet . from from the counter to to the right sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6101950432112578
# put a spray bottle in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.33260249505555045
# put a spray bottle into the cabinet cabinet under the sink sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 6.784827072174911e-78
# put away the spray bottle away a cabinet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.5559599117673093
# put a spray bottle to the cabinet cabinet the the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.7272454093000141
# put a spray bottle to the cabinet beneath right the right sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.8801117367933934
# put a spray bottle to the cabinet beneath the right .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.3667625610580775
# put a spray bottle away the cabinet . right the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.8633400213704505
# put move the spray bottle away under the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.6941764328740241
# put a spray bottle to the cabinet beneath the sink sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a spray bottle away under the sink .
# - Decoding by Sampling:
# BLEU score: 0.6941764328740241
# put a spray bottle to the cabinet beneath the sink sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_144907_367045_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-LettuceSliced-None-DiningTable-24/trial_T20190909_144907_367045
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'SliceObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a chilled slice of lettuce on the table. .
# ['Turn around and go to the front of the counter on the left of the stove.', 'Pick up the gray knife behind the salt shaker. ', 'Turn around and go to the left side of the white table on the left. ', 'Slice the lettuce on the table. ', 'Turn right and go to the refrigerator on the left. ', 'Place the knife in the refrigerator. ', 'Turn around and go back to the left side of the white table with the sliced lettuce on top.', 'Pick up one end slice of the lettuce. ', 'Turn right and go back to the refrigerator on the left. ', 'Chill the lettuce in the refrigerator and take it out. ', 'Turn around and go back to the white table on the right. ', 'Place the lettuce on the table in the middle. ']
#
# Annotation 1
# put a chilled slice of potato on the table
# ['go to the counter to the left of the stove', 'pick up the knife', 'take the knife to the table', 'cut the lettuce with the knife', 'take the knife to the fridge', 'put the knife in the fridge', 'go back to the table', 'pick up a slice of lettuce', 'take the slice to the fridge', 'chill the slice in the fridge, then remove', 'take the slice back to the table', 'put the slice on the table']
#
# Annotation 2
# Put a chilled slice of lettuce on the table.
# ['Turn around and go to the counter with the sponge on it.', 'Pick up the knife on the counter.', 'Turn right and go to the end of the table.', 'Cut the lettuce on the table.', 'Go across the room to the fridge.', 'Put the knife in the fridge.', 'Go back to the table.', 'Pick up a slice of lettuce.', 'Head back to the fridge.', 'Chill the slice of lettuce in the fridge and then pick it back up.', 'Turn left and head to the coffee maker on the table.', 'Put the slice of lettuce in front of the glass on the table.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5555238068023582
# put a chilled slice of lettuce in the sink .
# - Decoding by Sampling:
# BLEU score: 0.7419446627365011
# put a chilled slice of lettuce on the sink table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 0.5341735956899847
# put a chilled slice slice on the table .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 3.6170146665513074e-78
# put a lettuce , it inside the fridge , put it slice on the table
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 0.2533654946448647
# put cool a slice plus slice of lettuce plus place it on the table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 0.5316967153331754
# put a chilled slice of lettuce table empty table table on the table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of potato on the table .
# - Decoding by Sampling:
# BLEU score: 0.23961829057131984
# put a chilled slice slice on lettuce the lettuce on on the knife on the table
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of lettuce on the table .
# - Decoding by Sampling:
# BLEU score: 0.6767781116542884
# put a chilled slice of lettuce on the table . the the table of
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of potato on the table .
# - Decoding by Sampling:
# BLEU score: 0.7115965735877551
# put a chilled slice of potato on the table . the foot . .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of potato on the table .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled slice of potato on the table .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of potato on the table .
# - Decoding by Sampling:
# BLEU score: 0.2978201796359045
# put cool a slice of potato and place it on the table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_002819_330666_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-WineBottle-None-CounterTop-17/trial_T20190907_002819_330666
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the chilled bottle onto the counter.
# ['Turn around and face the toaster.', 'Open the cabinet below the toaster and take the bottle out.', 'Turn around and face the refrigerator.', 'Open the fridge, place the bottle inside and chill it for 5 seconds. Then take the bottle back out. ', 'Turn left and walk to the counter.', 'Place the bottle on the counter to the right of the fork.']
#
# Annotation 1
# Place the cooled bottle on the counter.
# ['Turn around towards the toaster on the counter.', 'Open the cabinet below the toaster and get the bottle from it.', 'Turn around and walk towards the fridge.', 'Put the bottle to the left of the plate in the fridge for it to cool and then take it out of the fridge.', 'Turn left towards the dishwasher.', 'Place the bottle to the right of the fork on the counter.']
#
# Annotation 2
# Place a chilled bottle of wine on the counter.
# ['Turn right, move forward slightly, then turn right and face the toaster on the edge of the counter.', 'Open the cabinet door beneath the toaster, pick up the bottle of wine, and then close the cabinet door.', 'Turn around and move toward the refrigerator.', 'Open the refrigerator and place the bottle of wine to the left of the plate. Close the refrigerator, open the refrigerator, and pick up the bottle of wine to the left of the plate and close the refrigerator.', 'Turn left and move toward the dishwasher to the right of the sink.', 'Place the bottle of wine near the edge of the counter to the right of the fork.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.329397756741367e-155
# put a chilled wine bottle in the sink .
# - Decoding by Sampling:
# BLEU score: 5.705336763108155e-78
# put a chilled wine bottle in the counter .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# put a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 4.640083527732319e-78
# put the the fridge , put it on the counter
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# put a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 0.45622720708659226
# put a chilled bottle of the counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098448
# put a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098448
# put a chilled bottle of wine on the counter .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# place a chilled bottle of a counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 3.573163960771238e-78
# place wine bottle from fridge in the fridge , put it on the counter
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a chilled bottle of wine on the counter .
# - Decoding by Sampling:
# BLEU score: 0.8891397050194614
# place the chilled bottle of wine on the counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_031131_996875_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spatula-Pot-CounterTop-26/trial_T20190907_031131_996875
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject', 'PickupObject', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move pan to counter, move spatula to pan
# ['Go to the right to white table with toaster', 'Pick up square pan off of white table', 'Turn right, go to counter with wine bottles, paper bag', 'Place pan on counter by paper bag with handle between salt shaker and cup', 'Pick up spatula to right of cup', 'Place spatula in square pan on counter']
#
# Annotation 1
# Place the pan with the spatula on the counter.
# ['Turn left and head towards the table.', 'Pick up the metal pan in front of the toaster.', 'Turn around, head towards the table, turnn left and head towards the counter.', 'Place the pan in front of the bag.', 'Pick up the spatula on the counter.', 'Place the spatula in the pan.']
#
# Annotation 2
# place a pan down on the counter with a spatula in it
# ['turn around and walk over to the kitchen counter with the toaster', 'grab the pan in front of the toaster', 'turn around and walk over to the kitchen counter to the right of the sink', 'place the pan down on the counter in front of the paper bag', 'pick up a spatula from the counter', 'place the spatula inside of the pan you set down on the left']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3294791210580041
# put a pan with a knife in it on the counter .
# - Decoding by Sampling:
# BLEU score: 8.969265027547596e-155
# put a pan with place white the on the pan . . the sink . . sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3294791210580041
# put a pan with a knife in it on the counter .
# - Decoding by Sampling:
# BLEU score: 8.451929273732148e-232
# put a with knife on counter
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# move pan to counter , move spatula to pan
# - Decoding by Sampling:
# BLEU score: 6.090564670197869e-155
# move pan on counter with spatula
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8948393168143697
# move pan to counter , move spatula to pan
# - Decoding by Sampling:
# BLEU score: 5.607773684948284e-78
# move pan on counter counter with with the spatula .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4933885363281902
# place a pan with a spatula in it on a counter .
# - Decoding by Sampling:
# BLEU score: 0.8891397050194614
# place a pan with the spatula on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4933885363281902
# place a pan with a spatula in it on a counter .
# - Decoding by Sampling:
# BLEU score: 0.4933885363281902
# place a pan with a spatula in it on a counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a pan down on the counter with a spatula in it
# - Decoding by Sampling:
# BLEU score: 0.4491846617388952
# place pan to counter , move knife in pan
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a pan down on the counter with a spatula in it
# - Decoding by Sampling:
# BLEU score: 4.963273987908844e-78
# place pan pan pan to the counter to the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a pan down on the counter with a spatula in it
# - Decoding by Sampling:
# BLEU score: 0.5169731539571706
# place a pan with the counter with the spatula on
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a pan down on the counter with a spatula in it
# - Decoding by Sampling:
# BLEU score: 0.4026190971287384
# place a pan down a on the counter
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a pan down on the counter with a spatula in it
# - Decoding by Sampling:
# BLEU score: 0.5968774175634496
# place pan to counter , move spatula to pan . move pan to counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_091158_217271_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Cloth-None-SideTable-420/trial_T20190909_091158_217271
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a towel on an end table
# ['Take a step to the left and then walk to the bathtub', 'Pick up the purple towel that is on the very left', 'Turn to the left and face the black end table', 'Place the towel on the end table to the left of the potted plant']
#
# Annotation 1
# Put a purple rag on the black table.
# ['Go to the tub.', 'Pick up the purple rag on the left in the tub.', 'Turn around to the black table.', 'Put the rag on top of the the table to the left of the plant.']
#
# Annotation 2
# put purple rag on bathroom table
# ['walk to face bath tub', 'pick up purple rag from tub', 'turn left to face black table', 'put rag on table']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1231644147255971e-154
# put a washed on the white table .
# - Decoding by Sampling:
# BLEU score: 8.534204031625306e-155
# put a rag from the on table table
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 9.035368920308834e-155
# put a rags from the end table . front of the . black
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7652058832556895
# put a rag on the black table .
# - Decoding by Sampling:
# BLEU score: 0.5081327481546147
# put a rag on the black .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 0.691441569283882
# put a purple on the black table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 7.101238428437038e-78
# put a towel on top end table
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 0.39832871551569504
# put wash a purple rag and put it on the black table .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 0.691441569283882
# put a purple on the black table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 7.101238428437038e-78
# put a towel on top table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 8.40808171968649e-155
# put a rag on table
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 7.101238428437038e-78
# put a towel on top end table
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a purple rag on the black table .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a purple rag on the black table .
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# BEST valid_seen
best_valid_seen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_seen_ids_best_10, epoch_list=valid_seen_epoch_list, split='valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190908_165525_911839_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-TomatoSliced-None-Microwave-12/trial_T20190908_165525_911839
# Number of subgoals : 12
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'SliceObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a chilled slice of tomato in the microwave.
# ['Turn and go to the counter by the sink.', 'Pick up the knife on the counter.', 'Cut the tomato on the counter. ', 'Turn and go to the microwave.', 'Put the knife in the microwave. ', 'Turn and go to the counter by the sink.', 'Pick up a slice of tomato on the counter. ', 'Turn and go to the refrigerator. ', 'Chill the slice of tomato in the refrigerator. ', 'Turn and go to the microwave. ', 'Put the slice of tomato in the microwave.']
#
# Annotation 1
# Put the chilled sliced tomato in the microwave
# ['Turn left then face the sink counter', 'Pick up the bread knife on the left counter', 'Slice the tomato on the sink', 'Turn right then face on your left to the microwave', 'Open the microwave put in the knife in the microwave, close the microwave', 'Look down and step on the side to face the tomato', 'Pick up a slice tomato', 'Turn right and head to the fridge', 'Open the fridge then put in and out the fridge then close it', 'Turn right then then back to the microwave', 'Open the microwave and put in the slice tomato then close it']
#
# Annotation 2
# Place a tomato and a knife in the microwave.
# ['Turn left then face the sink on your right.', 'Take the knife from the sink in front of you.', 'Slice the tomato on the sink in front of you.', 'Turn right then face the microwave above the sink to your left.', 'Place the knife in the microwave then close it.', 'Turn left then face the tomato on the sink to your right.', 'Take a tomato slice from the sink in front of you.', 'Turn right then face the fridge to your right.', 'Place the tomato slice in the fridge then take it out.', 'Turn right then face the microwave above the sink on your right.', 'Place the tomato slice in the microwave and close it.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4122478184247683
# put a tomato slice in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.111565467761957e-235
# put
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 5.667113443314699e-155
# put a , cool it fridge , place , , place , put in counter microwave
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.47718970758108814
# put a chilled slice in the microwave . the a knife .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4412484512922977
# put a chilled slice into the microwave .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.7259795291154771
# put a chilled slice of tomato in a microwave .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5410822690539396
# put a chilled of chilled tomato in the microwave .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5969491792019646
# put a chilled slice slice in the microwave .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 8.19541720095112e-155
# put out a chilled of tomato .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled slice of tomato in the microwave .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_001852_804129_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-AppleSliced-None-SinkBasin-30/trial_T20190909_001852_804129
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the warm slice apple in the sink
# ['Turn right then head to the counter on your left', 'Pick up the knife on the counter beside the toaster', 'Turn left then head to the left side stove counter', 'Slice the apple beside the stove', 'Turn left then head the sink', 'Put the knife in the sink', 'Turn right then head to the stove counter on you left', 'Pick up a slice of apple on the counter', 'Turn right then head to the microwave', 'Open the microwave put in and out the microwave', 'Turn left then head to the sink', 'Put the slice apple in the sink']
#
# Annotation 1
# To heat a piece of apple and place it in the sink.
# ['Turn right and walk forward to face the knife on the counter.', 'Pick up the knife on the counter.', 'Turn left and walk forward to face the apple on the counter.', 'Cut the apple on the counter into three pieces.', 'Turn left and walk across the room to face the sink.', 'Place the knife in the sink.', 'Turn around and walk forward to face the apple pieces on the counter.', 'Pick up a piece of apple on the counter.', 'Turn right and walk to the end of the counter and turn left to face the microwave.', 'Heat the apple piece in the microwave and remove it.', 'Walk around the room to face the sink.', 'Place the piece of apple in the sink.']
#
# Annotation 2
# Put a knife and microwaved apple slice in the sink.
# ['Turn around and go to the knife on the counter to the left.', 'Pick up the knife from the counter.', 'Walk to the counter corner by the refrigerator with the phone on it.', 'Use the knife to cut the yellow apple in three pieces.', 'Turn around then go right to the sink.', 'Put the knife in the sink to the left of the spoon.', 'Walk back over to the counter corner by the refrigerator.', 'Pick up the apple slice that is farthest to the right.', 'Turn around and then go forward to the microwave on the left.', 'Open the microwave, put the apple inside, turn it on then take the apple out and close it.', 'Turn left, then left again at the oven, then go straight ahead to the sink.', 'Put the apple slice in the sink to the left of the knife.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5623413251903491
# put a heated piece of apple in the sink .
# - Decoding by Sampling:
# BLEU score: 0.4139790020029942
# put a heated piece of apple in the sink . . sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6606328636027614
# put a cooked apple slice in the sink .
# - Decoding by Sampling:
# BLEU score: 0.47287080450158786
# put a put a slice apple slice in the sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5035337887555859
# put a heated slice of apple in the sink .
# - Decoding by Sampling:
# BLEU score: 5.488849172048681e-78
# put microwave of apple in the microwave , put the in the sink
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5035337887555859
# put a heated slice of apple in the sink .
# - Decoding by Sampling:
# BLEU score: 9.013778876140909e-155
# put a apple slice the microwave , be placed .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 9.308300767049977e-155
# to a slice of apple in use .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.47085197326451766
# to heat a heated slice of apple in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.47085197326451766
# to heat a heated slice of apple in the sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.34329452398451965
# to a microwaved slice slice in the sink sink
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 6.130783336563573e-78
# to a piece slice of apple in the microwave
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# to heat a piece of apple and place it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.48109772909788073
# to a heated slice of apple in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_120047_968274_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-CellPhone-None-ArmChair-318/trial_T20190909_120047_968274
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a cell phone on a chair.
# ['Turn left and walk to the wall, then turn left to the counter.', 'Pick up the cell phone on the counter.', 'Turn around and walk ahead and slightly right to the multicolored chair.', 'Place the cell phone on the chair, to the left of the credit card and CD.']
#
# Annotation 1
# Move a phone to the chair
# ['Move to the right side of the wood desk top in the corner of the room', 'Pick up the phone on top of the right side of the desk', 'Carry the phone over to the single chair with flowers on it', 'Place the phone on top of the chair to the left ']
#
# Annotation 2
# Put a phone on a chair.
# ['Turn left and then left again to face the desk with clocks and a phone on it.', 'Pick the phone up from the brown desk.', 'Turn around and face the chair with flowers on it.', 'Put the phone on the chair.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.803659209895733e-78
# place a phone on the chair .
# - Decoding by Sampling:
# BLEU score: 0.7400828044922853
# place a phone to the chair .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8801117367933934
# place a phone on a chair .
# - Decoding by Sampling:
# BLEU score: 0.6223329772884784
# place a phone phone on a chair .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 0.5946035575013605
# place a cell on a chair .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a cell phone on a chair .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a cell phone on a chair .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a cell phone on a chair .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 0.4854917717073234
# place a cell phone on the sofa . .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.3263013755348475e-154
# place a phone phone on the chair .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a cell phone on a chair .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 7.803659209895733e-78
# place a phone on the chair .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# place a cell phone on a chair .
# - Decoding by Sampling:
# BLEU score: 1.0
# place a cell phone on a chair .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_012524_159092_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Tomato-None-Microwave-18/trial_T20190909_012524_159092
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold tomato in the microwave.
# ['Turn left and cross the room to stand in front of the microwave.', 'Pick up the tomato from the counter next to the microwave.', 'Turn around and carry the tomato to the fridge.', 'Place the tomato on the top shelf in the fridge, close the door, and then open the door to remove it after a few seconds.', 'Turn right and carry the tomato across the room to the microwave.', 'Place the tomato in the microwave.']
#
# Annotation 1
# Chill a tomato and heat it.
# ['Walk to the microwave behind you.', 'Grab a tomato from the counter.', 'Walk to the fridge on the left of the kitchen counters.', 'Put the tomato in the fridge, then take it out.', 'Walk to the microwave on your right.', 'Put the tomato in the microwave.']
#
# Annotation 2
# Putting a cooled tomato in the microwave
# ['Turn left and go to the counter with the microwave', 'Grab the tomato off of the counter', 'Turn around and go to the fridge', 'Put the tomato in the fridge and then close the door. Then take the tomato out', 'Turn right and go to the microwave', 'Put the apple in the microwave']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# put a chilled tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.4234197579236933
# put a tomato and place it in the microwave .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# put a chilled tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5946035575013605
# put a chilled tomato in the microwave .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold tomato in the microwave .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.42383656282787796
# put a chilled tomato in the microwave
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.42383656282787796
# put a chilled tomato in the microwave
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold tomato in the microwave .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.8668778997501817
# put a cold tomato in the microwave
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.8668778997501817
# put a cold tomato in the microwave
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5578002860768766
# put a cold tomato in a microwave
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.3768499164492419
# put the tomato tomato in the microwave
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold tomato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5593684915933074
# put a cold tomato in the microwave . . . the microwave .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_234112_645480_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Egg-None-Microwave-24/trial_T20190908_234112_645480
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cold egg in the microwave.
# ['Turn right and walk to the stove then turn left and walk to the wall then turn left.', "Pick up the egg that's in front of you to the right of the sponge.", 'Turn left and take a step then turn left to face the fridge.', 'Chill the egg in the fridge then get it back out and close the door.', "Turn right and walk to the sink that's in front of you and slightly to the right.", 'Open the microwave and put the egg in there then close the door.']
#
# Annotation 1
# Putting a cooled egg in the microwave
# ['Turn right and go to the right side of the white table', 'Grab the egg off of the table', 'Turn left and stop at the fridge', 'Cool the egg in the fridge and then take it out', 'Turn right and go to the microwave', 'Put the egg in the microwave']
#
# Annotation 2
# Place a cold potato in the microwave.
# ['Turn right, then left and face the table to your left.', 'Take the potato off the table in front of you.', 'Turn left and face the fridge to your left.', 'Place the potato in the fridge, take out the potato and close the fridge.', 'Turn right and face the sink in front of you.', 'Place the potato in the microwave on top of the sink in front of you.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# put a egg egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.30576902884505114
# put a egg in the microwave . the . the . the microwave .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# put a chilled egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.23397625978961173
# put the egg egg to the microwave . move the egg in the microwave
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold egg in the microwave .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.829195976849487e-155
# put away a egg potato in
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.8839550783001316e-155
# put a egg in microwave
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold egg in the microwave .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold egg in the microwave .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0462511552442487e-154
# put a egg in microwave microwave .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold egg in the microwave .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cold egg in the microwave .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cold egg in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.22997519112894443
# put a egg in the refrigerator , put the egg in the microwave
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_212725_836398_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Plate-None-CounterTop-19/trial_T20190908_212725_836398
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a clean plate on the counter.
# ['Turn around and cross the room to face the counter to the left of the sink.', 'Pick the plate up from the counter.', 'Go to the right and face the sink.', 'Put the plate in the sink and turn the water on and then off and pick the plate up again.', 'Move to the left and stand next to the counter to the left of the sink.', 'Place the plate down on the counter to the right of the sink.']
#
# Annotation 1
# place a clean plate down on the kitchen counter to the right of the sink
# ['turn around and walk over to the kitchen counter to the left of the sink', 'grab the dirty plate off of the kitchen counter there', 'move to the right a bit and face the kitchen sink', 'place the plate inside the sink and clean it off', 'move left a bit towards the left side of the kitchen counter to the left of the stove, but then turn right and face away from the counter top', 'place the plate down on the kitchen counter to the right of the sink']
#
# Annotation 2
# Place a clean plate on a counter
# ['Turn around and head to the counter to the left of the sink', 'Pick up the dirty plate that is sitting on the counter to the right of the pan', 'Take a step to the right and stand in front of the sink ', 'Place the plate in the sink and turn on the faucet to rinse off the plate, then turn off the faucet and pick up the clean plate', 'Take a step over to your left to stand in front of the counter to the left of the sink, then turn right to face the counter to the right of the sink', 'Place the clean plate on the counter to the right of the sink by the egg']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.30213753973567675
# put the clean and put it on the counter .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a clean plate on the counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean plate on a counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.25919218840980945
# put the dirty plate on the counter , put it on the counter .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 8.534204031625306e-155
# put the dirty plate on put sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.2790159393585827
# put the dirty plate to put it on the counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.8668778997501817
# put a clean plate on the counter
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.7259795291154771
# put a clean plate plate on the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.17181529671327242
# put the dirty plate on the counter by the sink , , put it plate on the counter
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a clean plate on the counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a clean plate on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6783686168526631
# put a clean plate on the counter . the right of the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_062333_424779_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Mug-None-Cabinet-26/trial_T20190909_062333_424779
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place microwaved black mug in upper cabinet in between microwave and sink
# ['go to the black mug above the brown paper bag to the left', 'pick up the black mug above the brown paper bag', 'go to the counter with the microwave to the left', 'open microwave, put black mug on plate in microwave, close microwave, turn on microwave, pick up black mug from microwave, close microwave', 'look to upper cabinet in between microwave and sink', 'open upper cabinet, place black mug on right side of cabinet, close cabinet']
#
# Annotation 1
# put a heated mug into a cabinet
# ['walk to face counter top to the right of the sink', 'pick up black mug from above the paper bag on the counter', 'walk to the left to face the microwave', 'heat the mug in microwave, pick up mug from microwave', 'walk right to face cabinet above sink', 'put the mug inside the cabinet']
#
# Annotation 2
# Put a warm mug in the cabinet.
# ['Turn left, move forward, then turn right to face the counter next to the sink.', 'Pick up the mug on top of the bag.', 'Turn around and step forward, then turn right to go toward the door, then turn right to face the microwave.', 'Open the microwave, heat the mug inside of it, then take the mug out.', 'Look up to the cabinet above the counter.', 'Open the cabinet and put the mug inside, and close it.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.320647992786978e-78
# put a heated cup in the cabinet
# - Decoding by Sampling:
# BLEU score: 5.30941411456236e-78
# put a cup and put it in the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.30941411456236e-78
# put a warm coffee cup in the cupboard .
# - Decoding by Sampling:
# BLEU score: 0.7071067811865475
# put a warm mug in the cupboard .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.4497332084013506
# put a warm mug in a cabinet cabinet . the .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a warm mug in the cabinet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a warm mug in the cabinet .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a warm mug in the cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.8668778997501817
# put a warm mug in the cabinet
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.6204032394013996
# put a warm mug mug into a cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a warm mug in the cabinet .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.20624574461560563
# put up the cup from put it away in the cabinet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a warm mug in the cabinet .
# - Decoding by Sampling:
# BLEU score: 0.1892240568795935
# put up the cup and the microwave to put it away in the cabinet .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_215856_374127_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Pan-None-StoveBurner-23/trial_T20190906_215856_374127
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a chilled pan on the stove.
# ['Move to the stove.', 'Pick up the right pan on the stove. ', 'Bring the pan to the fridge.', 'Chill the pan in the fridge.', 'Bring the pan back to the stove.', 'Put he pan on the back right of the stove. ']
#
# Annotation 1
# place a cold pan on the gas cooker
# ['turn around and move towards the gas cooker', 'pick up the pan from the gas cooker', 'turn around and head for the fridge', 'place the pan in the fridge and allow to cool for some time before taking it out', 'turn right and move towards the  gas', 'place the pan on the gas']
#
# Annotation 2
# Put the tray in the freezer.
# ['Turn all the way around. Move forward to the stove. ', 'Pick up the tray that is in the right hand corner of the stove.', 'Turn all the way around.  Move to the wall.  Turn left and stop in front of the fridge.', 'Open the freezer on the bottom of the fridge.  Put the tray in.  Close the door.  Open the freezer and grab the tray out.', 'Turn all the way around facing the stove.  Go to the stove. ', 'Put the tray on the back right corner of the stove.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7071067811865475
# put a chilled pan on the counter .
# - Decoding by Sampling:
# BLEU score: 9.367929145127228e-155
# put a pan pan place it on the counter .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled pan on the stove .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.6129752413741056
# put a pan on the stove .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5133450480401704
# put the skillet frying pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.4111336169005197
# put the skillet frying on the stove .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.5946035575013605
# put the the pan on the stove .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 8.693790938244096e-155
# put the pan from the fridge , cool it in in the stove
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.42383656282787796
# put a skillet pan on the stove
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled pan on the stove .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 4.1696290531635676e-155
# put a pan in
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 0.6129752413741056
# put the pan on the stove .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled pan on the stove .
# - Decoding by Sampling:
# BLEU score: 9.367929145127228e-155
# put a pan in the fridge to return place .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_002804_564168_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Spatula-None-DiningTable-4/trial_T20190909_002804_564168
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a spatula on the table.
# ['Walk to your right to the side of the table where the other loaf of bread is sitting.', 'Grab the spatula behind the lettuce on the table.', 'Take the spatula to the sink to your right.', 'Place the spatula in the sink, wash it and remove it from the sink.', 'Turn around and walk to the end of the table to your right.', 'Place the spatula standing next to the lettuce to the left of the bread.']
#
# Annotation 1
# Put a clean spatula on a wooden table.
# ['Turn right and walk toward the sink, then turn left and walk up to the wooden table.', 'Pick up the metal spatula off of the wooden table.', 'Turn right and walk over to the sink.', 'Put the spatula in the sink and turn on the water, after a couple seconds turn the water off and remove the now clean spatula.', 'Turn right and take a step forward, then turn right and walk over to the wall, turn right again to face the wooden table.', 'Put the clean spatula on the wooden table in front of the leftmost head of lettuce.']
#
# Annotation 2
# put a washed spatula on a table
# ['walk to face wooden table', 'pick up spatula from the table', 'walk to face kitchen sink', 'wash spatula in sink, pick up spatula', 'turn around to face left side of wooden table', 'put spatula onto the table in front of the lettuce on the left']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.46905226098954195
# put the clean spatula on the table
# - Decoding by Sampling:
# BLEU score: 6.458654791343583e-155
# put the clean in the table
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.7825422900366437
# put a clean spatula on the table table
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 3.603235312613151e-78
# put the spatula in the sink , put the on the table
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.6025286104785453
# put a spatula on the table
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 5.475733548646979e-78
# put a spatula and place it on the table table .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# - Decoding by Sampling:
# BLEU score: 0.9457416090031758
# put a clean spatula on the table .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_083541_210340_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CreditCard-None-FloorLamp-206/trial_T20190908_083541_210340
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a credit card by the light of a floor lamp.
# ['Turn around and walk forward to the garbage bin on the floor by the TV.', 'Pick up the blue credit card on the TV stand.', 'Turn right, walk forward to the blue sofa, then turn left and walk to the floor lamp to the left of the sofa.', 'Turn on the lamp.']
#
# Annotation 1
# Take the blue bank card from behind the TV, turn on the lamp in the corner
# ['Turn around, head to the window', 'Take the blue bank card from behind the TV', 'Turn to the right, head across the living room to the corner', 'Turn the lamp on']
#
# Annotation 2
# Pick up a credit card and use it to turn the lamp
# ['Turn right, take a step, again turn right, move across the room, and turn right to face the dust bin on the left of the table with a monitor', 'Pick up the blue credit card from the table', 'Go back to the starting position, continue forward to the other side of the room, turn right, go ahead, and stand in front of the lamp ', 'Use the credit card to turn on the lamp']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7097039016115906
# examine a credit card by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.7097039016115906
# examine a credit card by the light of a lamp .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 2.6794871946199655e-78
# turn on the living room lamp .
# - Decoding by Sampling:
# BLEU score: 0.7626264731696686
# turn a credit card by the light of a floor lamp
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2767783451247154
# turn on the lamp while holding a credit card
# - Decoding by Sampling:
# BLEU score: 0.5390594848489677
# turn at a credit card by the light of the lamp lamp
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 0.4758015944333653
# examine a credit card by the lamp of the floor lamp
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 0.2561162565311301
# examine a credit card under the of the floor lamp
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 4.521220735883041e-78
# examine on the lamp while holding a credit card
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 4.521220735883041e-78
# examine on the lamp while holding a credit card
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 2.2614485705630703e-78
# examine a credit with the lamp
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 0.36782088518014455
# examine up a credit card and turn on lamp on .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# examine a credit card by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 3.0761252566884164e-78
# examine on the lamp while holding a card card
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# BEST valid_unseen
best_valid_unseen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_unseen_ids_best_10, epoch_list=valid_unseen_epoch_list, split='valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190907_033157_424297_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Potato-None-Microwave-10/trial_T20190907_033157_424297
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a potato inside the microwave
# ['walk over to the kitchen island', 'grab a potato off of the kitchen island counter', 'walk over to the fridge', 'place the potato inside the fridge to cool, then take it back out', 'bring the potato over to the microwave above the stove', 'place the potato inside the microwave and close the door']
#
# Annotation 1
# Place the potato in the microwave.
# ['Turn left then right to face the counter with the knife on it. ', 'Pick up the potato from the counter.', 'Turn right and face the fridge. ', 'Open the fridge and chill the potato for 5 seconds then take it out.', 'Turn right and walk then turn left to face the stove.', 'Look above the stove to the microwave and place the potato inside.']
#
# Annotation 2
# Put a chilled potato in the microwave.
# ['Go to the counter in front of you.', 'Pick up the potato the the left of the bread.', 'Go to the fridge behind you.', 'Chill the potato in the fridge.', 'Take the potato to the microwave to your right.', 'Placed a potato in the microwave.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.846481724890614
# put a chilled potato in the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a chilled potato in the microwave .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.47987820666906633
# put a chilled potato in the cabinet . a sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.887578243315168e-155
# put an egg in the fridge and place it up .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5
# put a chilled egg in the microwave .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.887578243315168e-155
# put the egg from to the microwave put away bowl in
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 8.44484326442819e-78
# put a chilled in the microwave microwave
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5491004867761125
# put a chilled potato in the microwave side the sink sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.631196907822589
# put a chilled potato in the the left .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 0.5408536609893481
# put a potato in the microwave
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a chilled potato in the microwave .
# - Decoding by Sampling:
# BLEU score: 6.6056549084510665e-78
# put a potato in the kitchen
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_124126_852630_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_124126_852630
# Number of subgoals : 11
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'SliceObject', 'PutObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Putting a hot potato slice in the fridge
# ['Turn right and go to the counter with the coffee maker', 'Grab the knife off of the counter', 'Look up at the counter', 'Slice the potato on the counter', 'Put the knife down on the counter', 'Grab a potato slice off of the counter', 'Turn left and go to the microwave', 'Heat the potato slice in the microwave and then take it out', 'Turn left and go to the fridge', 'Put the potato slice in the fridge']
#
# Annotation 1
# place a cooked potato slice  in the fridge
# ['move right to the table ', 'pick up the knife', 'move up to the potato on the table', 'slice the potato on the table', 'drop the knife on the coffee maker', 'pick up a slice of the potato', 'move left to the oven ', 'cook the potato in the oven  and take it out', 'move left to the fridge', 'place the potato in the fridge']
#
# Annotation 2
# Put a cooked slice of potato in the fridge.
# ['Turn right and go to the coffee maker.', 'Pick up the knife on the counter.', 'Look up at the potato on the counter.', 'Cut the potato on the counter.', 'Put the knife on the counter in front of the coffee maker.', 'Pick up a slice of potato.', 'Go left to the microwave above the stove.', 'Cook the slice of potato in the microwave and pick it back up.', 'Turn left and go to the fridge.', 'Put the slice of potato on the shelf in the fridge with the lettuce.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9554427922043668
# put a cooked potato slice in the fridge .
# - Decoding by Sampling:
# BLEU score: 1.2179419412838124e-154
# put a hot of potato potato in of the fridge
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a potato of potato in the fridge
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.25142385353045044
# put a chill a slice of green , place a slice in the fridge
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 7.709051917538099e-78
# put a cooked of cooked potato the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.3945881255591767
# put away a cooked slice of potato . the microwave .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5022573937283119
# put a cooked of cooked potato potato in the fridge .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.30576902884505114
# put heat a slice of potato and place it in the fridge .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.30576902884505114
# put heat a slice of potato and place it in the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_225359_617900_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Tomato-None-GarbageCan-10/trial_T20190908_225359_617900
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Heat a tomato and place in the bin.
# ['Turn to the left and go around the island to the other side.', 'Pick up the tomato from the kitchen island. ', 'Turn around completely and head to the right. Then turn left once you reach the wall and go forward. Turn right and then left to face the oven. ', 'Place the tomato in the microwave above the oven. Heat the tomato then take it out. ', 'Turn left then turn right twice to face a black bin.', 'Place the tomato inside the black bin. ']
#
# Annotation 1
# Put a microwaved tomato in the garbage.
# ['Turn left and walk past the counter then turn left and walk past the counter and chair then turn left and walk to the middle of the chairs and turn left.', "Pick up the tomato that's in front of you on the counter between the chairs.", "Walk around the counter island and walk to the stove that's in front of you.", 'Cook the tomato in the microwave then take it back out and close the door.', 'Turn left and walk past the counter then turn left and take a step then turn left to face the garbage.', 'Put the tomato in the garbage.']
#
# Annotation 2
# Put a heated tomato in the trash can.
# ['Turn left, move around the island to the left, then turn around so you facing the other side of the island. ', 'Pick up the tomato on the island. ', 'Bring the tomato around the right side of the island, to the other side, to the stove, to the microwave above the stove.', 'Heat the tomato in the microwave. ', 'Bring the heated tomato to the left, around the other side of the island, to the trash can at the end.', 'Put the heated tomato in the trash can.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a microwaved tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.44833867003844585
# put a microwaved tomato in the desk . the a trash .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6606328636027614
# put a cooked tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 3.5318487635731415e-78
# put up tomato and place it in on the of the kitchen side
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6606328636027614
# put a cooked tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 2.99414049262426e-78
# put a cooked tomato in the room by the room . the place the the desk table unit .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.8034284189446518
# put a heated tomato in the trash bin .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 5.185404073830853e-78
# put a cooked tomato in the small .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 4.1735993043546123e-78
# put a cooked tomato in the room box of the desk bin
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.767279645960659
# put a heated tomato in the trash .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 5.185404073830853e-78
# put a cooked tomato in the box .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a heated tomato in the trash can
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.767279645960659
# put a heated tomato in the trash .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a heated tomato in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.7506238537503395
# put a heated tomato in the trash box .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_123133_763972_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Lettuce-None-CounterTop-10/trial_T20190909_123133_763972
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# chill the lettuce then return it to the counter
# ['go to the counter to the left of the stove', 'pick up the lettuce from the counter', 'take the lettuce to the fridge', 'put in the fridge then remove', 'take the chilled lettuce back to the counter', 'put the lettuce back on the counter']
#
# Annotation 1
# Place a chilled head of lettuce on a plate on a counter.
# ['Turn right and walk to the fridge, then turn right and walk to the counter on the left side of the stove.', 'Pick up the head of lettuce on the counter.', 'Walk left back to the fridge.', 'Place the lettuce in the fridge, to the left and behind the tan plate. Close the door, wait a moment, and take it out again.', 'Take a couple steps right, facing the counter to the left of the stove.', 'Place the head of lettuce on the plate on the counter.']
#
# Annotation 2
# Put a head of chilled lettuce on the counter.
# ['Turn right, go across the room, turn right and go to the dishwasher.', 'Pick up the lettuce on the counter.', 'Turn right and go to the fridge.', 'Chill the lettuce in the fridge and pick it back up.', 'Turn left and go to the dishwasher.', 'Put the lettuce on the counter in front of the spatula.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.707897789452821e-155
# put chilled lettuce in the sink .
# - Decoding by Sampling:
# BLEU score: 8.747213257062311e-155
# put a chilled lettuce in a sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.41917424905767126
# put cold lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.41917424905767126
# put cold lettuce on the counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8891397050194614
# put a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4846734100434258
# put a chilled lettuce on the counter counter
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8891397050194614
# put a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 8.52863367187932e-155
# put a chilled in the sink . bin on
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6717110910584733
# place a chilled head of lettuce on the counter . the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4630777161991027
# place a lettuce lettuce on the counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a chilled head of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6147881529512643
# place a chilled lettuce of lettuce on the counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_123918_983775_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123918_983775
# Number of subgoals : 13
# https://youtu.be/1Ha8RLnfsBg
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'SliceObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# place a cooked potato slice in the fridge
# ['move around to the table', 'pick up a knife from the table', 'move forward to the fridge', 'slice the potato in the fridge', 'turn around to the shelf ', 'place the knife on the shelf', 'turn right to the fridge', 'pick up a slice of the potato', 'move right to the oven', ' cook the potato in the oven and take it out', 'move left to the fridge', 'place the cooked slice in the fridge']
#
# Annotation 1
# To heat a potato slice and place it in the fridge.
# ['Turn around and cross the room and turn around to face the end of the center table.', 'Pick up the knife on the counter.', 'Walk to the right past the center table and turn right to face the fridge.', 'Cut the potato on the bottom in the fridge into slices.', 'Turn left and step forward to face the shelves.', 'Place the knife on the shelf.', 'Turn right to face the fridge.', 'Pick up a slice of potato in the fridge.', 'Turn right and step forward and turn left to face the microwave.', 'Heat the potato slice in the microwave and remove it.', 'Turn left and walk forward and turn right to face the fridge.', 'Place the potato slice in the fridge.']
#
# Annotation 2
# Put a cooked slice of potato in the fridge.
# ['Turn around, go across the room and turn right to face the end of the counter.', 'Pick up the knife on the counter by the statue.', 'Go back across the room to the fridge.', 'Cut the potato on the second shelf in the fridge.', 'Turn around and go to the brown shelf on the left.', 'Put the knife on the top shelf.', 'Go back to the fridge.', 'Pick up a slice of potato in the fridge.', 'Turn right and go to the microwave.', 'Cook the slice of potato in the microwave and pick it back up.', 'Turn left and go back to the fridge.', 'Put the cooked slice of potato in the fridge between the mug and the potato.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6580370064762462
# put a cooked slice of tomato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6101950432112578
# put a cooked slice of the fridge .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6360188027707555
# put heat a slice of potato and place it in the fridge .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.7083397532288122
# place a cooked slice of potato in the fridge . a can .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5623413251903491
# place a cooked of cooked potato in the fridge .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 5.471968861960635e-78
# place a chill and a slice of potato . heat it slice in the microwave
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9621954581957615
# place a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6511928252400603
# place a cooked slice of potato in the fridge . a the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_155109_353266_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spoon-Mug-CounterTop-10/trial_T20190907_155109_353266
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'PickupObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a mug with a spoon inside of it on the counter.
# ['Turn around, then begin walking to the door, hang a right and walk up to the fridge, then turn right again and walk over to where the toaster is on the counter.', 'Pick up the metal spoon that is to the right of the toaster on the counter.', 'Turn left and walk over to the fridge.', 'Open the fridge door and place the metal spoon inside the white mug that is in the fridge.', 'Remove the white mug with the spoon inside of it from the fridge and close the fridge door.', 'Turn right and walk over to the section of counter above the dishwasher.', 'Place the mug with the spoon inside of it onto the front edge of the counter just above the middle of the dishwasher.']
#
# Annotation 1
# Put a mug with a spoon in it on the counter.
# ['Turn around, go straight, turn right, turn right at the refrigerator, move forward, then turn left to face the counter with the dishwasher.', 'Pick up the spoon on the counter, to the right of the toaster.', 'Turn left, go forward, then turn right to go to the fridge.', 'Put the spoon in the mug inside of the fridge.', 'Pick up the mug with the spoon in it from in the fridge.', 'Turn right, go forward, then turn left to return to the counter above the dishwasher.', 'Put the mug with the spoon in it on the counter, to the right of the fork.']
#
# Annotation 2
# To get a chilled mug for coffee.
# ['Turn to the left and walk in front of the counter with the toaster on it. ', "Pick up the spoon that's next to the toaster. ", 'Move to the front of the fridge. ', 'Open the fridge and put the spoon in the white mug. ', 'Take the mug out of the fridge and close the door. ', 'Turn to the right and stand in front of the counter with two heads of lettuce on it. ', 'Put the mug down on the edge of the counter. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.389137965329953e-78
# put a chilled mug in a sink .
# - Decoding by Sampling:
# BLEU score: 6.227170448085464e-155
# put the a mug the , cup
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.013778876140909e-155
# put the white mug with spoon in the kitchen sink
# - Decoding by Sampling:
# BLEU score: 6.8489908526642754e-155
# put the white mug with the refrigerator , the sink
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.389137965329953e-78
# put the mug with spoon on the counter
# - Decoding by Sampling:
# BLEU score: 1.646211035903463e-231
# put the mug in mug on a kitchen sink
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.3814165616365676
# put a mug with spoon on the kitchen counter
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 4.688311033309527e-78
# put a mug mug with spoon on the kitchen counter the counter
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.8626751460052914
# put a mug with a spoon in it on the counter counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 4.570287952808815e-78
# put put a spoon in the refrigerator and the refrigerator and put the to the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.32559641262003014
# put a mug with a refrigerator and put the spoon in the mug on
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.8343519768888821
# put a mug mug with a spoon in it on the counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9200444146293233
# put a mug with a spoon in it on the counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_201444_037645_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Mug-None-DeskLamp-308/trial_T20190908_201444_037645
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a mug using the light of a desk lamp.
# ['Turn to the left, walk to the bed, turn right, walk almost to the window, then turn right to face the desk.', 'Pick up the mug that is on the desk closest to the wall. ', 'Turn to the right, walk almost to the hamper, turn left, walk to the wall, then turn left to face the desk. ', 'Turn on the lamp that is on the desk.']
#
# Annotation 1
# examine a mug with the lamp
# ['turn left, walk to the bed, turn right, walk across room, turn right to face desk', 'pick up the white mug from the desk', 'turn right, walk across the room, turn left, walk to the wall, turn left to face desk', 'turn the lamp on']
#
# Annotation 2
# Examine a mug in the light of a lamp.
# ['Turn left and go to the bed, then turn right and go towards the wall, then turn right to face the desk.', 'Pick up the mug nearest to the wall on the desk.', 'Turn right and go toward the wall, then turn left go to the wall, then turn left to face the lamp on the desk.', 'Turn on the lamp.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.670614669285479e-78
# place a mug with a pencil in it on the white table .
# - Decoding by Sampling:
# BLEU score: 5.186903763466333e-155
# place a mug cup a mug cup . put it coffee cup . to put to the end table
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.792595621977062e-155
# to see a mug and turn the lamp on .
# - Decoding by Sampling:
# BLEU score: 6.858354866987037e-155
# to a lamp on with a coffee in hand .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5115078115793242
# examine a mug with a lamp
# - Decoding by Sampling:
# BLEU score: 4.484824319939061e-78
# examine a mug to a lamp at under a lamp lamp .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 3.739798960152716e-78
# examine a mug from the mug , turn it in the lamp on the lamp
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 4.126725147240115e-78
# examine on lamp on with a mug in hand .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 4.722003949438406e-78
# examine a mug cup to a lamp on the lamp
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.47538527325677404
# examine a mug cup under the light of a lamp
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.343763879968285
# examine a mug cup under a light of a lamp
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# examine a mug in the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 5.705336763108155e-78
# examine a mug cup under a lamp lamp .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_123732_489327_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-10/trial_T20190909_123732_489327
# Number of subgoals : 11
# https://youtu.be/4V2hh2cw4No
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'PutObject', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'SliceObject', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# To heat a potato slice and place it in the fridge.
# ['Walk around the center table to the left and turn right to face the knife on the table.', 'Pick up the knife on the table.', 'Turn left and walk forward and turn around to the right to face the trash can.', 'Cut the potato in the trash can into slices.', 'Place the knife in the trash can.', 'Pick up a slice of potato in the trash can.', 'Turn left and walk to the right around the table and turn left to face the microwave.', 'Heat the potato slice in the microwave and remove it.', 'Turn left and step forward and turn right to face the fridge.', 'Place the potato slice in the fridge.']
#
# Annotation 1
# Put a cooked slice of potato in the fridge.
# ['Go left and around the counter to the back of the sink.', 'Pick up the knife on the counter.', 'Go to the end of the counter and face the trash can.', 'Cut the potato in the trash can.', 'Put the knife in the trash can.', 'Pick up a slice of potato from the trash can.', 'Turn left and go to the stove.', 'Cook the slice of potato in the microwave above the stove and pick it back up.', 'Turn left and go to the fridge.', 'Put the slice of potato to the left of the potato on the shelf in the fridge.']
#
# Annotation 2
# Put a slice of heated potato in the fridge.
# ['Turn left and go to the side of the island without the sink.', 'Pick up the gray knife from the table. ', 'Turn left and go to the black trash can on the floor at the end of the island.', 'Slice the potato on the right in the trash can. ', 'Place the knife in the trash can. ', 'Take out one slice of potato from the trash can. ', 'Turn left and go around the island to the microwave above the stove. ', 'Heat the potato slice in the microwave and take it out. ', 'Turn left and go to the refrigerator on the right. ', 'Place the potato slice in the refrigerator. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5954165059120786
# put a cooked slice of tomato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.5773502691896257
# put heat a slice of potato and place it in the fridge . the the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.335783404331301
# put a cooked slice the fridge .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.335783404331301
# put a cooked slice in the fridge
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 3.917372151449784e-155
# put a microwaved slice slice fridge
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.7941386679207173
# put a cooked slice of potato potato in the fridge .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 3.573006738452943e-155
# put a cut of potato
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a cooked slice of potato in the fridge .
# - Decoding by Sampling:
# BLEU score: 0.6113082296626929
# put a cooked slice of potato to the fridge .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_032434_013084_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Pan-None-CounterTop-10/trial_T20190908_032434_013084
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a cleaned pan on the counter.
# ['Move right, then turn left, go forward, face the stove on the left.', 'Pick up the dirty pan on the left of the stove. ', 'Turn around, bring the dirty pan to the sink.', 'Wash the pan in the sink with water. ', 'Bring the pan back to the counter left of the stove. ', 'Put the pan on the counter next to the toaster. ']
#
# Annotation 1
# drop a clean pan on the table
# ['move forward towards the gas', 'pick up the pan', 'turn around and head to the sink', 'rinse the pan inside the sink', 'turn around to the table', 'drop the pan on the table']
#
# Annotation 2
# Wash the pan in the sink, put the pan on the counter
# ['Head across the kitchen to the stove', 'Pick up the pan from the stove', 'Head back to the left to the sink', 'Put the pan in the sink', 'Turn on the water for 4 seconds, Take the pan out of the sink', 'Turn around, put the pan on the counter']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 4.0636244822144107e-78
# put a clean and place in pan , put it pan pan , in the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1231644147255971e-154
# put a clean pot on the stove .
# - Decoding by Sampling:
# BLEU score: 7.711523862191631e-155
# put a pan and put it on on
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 5.639368026146393e-78
# put a clean on the the counter . bin pan .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.6865890479690392
# put a clean pan on the counter counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.33932513407933634
# put the pan and place it back on the counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9036020036098449
# put a clean pan on the counter .
# - Decoding by Sampling:
# BLEU score: 0.7400828044922853
# put a clean pan on the counter counter
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_173120_648218_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Egg-None-SinkBasin-10/trial_T20190907_173120_648218
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Pick up the egg, put it in the refrigerator and then put it in the sink.
# ['Turn around, walk forward, turn to the left to face the counter top', 'Pick up the egg on the counter top behind the trophy.', 'Turn around and face the refrigerator, open the refrigerator door', 'Place the egg inside the refrigerator by the tomato. Close the door, then open the door and pick the egg up. ', 'Turn to the right, walk forward, turn to the right to face the sink. ', 'Place the egg in the sink in front of the white bowl.']
#
# Annotation 1
# Put a cold egg in the sink.
# ['Turn around and stand in front of the toaster.', 'Pick up the egg to the right of the toaster.', 'Turn left and go to the fridge.', 'Chill the egg and pick it up again.', 'Turn right and then go to the sink on your right.', 'Put the egg in the sink.']
#
# Annotation 2
# Chill an egg and put it in the sink
# ['Turn around and walk forwards before turning left to face the statue', 'Pick up an egg from off of the kitchen counter', 'Turn to your left and maneuver to face the fridge', 'Open the fridge, put the egg in to chill for a few seconds and then take it back out', 'Turn right and walk into the kitchen until you face the sink', 'Place the cold egg in the sink']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a egg egg in the sink .
# - Decoding by Sampling:
# BLEU score: 4.560736619621221e-78
# put cool egg and put , it the counter table
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a chilled egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a chilled egg in the sink .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a chilled egg in the sink .
# - Decoding by Sampling:
# BLEU score: 7.8302522937563e-155
# put a cooled egg inside the sink
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5247357977607321
# put a chilled egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.5247357977607321
# put a chilled egg in the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 6.227170448085464e-155
# put a cooled egg inside a sink
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 6.8489908526642754e-155
# put an egg from the counter to place an egg
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# - Decoding by Sampling:
# BLEU score: 0.8824969025845955
# put a cold egg in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# WORST train_sanity
worst_train_sanity_res = examine_sampled_tasks(sampled_task_ids=ranked_train_sanity_ids_worst_10, epoch_list=train_sanity_epoch_list, split='train_sanity')
# Out:
# SPLIT: train_sanity
#
#
#
# TASK : trial_T20190908_042518_905827_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Watch-None-FloorLamp-205/trial_T20190908_042518_905827
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Turn off the floor lamp with a watch in hand.
# ['Turn right, walk forward a few steps before hanging a right at the ottoman, walk behind the burgundy chair, then walk a few steps forward and face the table that is on your left. ', 'Pick up the watch that is closest to you. ', 'Turn around to face the wall, walk forward to the wall, then make a right to walk to the floor lamp. ', 'Turn off the lamp that is in front of you.']
#
# Annotation 1
# Examine a watch by the dim natural light of a living room.
# ['Turn right, walk toward the fireplace, turn right and walk to the dining table.', 'Pick up the watch on the table that is closest to the laptop.', 'Turn around and walk to the floor lamp that is to the left of the red sofa.', 'Turn off the lamp.']
#
# Annotation 2
# pick up watch from table, turn off lamp
# ['turn right walk to the end of the rug, turn right walk until you pass the couch, turn right walk until you reach the edge of the couch, turn left walk until you reach the chair, turn left to face the table', 'pick up watch in front of the remote', 'turn around walk until you reach wall, turn right walk until you reach lamp', 'look up, turn off lamp']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5280972216470737
# examine a watch by the light of a floor lamp .
# - Decoding by Sampling:
# BLEU score: 4.755897562004732e-78
# examine at a watch by of a lamp
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.35930411196308415
# turn a watch by the light of a a lamp room .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.5923033072023249
# turn at a watch by the light light of a living room .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.3716723368203945
# turn off a lamp with watch in hand .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 6.646444782720929e-155
# turn a watch while turning off a lamp
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.9306048591020996
# turn a watch by the dim natural light of a living room .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.37097233136825053
# turn at a watch by the light of a lamp .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.9306048591020996
# turn a watch by the dim natural light of a living room .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.4366835442847812
# turn off a of a living next turn off the floor lamp
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.863722645159635e-155
# turn off a lamp while holding a watch .
# - Decoding by Sampling:
# BLEU score: 0.7725505949016372
# turn up watch from table , turn off lamp
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_185723_946017_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-22/trial_T20190908_185723_946017
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'SliceObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Cook  a potato slice and put it in the fridge
# ['Turn right, go forward a bit, turn around and go to the table', 'Pick up the knife on the table', 'Turn right and go to the counter', 'Slice the potato on the counter', 'Move to the left in front of the microwave', 'Put the knife in the microwave', 'Move to the right a bit', 'Pick up a slice of potato', 'Move to the left in front of the microwave', 'Put the potato slice in the microwave, start the microwave, wait, pick up the potato slice from the microwave', 'Turn right, go forward a bit, turn right, go forward, turn left and go to the fridge', 'Put the potato slice in the fridge']
#
# Annotation 1
# To heat a potato slice and place it in the fridge.
# ['Turn left to face the knife on the table.', 'Pick up the knife on the table.', 'Turn right and walk across the room to face the potato on the counter.', 'Cut the potato on the counter into slices.', 'Take a step to the left to face the microwave.', 'place the knife in the microwave.', 'Take a step to the right to face the potato on the counter.', 'Pick up a slice of potato on the counter.', 'Take a step to the left to face the microwave.', 'Heat the potato slice in the microwave and remove it.', 'Turn right and walk across the room to face the fridge.', 'Place the potato slice in the fridge.']
#
# Annotation 2
# Put the cooked potato slice into the Refrigerator
# ['look down and turn right then walk towards the window then turn right towards the table', 'take the knife off of the table ', 'Carry the knife to the right', 'Cut the potato with the knife', 'turn to the left and walk towards the wall', 'turn towards the right  and open the microwave place the knife in the microwave', 'Close the microwave and turn to the right', 'turn left towards the counter and pick up a potato slice', 'turn left with the potato slice then turn right towards the microwave', 'place the potato slice in the microwave then close and start the microwave open the microwave', 'pull the potato slice out and turn right the left towards the window then right towards the refrigerator', 'Open the refrigerator and place potato slice in. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45966135761245924
# put a cooked potato slice in the fridge .
# - Decoding by Sampling:
# BLEU score: 5.095744247519182e-78
# put a cooked potato slice in place in . the fridge
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.45966135761245924
# put a cooked potato slice in the fridge .
# - Decoding by Sampling:
# BLEU score: 3.980096073289859e-78
# put away cooked potato slice in
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 6.70637658081224e-78
# put a potato of potato and place it the fridge .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 5.987588875766468e-78
# put a cooked potato slice in the refrigerator
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 0.3356891925037239
# put a cooked potato of potato in the fridge .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 8.014508691042773e-155
# put a potato of potato and the microwave .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 0.4863383168079943
# put a potato , cook a slice and put it in the refrigerator
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 0.45966135761245924
# put a cooked potato slice in the fridge .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 0.9234732618882052
# put heat a potato slice and place it in the fridge .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.975386110402101e-155
# put a cooked slice of potato in the refrigerator .
# - Decoding by Sampling:
# BLEU score: 0.2589372963482687
# put a potato slice and the microwave , put the potato in the refrigerator
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_224412_871995_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-ToiletPaper-None-CounterTop-417/trial_T20190906_224412_871995
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put an empty roll as well as an full roll of toilet paper on the bathroom counter.
# ['Move to the toilet to the left of the shower', 'Pick up the toilet paper roll to the left of the toilet', 'Move to the counter in between the two sinks', 'Put the roll onto the counter', 'Move to the same toilet again', 'Pick up the full toilet paper roll from the shelf above.', 'Move to the counter in between the two sinks again', 'Put the full roll behind the empty one on the counter']
#
# Annotation 1
# place two toilet rolls (one used, one new) on to the counter with two sinks
# ['Turn left and go to the toilet', 'pick up the toilet roll off the ground', 'turn right and go to the counter with two sinks', 'put the toilet roll on to the counter between the two sinks', 'turn left and go to the toilet', 'pick up the toilet roll that is on the water tank of the toilet', 'turn right and go to the counter with two sinks', 'place the toilet roll on the sink behind the used toilet roll and between two sinks']
#
# Annotation 2
# Bring toilet paper to counter.
# ['Move over to the toilet.', 'Pick up empty toilet paper roll on the floor. ', 'Bring empty roll to the sink. ', 'Put empty roll on the counter between the sinks. ', 'Move over to the toilet. ', 'Pick up toilet paper from toilet tank lid. ', 'Bring toilet paper over to counter. ', 'Put toilet paper on counter next to soap. ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6223329772884784
# put a roll of toilet paper on the counter .
# - Decoding by Sampling:
# BLEU score: 7.241926111174567e-155
# put a roll on on the . the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.537284965911771
# put toilet paper on the counter .
# - Decoding by Sampling:
# BLEU score: 0.5558391766749284
# put toilet roll of toilet paper on the counter counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7598356856515925
# place two rolls of toilet paper on the bathroom counter .
# - Decoding by Sampling:
# BLEU score: 0.3814165616365676
# place two rolls paper rolls on the bathroom counter
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2969185543721047e-154
# put toilet paper rolls on the counter .
# - Decoding by Sampling:
# BLEU score: 1.2248038575119736e-154
# put toilet paper rolls on the counter counter . two sinks
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2969185543721047e-154
# put toilet paper rolls on the counter .
# - Decoding by Sampling:
# BLEU score: 8.15394372921771e-155
# put toilet paper rolls sitting toilet on on
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
# - Decoding by Sampling:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
# - Decoding by Sampling:
# BLEU score: 8.443982041183043e-155
# put toilet paper rolls the .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
# - Decoding by Sampling:
# BLEU score: 0.6731821382417487
# put toilet paper to counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
# - Decoding by Sampling:
# BLEU score: 3.3239943607534095e-78
# put toilet empty roll and a toilet paper roll on the the bathroom counter
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4417918226831577
# put toilet paper rolls on the bathroom counter
# - Decoding by Sampling:
# BLEU score: 9.487289885028994e-155
# put toilet paper rolls with on the paper . countertop counter
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.133422688662942e-154
# put toilet paper rolls on bathroom counter
# - Decoding by Sampling:
# BLEU score: 7.738198552375147e-155
# put toilet empty roll and a full roll on the counter . hanger sinks
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_011730_702236_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Pillow-None-ArmChair-206/trial_T20190909_011730_702236
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a pillow on a chair.
# ['Turn left and walk to the couch ahead.', 'Pick up the blue pillow from the left side of the couch.', 'Turn right, head to the wall to the right and turn left to face the blue chair.', 'Put the pillow on the cushion of the chair to the left of the keys.']
#
# Annotation 1
# Carry the pillow to put on the chair.
# ['Look down and turn to the left and take one step, then turn to the right and take one step, then turn left and walk to the couch and look down.', 'Pick up the blue pillow from the left side of the couch.', 'Look up and turn right and take two steps, then turn right and walk across the room, then turn left and walk to the chair. ', 'Place the blue pillow on the chair.']
#
# Annotation 2
# place blue pillow on blue chair
# ['turn left, go to left end of blue couch', 'pick up blue pillow from left end of blue couch', 'turn around, go to blue chair in corner to the left', 'place blue pillow on blue chair in corner']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7952707287670506
# place a pillow on the chair .
# - Decoding by Sampling:
# BLEU score: 0.7952707287670506
# place a pillow on the chair .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5946035575013605
# put a pillow on the chair .
# - Decoding by Sampling:
# BLEU score: 3.85155751147022e-78
# put a pillow on an on onto the blue of the room chair . .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2967862918337585e-231
# move pillow from couch to chair
# - Decoding by Sampling:
# BLEU score: 1.04198122363916e-154
# move the pillow from the blue chair
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2967862918337585e-231
# move pillow from couch to chair
# - Decoding by Sampling:
# BLEU score: 1.046685547397662e-154
# move up the pillow and place it on the blue chair .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3478743256634661e-154
# put the pillow on the blue chair
# - Decoding by Sampling:
# BLEU score: 1.0595307178088398e-154
# put the pillow on the couch on onto the blue chair
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3478743256634661e-154
# put the pillow on the blue chair
# - Decoding by Sampling:
# BLEU score: 9.860044343608264e-155
# put the pillow on the couch on the blue arm chair
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.846481724890614
# place blue pillow on blue chair
# - Decoding by Sampling:
# BLEU score: 1.3934875572055278e-231
# place pillow from couch to chair
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3478743256634661e-154
# put the pillow on the blue chair
# - Decoding by Sampling:
# BLEU score: 1.3934875572055278e-231
# put pillow from couch to chair
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.846481724890614
# place blue pillow on blue chair
# - Decoding by Sampling:
# BLEU score: 8.761982757198608e-155
# place blue from blue couch on chair
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3478743256634661e-154
# put the pillow on the blue chair
# - Decoding by Sampling:
# BLEU score: 9.342086335797231e-155
# put up the cushion from place it on the blue chair chair .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3478743256634661e-154
# put the pillow on the blue chair
# - Decoding by Sampling:
# BLEU score: 6.269681580989379e-78
# put the pillow to place on the blue chair .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_202335_083129_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-CellPhone-Box-Desk-204/trial_T20190907_202335_083129
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# pick up cell phone from glass table in living room, put in box, put box onto black desk
# ['turn right, walk around table, turn left, walk around table, turn left, walk around table, turn right and walk out of dining room, walk straight into living room, turn right at glass table, turn left and face glass table with two red chairs behind', 'pick up cell phone from on the table', 'walk around the glass table and face box on grey couch in front', 'put phone into the box on the couch', 'pick up the box from on the couch', 'turn left, and walk straight to black desk, face black desk', 'put box on desk to the left of the hand statue']
#
# Annotation 1
# Box up a smart phone and place it on the desk
# ['Make your way around the wooden table, then exit the room and proceed straight until you reach the glass table', 'pick up the smart phone on the glass table', 'Go around the glass table, then walk straight to the large grey couch with a cardboard box on it', 'place the phone in the box', 'pick up the box with the phone in it', 'move left until you reach the wall, then right to face the black desk', 'place the box on the black desk to the right of the computer']
#
# Annotation 2
# Move a box with a phone in it to the desk.
# ['Move around the table and through the doorway to stand between the coffee table and two chairs. ', 'Pick up the cell phone from the coffee table. ', 'Carry the cell phone to stand in front of the open box on the sofa. ', 'Place the cell phone inside the box on the sofa. ', 'Pick up the box with the phone in it from the sofa. ', 'Carry the box with the phone in it across the room to stand in front of the black desk. ', 'Place the box with the phone in it on top of the black desk.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7972714256536028
# put a box with a phone in it on the desk .
# - Decoding by Sampling:
# BLEU score: 0.2819489698613971
# put a box with a on the in the cabinet .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6175637907926896
# put a box with a phone in it on the black table .
# - Decoding by Sampling:
# BLEU score: 7.600793306264725e-78
# put a box with the phone in it on the black .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.373421126552421
# place a box with a cell phone in it on a desk
# - Decoding by Sampling:
# BLEU score: 4.772234596095121e-78
# place a box box containing a cell phone on a on the desk
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9131007162822624
# move a box with a phone in it to the desk
# - Decoding by Sampling:
# BLEU score: 0.25336549464486463
# move a box box containing a cell in a box on move it to the desk
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 4.644924339981128e-78
# move a phone from table table to the desk
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 6.9104016595143256e-155
# move up a a cell up and a and a living bring in a to table up the desk
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 0.4933885363281902
# move a box with a cell phone in it on a desk
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 0.4933885363281902
# move a box with a cell phone in it on a desk
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 6.668454445645829e-155
# move up a cardboard and move it in the box
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.693972364924616e-78
# move a box from a table to a desk
# - Decoding by Sampling:
# BLEU score: 0.6269249514920864
# move up a cell phone and place it on the desk
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190911_191424_759852_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-CreditCard-Box-SideTable-205/trial_T20190911_191424_759852
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a box with a credit card in it, on top of the table beside the TV cabinet.
# ['Turn around, walk straight, turn right near the lamp, walk straight, turn left at the end of the couch, walk straight a little bit and turn left to go to the box on the couch. ', 'Pick up a credit card next to the box on top of the couch', 'Walk slightly to the right to be in front of the box. ', 'Put the credit car in the box. ', 'Pick up the box that has a credit card in it. ', 'Turn around and turn left to go to the table beside the TV cabinet. ', 'Put the box on top of the table. ']
#
# Annotation 1
# Place a box with a credit card in it on a table
# ['Go to the sofa', 'Pick up a credit card from the sofa', 'Go to the box on the right of the sofa', 'Place the credit card in the box', 'Pick up the box', 'Go to the small round table', 'Place the box on the table']
#
# Annotation 2
# Move the box on the sofa to the round table.
# ['Turn and go to the sofa.', 'Pick up a credit card on the sofa.', 'Turn right and go to the box on the sofa.', 'Put the credit card in the box on the sofa. ', 'Pick up the box on the sofa. ', 'Turn and go to the round table by the television.', 'Put the box on the round table.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7598356856515925
# place a box with a credit card in it on the white table .
# - Decoding by Sampling:
# BLEU score: 0.6182518852201093
# place a box with a credit card in put it in a table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0543752260658088e-154
# put the box with the credit card on the table
# - Decoding by Sampling:
# BLEU score: 6.432062707336974e-78
# put a box in the box , move the box to the table
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.28897629773533684
# move a box from the sofa to the table
# - Decoding by Sampling:
# BLEU score: 0.5586536422204545
# move a box with a card card in it on the round table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0543752260658088e-154
# put the box with the credit card on the table
# - Decoding by Sampling:
# BLEU score: 1.254338396921439e-154
# put the box with the credit card on it on the table
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 0.27629350710622463
# move a box on the sofa side table , move the table table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 3.7038967454966704e-78
# move a box with the table table ,
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 0.9234732618882052
# move a box with a credit card in it on a table
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 6.8123365342927024e-155
# move a box and under to the table
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 0.8091067115702212
# move a box with a credit card in it on a table table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.980096073289859e-78
# move a box and sofa to the table
# - Decoding by Sampling:
# BLEU score: 0.5041868819422426
# move a box with a credit card in it on on the table . the table of of the round .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_062121_532423_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Apple-Pan-DiningTable-18/trial_T20190908_062121_532423
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject', 'PickupObject', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a fry pan containing an apple, on the table.
# ['Walk across the room, towards the black, round table, then turn right and go to the stove. ', 'Pick up the fry pan on the front left corner of the stove. ', 'Turn to your left and go to the back of the black, round table.', 'Place the fry pan in front of the apple and tomato, on the black, round table, ', 'Pick up the apple, that is on a fork, on the black, round table. ', 'Place the apple on the fry pan. ']
#
# Annotation 1
# Put an apple in a pan on the table.
# ['Move forward, then turn right, go to the stove.', 'Pick up the front left pan on the stove. ', 'Bring the pan to the black table on the left. ', 'Put the pan on the table.', 'Pick up the apple on the table. ', 'Put the apple in the pan on the table. ']
#
# Annotation 2
# Putting a pan on the table with an apple on the pan.
# ['Walk over to the stove.', 'Grab the pan.', 'Walk over to the table.', 'Put the pan on the table.', 'Grab the apple.', 'Put the apple on the pan.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.49701504715895245
# put a pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.21305413619585087
# put a a pan pan pan table place it on the table . the trash .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5631101643283382
# put a apple on a pan on the table .
# - Decoding by Sampling:
# BLEU score: 4.510039708505753e-78
# put a apple on the black table .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6615360879944735
# put an apple on a pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.5216948600244291
# put an apple on in a pan on the black table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6615360879944735
# put an apple on a pan on the table .
# - Decoding by Sampling:
# BLEU score: 0.5418220425805959
# put a pan on a pan on the table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 6.677922026875118e-78
# put a apple in a on the table table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.4211813371894876
# put a pan on a table with an apple in the pan .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.5022573937283119
# put a apple in a pan on place the table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.5418220425805959
# put a pan on a pan on the table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.5261002868050687
# put a golden on a pan on the table .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.7321100278127648
# put a apple in a pan on the table .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.618846890203085e-78
# put a golden on the table , left of the apple .
# - Decoding by Sampling:
# BLEU score: 0.32069326294908396
# put a apple in the pan on the table . put the apple in the pan
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_143948_082471_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_cool_then_place_in_recep-Bread-None-CounterTop-16/trial_T20190908_143948_082471
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CoolObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'OpenObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put chilled bread on a counter.
# ['move to the table in the opposite corner of the room', 'pick up bread from the table', 'move to the fridge to the left from the sink', 'chill the bread in the fridge for a moment', 'move to the counter across from the sink', 'put the bread on the counter']
#
# Annotation 1
# Put the chilled bread on the kitchen counter
# ['Turn around and go as far as the door then turn left and go almost to the wall then turn right and go to the table and turn left', 'Pick up the loaf of bread in the middle of the table', 'Turn left and go towards the garbage can then turn left and go towards the door then turn right and go to the fridge', 'Put the bread on the top shelf in the fridge and wait a bit, then take the bread out of the fridge', 'Turn right, then turn right again and go to the counter', 'Put the bread on the counter']
#
# Annotation 2
# Chill bread and place it on the counter.
# ['Turn around and then to the left and go straight back. Turn to the right and face the white table on the left.', 'Pick up the bread from the center of the table.', 'Carry the bread and turn to the left. Find the fridge on the right.', 'Open the fridge and place the bread inside. Shut the door then open the door and take the bread out. Shut the door again.', 'Take the bread and turn around to the counter.', 'Place the bread on the counter.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8067207857557418
# put chilled bread on the counter .
# - Decoding by Sampling:
# BLEU score: 6.297987860748305e-78
# put chilled chilled loaf of bread on the counter counter .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.37150115998267197
# put a chilled loaf of bread on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4874812669237438
# put a bread on the counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.42728700639623407
# place a chilled loaf of bread on a counter .
# - Decoding by Sampling:
# BLEU score: 0.4099212498595153
# place a chilled on the counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.17862905677001e-78
# put a chilled loaf of bread on a kitchen counter .
# - Decoding by Sampling:
# BLEU score: 0.4874812669237438
# put a bread on the counter .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.17862905677001e-78
# put a chilled loaf of bread on a kitchen counter .
# - Decoding by Sampling:
# BLEU score: 0.2620251007173262
# put bread and bread to put on back on the kitchen counter
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.17862905677001e-78
# put a chilled loaf of bread on a kitchen counter .
# - Decoding by Sampling:
# BLEU score: 0.3759663529467017
# put bread and place it the fridge . some is on the counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.047284757449962e-78
# put a chilled loaf of bread on a kitchen counter
# - Decoding by Sampling:
# BLEU score: 0.7311104457090247
# put a chilled bread on the kitchen counter
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.047284757449962e-78
# put a chilled loaf of bread on a kitchen counter
# - Decoding by Sampling:
# BLEU score: 4.560736619621221e-78
# put a chilled loaf of bread on a kitchen .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.047284757449962e-78
# put a chilled loaf of bread on a kitchen counter
# - Decoding by Sampling:
# BLEU score: 0.591460168684858
# put cool a loaf of bread and place it on the counter .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.047284757449962e-78
# put a chilled loaf of bread on a kitchen counter
# - Decoding by Sampling:
# BLEU score: 0.42728700639623407
# put a chilled loaf of bread on a counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.17862905677001e-78
# put a chilled loaf of bread on a kitchen counter .
# - Decoding by Sampling:
# BLEU score: 0.5578002860768766
# put a bread on a counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190918_152439_600414_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Spoon-Bowl-SinkBasin-3/trial_T20190918_152439_600414
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'OpenObject', 'PutObject', 'PickupObject', 'CloseObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move the pot with a spoon in it to the sink.
# ['Turn right and go to the front of the counter on the left of the sink. ', 'Pick up the gray spoon on the counter.', 'Move over left to the cabinet below the counter with a gray plate on top.', 'Place the spoon inside the gray pot in the cabinet. ', 'Pick up the pot with the spoon in it. ', 'Move over right to the sink.', 'Place the pot with the spoon in it into the sink.']
#
# Annotation 1
# Place a bowl with a spoon inside the sink.
# ['Turn right then left towards the stove, then right towards the sink.', 'From the sink pick up the spoon in between two spatulas.', 'Turn left then head towards the stove, turn right then face the counter top', 'Open the cabinet door underneath the counter top then place the spoon inside the bowl.', 'Remove the pan from the cabinet then close the door. ', ' Turn right then head towards the sink.', 'Place the bowl in the sink on the right side.']
#
# Annotation 2
# Place a bowl with a spoon in a sink.
# ['Turn right, hang a left around the counter and walk to the sink on the right.', 'Pick up the spoon from the left side of the sink.', 'Turn left and hang a right at the stove to face the counter.', 'Open the lower cabinet under the counter and put the spoon inside the bowl.', 'Pick up the bowl with the spoon from inside the cabinet and close the door.', 'Turn right and walk to the sink on the left.', 'Put the bowl with the spoon inside the sink.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6340466277046861
# put a bowl with a spoon in it in the sink .
# - Decoding by Sampling:
# BLEU score: 4.566972108023278e-78
# put a bowl pan with put in the sink .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.6340466277046861
# put a bowl with a spoon in it in the sink .
# - Decoding by Sampling:
# BLEU score: 0.6340466277046861
# put a bowl with a spoon in it in the sink .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.710866788975034
# place a bowl with a spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.710866788975034
# place a bowl with a spoon in the sink .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.502658727004553
# place the bowl with a spoon in the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.502658727004553
# place the bowl with a spoon in the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.9234732618882052
# place the pot with a spoon in it to the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.502658727004553
# place the bowl with a spoon in the sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.4089601472043678
# place the bowl with a spoon in the sink into the sink .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.502658727004553
# place the bowl with a spoon in the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 0.502658727004553
# place the bowl with a spoon in the sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.225756395596991e-78
# place the bowl with the spoon in the sink .
# - Decoding by Sampling:
# BLEU score: 4.376214235595946e-78
# place the bowl with the spoon in the , in knife the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_123042_656948_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Plunger-None-Cabinet-417/trial_T20190907_123042_656948
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a plunger in a cabinet.
# ['Go left to stand in front of the toilet.', 'Pick the red plunger up from the floor.', 'Turn around and go left to stand in front of the sink.', 'Open the lower, right cabinet door and put the plunger in and shut the door.']
#
# Annotation 1
# Place the plunger underneath the sink in the cabinet
# ['turn to the left and go forward to the toilet', 'pick up the plunger on the right side of the toilet', 'turn completely around facing the other direction and go forward a few steps and turn to the left and go forward to the sink cabinet', 'open the right hand side door of the sink cabinet and place the plunger inside and close the door']
#
# Annotation 2
# Take the plunger next to the toilet, put it under the sink
# ['Turn to the left, walk to the toilet', 'Pick up the plunger next to the toilet', 'Turn around, walk to the sink on the left', 'Put the plunger in the cabinet']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.8668778997501817
# put a plunger in a cabinet .
# - Decoding by Sampling:
# BLEU score: 9.455927443711748e-232
# put plunger from the the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5797161910562567
# put the plunger underneath the sink .
# - Decoding by Sampling:
# BLEU score: 0.42728700639623407
# put the plunger underneath the the cabinet below
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.309682159925016e-78
# put the plunger in the cabinet under the sink
# - Decoding by Sampling:
# BLEU score: 1.2778269941762074e-231
# put plunger from counter into the bathroom
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 6.15590665446878e-78
# put the plunger in the cabinet cabinet
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 0.5066641486392105
# put a plunger in the cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 5.929498746342409e-78
# put the plunger in the in the cabinet cabinet
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 0.4234197579236933
# put a plunger in the cabinet . a sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 4.945830350570697e-78
# put the away . a cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 5.639368026146393e-78
# put the plunger in the cabinet . a left sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 6.237049021538533e-232
# put the away .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.85232962827326e-78
# put the plunger in the cabinet
# - Decoding by Sampling:
# BLEU score: 0.4063798282013443
# put the plunger from the floor , put it under the cabinet
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# WORST valid_seen
worst_valid_seen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_seen_ids_worst_10, epoch_list=valid_seen_epoch_list, split='valid_seen')
# Out:
# SPLIT: valid_seen
#
#
#
# TASK : trial_T20190908_001247_096796_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-Plate-None-DiningTable-28/trial_T20190908_001247_096796
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Warm a plate and place it on the table.
# ['Turn to the right and move towards the range, then turn to the right and move to the dishwasher in front of the window.', 'Pick up the gray patterned plate from the counter to the left of the toaster and in front of the window.', 'Turn to the left and then move to and face the range.', 'Open the microwave above the range, place the plate on top of the plate in the microwave, microwave both plates, then open up the microwave and remove the gray patterned plate.', 'Turn around and move towards the kitchen door then turn left and move to the black table in the corner.', 'Place the gray patterned plate on the table between the gray plate and the blue bowl.']
#
# Annotation 1
# To heat a plate and place it on the kitchen table.
# ['Turn around and walk across the room and face the counter to the left of the toaster.', 'Pick up the plate on the counter.', 'Turn to the left and walk over to face the microwave above the stove.', 'Heat the plate and remove it from the microwave.', 'Turn around and walk across the room and turn left to face the kitchen table.', 'Place the plate to the right of the plate already on the table.']
#
# Annotation 2
# get a plate, warm it in the microwave and take it to the table.
# ['walk over to the counter where the dishwasher is', 'pick up the paper plate from the counter', 'take the plate to the microwave above the stove', 'put the plate in the microwave and then take it back out', 'take the plate over to the small green table', 'set the plate on the table to the right of the plate that is already there']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.27329052280893856
# put a warm plate on the table .
# - Decoding by Sampling:
# BLEU score: 5.189523011169849e-232
# put a warm plate on
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2629588998147059
# put a warmed plate on the table .
# - Decoding by Sampling:
# BLEU score: 5.17862905677001e-78
# put a warmed plate on the microwave . the table .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.527642039019229e-78
# warm the plate in the microwave , put the plate on the table
# - Decoding by Sampling:
# BLEU score: 4.987732975106126e-78
# warm the plate in the microwave . put it on on the table table table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.527642039019229e-78
# warm up plate in the microwave , put the plate on the table
# - Decoding by Sampling:
# BLEU score: 5.527642039019229e-78
# warm the tray in the microwave , put the plate on the table
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 2.851863455603975e-78
# warm up plate in the microwave
# - Decoding by Sampling:
# BLEU score: 0.3264971028628052
# warm up plate in the microwave then put it on the table
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 8.945003936224672e-232
# warm up up by place on table
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 4.648174375417067e-78
# warm up plate in the microwave then put it the table table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 0.2936697784628213
# warm a warmed plate on the table .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 5.502798075292677e-78
# warm up plate in the microwave then put it on on the table table
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 4.337579510280189e-78
# warm up plate tray in set on the table table table .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.189523011169849e-232
# warm up plate in microwave
# - Decoding by Sampling:
# BLEU score: 2.851863455603975e-78
# warm up plate in the microwave
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_005709_232606_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-LettuceSliced-None-CounterTop-19/trial_T20190909_005709_232606
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'SliceObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'PutObject', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a washed piece of lettuce on the counter by the sink.
# ['Go to the counter to the left of the toaster.', 'Pick up the butter knife on the counter.', 'Turn to the counter on the left of the sink.', 'Slice the lettuce on the counter.', 'Move away from the counter.', 'Set the butter knife in front of the lettuce on the counter.', 'Move back to the counter to the left of the sink.', 'Pick up a slice of lettuce.', 'Move over to the sink on the right.', 'Wash the lettuce in the sink.', 'Take the cleaned lettuce to the counter to the left of the sink.', 'Set the lettuce down on the counter.']
#
# Annotation 1
# Put a clean slice of lettuce on the counter.
# ['Turn right, go towards the sink, turn left and go to the counter.', 'Pick up the knife on the counter.', 'Turn right and go to the lettuce beside the sink.', 'Cut the lettuce on the counter.', 'Turn left and then turn back around.', 'Put the knife on the counter in front of the lettuce.', 'Turn left towards the counter.', 'Pick up a slice of lettuce.', 'Turn right and go to the sink.', 'Put the lettuce in the sink, rinse it and pick it back up.', 'Turn left and then turn around.', 'Put the slice of lettuce on the counter by the salt.']
#
# Annotation 2
# put a clean slice of lettuce on to the counter
# ['move forward facing the counter that is to the right of the stove', 'pick up the butter knife that is on the counter to the right of the stove', 'turn to the right and move slightly to the right to face the head of lettuce on the counter', 'cut the head of lettuce that is on the counter with the knife', 'turn to the right staying in place', 'put the knife on to the counter in front of the head of lettuce', 'turn to the left to face the counter with the head of lettuce', 'pick up the end slice of the lettuce from the counter', 'move to the right to face the sink', 'put the lettuce slice in to the sink, turn on the faucet to rinse off the slice, turn off the water and pick up the lettuce slice from the sink', 'move to the left to face the counter to the left of the sink and to the left of the remaining head of lettuce and turn to the right', 'put the slice of lettuce on to the counter to the right of the sink next to the salt shaker']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.611185193027874e-78
# put a clean piece of lettuce in the sink .
# - Decoding by Sampling:
# BLEU score: 4.0383967532411216e-78
# put a a slice , the counter .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.9048374180359595
# put a clean slice of lettuce on the counter .
# - Decoding by Sampling:
# BLEU score: 0.9048374180359595
# put a clean slice of lettuce on the counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3229365231336651
# put a piece of lettuce on a counter .
# - Decoding by Sampling:
# BLEU score: 0.3229365231336651
# put a piece of lettuce on a counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 0.283130219764777
# slice the lettuce to put it on the counter . the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 0.30541450699432376
# slice a piece of lettuce on a counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 6.887578243315168e-155
# slice a , wash it , put in on a counter .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 0.42268392163412416
# slice knife to clean slice of lettuce on sink .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 6.158669933793385e-155
# slice a lettuce on a counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 0.35084396956386854
# slice a piece of lettuce on a counter . the sink .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.324264127738903e-232
# slice a lettuce , wash a slice
# - Decoding by Sampling:
# BLEU score: 3.9543559515104263e-78
# slice a lettuce , wash it , put it on the counter counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190906_181531_703961_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-Vase-None-Desk-204/trial_T20190906_181531_703961
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the yellow and blue jars on the black desk.
# ['Turn around and stand in front of the white shelves.', 'Pick up the blue jar from the white shelf.', 'Turn around and walk over to the black desk with the box on top of it.', 'Put the Blue jar next to the open box.', 'Turn around and walk to the black entertainment center.', 'Pick up the yellow jar from the entertainment center.', 'Walk over to the black desk. ', 'Put the yellow jar on the black desk next to the blue jar.']
#
# Annotation 1
# Put all the vases on the black desk.
# ['Turn around and face the shelves.', 'Pick up the blue vase on the bottom shelf.', 'Turn right, go towards the couch, turn right, walk in front of the black desk.', 'Put the blue vase on the desk to the right of the box.', 'Turn around, walk to the television stand.', 'Pick up the yellow vase on the left side of the television stand.', 'Turn around, walk to the black desk.', 'Put the yellow vase on the black desk to the right of the blue vase.']
#
# Annotation 2
# Place the yellow and blue vase on the table.
# ['Turn left and left again to face the shelf.', 'Pick up the vase from the lower shelf.', 'Turn around and walk to the black table to your right.', 'Place the vase on the table.', 'Turn around and walk to the television stand to your right.', 'Grab the yellow vase on the table.', 'Turn around and take the yellow vase to the table to your left.', 'Place the yellow vase next to the blue vase on the table.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.7166792038564594e-78
# place two vases on the dresser .
# - Decoding by Sampling:
# BLEU score: 5.3981964394227255e-155
# place two vases in on the dresser
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.3050004770504307e-78
# put two vases on the desk .
# - Decoding by Sampling:
# BLEU score: 4.337579510280189e-78
# put two vases on the desk . the of the desk .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.3981964394227255e-155
# move two vases to the desk .
# - Decoding by Sampling:
# BLEU score: 4.1131816762341247e-78
# move two vases on the desk .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 9.064562738204195e-155
# move two vases on a desk on the desk . .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 1.0032743411283238e-231
# move two vases to a dresser dresser .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 6.005740822548667e-155
# move two vases on a desk dresser .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 6.419573613943772e-155
# move two vases on a desk .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 8.676910262183261e-232
# move two vases to a top .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 9.602579706020654e-232
# move two vases to the top .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.676910262183261e-232
# move two vases to a dresser .
# - Decoding by Sampling:
# BLEU score: 1.2387197655613557e-231
# move two vases bottle to the dresser dresser .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_122858_883968_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-406/trial_T20190908_122858_883968
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put an empty toilet paper roll on a toilet paper holder.
# ['Turn left and then left again to stand in front of the tub.', 'Pick the empty toilet paper roll up from the side of the tub.', 'Turn around and cross the room and then go right to face the toilet paper holder on the wall to the left of the toilet.', 'Put the empty roll on the toilet paper holder.']
#
# Annotation 1
# Pick up the toilet paper roll and put it by the toilet.
# ['Turn left keeping the black door on your right and go to the sink across the room from it.', 'Pick up the toilet paper roll in the sink.', 'Turn around and go towards the black door turning right to get to the toilet.', 'Put the toilet paper roll on the hanger next to the toilet on the left.']
#
# Annotation 2
# Put an empty toilet paper roll on the toilet paper dispenser.
# ['Turn around and go across the bathroom to the bathtub. ', 'Pick up the empty toilet paper roll on the edge of the bathtub. ', 'Turn back around and go to the toilet paper holder, on the wall, to the left of the toilet. ', 'Place the empty toilet paper roll on the toilet paper holder, hanging from the wall.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.631011170724675e-232
# put a candles in a trash can .
# - Decoding by Sampling:
# BLEU score: 2.841924583559539e-78
# put a candles on the toilet corner .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.6316562309066614e-78
# put the toilet paper on the holder .
# - Decoding by Sampling:
# BLEU score: 4.909777631374571e-155
# put a toilet of the to the trash trash
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.5658266414297971
# move a roll paper roll on a toilet paper holder .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0733342226651737e-231
# move a roll of toilet to a grey container .
# - Decoding by Sampling:
# BLEU score: 2.421189997705526e-78
# move a roll of the toilet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.26518122980477765
# move the toilet paper roll from the tub , put it on the toilet trash
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.3003918358815796
# move a empty roll paper roll to the toilet paper holder .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.2910042507378282
# move a tube tube in a toilet paper holder .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.42818185319516083
# move tub toilet paper roll on an roll paper roll holder on a toilet paper holder .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.3061587630360045
# move a roll of roll to a toilet paper holder .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.26176079745548464
# move a roll to the toilet paper holder .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.537683887743056e-232
# move a roll of toilet to a container .
# - Decoding by Sampling:
# BLEU score: 0.26176079745548464
# move a roll to the toilet paper holder .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_055649_717880_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-SoapBar-None-GarbageCan-418/trial_T20190909_055649_717880
# Number of subgoals : 9
# https://youtu.be/C9gkb77sF14
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two bars of soap into the trash can.
# ['Make a left to reach the sink.', 'Pick up the pink soap next to the sink on the left.', 'Turn around and walk to the trash can next to the toilet.', 'Put the pink soap in the trash can.', 'Turn around to walk to the sink.', 'Pick up the bar of pink soap in the sink basin.', 'Turn around the walk to the trash can.', 'Put the other bar of pink soap in the trash can.']
#
# Annotation 1
# Put two soap in the trash bin
# ['Turn right then face the sink  counter on your left', 'Pick up the soap on the counter', 'Turn left then head to the trash bin ', 'Put the soap in the trash bin', 'Turn left then head to the sink ', 'Pick up the soap in the sink', 'Turn around then head to the trash bin ', 'Put the soap in the trash bin']
#
# Annotation 2
# Putting two bars of soap in the trash can
# ['Turn around and go to the left of the sink', 'Grab the bar of soap off of the counter', 'Turn around and go to the trash can', 'Put the soap in the trash can', 'Turn around and go to the sink', 'Grab the bar of soap out of the sink', 'Turn around and go to the trash can', 'Put the soap in the trash can']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash bin
# - Decoding by Sampling:
# BLEU score: 1.0
# put two bars of soap in the trash
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.20149416157064579
# put to two soap pink place out in soap sponges in the trash can bin .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 6.458654791343583e-155
# put away bars bars the trash
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.0
# put two bars of soap in the trash can .
# - Decoding by Sampling:
# BLEU score: 0.7825422900366437
# put away bars of soap into the trash can .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 5.094696780347207e-155
# throw away two soap bars
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 0.5706745777055999
# throw two soap in the trash can . the . .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.5
# place two bars of in the trash can
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 0.32466791547509893
# throw two bars in in bin in the trash can
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.21972813874997157
# place move two bars in and the shelf and and the trash can .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.051402097550211e-78
# throw away two soap bars into the trash bin
# - Decoding by Sampling:
# BLEU score: 8.909555824566607e-155
# throw away two bars in into the small black bin .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# place two pink sponges in black bin
# - Decoding by Sampling:
# BLEU score: 0.6989307622784944
# place two bars of soap in the trash bin bin .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_034437_413802_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-WateringCan-None-FloorLamp-212/trial_T20190907_034437_413802
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Turn on the lamp while holding the teapot.
# ['Turn around and move to the wall, turn left and move forward to the edge of the TV, turn right.', 'Pick up the teapot on the bottom shelf.', 'Turn left and move forward all the way to the trash bin, turn left and move all the way to the lamp.', 'Turn on the lamp.']
#
# Annotation 1
# Turning on a lamp
# ['Go right to the TV stand across the room', 'Pick up the watering can from the TV stand', 'Turn left and walk to the lamp across the room', 'Turn on the lamp']
#
# Annotation 2
# Turn a light on while holding a white object.
# ['Go right and face the right side of the television.', 'Pick up the white object from the shelf below the television.', 'Turn around and walk past the black table to the right and approach the green lamp with the pink stand.', 'Turn the light on.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.480360213743594e-155
# place a watering can on the black table .
# - Decoding by Sampling:
# BLEU score: 6.513869329968086e-155
# place a phone and move it on on the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.727983169734501e-78
# turn on a lamp while holding a tea pot
# - Decoding by Sampling:
# BLEU score: 6.887578243315168e-155
# turn a tea pot by lamp of a tall lamp .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 3.3744794443119017e-78
# examine the watering can by the tv , turn on the floor lamp
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 1.4637115948630222e-231
# examine the watering can by the light of the tall lamp .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 3.3744794443119017e-78
# examine the watering can , the tv , turn on the floor lamp
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 1.4637115948630222e-231
# examine the watering can by the light of the floor lamp .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 5.74867560479262e-155
# examine the watering can from the tv and turn the on the floor lamp . the .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 0.537284965911771
# examine on the lamp while holding the watering can .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4147351699132998e-231
# examine the watering can by the light of the floor lamp
# - Decoding by Sampling:
# BLEU score: 3.3744794443119017e-78
# examine the watering can , the tv , turn on the floor lamp
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_154618_526741_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-CD-None-DeskLamp-302/trial_T20190907_154618_526741
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Grab the disc from the shelf, turn on the lamp on the cabinet
# ['Walk to the table, turn right', 'Grab the disc from the shelf above the table', 'Turn right, walk to the cabinet by the door', 'Turn on the lamp on the cabinet']
#
# Annotation 1
# Examine a CD under a lamp.
# ['Walk to the desk in front of you and turn left towards the shelf above it ', 'Pick up the CD that is laying on the shelf', 'Turn around and walk to the lamp sitting on the stand across the room', 'Turn on the lamp that is on top of the stand']
#
# Annotation 2
# take a cd from the desk to the small table
# ['turn to the right and stand in front of the desk', 'pick up the cd that is on the desk', 'turn to the right and walk towards the small table by the door', 'face the small table that has a lamp on it']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.836070671413084e-78
# examine a cd by the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 0.34329452398451965
# examine the cd turn and turn on the lamp
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1231644147255971e-154
# turn on a lamp while holding a cd
# - Decoding by Sampling:
# BLEU score: 9.212002349967284e-155
# turn a cd by the light of a small lamp .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.661032518640916e-78
# look at the cd under the light of a lamp .
# - Decoding by Sampling:
# BLEU score: 4.394319820046742e-78
# look a cd by the light of a lamp .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 3.5608750821685696e-78
# look at the disk in the light on the lamp . the dresser .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# look at the cd in the light .
# - Decoding by Sampling:
# BLEU score: 4.661032518640916e-78
# look at the cd in the light on the lamp .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 1.4875195904069663e-231
# look at the disk in the light . the
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 7.208781414766327e-155
# look at the disk in the light on the table .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 7.657404561915943e-155
# look the cd by the light of the lamp
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 7.657404561915943e-155
# look the cd by the light of the lamp
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# - Decoding by Sampling:
# BLEU score: 1.4256605770826504e-231
# look at the disk in the light .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_055221_984342_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-SoapBar-None-Cabinet-402/trial_T20190908_055221_984342
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a clean bar of soap under the sink.
# ['Turn to the garbage can, on the floor to your right.', 'Pull out the bar of soap inside the garbage can. ', 'Move to your right, away from the sink, then go across the room to the last sink on your left.', 'Place the bar of soap in the sink, turn the water on, rinse the soap off, turn the water off, and remove the bar of soap from the sink. ', 'Step back from the sink. ', 'Place the bar of soap in the right cabinet, under the sink. ']
#
# Annotation 1
# wash the pink bar, put the pink bar in the cabinet
# ['turn right, walk to the trash bin', 'grab the pink bar from the trash bin', 'turn right, walk to the sink', 'put the pink bar in the sink, wash the bar, take it out', 'turn around, turn around to the cabinet under the sink', 'open the right door, put the pink bar in']
#
# Annotation 2
# drop a wet soap in the cupboard under the sink
# ['turn right and head for the bin', 'pick up the soap from the bin', 'head right towards the sink', 'wet the soap in the sink', 'move below the sink to the cupboard', 'drop the soap in the cupboard below the sink']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.150052191025993e-78
# put a cleaned bar of soap in the cabinet
# - Decoding by Sampling:
# BLEU score: 7.150052191025993e-78
# put a cleaned bar of soap in the cabinet
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5418220425805959
# put a clean bar of soap in a cabinet .
# - Decoding by Sampling:
# BLEU score: 0.30374414220764573
# put a clean bar soap in a the left cabinet
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.5046529460506622e-78
# put wet soap in a cabinet .
# - Decoding by Sampling:
# BLEU score: 4.0636244822144107e-78
# put wet soap from the cabinet , wash it sink , put it back under the sink
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.5046529460506622e-78
# put wet soap in a cabinet .
# - Decoding by Sampling:
# BLEU score: 6.012453256310808e-78
# put wet soap in a cabinet under the sink
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 5.178803470057466e-155
# put wet wet bar in a cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 6.669660327594168e-155
# put the soap and put in a under sink
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 7.63175672830452e-155
# put the soap bar put it into the cabinet
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 5.1555516875869265e-155
# put the soap in a cabinet
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 7.137938557144741e-78
# put a wet bar of soap inside the sink . the cabinet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 7.63175672830452e-155
# put the soap bar put it into the cabinet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# - Decoding by Sampling:
# BLEU score: 4.142116741145382e-155
# put wet soap into a cabinet
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_023218_500741_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_with_movable_recep-Pen-Mug-Desk-309/trial_T20190909_023218_500741
# Number of subgoals : 8
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PutObject', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a mug with a pen in it on the shelf.
# ['Go to the shelf to your left with the plant on it.', 'Pick up the pen from the shelf.', 'Turn around and move forward to cross the room, then turn right at the end of the bed and go to the nightstand ahead.', 'Put the pen in the mug on the nightstand.', 'Pick up the mug from the nightstand.', 'Turn around and move forward to the end of the bed, then turn left and return to the shelf ahead.', 'Put the mug on the shelf in front of you.']
#
# Annotation 1
# place a cup with a pencil in it on top of the cabinet
# ['turn left and walk to the end of the room', 'grab a pencil off of the cabinet there', 'turn around and walk past the foot of the bed on your right, then turn right and walk over to the night stand on the left side of the bed', 'place the pencil inside a cup on the nightstand', 'pick up the cup with the pencil in it off of the nightstand', 'turn around and walk past the bed on your left, then take a left and walk to the end of the room where the cabinet is', 'place the cup on top of the cabinet']
#
# Annotation 2
# Put a mug with a pen in it on a white dresser.
# ['Turn around and take a step forward, then turn right and walk over to the white dresser.', 'Pick up the black pen off of the white dresser.', 'Turn around and begin walking across the room, then turn right and walk up to the small wooden table.', 'Put the pen in the white mug on the small wooden table.', 'Pick up the white mug with the pen in it off of the wooden table.', 'Turn around and begin walking across the room, then hang a left and walk up to the white dresser.', 'Put the mug with the pen in it on the dresser in front of the laptop.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7316843921203164
# put a mug with a pencil in it on the desk .
# - Decoding by Sampling:
# BLEU score: 4.0179464750439964e-78
# put a cup and to it on the table .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.7604321823471476
# put a mug with a pen in it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.4775586214302964
# put a mug with a pen in it on the counter . a left . the fridge . fridge .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 0.23397625978961173
# move a pen and mug to a pencil in it . the counter .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 4.648174375417067e-78
# move a pen and a mug and place it on the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 0.22758576422172913
# move a mug with a on the counter counter
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 6.336877893084566e-155
# move a pen and mug to a table to a counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 6.336877893084566e-155
# move a pen and mug to a table to a counter .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 7.855726910762709e-155
# move a mug in a mug and put the mug on the counter oven
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 7.107615103904954e-232
# move a with pencil to the .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 4.909777631374571e-155
# move a pen and mug to a counter .
# - Decoding by Sampling:
# BLEU score: 4.56643251085054e-78
# move a pen and mug with place it on the counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_201550_622420_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-Laptop-None-DeskLamp-328/trial_T20190908_201550_622420
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'CloseObject', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookDown_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Pick up a laptop and turn on a lamp
# ['Turn right and go to the desk', 'Close the laptop and pick it up from the desk', 'Turn left and go to the lamp on the desk', 'Turn on the lamp']
#
# Annotation 1
# Pick up the laptop and turn on the lamp
# ['Turn around and go to the table with a laptop', 'Close the laptop and pick it up from the table', 'Go to the end of the table by the wall', 'Turn on the lamp that is on far left end of the table']
#
# Annotation 2
# pick up the lap top from the desk and turn on the lamp
# ['Look down and turn right towards the trash can  then turn right towards the desk ', 'close the lap top and pick it up from the desk ', 'go left then right towards the desk again ', 'turn on the lamp ']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.208781414766327e-155
# examine a laptop by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 5.931400068694656e-155
# examine at a laptop by the light of a desk lamp . . a desk .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.3201911827891037
# turn on a lamp while holding a laptop
# - Decoding by Sampling:
# BLEU score: 8.357461858335003e-155
# turn on lamp lamp on a laptop in
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.208781414766327e-155
# examine a laptop by the light of a desk lamp .
# - Decoding by Sampling:
# BLEU score: 7.512015949287511e-155
# examine a laptop on the desk .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 0.7598356856515925
# examine up a laptop and turn on a lamp .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 0.6786502681586727
# examine up a laptop and turn on a lamp . .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 0.3661926362999429
# examine up a laptop and turn it on the lamp . bowl on the
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 8.747213257062311e-155
# examine pick a laptop on the desk .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 0.7598356856515925
# examine up a laptop and turn on a lamp .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# examine a laptop under a lamp
# - Decoding by Sampling:
# BLEU score: 6.480360213743594e-155
# examine pick at a laptop under a lit .
# ---------------------------
# --------------------------------------------------------------------------------------

# %%
# WORST valid_unseen
worst_valid_unseen_res = examine_sampled_tasks(sampled_task_ids=ranked_valid_unseen_ids_worst_10, epoch_list=valid_unseen_epoch_list, split='valid_unseen')
# Out:
# SPLIT: valid_unseen
#
#
#
# TASK : trial_T20190909_021728_339782_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-SaltShaker-None-Drawer-10/trial_T20190909_021728_339782
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# move salt shaker from counter to drawer
# ['turn around, walk to the window, turn left, walk forward, turn left to face counter', 'pick up the salt shaker that is on the counter', 'turn right, take a step, turn left, walk forward two steps', 'open the drawer on the right, put salt shaker in, shut it']
#
# Annotation 1
# Move a salt shaker to a drawer.
# ['Turn to the right then walk forward, Make a left and face the table.', 'Pick up the salt shaker from the kitchen island.', 'Move left then right  around the kitchen island.', 'Open the drawer next to the dishwasher and put away the salt shaker.']
#
# Annotation 2
# Put a salt shaker into a kitchen drawer.
# ['Turn around and go to the windows, then go between the windows and the kitchen island and turn left to face the end of the island.', 'Pick up the salt shaker from the island.', 'Turn toward your right, then go to the drawers to the left of the stove.', 'Put the salt shaker in the second drawer from the top.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.508645449069235e-78
# put a salt shakers in a drawer .
# - Decoding by Sampling:
# BLEU score: 4.797597231912944e-78
# put a salt shakers in in the drawer
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.2778269941762074e-231
# put the salt shakers in the drawer
# - Decoding by Sampling:
# BLEU score: 5.047284757449962e-78
# put the salt shaker from the counter to the drawer
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.657404561915943e-155
# move the salt from the counter to the cabinet
# - Decoding by Sampling:
# BLEU score: 6.887578243315168e-155
# move the salt to from the counter to the cabinet counter
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.657404561915943e-155
# move the salt from the counter to the cabinet
# - Decoding by Sampling:
# BLEU score: 1.384292958842266e-231
# move the two drawers from to the sink . the right .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.686350417856737e-232
# pick up the food .
# - Decoding by Sampling:
# BLEU score: 1.1409851298103347e-231
# pick up the from from the sink , put in in the cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.686350417856737e-232
# pick up the food .
# - Decoding by Sampling:
# BLEU score: 1.2778269941762074e-231
# pick the salt to the cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.686350417856737e-232
# pick up the food .
# - Decoding by Sampling:
# BLEU score: 0.24808415001701817
# pick put a salt shaker in in the cabinet cabinet .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.686350417856737e-232
# pick up the food .
# - Decoding by Sampling:
# BLEU score: 1.1484186507842885e-231
# pick up the food . put it yellow silver , the counter , the put in in the cabinet
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.686350417856737e-232
# pick up the food .
# - Decoding by Sampling:
# BLEU score: 1.1409851298103347e-231
# pick up the food from the sink , put it in the cabinet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1008876702055895e-231
# pick up the food ' s from the sink , put it in the cabinet
# - Decoding by Sampling:
# BLEU score: 1.1200407237786664e-231
# pick up the food from the sink , put it in the cabinet cabinet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1008876702055895e-231
# pick up the food ' s from the sink , put it in the cabinet
# - Decoding by Sampling:
# BLEU score: 7.951455490316087e-232
# pick the the counter .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_103507_522012_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-KeyChain-None-FloorLamp-219/trial_T20190909_103507_522012
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Examine a key chain by the light of a floor lamp.
# ['Walk forward to the safe, then turn left and walk to the blue armchair.', 'Pick up the key chain in front of the remote control on the armchair.', 'Turn right and walk slightly forward to the tall lamp in front of you.', 'Turn on the lamp.']
#
# Annotation 1
# Look at keys using an illuminated lamp.
# ['Cross the room and when you get to the sofa, head left to stand in front of the blue chair.', 'Pick up the leftmost set of keys from the chair.', 'Turn right to carry the keys closer to the lamp, which is between the chair and sofa.', 'Turn on the lamp to look at the keys.']
#
# Annotation 2
# Look at some keys under the light of a tall lamp.
# ['Turn around and hang a left to walk to the blue armchair.', 'Pick up the leftmost keys from the blue armchair.', 'Turn to face the tall lamp on the right.', 'Turn on the tall lamp.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a remote of keys on the white table .
# - Decoding by Sampling:
# BLEU score: 1.501620878508543e-231
# put a remote with a a lamp on the of the dresser .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4875195904069663e-231
# pick up keys and turn the lamp on .
# - Decoding by Sampling:
# BLEU score: 0.21972813874997157
# pick the and the light of a lamp lamp . a coffee maker .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3483065280626046e-231
# move the keys from the chair to the nightstand .
# - Decoding by Sampling:
# BLEU score: 1.3483065280626046e-231
# move the keys to the the lamp in the corner
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.1852285898528657e-231
# turn the keys from the sofa sofa , turn on the lamp
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.3483065280626046e-231
# turn move keys in the room to the table .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.4488496539373276e-231
# turn on the lamp lamp the key in hand .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.3483065280626046e-231
# turn move keys in the chair to the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.258141043412406e-231
# turn on the lamp while holding keys keys
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 0.32466791547509893
# turn at the in the light of a lamp .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 3.9907658014438832e-78
# turn at the keys under the lamp of the lamp lamp .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1077199809555581e-231
# turn on the lamp while holding keys
# - Decoding by Sampling:
# BLEU score: 1.3483065280626046e-231
# turn on the lamp while the drawer while holding keys
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_073749_086690_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_heat_then_place_in_recep-AppleSliced-None-GarbageCan-10/trial_T20190908_073749_086690
# Number of subgoals : 13
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'SliceObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'HeatObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'SliceObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject', 'LookUp_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'OpenObject', 'PutObject', 'CloseObject', 'ToggleObjectOn', 'ToggleObjectOff', 'OpenObject', 'PickupObject', 'CloseObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put a slice of green apple in the trash can near the fridge.
# ['Walk 1 step to the left and turn around to face the counter top with a bread on top of it. ', 'Pick up the knife that is in front of the white cup.', 'Go slightly to the left to be in front of the white vase. ', 'Cut the green apple  which is next to the white vase. ', 'While holding the knife, walk to the left, turn left and turn left again to face the black trash can. ', 'Put the knife in the trash can.', 'Go back to the counter top with the green apple that you just cut. ', 'Pick up a slice of apple from on top of the counter top.', 'Walk to the right and turn left to go to the stove. Look up to the microwave. ', 'Open the microwave, put the slice of apple in, heat it for a few seconds, pick it up again and close the microwave', 'Go to the left, turn left near the fridge to go back to the trash can again. ', 'Put the slice of apple in the trash can. ']
#
# Annotation 1
# To heat a piece of an apple and place it in a black bin.
# ['Turn around and face the counter above the dishwasher. ', 'Pick up the knife to the left of the bread. ', 'Move to the counter with the toaster on it. ', 'Slice the green apple to the right of the white vase. ', 'Turn and walk to the sculpture on the counter, look down at the black bin. ', 'Place the knife inside of the black bin. ', 'Walk back over to the apple. ', 'Pick up a piece of green apple. ', 'Turn right and walk to the stove, look up at the microwave. ', 'Place the piece of apple inside of the microwave, heat it up, take the piece out of the microwave and close the door. ', 'Walk back over to the black bin on the floor. ', 'Place the piece of apple in the black bin. ']
#
# Annotation 2
# Put a piece of cooked apple in a bin.
# ['Turn left, go forward, turn left at the dishwasher.', 'Take the large knife to the let of the bread on the counter.', 'Turn left, go forward, turn right at the toaster on the counter.', 'Cut the apple to the right of the vase into pieces.', 'Turn left, go forward a step, turn left, go forward, turn left at the black bin.', 'Put the knife in the black bin.', 'Turn left, go forward to the fridge, turn right, go forward, turn left to the counter with the cut apple. Go to the counter.', 'Take a piece of apple from the counter.', 'Turn right, go forward, turn left at the oven.', 'Cook the apple in the microwave. Take the apple from the microwave.', 'Turn left, go forward, turn left at the fridge, go forward, turn left at the black bin.', 'Put the apple in the bin.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.476452820020735e-155
# put a warm piece of apple on the table .
# - Decoding by Sampling:
# BLEU score: 8.80154124704578e-155
# put a microwaved piece of apple on a on a trash in
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.0757394012695e-155
# put a cooked apple slice in the kitchen .
# - Decoding by Sampling:
# BLEU score: 6.417516874919776e-155
# put a of to to to the counter .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.5656618337072542e-231
# place a microwaved apple of apple on the white table .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.450830536844438e-231
# place a microwaved apple slice on the white table .
# - Decoding by Sampling:
# BLEU score: 6.669660327594168e-155
# place a microwaved apple slice in a table .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.052907923529733e-231
# place a microwaved apple on on the table
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.3861855791380656e-231
# place a microwaved of microwaved apple on the kitchen counter
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.42636209861806e-231
# place a microwaved apple slice on the table . left the bed . .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.052907923529733e-231
# place a microwaved apple on on the table
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 4.126725147240115e-78
# place a cooked of cooked apple on the counter .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.113314581389163e-231
# place a microwaved apple slice on the table
# - Decoding by Sampling:
# BLEU score: 1.318182749542327e-231
# place a microwaved apple slice on the kitchen .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_110445_675754_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-Knife-None-CounterTop-10/trial_T20190909_110445_675754
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Place a clean knife on a plate on the counter.
# ['Turn left and move to the gray coffee maker to the right of the lettuce, then move to the silver dishwasher to the right of the black toaster.', 'Pick up the yellow handled knife to the left of the square plate from the counter.', 'Turn around and move to the sink to the right of the loaf of bread.', 'Place the knife in the sink to the left of the lettuce, turn on the faucet to rinse the knife, then pick up the knife from the sink.', 'Turn around and face the dishwasher underneath the green glass.', 'Place the knife on the plate to the rear of the potato on the counter.']
#
# Annotation 1
# Rinse a knife and put it on a plate.
# ['Turn around and move through the room. Turn left and then face the counter on the right, where the dishwasher is.', 'Pick up the knife from the counter.', 'Hold the knife and turn around to the sink.', 'Place the knife in the sink and turn the water on. Turn the water off and pick up the knife.', 'Carry the knife and turn around to the counter.', 'Place the knife on the plate, that is on the counter.']
#
# Annotation 2
# clean a knife and put it back onto the counter
# ['turn left walk straight then turn left and walk towards the coffee machine and turn left and walk straight towards the dishwasher and turn right', 'pick up the knife on the counter top', 'turn right walk straight then turn right towards the sink', 'put the knife inside the sink and fill it with water then drain the water and remove the knife', 'turn right then walk straight then turn right again towards the counter', 'put the knife down on the counter top']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2936697784628213
# put a clean fork on the counter .
# - Decoding by Sampling:
# BLEU score: 5.287667392736108e-155
# put a clean to by the sink . the sink . the a fork . . the sink . the
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.63175672830452e-155
# put a clean fork in the kitchen counter .
# - Decoding by Sampling:
# BLEU score: 5.60411810495621e-155
# put a clean fork in the kitchen .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.8719283242189536e-78
# place a clean slice of potato in the kitchen sink .
# - Decoding by Sampling:
# BLEU score: 3.603235312613151e-78
# place a clean slice of potato tomato in the bin bin .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.486509539245492e-78
# place a clean fork in the kitchen .
# - Decoding by Sampling:
# BLEU score: 3.486509539245492e-78
# place a clean fork in the sink .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.670443885491954e-78
# place a clean fork in the recycling bin .
# - Decoding by Sampling:
# BLEU score: 3.8584570699456806e-78
# place a cleaned fork in the counter .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.052907923529733e-231
# put a cleaned fork in the left .
# - Decoding by Sampling:
# BLEU score: 1.3109733799909448e-231
# put a cleaned slice of potato in the bin .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.670443885491954e-78
# place a clean fork in the recycling bin .
# - Decoding by Sampling:
# BLEU score: 3.4712915060210913e-78
# place a clean fork of potato in the recycling
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1911125736103481e-231
# put a cleaned fork in the left ready .
# - Decoding by Sampling:
# BLEU score: 1.4147351699132998e-231
# put a cleaned slice of potato in the kitchen bin .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.670443885491954e-78
# place a clean fork in the recycling bin .
# - Decoding by Sampling:
# BLEU score: 4.658566834617536e-155
# place a knife in the living
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1911125736103481e-231
# put a cleaned fork in the left ready .
# - Decoding by Sampling:
# BLEU score: 1.1911125736103481e-231
# put a cleaned slice fork in the left .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1911125736103481e-231
# put a cleaned fork in the left ready .
# - Decoding by Sampling:
# BLEU score: 1.1911125736103481e-231
# put a cleaned fork in the left . .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_011850_153676_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_two_obj_and_place-KeyChain-None-Safe-219/trial_T20190909_011850_153676
# Number of subgoals : 9
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject', 'LookUp_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put two sets of keys in the safe.
# ['Turn around and go to the right end of the cream colored couch across from you. ', 'Pick up the keys on the right cushion of the couch. ', 'Turn to your right and go to the safe across from you, on the floor. ', 'Place the keys in the safe on the floor. ', 'Turn around and go to the blue arm chair across from you. ', 'Pick up the keys on the seat of the chair. ', 'Turn around and go to the safe on the floor, across from you. ', 'Place the keys in the safe on the floor. ']
#
# Annotation 1
# Put two key-chains inside the safe or locker
# ['Turn around, go to the white sofa', 'Pick up the key-chain from the sofa', 'Turn around and go to the safe on the floor to the right of a cabinet with a small statue', 'Open the safe, place the key-chain inside it, and close it', 'Turn around, move across the room to the somewhat blue sofa.', 'Pick the key-chain from that sofa', 'Go back to the safe', 'Put the key-chain inside the safe and close it']
#
# Annotation 2
# Move two sets of keys into a small white safe.
# ['Turn left and walk towards the small black table in the corner of the room, then hang a left and walk over to the right side of the couch.', 'Pick up the set of keys off of the seat of the couch.', 'Walk over to the small white safe on your right.', 'Open the safe and put the keys inside, then close the safe', 'Walk over to the blue chair that is next to the couch behind you.', 'Pick up the set of keys off of the seat of the couch.', 'Turn around and walk over to the small white safe.', 'Open the safe and put the keys inside the safe, then close the safe.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 5.5034464391059774e-155
# put two candles in the sink
# - Decoding by Sampling:
# BLEU score: 6.419573613943772e-155
# put two candles in in the sink
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.551819280284158e-155
# put two candles in the left cabinet .
# - Decoding by Sampling:
# BLEU score: 7.551819280284158e-155
# put two candles in the left cabinet .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5298765308495281
# place two sets of keys in the sink
# - Decoding by Sampling:
# BLEU score: 7.49201355438059e-155
# place two sets into keys inside of the bathroom sink cabinet
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.5462757644646491
# place two sets of keys in the cabinet .
# - Decoding by Sampling:
# BLEU score: 7.57965434483665e-155
# place two sets inside of the bathroom into the cabinet
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 7.855726910762709e-155
# place two sets in the sink . the left of the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 4.1131816762341247e-78
# place two sets of in the sink
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 1.4488496539373276e-231
# place two study inside of bathroom side of the sink
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 1.0318643420027732e-231
# place two study of the cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 1.4637115948630222e-231
# place two study of the in of the bathroom into the cabinet
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom sink
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.1931009847695213e-231
# place two study inside of the bathroom cabinet
# - Decoding by Sampling:
# BLEU score: 0.5462757644646491
# place two sets of keys in the sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_203041_433487_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Mug-None-Desk-308/trial_T20190909_203041_433487
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'PickupObject', 'LookDown_15', 'LookDown_15', 'LookDown_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# take the mug from the desk shelf to put it on the desk.
# ['walk around to the desk and face the middle row of books', 'Pick up the white mug from the top shelf', 'walk the mug around to the side of the desk', 'set the mug on the desk']
#
# Annotation 1
# Move a mug from the shelf to the desk.
# ['Turn left, move to the bed, go to the desk left of the bed, face the books on the shelf above the desk.', 'Pick up the mug on the shelf. ', 'Turn around, move to the side of the desk closer to the bed, face the side of the desk.', 'Put the mug on the desk. ']
#
# Annotation 2
# Move a cup from the top shelf to the edge of the desk.
# ['Walk around the bed to the front of the computer desk on your left.', 'Pick up the coffee cup from the top shelf of the desk.', 'Walk to the side of the computer desk.', 'Place the cup on the edge of the desk.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.2513293635022765
# examine a pencil and put it on the coffee table
# - Decoding by Sampling:
# BLEU score: 7.836955625110686e-155
# examine a pencil in of a lamp put it it to the the to .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.975255010667348e-155
# put a mug on the coffee table .
# - Decoding by Sampling:
# BLEU score: 5.60411810495621e-155
# put put a cup and the coffee .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.40352786374639904
# pick up a mug and place it on the desk .
# - Decoding by Sampling:
# BLEU score: 4.661032518640916e-78
# pick a mug with a pen on the desk of .
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.57273414893938e-155
# pick up a mug and place it on a shelf .
# - Decoding by Sampling:
# BLEU score: 4.932250118548181e-155
# pick a mug with a coffee machine .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 3.480275084383042e-78
# pick up a white and cup a cup and place it on the counter .
# - Decoding by Sampling:
# BLEU score: 0.2936697784628213
# pick a mug cup on the desk .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 4.337579510280189e-78
# pick a cup and place a to place it on the .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 5.917948028803548e-155
# pick up a pencil and cup to a for is on the counter .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 8.190757052088229e-155
# pick a cup to and to the counter . the room .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 6.552765724042392e-155
# pick up a pencil and cup to to put .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 0.27447938256311044
# pick on the desk . well as move mug on place it on the counter of the desk .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3109733799909448e-231
# pick up a pencil and cup to a for .
# - Decoding by Sampling:
# BLEU score: 0.2224246939793677
# pick up a pencil and and place it cup on the desk .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190908_205246_776817_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Vase-None-Safe-219/trial_T20190908_205246_776817
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'PickupObject', 'RotateRight_90', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'RotateLeft_90', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Put the gold vase into the white safe
# ['Go forward to the table then turn left and walk straight until you reach the white shelves in front of you. Face the shelf on your right.', 'Pick up the gold vase that is on the shelf', 'Turn in a circle and face the white safe on the floor next to the shelf.', 'Open the safe, place the vase inside the safe, and shut the safe']
#
# Annotation 1
# Place a gold bottle in a safe.
# ['Take a left at the black table ahead and walk to the white book case to the right of the couch.', 'Pick up the gold bottle on the shelf above the black statue on the book case.', 'Turn around, take a left at the couch and turn left to face the white safe next to the fireplace.', 'Put the gold bottle inside the safe and close the door.']
#
# Annotation 2
# Put the golden object from the shelf into the safe.
# ['Move forward, turn left at the end table, walk forward and turn right to face the white shelf.', 'Grab the golden object from the shelf.', 'Turn to the right to face the safe.', 'Place the golden object into the safe.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a tomato in a cabinet .
# - Decoding by Sampling:
# BLEU score: 6.227170448085464e-155
# put a tomato pairs in a in
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.501620878508543e-231
# put a plate with a tomato in it in the left cabinet .
# - Decoding by Sampling:
# BLEU score: 1.404215963202711e-231
# put move a tomato to the counter to to the sink maker . the the left .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4875195904069663e-231
# put a red and a pot into a cabinet
# - Decoding by Sampling:
# BLEU score: 1.1077199809555581e-231
# put a sauce pen inside a cabinet
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.4875195904069663e-231
# put a red and a red into a cabinet
# - Decoding by Sampling:
# BLEU score: 1.3519605352440902e-231
# put a red card inside the cabinet .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a red and a pot into a cabinet .
# - Decoding by Sampling:
# BLEU score: 3.7690910616910046e-155
# put the red , sink
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a sauce in a cabinet .
# - Decoding by Sampling:
# BLEU score: 1.384292958842266e-231
# put a sauce inside paper inside the cabinet cabinet
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a sauce in a cabinet .
# - Decoding by Sampling:
# BLEU score: 7.1958300848837144e-155
# put a sauce in a cabinet cabinet .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a sauce in a cabinet .
# - Decoding by Sampling:
# BLEU score: 7.1958300848837144e-155
# put a sauce in a cabinet cabinet .
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a sauce in a cabinet .
# - Decoding by Sampling:
# BLEU score: 5.931400068694656e-155
# put a sauce with a newspapers in a sink into in of sink . to .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.58443108435194e-155
# put a sauce in a cabinet .
# - Decoding by Sampling:
# BLEU score: 1.4875195904069663e-231
# put a red pot the cabinet to the cabinet
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.3519605352440902e-231
# put a yellow card inside a cabinet .
# - Decoding by Sampling:
# BLEU score: 1.501620878508543e-231
# put a sauce in the sink inside the sink to to sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190909_032721_511027_0
# ROOT: /root/data_alfred/json_feat_2.1.0/look_at_obj_in_light-RemoteControl-None-FloorLamp-219/trial_T20190909_032721_511027
# Number of subgoals : 5
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'ToggleObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'LookUp_15', 'LookUp_15', 'LookUp_15', 'ToggleObjectOn']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Hold a remote and turn on the lamp.
# ['Turn to the left and then right to the brown dresser.', 'Pick up the remote from the middle of the dresser, directly behind the tissues.', 'Hold the remote and move a step to the left.', 'Hold the remote and turn on the lamp.']
#
# Annotation 1
# Turn on the corner lamp.
# ['Turn to your left and go to the door, then turn right and go to the dresser against the wall. ', 'Pick up the remote behind the box of tissue, on the dresser. ', 'Turn to your left and go to the wall, then turn to the lamp to your right. ', 'Turn on the lamp in the corner. ']
#
# Annotation 2
# Look at a remote under a lit lamp.
# ['Hang a right to walk towards the dresser in the corner.', 'Pick on the remote that is on the dresser.', 'Turn to face the lamp on the right of the dresser.', 'Turn on the lamp next to the dresser.']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.190757052088229e-155
# put a bin with a remote in it on the table .
# - Decoding by Sampling:
# BLEU score: 6.311514251575017e-155
# put a above by the light of a lamp lamp . . .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.39938791763778786
# pick up the green and turn on the lamp
# - Decoding by Sampling:
# BLEU score: 1.1549495860711975e-231
# pick at the a .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.4180134288483488
# use the remote to turn on the lamp .
# - Decoding by Sampling:
# BLEU score: 1.331960397810445e-231
# use a bar container in the light
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 6.887578243315168e-155
# examine a bar in the light of a tall lamp .
# - Decoding by Sampling:
# BLEU score: 1.2882297539194154e-231
# examine the remote to on s the the shelf side of the room room . .
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 3.00466076572634e-78
# examine the remote to to the left side of , turn on the floor
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 6.8521466667561e-155
# examine look at the remote in the light .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 1.4740564900137075e-231
# examine a bar of a light .
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 2.841632707086713e-78
# examine the remote from the table , put it floor on on the corner bin
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 8.15394372921771e-155
# examine on a lamp with holding a remote
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 5.607773684948284e-78
# examine a remote card and turn on a lamp .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# examine a bar in a lamp light .
# - Decoding by Sampling:
# BLEU score: 0.31314224813827346
# examine the remote to the table side of the table and turn on the lamp .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074045_109439_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_clean_then_place_in_recep-SoapBar-None-CounterTop-424/trial_T20190907_074045_109439
# Number of subgoals : 7
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'CleanObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateLeft_90', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'LookDown_15', 'PickupObject', 'LookUp_15', 'RotateRight_90', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'RotateLeft_90', 'PutObject', 'ToggleObjectOn', 'ToggleObjectOff', 'PickupObject', 'RotateLeft_90', 'MoveAhead_25', 'RotateRight_90', 'PutObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Rinse off the soap and place it on the counter.
# ['Turn to the left to face the sinks.', 'Pick up the bar of soap from in between the sinks.', 'Take the soap and move a step to the right.', 'Place the soap in the sink and turn the water on. Turn it off and pick up the soap again.', 'Hold the soap and take a step to the left.', 'Place the soap on the counter in between the sinks.']
#
# Annotation 1
# Place wet soap on a counter
# ['Turn around and take a step then turn to your right and face the vanity', 'Pick up the bar of soap that is in between the sinks', 'Turn around and take a step, turn left and take a step, the turn left and face the right sink', 'Place the soap in the right sink then turn on the sink.  Turn off the sink and pick up the soap', 'Take a step to your left', 'Place the soap on the counter in between the two sinks to the right of the bottle of soap']
#
# Annotation 2
# Put the rinsed soap on the bathroom counter
# ['Turn left and face toward the bathroom counter between the sinks', 'Pick up the soap bar from the bathroom counter', 'Move slightly right then turn left to face the sink', 'Rinse the soap under water in the sink then remove it', 'Move slightly left then turn right to face the counter', 'Put the soap bar on the counter just right of the pump bottle']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a cleaned bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 4.9823743656555826e-155
# put the bars .
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 0.35930411196308415
# put a clean bar of soap on the counter .
# - Decoding by Sampling:
# BLEU score: 7.858812176232387e-78
# put a soap on the counter counter
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 6.5806869883189804e-155
# put the bar bar to soap , put it in the sink
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.4875195904069663e-231
# put a bar on top of the sink sink
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.2917956969975423e-231
# put a clean bar of washed in in the sink .
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.583976781977924e-231
# put a cushion in the sink .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.2967862918337585e-231
# put a opposite on inside phone
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 7.711523862191631e-155
# put a washed bar on the sink sink
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.3934875572055278e-231
# put a cushion the sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.4740564900137075e-231
# put a washed bar in the sink
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.5319719891192393e-231
# put a clean bar of soap in the sink .
# - Decoding by Sampling:
# BLEU score: 1.5319719891192393e-231
# put a rinsed bar of soap in a sink .
# ---------------------------
# --------------------------------------------------------------------------------------
#
#
#
#
#
# TASK : trial_T20190907_074524_006355_0
# ROOT: /root/data_alfred/json_feat_2.1.0/pick_and_place_simple-Watch-None-Safe-219/trial_T20190907_074524_006355
# Number of subgoals : 5
# https://youtu.be/_TobcwcYR9Q
# ---------------------------
# Gold Input high-level action description:
#
#  ['GotoLocation', 'PickupObject', 'GotoLocation', 'PutObject', 'NoOp']
# ---------------------------
# Gold Input low-level action description:
#
#  ['LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'RotateLeft_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookUp_15', 'PickupObject', 'LookDown_15', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'RotateRight_90', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'MoveAhead_25', 'LookDown_15', 'OpenObject', 'PutObject', 'CloseObject']
# ---------------------------
# Gold instruction descriptions:
#
# Annotation 0
# Move a watch to the inside of a small safe.
# ['Turn right and take a step forward, then turn left and walk up to the large wooden dresser.', 'Pick up the watch that is on top of the large wooden dresser.', 'Turn right and begin walking across the room, then hang a right and walk up to the small white safe on the ground.', 'Open the small white safe, place the watch inside, then close the safe door.']
#
# Annotation 1
# Take the watch on top of the chest of drawers  put it inside the safe and lock it up.
# ['Go to the chest of drawers ahead of you.', 'Pick up the brown banded watch.', 'Take the watch across the room toward the safe.', 'Open the safe, set the watch inside the safe, close the safe.']
#
# Annotation 2
# place a watch in a safe box
# ['turn right then turn left towards the  dresser', 'pick up the watch from the dresser', 'turn right and walk towards the sofa then turn right again towards the  safe box', 'place the watch in the safe box']
#
# ---------------------------
#
# Epoch 0 Prediction Output
# - Decoding by Argmax:
# BLEU score: 8.014508691042773e-155
# put a slice of potato in a drawer .
# - Decoding by Sampling:
# BLEU score: 6.237049021538533e-232
# put a slice of
#
# Epoch 5 Prediction Output
# - Decoding by Argmax:
# BLEU score: 9.53091075863908e-155
# place a slice of potato in a cabinet .
# - Decoding by Sampling:
# BLEU score: 6.9457064195067245e-155
# place a slice of potato in the cabinet of the sink . bin . window . put it in the cabinet table the . the left .
#
# Epoch 10 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.619863157690489e-231
# put a potato slice in the sink to
#
# Epoch 15 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.5319719891192393e-231
# put a bench potato in the cabinet tub
#
# Epoch 20 Prediction Output
# - Decoding by Argmax:
# BLEU score: 7.241926111174567e-155
# place a potato slice in the cabinet by the sink
# - Decoding by Sampling:
# BLEU score: 7.183445846156676e-155
# place a potato in the cabinet cabinet
#
# Epoch 25 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.451891777777915e-231
# put a potato in the cabinet .
#
# Epoch 30 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 6.164444051541174e-155
# put a potato slice in the microwave sink , put it potato in the cabinet of
#
# Epoch 35 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 3.795218485083911e-78
# put a potato slice the cabinet from the top of the sink to
#
# Epoch 40 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 6.538304094864068e-155
# put take the potato out of the red , place it in the cabinet to well sink .
#
# Epoch 45 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 1.451891777777915e-231
# put a potato in the cabinet .
#
# Epoch 49 Prediction Output
# - Decoding by Argmax:
# BLEU score: 1.6034157163765524e-231
# put a potato in the cabinet by the sink .
# - Decoding by Sampling:
# BLEU score: 7.065448889524842e-155
# put a bench potato of the top of of the cabinet in the cabinet to the right of
# ---------------------------
# --------------------------------------------------------------------------------------
